# %% [markdown]
# # Preparation

# %%
# import all libraries
import os
import glob
import pandas as pd
import numpy as np
import math
import scipy
import matplotlib.pyplot as plt
import matplotlib.pyplot as plt
import math
import xml.etree.ElementTree as ET

#make all folders
curfolder = os.getcwd()
print(curfolder)
flesh_folder = os.path.dirname(curfolder)
mtfolder = curfolder + '/MotionTracking_complex/OutputTimeseries/'
print(mtfolder)
processedfolder = curfolder + '/TS_processed/'
vidfolder = flesh_folder + '/Motion_Tracking_Folder/Output_Videos/'

# get all the files in the folder
mtfiles = glob.glob(mtfolder + '*.mp4_body_world.csv')
vidfiles = glob.glob(vidfolder + '*.mp4')

print(len(mtfiles))
# Out:
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/MotionTracking_complex/OutputTimeseries/
# 439

# %% [markdown]
# # Clean, flip, interpolate, smooth the data

# %%
# returns a cleaned file with visibility columns dropped and with fileID and participantID added
def clean_data(file):
    # reads file
    sample = pd.read_csv(file)
    sample
    fileID = os.path.basename(file)
# replace _body.csv with ''
    fileID = fileID.replace('_body_world.csv', '')

# add fileID column to the sample
    sample['fileID'] = fileID

# get the participant ID from the fileID:
    split_string = fileID.split('ch')[1]
    split_string = split_string.split('_g')
    chain_num = split_string[0]
    split_string_gen = split_string[1].split("_compr")
    gen_num = split_string_gen[0]
    participantID = "ch" + chain_num + "g" +gen_num
    sample['participantID'] = participantID

# in the sample, get rid of all columns that contain visibility
    visibility_columns = [col for col in sample.columns if 'visibility' in col]
    sample = sample.drop(visibility_columns, axis=1)
    return sample

# returns data with y values flipped. 
# code modified from Trujillo, J.P. & Pouw, W.T.J.L. (2021-11-18). Kinematic Feature Extraction for Motion Tracking Analysis. Retrieved from: https://github.com/WimPouw/EnvisionBootcamp2021/tree/main/Python/Analysis_kinematic_features
def flip_data(df):
    cols = df.columns
    cols  = [col for col in df.columns if 'Y_' in col]
    cols = list(cols)
        # first get the vertical height of the configuration
        # we only do this for the first frame; the transformation will be applied to all frames
    maxpoint = []
    for joint in cols:
        maxpoint.append(df.loc[0, joint])
        # iterate over each joint, in each frame, to flip the y-axis
    for frame in range(len(df)):
        for joint in cols:
            ytrans = max(maxpoint) - df.loc[frame, joint] - 1
            df.loc[frame, joint] = ytrans
    return df

# returns the file with all missing data interpolated 
def interpolate(sample):
    cols = sample.columns

# put away time and fileID from cols
    cols = cols.drop(['time', 'fileID', 'participantID'])

# loop over the cols and interpolate missing data
    for col in cols:
        sample[col] = sample[col].interpolate(method='linear', x = sample['time'], limit=10)
    return cols, sample

# returns the file with the data smoothed
def smooth_data(sample):
    cols_upperbody = ['X_NOSE', 'Y_NOSE', 'Z_NOSE', 'X_LEFT_EYE_INNER', 'Y_LEFT_EYE_INNER', 'Z_LEFT_EYE_INNER', 'X_LEFT_EYE', 'Y_LEFT_EYE', 'Z_LEFT_EYE', 'X_LEFT_EYE_OUTER', 'Y_LEFT_EYE_OUTER', 'Z_LEFT_EYE_OUTER', 'X_RIGHT_EYE_OUTER', 'Y_RIGHT_EYE_OUTER', 'Z_RIGHT_EYE_OUTER', 'X_RIGHT_EYE', 'Y_RIGHT_EYE', 'Z_RIGHT_EYE', 'X_RIGHT_EYE_OUTER.1', 'Y_RIGHT_EYE_OUTER.1', 'Z_RIGHT_EYE_OUTER.1', 'X_LEFT_EAR', 'Y_LEFT_EAR', 'Z_LEFT_EAR', 'X_RIGHT_EAR', 'Y_RIGHT_EAR', 'Z_RIGHT_EAR', 'X_MOUTH_LEFT', 'Y_MOUTH_LEFT', 'Z_MOUTH_LEFT', 'X_MOUTH_RIGHT', 'Y_MOUTH_RIGHT', 'Z_MOUTH_RIGHT', 'X_LEFT_SHOULDER', 'Y_LEFT_SHOULDER', 'Z_LEFT_SHOULDER', 'X_RIGHT_SHOULDER', 'Y_RIGHT_SHOULDER', 'Z_RIGHT_SHOULDER', 'X_LEFT_ELBOW', 'Y_LEFT_ELBOW', 'Z_LEFT_ELBOW', 'X_RIGHT_ELBOW', 'Y_RIGHT_ELBOW', 'Z_RIGHT_ELBOW', 'X_LEFT_WRIST', 'Y_LEFT_WRIST', 'Z_LEFT_WRIST', 'X_RIGHT_WRIST', 'Y_RIGHT_WRIST', 'Z_RIGHT_WRIST', 'X_LEFT_PINKY', 'Y_LEFT_PINKY', 'Z_LEFT_PINKY', 'X_RIGHT_PINKY', 'Y_RIGHT_PINKY', 'Z_RIGHT_PINKY', 'X_LEFT_INDEX', 'Y_LEFT_INDEX', 'Z_LEFT_INDEX', 'X_RIGHT_INDEX', 'Y_RIGHT_INDEX', 'Z_RIGHT_INDEX', 'X_LEFT_THUMB', 'Y_LEFT_THUMB', 'Z_LEFT_THUMB', 'X_RIGHT_THUMB', 'Y_RIGHT_THUMB']
    cols_lowerbody = ['X_LEFT_HIP',
       'Y_LEFT_HIP', 'Z_LEFT_HIP', 'X_RIGHT_HIP', 'Y_RIGHT_HIP', 'Z_RIGHT_HIP',
       'X_LEFT_KNEE', 'Y_LEFT_KNEE', 'Z_LEFT_KNEE', 'X_RIGHT_KNEE',
       'Y_RIGHT_KNEE', 'Z_RIGHT_KNEE', 'X_LEFT_ANKLE', 'Y_LEFT_ANKLE',
       'Z_LEFT_ANKLE', 'X_RIGHT_ANKLE', 'Y_RIGHT_ANKLE', 'Z_RIGHT_ANKLE',
       'X_LEFT_HEEL', 'Y_LEFT_HEEL', 'Z_LEFT_HEEL', 'X_RIGHT_HEEL',
       'Y_RIGHT_HEEL', 'Z_RIGHT_HEEL', 'X_LEFT_FOOT_INDEX',
       'Y_LEFT_FOOT_INDEX', 'Z_LEFT_FOOT_INDEX', 'X_RIGHT_FOOT_INDEX',
       'Y_RIGHT_FOOT_INDEX', 'Z_RIGHT_FOOT_INDEX']

# smooth upperbody and face with savgol 20,4
    for col in cols_upperbody:
        sample[col] = scipy.signal.savgol_filter(sample[col], 30, 1) 

# smooth lowerbod with savgol 30,3
    for col in cols_lowerbody:  
        sample[col] = scipy.signal.savgol_filter(sample[col], 30, 1) 
    return(sample)

# %% [markdown]
# # Obtain heights and normalize data

# %%
# returns the height of the body of the individual in the file  adds in a new mid shoulder point and mid ankle point to the file
def obtain_height_by_ankle2D(sample):
    #obtain left shoulder values
    x_left = sample['X_LEFT_SHOULDER'].iloc[0]
    y_left = sample['Y_LEFT_SHOULDER'].iloc[0]
    left_shoulder = (x_left, y_left)
    left_shoulder = np.array(left_shoulder)

   #obtain right shoulder values
    x_right = sample['X_RIGHT_SHOULDER'].iloc[0]
    y_right = sample['Y_RIGHT_SHOULDER'].iloc[0]
    right_shoulder = (x_right, y_right)
    right_shoulder = np.array(right_shoulder)

    #calculate the mid shoulder point
    new_shoulder_point = (left_shoulder + right_shoulder)/2 

    # obtain left ankle values
    x_left = sample['X_LEFT_ANKLE'].iloc[0]
    y_left = sample['Y_LEFT_ANKLE'].iloc[0]
    left_ankle = (x_left, y_left)
    left_ankle = np.array(left_ankle)

    # obtain right ankle values
    x_right = sample['X_RIGHT_ANKLE'].iloc[0]
    y_right = sample['Y_RIGHT_ANKLE'].iloc[0]
    right_ankle = (x_right, y_right)
    right_ankle = np.array(right_ankle)

    # calculate the mid ankle point 
    new_ankle_point = (left_ankle + right_ankle)/2

    sample['X_MID_ANKLE'] = new_ankle_point[0] ##FLAG: why is the same chunk of code below again?
    sample['Y_MID_ANKLE'] = new_ankle_point[1]

    # length of body for 2 dimensions (identical result as above)
    length_of_body = math.sqrt(((new_shoulder_point[0]-new_ankle_point[0])**2)+((new_shoulder_point[1]-new_ankle_point[1])**2))

    # adds the points to the sample sheet
    sample['X_MID_SHOULDER'] = new_shoulder_point[0]
    sample['Y_MID_SHOULDER'] = new_shoulder_point[1]

    return length_of_body

# returns the file with all values normalized by the height of the body
def normalize_by_body2D(sample, length_of_body):
    cols = sample.columns
    # put away time and fileID and participantID from cols
    cols = cols.drop(['time', 'fileID', 'participantID'])
    cols = [col for col in cols if 'Z_' not in col]
    # divide by the length of the body
    for col in cols: 
        sample[col] = sample[col] / length_of_body
    return(sample)

# %% [markdown]
# # 2D Animation

# %%
## plot all the keypoints in 2d space
## Code modified from Šárka Kadavá
import pandas as pd
import glob
import os
import matplotlib.pyplot as plt
from matplotlib.animation import FuncAnimation
import ffmpeg

import pandas as pd
import glob
import os
import matplotlib.pyplot as plt
from matplotlib.animation import FuncAnimation
import ffmpeg

def animation2D(sample):
    # Define the tracking data
    MT_tracking = sample

    # Create a figure and axis for 2D plotting (keeping the original size)
    fig = plt.figure(figsize=(10, 6))
    ax = fig.add_subplot(111)

    # Define the number of frames (assuming sample is a DataFrame with multiple rows)
    num_frames = len(MT_tracking)

    # Define the scatter plot (this will be updated in each frame)
    scatter = ax.scatter([], [], marker='o')

    # Update function for animation
    def update(frame):
        # Clear the axis for each frame (reset)
        ax.clear()

        # Set axis labels and title
        ax.set_xlabel('X Label')
        ax.set_ylabel('Y Label')
        ax.set_title('2D Animation')

        # Set the limits of the axes, keeping the original similar limits
        ax.set_xlim(-1.1, 1.1)  # Keeping similar range to original X limits
        ax.set_ylim(-0.8, 0.8)   # Keeping similar range to original Y limits

        # Get the data for the current frame
        frame_data = MT_tracking.iloc[frame]
        x = frame_data.filter(like='X_')
        y = frame_data.filter(like='Y_')

        # Create the scatter plot for the current frame
        scatter = ax.scatter(x, y, color='red')

        return scatter,

    # Create the animation
    ani = FuncAnimation(fig, update, frames=num_frames, interval=1000/60)

    # Save the animation as a video
    ani.save('2d_animation.mp4', writer='ffmpeg')

# %% [markdown]
# # Derive Speed and Smooth

# %%
# returns a file with derived smoothed speed (and changes from cm/frame/second to cm/second)
def derive_2dspeed_smooth(cols, sample, sr):
    speedcols = [col.replace('Y_', '') for col in cols] 
    speedcols = [col.replace('X_', '') for col in speedcols]
    speedcols = [col.replace('Z_', '') for col in speedcols]

# keep only unique values
    speedcols = list(set(speedcols))

    for col in speedcols:
        x = sample['X_' + col]
        y = sample['Y_' + col]

    # calculate speed
        sample[col + '_speed2D'] = np.insert(np.sqrt(np.diff(x) ** 2 + np.diff(y) ** 2), 0, 0)
        #switch to centimeters/second
        sample[col + '_speed2D'] = sample[col + '_speed2D']*sr
    #  smooth speed:
    for col in speedcols:
        sample[col + '_speed2D'] = scipy.signal.savgol_filter(sample[col + '_speed2D'], 20, 4)
    return(speedcols, sample)

# %% [markdown]
# # Derive vertical velocity and smooth

# %%
# returns the file with columns for vertical velocity for each key point
def derive_vertical_vel_smooth(sample):
    #Get a list of the columns that contain Y_
    verticalcols = [col for col in sample.columns if 'Y_' in col]
    verticalcols = [col for col in verticalcols if 'speed' not in col]

# calculate the velocity
    for col in verticalcols:
        sample[col + '_velocity'] = np.insert(np.diff(sample[col]), 0, 0)  
    vel_cols = [col for col in sample.columns if "_velocity" in col]
    for col in vel_cols:
        sample[col] = scipy.signal.savgol_filter(sample[col], 20, 4)
    return verticalcols, sample

# %% [markdown]
# # Derive Acceleration and Smooth

# %%
# returns the file with columns for acceleration for each key point
def derive_accel2D_smooth(speedcols, sample):
    # calculate acceleration as derivate of speed
    for col in speedcols:
        sample[col + '_acceleration2D'] = np.insert(np.diff(sample[col + "_speed2D"]), 0, 0) 
    accel_cols = [col for col in sample.columns if "_acceleration2D" in col]
    # smooth the acceleration columns
    for col in accel_cols:
        sample[col] = scipy.signal.savgol_filter(sample[col], 20, 4)
    return (sample)

# %% [markdown]
# # Derive Jerk and Smooth

# %%
# returns the file with columns for jerk derived from acceleration for each key point
def derive_jerk2D_smooth(speedcols, sample):
    # calcuates the jerk for each vertical column
    for col in speedcols:
        sample[col + '_jerk2D'] = np.insert(np.diff(sample[col + "_acceleration2D"]), 0, 0)
    # gets a list of all jerk columns
    jerk_cols = [col for col in sample.columns if "_jerk2D" in col]
    # smooths all jerk columns
    for col in jerk_cols:
        sample[col] = scipy.signal.savgol_filter(sample[col], 20, 4)
    return (sample)

# %% [markdown]
# # Final code to process every file in Output_TimeSeries

# %% [markdown]
# Clean every file

# %%
# This block contains code to go through every file and clean it

import os
import glob
import pandas as pd
import numpy as np
import warnings
warnings.filterwarnings("ignore")

#get the timeseries files
curfolder = os.getcwd()
print(curfolder)

flesh_folder = os.path.dirname(curfolder)
print(flesh_folder)

mtfolder = curfolder + '/MotionTracking_complex/OutputTimeseries/'
print(mtfolder)

cleanedfolder = curfolder + '/TS_cleaned'
if not os.path.exists(cleanedfolder):
    os.makedirs(cleanedfolder) 
processedfolder = curfolder + '/TS_processed/'
if not os.path.exists(processedfolder):
    os.makedirs(processedfolder)
vidfolder = flesh_folder + '/Motion_Tracking_Folder/Output_Videos/'

# get all the files in the folder
mtfiles = glob.glob(mtfolder + '*.mp4_body_world.csv')

vidfiles = glob.glob(vidfolder + '*.mp4')

# Loop through every file in the timeseries folder, clean it, and save it to a cleaned folder
for file in mtfiles:
    print(file)
    # clean, flip, interpolate, and smooth
    sample = clean_data(file)
    sample = flip_data(sample)
    cols, sample = interpolate(sample)
    sample = smooth_data(sample)
    # save it 
    fileID=sample['fileID'][0]
    globals()[fileID] = sample
    globals()[fileID].to_csv(os.path.join(cleanedfolder, f'{fileID}.csv'), index=False)
# Out:
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/MotionTracking_complex/OutputTimeseries/
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/MotionTracking_complex/OutputTimeseries/kalt_g_ch2_g20_compr.mp4_body_world.csv
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/MotionTracking_complex/OutputTimeseries/leise_g_ch2_g18_compr.mp4_body_world.csv
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/MotionTracking_complex/OutputTimeseries/langsam_g_ch2_g8_compr.mp4_body_world.csv
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/MotionTracking_complex/OutputTimeseries/kalt_g_ch2_g17_compr.mp4_body_world.csv
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/MotionTracking_complex/OutputTimeseries/lndw_lndw_rennen_g_ch1_g15_compr.mp4_body_world.csv
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/MotionTracking_complex/OutputTimeseries/lndw_lndw_rennen_g_ch2_g5_compr.mp4_body_world.csv
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/MotionTracking_complex/OutputTimeseries/stil_g_ch2_g3_compr.mp4_body_world.csv
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/MotionTracking_complex/OutputTimeseries/Donner_g_ch1_g14_compr.mp4_body_world.csv
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/MotionTracking_complex/OutputTimeseries/kalt_g_ch1_g9_compr.mp4_body_world.csv
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/MotionTracking_complex/OutputTimeseries/nijmegen_nijmegen_rennen_g_ch1_g15_compr.mp4_body_world.csv
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/MotionTracking_complex/OutputTimeseries/Donner_g_ch3_g16_compr.mp4_body_world.csv
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/MotionTracking_complex/OutputTimeseries/lndw_lndw_rennen_g_ch3_g17_compr.mp4_body_world.csv
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/MotionTracking_complex/OutputTimeseries/lndw_lndw_rennen_g_ch3_g20_compr.mp4_body_world.csv
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/MotionTracking_complex/OutputTimeseries/kalt_g_ch3_g2_compr.mp4_body_world.csv
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/MotionTracking_complex/OutputTimeseries/onweer_g_ch1_g16_compr.mp4_body_world.csv
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/MotionTracking_complex/OutputTimeseries/Donner_g_ch2_g1_compr.mp4_body_world.csv
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/MotionTracking_complex/OutputTimeseries/lndw_lndw_rennen_g_ch2_g1_compr.mp4_body_world.csv
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/MotionTracking_complex/OutputTimeseries/lndw_lndw_rennen_g_ch1_g11_compr.mp4_body_world.csv
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/MotionTracking_complex/OutputTimeseries/koud_g_ch1_g9_compr.mp4_body_world.csv
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/MotionTracking_complex/OutputTimeseries/kalt_g_ch2_g13_compr.mp4_body_world.csv
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/MotionTracking_complex/OutputTimeseries/Donner_g_ch1_g10_compr.mp4_body_world.csv
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/MotionTracking_complex/OutputTimeseries/stil_g_ch2_g7_compr.mp4_body_world.csv
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/MotionTracking_complex/OutputTimeseries/nijmegen_nijmegen_rennen_g_ch1_g11_compr.mp4_body_world.csv
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/MotionTracking_complex/OutputTimeseries/Donner_g_ch3_g12_compr.mp4_body_world.csv
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/MotionTracking_complex/OutputTimeseries/langsam_g_ch1_g18_compr.mp4_body_world.csv
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/MotionTracking_complex/OutputTimeseries/Donner_g_ch2_g5_compr.mp4_body_world.csv
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/MotionTracking_complex/OutputTimeseries/onweer_g_ch1_g12_compr.mp4_body_world.csv
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/MotionTracking_complex/OutputTimeseries/kalt_g_ch3_g6_compr.mp4_body_world.csv
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/MotionTracking_complex/OutputTimeseries/lndw_lndw_rennen_g_ch3_g13_compr.mp4_body_world.csv
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/MotionTracking_complex/OutputTimeseries/langzaam_g_ch2_g7_compr.mp4_body_world.csv
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/MotionTracking_complex/OutputTimeseries/langsam_g_ch3_g16_compr.mp4_body_world.csv
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/MotionTracking_complex/OutputTimeseries/langzaam_g_ch1_g16_compr.mp4_body_world.csv
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/MotionTracking_complex/OutputTimeseries/koud_g_ch1_g5_compr.mp4_body_world.csv
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/MotionTracking_complex/OutputTimeseries/nijmegen_nijmegen_rennen_g_ch2_g5_compr.mp4_body_world.csv
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/MotionTracking_complex/OutputTimeseries/onweer_g_ch2_g3_compr.mp4_body_world.csv
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/MotionTracking_complex/OutputTimeseries/leise_g_ch2_g10_compr.mp4_body_world.csv
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/MotionTracking_complex/OutputTimeseries/leise_g_ch2_g3_compr.mp4_body_world.csv
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/MotionTracking_complex/OutputTimeseries/Donner_g_ch2_g9_compr.mp4_body_world.csv
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/MotionTracking_complex/OutputTimeseries/kalt_g_ch1_g1_compr.mp4_body_world.csv
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/MotionTracking_complex/OutputTimeseries/stil_g_ch1_g16_compr.mp4_body_world.csv
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/MotionTracking_complex/OutputTimeseries/langsam_g_ch1_g14_compr.mp4_body_world.csv
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/MotionTracking_complex/OutputTimeseries/langzaam_g_ch1_g12_compr.mp4_body_world.csv
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/MotionTracking_complex/OutputTimeseries/Donner_g_ch1_g18_compr.mp4_body_world.csv
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/MotionTracking_complex/OutputTimeseries/langsam_g_ch3_g12_compr.mp4_body_world.csv
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/MotionTracking_complex/OutputTimeseries/langzaam_g_ch2_g3_compr.mp4_body_world.csv
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/MotionTracking_complex/OutputTimeseries/leise_g_ch2_g7_compr.mp4_body_world.csv
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/MotionTracking_complex/OutputTimeseries/leise_g_ch2_g14_compr.mp4_body_world.csv
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/MotionTracking_complex/OutputTimeseries/langsam_g_ch2_g4_compr.mp4_body_world.csv
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/MotionTracking_complex/OutputTimeseries/onweer_g_ch2_g7_compr.mp4_body_world.csv
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/MotionTracking_complex/OutputTimeseries/nijmegen_nijmegen_rennen_g_ch2_g1_compr.mp4_body_world.csv
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/MotionTracking_complex/OutputTimeseries/lndw_lndw_rennen_g_ch1_g19_compr.mp4_body_world.csv
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/MotionTracking_complex/OutputTimeseries/koud_g_ch1_g1_compr.mp4_body_world.csv
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/MotionTracking_complex/OutputTimeseries/lndw_lndw_rennen_g_ch2_g9_compr.mp4_body_world.csv
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/MotionTracking_complex/OutputTimeseries/langsam_g_ch1_g10_compr.mp4_body_world.csv
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/MotionTracking_complex/OutputTimeseries/stil_g_ch1_g12_compr.mp4_body_world.csv
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/MotionTracking_complex/OutputTimeseries/kalt_g_ch1_g5_compr.mp4_body_world.csv
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/MotionTracking_complex/OutputTimeseries/nijmegen_nijmegen_rennen_g_ch1_g19_compr.mp4_body_world.csv
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/MotionTracking_complex/OutputTimeseries/Donner_g_ch1_g7_compr.mp4_body_world.csv
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/MotionTracking_complex/OutputTimeseries/langsam_g_ch2_g14_compr.mp4_body_world.csv
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/MotionTracking_complex/OutputTimeseries/leise_g_ch3_g12_compr.mp4_body_world.csv
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/MotionTracking_complex/OutputTimeseries/koud_g_ch1_g12_compr.mp4_body_world.csv
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/MotionTracking_complex/OutputTimeseries/langzaam_g_ch1_g9_compr.mp4_body_world.csv
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/MotionTracking_complex/OutputTimeseries/lndw_lndw_rennen_g_ch3_g8_compr.mp4_body_world.csv
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/MotionTracking_complex/OutputTimeseries/leise_g_ch1_g10_compr.mp4_body_world.csv
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/MotionTracking_complex/OutputTimeseries/langsam_g_ch3_g5_compr.mp4_body_world.csv
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/MotionTracking_complex/OutputTimeseries/stil_g_ch1_g5_compr.mp4_body_world.csv
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/MotionTracking_complex/OutputTimeseries/leise_g_ch3_g6_compr.mp4_body_world.csv
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/MotionTracking_complex/OutputTimeseries/lndw_lndw_rennen_g_ch1_g3_compr.mp4_body_world.csv
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/MotionTracking_complex/OutputTimeseries/langsam_g_ch2_g10_compr.mp4_body_world.csv
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/MotionTracking_complex/OutputTimeseries/Donner_g_ch1_g3_compr.mp4_body_world.csv
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/MotionTracking_complex/OutputTimeseries/kalt_g_ch3_g19_compr.mp4_body_world.csv
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/MotionTracking_complex/OutputTimeseries/koud_g_ch1_g16_compr.mp4_body_world.csv
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/MotionTracking_complex/OutputTimeseries/Donner_g_ch3_g8_compr.mp4_body_world.csv
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/MotionTracking_complex/OutputTimeseries/leise_g_ch3_g16_compr.mp4_body_world.csv
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/MotionTracking_complex/OutputTimeseries/leise_g_ch3_g2_compr.mp4_body_world.csv
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/MotionTracking_complex/OutputTimeseries/stil_g_ch1_g1_compr.mp4_body_world.csv
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/MotionTracking_complex/OutputTimeseries/langsam_g_ch3_g1_compr.mp4_body_world.csv
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/MotionTracking_complex/OutputTimeseries/leise_g_ch1_g14_compr.mp4_body_world.csv
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/MotionTracking_complex/OutputTimeseries/lndw_lndw_rennen_g_ch2_g19_compr.mp4_body_world.csv
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/MotionTracking_complex/OutputTimeseries/Donner_g_ch2_g18_compr.mp4_body_world.csv
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/MotionTracking_complex/OutputTimeseries/leise_g_ch1_g9_compr.mp4_body_world.csv
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/MotionTracking_complex/OutputTimeseries/onweer_g_ch1_g9_compr.mp4_body_world.csv
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/MotionTracking_complex/OutputTimeseries/lndw_lndw_rennen_g_ch1_g7_compr.mp4_body_world.csv
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/MotionTracking_complex/OutputTimeseries/kalt_g_ch3_g15_compr.mp4_body_world.csv
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/MotionTracking_complex/OutputTimeseries/Donner_g_ch3_g4_compr.mp4_body_world.csv
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/MotionTracking_complex/OutputTimeseries/leise_g_ch1_g5_compr.mp4_body_world.csv
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/MotionTracking_complex/OutputTimeseries/Donner_g_ch2_g14_compr.mp4_body_world.csv
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/MotionTracking_complex/OutputTimeseries/onweer_g_ch1_g5_compr.mp4_body_world.csv
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/MotionTracking_complex/OutputTimeseries/nijmegen_nijmegen_rennen_g_ch1_g3_compr.mp4_body_world.csv
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/MotionTracking_complex/OutputTimeseries/langsam_g_ch1_g6_compr.mp4_body_world.csv
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/MotionTracking_complex/OutputTimeseries/koud_g_ch2_g3_compr.mp4_body_world.csv
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/MotionTracking_complex/OutputTimeseries/kalt_g_ch1_g17_compr.mp4_body_world.csv
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/MotionTracking_complex/OutputTimeseries/kalt_g_ch1_g20_compr.mp4_body_world.csv
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/MotionTracking_complex/OutputTimeseries/leise_g_ch1_g18_compr.mp4_body_world.csv
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/MotionTracking_complex/OutputTimeseries/langzaam_g_ch1_g1_compr.mp4_body_world.csv
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/MotionTracking_complex/OutputTimeseries/lndw_lndw_rennen_g_ch2_g15_compr.mp4_body_world.csv
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/MotionTracking_complex/OutputTimeseries/kalt_g_ch3_g11_compr.mp4_body_world.csv
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/MotionTracking_complex/OutputTimeseries/kalt_g_ch2_g3_compr.mp4_body_world.csv
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/MotionTracking_complex/OutputTimeseries/langsam_g_ch2_g18_compr.mp4_body_world.csv
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/MotionTracking_complex/OutputTimeseries/koud_g_ch2_g7_compr.mp4_body_world.csv
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/MotionTracking_complex/OutputTimeseries/langsam_g_ch1_g2_compr.mp4_body_world.csv
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/MotionTracking_complex/OutputTimeseries/nijmegen_nijmegen_rennen_g_ch1_g7_compr.mp4_body_world.csv
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/MotionTracking_complex/OutputTimeseries/onweer_g_ch1_g1_compr.mp4_body_world.csv
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/MotionTracking_complex/OutputTimeseries/Donner_g_ch2_g10_compr.mp4_body_world.csv
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/MotionTracking_complex/OutputTimeseries/leise_g_ch1_g1_compr.mp4_body_world.csv
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/MotionTracking_complex/OutputTimeseries/lndw_lndw_rennen_g_ch3_g4_compr.mp4_body_world.csv
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/MotionTracking_complex/OutputTimeseries/lndw_lndw_rennen_g_ch2_g11_compr.mp4_body_world.csv
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/MotionTracking_complex/OutputTimeseries/langzaam_g_ch1_g5_compr.mp4_body_world.csv
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/MotionTracking_complex/OutputTimeseries/langsam_g_ch3_g9_compr.mp4_body_world.csv
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/MotionTracking_complex/OutputTimeseries/stil_g_ch1_g9_compr.mp4_body_world.csv
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/MotionTracking_complex/OutputTimeseries/kalt_g_ch1_g13_compr.mp4_body_world.csv
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/MotionTracking_complex/OutputTimeseries/leise_g_ch1_g8_compr.mp4_body_world.csv
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/MotionTracking_complex/OutputTimeseries/Donner_g_ch2_g19_compr.mp4_body_world.csv
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/MotionTracking_complex/OutputTimeseries/onweer_g_ch1_g8_compr.mp4_body_world.csv
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/MotionTracking_complex/OutputTimeseries/lndw_lndw_rennen_g_ch1_g6_compr.mp4_body_world.csv
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/MotionTracking_complex/OutputTimeseries/leise_g_ch3_g3_compr.mp4_body_world.csv
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/MotionTracking_complex/OutputTimeseries/leise_g_ch1_g15_compr.mp4_body_world.csv
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/MotionTracking_complex/OutputTimeseries/lndw_lndw_rennen_g_ch2_g18_compr.mp4_body_world.csv
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/MotionTracking_complex/OutputTimeseries/koud_g_ch1_g20_compr.mp4_body_world.csv
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/MotionTracking_complex/OutputTimeseries/kalt_g_ch3_g18_compr.mp4_body_world.csv
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/MotionTracking_complex/OutputTimeseries/leise_g_ch3_g20_compr.mp4_body_world.csv
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/MotionTracking_complex/OutputTimeseries/koud_g_ch1_g17_compr.mp4_body_world.csv
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/MotionTracking_complex/OutputTimeseries/Donner_g_ch3_g9_compr.mp4_body_world.csv
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/MotionTracking_complex/OutputTimeseries/leise_g_ch3_g17_compr.mp4_body_world.csv
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/MotionTracking_complex/OutputTimeseries/langsam_g_ch2_g11_compr.mp4_body_world.csv
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/MotionTracking_complex/OutputTimeseries/Donner_g_ch1_g2_compr.mp4_body_world.csv
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/MotionTracking_complex/OutputTimeseries/lndw_lndw_rennen_g_ch1_g2_compr.mp4_body_world.csv
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/MotionTracking_complex/OutputTimeseries/langzaam_g_ch1_g8_compr.mp4_body_world.csv
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/MotionTracking_complex/OutputTimeseries/lndw_lndw_rennen_g_ch3_g9_compr.mp4_body_world.csv
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/MotionTracking_complex/OutputTimeseries/leise_g_ch1_g11_compr.mp4_body_world.csv
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/MotionTracking_complex/OutputTimeseries/langsam_g_ch3_g4_compr.mp4_body_world.csv
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/MotionTracking_complex/OutputTimeseries/stil_g_ch1_g4_compr.mp4_body_world.csv
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/MotionTracking_complex/OutputTimeseries/leise_g_ch3_g7_compr.mp4_body_world.csv
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/MotionTracking_complex/OutputTimeseries/leise_g_ch3_g13_compr.mp4_body_world.csv
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/MotionTracking_complex/OutputTimeseries/koud_g_ch1_g13_compr.mp4_body_world.csv
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/MotionTracking_complex/OutputTimeseries/Donner_g_ch1_g6_compr.mp4_body_world.csv
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/MotionTracking_complex/OutputTimeseries/langsam_g_ch2_g15_compr.mp4_body_world.csv
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/MotionTracking_complex/OutputTimeseries/lndw_lndw_rennen_g_ch3_g5_compr.mp4_body_world.csv
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/MotionTracking_complex/OutputTimeseries/lndw_lndw_rennen_g_ch2_g10_compr.mp4_body_world.csv
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/MotionTracking_complex/OutputTimeseries/langzaam_g_ch1_g4_compr.mp4_body_world.csv
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/MotionTracking_complex/OutputTimeseries/langsam_g_ch3_g8_compr.mp4_body_world.csv
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/MotionTracking_complex/OutputTimeseries/stil_g_ch1_g8_compr.mp4_body_world.csv
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/MotionTracking_complex/OutputTimeseries/kalt_g_ch1_g12_compr.mp4_body_world.csv
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/MotionTracking_complex/OutputTimeseries/koud_g_ch2_g6_compr.mp4_body_world.csv
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/MotionTracking_complex/OutputTimeseries/langsam_g_ch1_g3_compr.mp4_body_world.csv
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/MotionTracking_complex/OutputTimeseries/nijmegen_nijmegen_rennen_g_ch1_g6_compr.mp4_body_world.csv
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/MotionTracking_complex/OutputTimeseries/leise_g_ch1_g0_compr.mp4_body_world.csv
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/MotionTracking_complex/OutputTimeseries/Donner_g_ch2_g11_compr.mp4_body_world.csv
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/MotionTracking_complex/OutputTimeseries/langsam_g_ch2_g19_compr.mp4_body_world.csv
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/MotionTracking_complex/OutputTimeseries/Donner_g_ch3_g1_compr.mp4_body_world.csv
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/MotionTracking_complex/OutputTimeseries/kalt_g_ch3_g10_compr.mp4_body_world.csv
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/MotionTracking_complex/OutputTimeseries/kalt_g_ch2_g2_compr.mp4_body_world.csv
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/MotionTracking_complex/OutputTimeseries/kalt_g_ch1_g16_compr.mp4_body_world.csv
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/MotionTracking_complex/OutputTimeseries/leise_g_ch1_g19_compr.mp4_body_world.csv
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/MotionTracking_complex/OutputTimeseries/lndw_lndw_rennen_g_ch3_g1_compr.mp4_body_world.csv
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/MotionTracking_complex/OutputTimeseries/lndw_lndw_rennen_g_ch2_g14_compr.mp4_body_world.csv
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/MotionTracking_complex/OutputTimeseries/Donner_g_ch2_g15_compr.mp4_body_world.csv
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/MotionTracking_complex/OutputTimeseries/leise_g_ch1_g4_compr.mp4_body_world.csv
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/MotionTracking_complex/OutputTimeseries/onweer_g_ch1_g4_compr.mp4_body_world.csv
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/MotionTracking_complex/OutputTimeseries/nijmegen_nijmegen_rennen_g_ch1_g2_compr.mp4_body_world.csv
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/MotionTracking_complex/OutputTimeseries/langsam_g_ch1_g7_compr.mp4_body_world.csv
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/MotionTracking_complex/OutputTimeseries/koud_g_ch2_g2_compr.mp4_body_world.csv
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/MotionTracking_complex/OutputTimeseries/kalt_g_ch2_g6_compr.mp4_body_world.csv
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/MotionTracking_complex/OutputTimeseries/kalt_g_ch3_g14_compr.mp4_body_world.csv
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/MotionTracking_complex/OutputTimeseries/Donner_g_ch3_g5_compr.mp4_body_world.csv
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/MotionTracking_complex/OutputTimeseries/Donner_g_ch2_g4_compr.mp4_body_world.csv
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/MotionTracking_complex/OutputTimeseries/onweer_g_ch1_g13_compr.mp4_body_world.csv
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/MotionTracking_complex/OutputTimeseries/kalt_g_ch3_g7_compr.mp4_body_world.csv
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/MotionTracking_complex/OutputTimeseries/lndw_lndw_rennen_g_ch3_g12_compr.mp4_body_world.csv
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/MotionTracking_complex/OutputTimeseries/nijmegen_nijmegen_rennen_g_ch1_g10_compr.mp4_body_world.csv
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/MotionTracking_complex/OutputTimeseries/Donner_g_ch3_g13_compr.mp4_body_world.csv
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/MotionTracking_complex/OutputTimeseries/langsam_g_ch1_g19_compr.mp4_body_world.csv
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/MotionTracking_complex/OutputTimeseries/Donner_g_ch1_g11_compr.mp4_body_world.csv
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/MotionTracking_complex/OutputTimeseries/stil_g_ch2_g6_compr.mp4_body_world.csv
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/MotionTracking_complex/OutputTimeseries/lndw_lndw_rennen_g_ch1_g10_compr.mp4_body_world.csv
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/MotionTracking_complex/OutputTimeseries/koud_g_ch1_g8_compr.mp4_body_world.csv
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/MotionTracking_complex/OutputTimeseries/kalt_g_ch2_g12_compr.mp4_body_world.csv
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/MotionTracking_complex/OutputTimeseries/lndw_lndw_rennen_g_ch3_g16_compr.mp4_body_world.csv
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/MotionTracking_complex/OutputTimeseries/kalt_g_ch3_g3_compr.mp4_body_world.csv
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/MotionTracking_complex/OutputTimeseries/onweer_g_ch1_g17_compr.mp4_body_world.csv
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/MotionTracking_complex/OutputTimeseries/onweer_g_ch1_g20_compr.mp4_body_world.csv
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/MotionTracking_complex/OutputTimeseries/kalt_g_ch1_g8_compr.mp4_body_world.csv
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/MotionTracking_complex/OutputTimeseries/Donner_g_ch3_g20_compr.mp4_body_world.csv
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/MotionTracking_complex/OutputTimeseries/nijmegen_nijmegen_rennen_g_ch1_g14_compr.mp4_body_world.csv
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/MotionTracking_complex/OutputTimeseries/Donner_g_ch3_g17_compr.mp4_body_world.csv
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/MotionTracking_complex/OutputTimeseries/stil_g_ch2_g2_compr.mp4_body_world.csv
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/MotionTracking_complex/OutputTimeseries/Donner_g_ch1_g15_compr.mp4_body_world.csv
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/MotionTracking_complex/OutputTimeseries/leise_g_ch2_g19_compr.mp4_body_world.csv
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/MotionTracking_complex/OutputTimeseries/langsam_g_ch2_g9_compr.mp4_body_world.csv
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/MotionTracking_complex/OutputTimeseries/kalt_g_ch2_g16_compr.mp4_body_world.csv
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/MotionTracking_complex/OutputTimeseries/lndw_lndw_rennen_g_ch1_g14_compr.mp4_body_world.csv
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/MotionTracking_complex/OutputTimeseries/lndw_lndw_rennen_g_ch2_g4_compr.mp4_body_world.csv
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/MotionTracking_complex/OutputTimeseries/langsam_g_ch1_g11_compr.mp4_body_world.csv
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/MotionTracking_complex/OutputTimeseries/stil_g_ch1_g13_compr.mp4_body_world.csv
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/MotionTracking_complex/OutputTimeseries/kalt_g_ch1_g4_compr.mp4_body_world.csv
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/MotionTracking_complex/OutputTimeseries/nijmegen_nijmegen_rennen_g_ch1_g18_compr.mp4_body_world.csv
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/MotionTracking_complex/OutputTimeseries/leise_g_ch2_g6_compr.mp4_body_world.csv
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/MotionTracking_complex/OutputTimeseries/leise_g_ch2_g15_compr.mp4_body_world.csv
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/MotionTracking_complex/OutputTimeseries/langsam_g_ch2_g5_compr.mp4_body_world.csv
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/MotionTracking_complex/OutputTimeseries/onweer_g_ch2_g6_compr.mp4_body_world.csv
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/MotionTracking_complex/OutputTimeseries/lndw_lndw_rennen_g_ch1_g18_compr.mp4_body_world.csv
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/MotionTracking_complex/OutputTimeseries/lndw_lndw_rennen_g_ch2_g8_compr.mp4_body_world.csv
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/MotionTracking_complex/OutputTimeseries/langzaam_g_ch1_g13_compr.mp4_body_world.csv
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/MotionTracking_complex/OutputTimeseries/Donner_g_ch1_g19_compr.mp4_body_world.csv
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/MotionTracking_complex/OutputTimeseries/langsam_g_ch3_g13_compr.mp4_body_world.csv
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/MotionTracking_complex/OutputTimeseries/langzaam_g_ch2_g2_compr.mp4_body_world.csv
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/MotionTracking_complex/OutputTimeseries/stil_g_ch1_g20_compr.mp4_body_world.csv
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/MotionTracking_complex/OutputTimeseries/kalt_g_ch1_g0_compr.mp4_body_world.csv
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/MotionTracking_complex/OutputTimeseries/stil_g_ch1_g17_compr.mp4_body_world.csv
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/MotionTracking_complex/OutputTimeseries/langsam_g_ch1_g15_compr.mp4_body_world.csv
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/MotionTracking_complex/OutputTimeseries/Donner_g_ch2_g8_compr.mp4_body_world.csv
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/MotionTracking_complex/OutputTimeseries/koud_g_ch1_g4_compr.mp4_body_world.csv
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/MotionTracking_complex/OutputTimeseries/nijmegen_nijmegen_rennen_g_ch2_g4_compr.mp4_body_world.csv
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/MotionTracking_complex/OutputTimeseries/onweer_g_ch2_g2_compr.mp4_body_world.csv
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/MotionTracking_complex/OutputTimeseries/langsam_g_ch2_g1_compr.mp4_body_world.csv
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/MotionTracking_complex/OutputTimeseries/leise_g_ch2_g11_compr.mp4_body_world.csv
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/MotionTracking_complex/OutputTimeseries/leise_g_ch2_g2_compr.mp4_body_world.csv
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/MotionTracking_complex/OutputTimeseries/langzaam_g_ch2_g6_compr.mp4_body_world.csv
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/MotionTracking_complex/OutputTimeseries/langsam_g_ch3_g20_compr.mp4_body_world.csv
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/MotionTracking_complex/OutputTimeseries/langsam_g_ch3_g17_compr.mp4_body_world.csv
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/MotionTracking_complex/OutputTimeseries/langzaam_g_ch1_g17_compr.mp4_body_world.csv
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/MotionTracking_complex/OutputTimeseries/langzaam_g_ch1_g20_compr.mp4_body_world.csv
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/MotionTracking_complex/OutputTimeseries/kalt_g_ch2_g4_compr.mp4_body_world.csv
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/MotionTracking_complex/OutputTimeseries/kalt_g_ch3_g16_compr.mp4_body_world.csv
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/MotionTracking_complex/OutputTimeseries/koud_g_ch1_g19_compr.mp4_body_world.csv
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/MotionTracking_complex/OutputTimeseries/Donner_g_ch3_g7_compr.mp4_body_world.csv
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/MotionTracking_complex/OutputTimeseries/leise_g_ch3_g19_compr.mp4_body_world.csv
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/MotionTracking_complex/OutputTimeseries/kalt_g_ch1_g14_compr.mp4_body_world.csv
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/MotionTracking_complex/OutputTimeseries/langzaam_g_ch1_g2_compr.mp4_body_world.csv
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/MotionTracking_complex/OutputTimeseries/lndw_lndw_rennen_g_ch2_g16_compr.mp4_body_world.csv
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/MotionTracking_complex/OutputTimeseries/lndw_lndw_rennen_g_ch3_g3_compr.mp4_body_world.csv
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/MotionTracking_complex/OutputTimeseries/leise_g_ch1_g6_compr.mp4_body_world.csv
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/MotionTracking_complex/OutputTimeseries/Donner_g_ch2_g17_compr.mp4_body_world.csv
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/MotionTracking_complex/OutputTimeseries/onweer_g_ch1_g6_compr.mp4_body_world.csv
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/MotionTracking_complex/OutputTimeseries/langsam_g_ch1_g5_compr.mp4_body_world.csv
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/MotionTracking_complex/OutputTimeseries/Donner_g_ch2_g20_compr.mp4_body_world.csv
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/MotionTracking_complex/OutputTimeseries/lndw_lndw_rennen_g_ch1_g8_compr.mp4_body_world.csv
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/MotionTracking_complex/OutputTimeseries/Donner_g_ch1_g8_compr.mp4_body_world.csv
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/MotionTracking_complex/OutputTimeseries/Donner_g_ch3_g3_compr.mp4_body_world.csv
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/MotionTracking_complex/OutputTimeseries/kalt_g_ch3_g12_compr.mp4_body_world.csv
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/MotionTracking_complex/OutputTimeseries/lndw_lndw_rennen_g_ch2_g12_compr.mp4_body_world.csv
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/MotionTracking_complex/OutputTimeseries/lndw_lndw_rennen_g_ch3_g7_compr.mp4_body_world.csv
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/MotionTracking_complex/OutputTimeseries/langzaam_g_ch1_g6_compr.mp4_body_world.csv
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/MotionTracking_complex/OutputTimeseries/kalt_g_ch1_g10_compr.mp4_body_world.csv
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/MotionTracking_complex/OutputTimeseries/leise_g_ch3_g9_compr.mp4_body_world.csv
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/MotionTracking_complex/OutputTimeseries/koud_g_ch2_g4_compr.mp4_body_world.csv
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/MotionTracking_complex/OutputTimeseries/langsam_g_ch1_g1_compr.mp4_body_world.csv
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/MotionTracking_complex/OutputTimeseries/nijmegen_nijmegen_rennen_g_ch1_g4_compr.mp4_body_world.csv
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/MotionTracking_complex/OutputTimeseries/onweer_g_ch1_g2_compr.mp4_body_world.csv
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/MotionTracking_complex/OutputTimeseries/Donner_g_ch2_g13_compr.mp4_body_world.csv
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/MotionTracking_complex/OutputTimeseries/leise_g_ch1_g2_compr.mp4_body_world.csv
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/MotionTracking_complex/OutputTimeseries/leise_g_ch3_g11_compr.mp4_body_world.csv
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/MotionTracking_complex/OutputTimeseries/koud_g_ch1_g11_compr.mp4_body_world.csv
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/MotionTracking_complex/OutputTimeseries/Donner_g_ch1_g4_compr.mp4_body_world.csv
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/MotionTracking_complex/OutputTimeseries/langsam_g_ch2_g17_compr.mp4_body_world.csv
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/MotionTracking_complex/OutputTimeseries/langsam_g_ch2_g20_compr.mp4_body_world.csv
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/MotionTracking_complex/OutputTimeseries/lndw_lndw_rennen_g_ch1_g0_compr.mp4_body_world.csv
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/MotionTracking_complex/OutputTimeseries/nijmegen_nijmegen_rennen_g_ch1_g8_compr.mp4_body_world.csv
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/MotionTracking_complex/OutputTimeseries/leise_g_ch1_g13_compr.mp4_body_world.csv
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/MotionTracking_complex/OutputTimeseries/langsam_g_ch3_g6_compr.mp4_body_world.csv
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/MotionTracking_complex/OutputTimeseries/stil_g_ch1_g6_compr.mp4_body_world.csv
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/MotionTracking_complex/OutputTimeseries/leise_g_ch3_g5_compr.mp4_body_world.csv
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/MotionTracking_complex/OutputTimeseries/kalt_g_ch2_g8_compr.mp4_body_world.csv
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/MotionTracking_complex/OutputTimeseries/koud_g_ch1_g15_compr.mp4_body_world.csv
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/MotionTracking_complex/OutputTimeseries/leise_g_ch3_g15_compr.mp4_body_world.csv
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/MotionTracking_complex/OutputTimeseries/langsam_g_ch2_g13_compr.mp4_body_world.csv
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/MotionTracking_complex/OutputTimeseries/Donner_g_ch1_g0_compr.mp4_body_world.csv
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/MotionTracking_complex/OutputTimeseries/langsam_g_ch1_g9_compr.mp4_body_world.csv
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/MotionTracking_complex/OutputTimeseries/lndw_lndw_rennen_g_ch1_g4_compr.mp4_body_world.csv
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/MotionTracking_complex/OutputTimeseries/leise_g_ch3_g1_compr.mp4_body_world.csv
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/MotionTracking_complex/OutputTimeseries/kalt_g_ch1_g18_compr.mp4_body_world.csv
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/MotionTracking_complex/OutputTimeseries/leise_g_ch1_g20_compr.mp4_body_world.csv
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/MotionTracking_complex/OutputTimeseries/stil_g_ch1_g2_compr.mp4_body_world.csv
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/MotionTracking_complex/OutputTimeseries/langsam_g_ch3_g2_compr.mp4_body_world.csv
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/MotionTracking_complex/OutputTimeseries/leise_g_ch1_g17_compr.mp4_body_world.csv
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/MotionTracking_complex/OutputTimeseries/koud_g_ch1_g6_compr.mp4_body_world.csv
# ...
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/MotionTracking_complex/OutputTimeseries/stil_g_ch1_g14_compr.mp4_body_world.csv
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/MotionTracking_complex/OutputTimeseries/langsam_g_ch1_g16_compr.mp4_body_world.csv
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/MotionTracking_complex/OutputTimeseries/langzaam_g_ch2_g5_compr.mp4_body_world.csv
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/MotionTracking_complex/OutputTimeseries/langsam_g_ch3_g14_compr.mp4_body_world.csv
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/MotionTracking_complex/OutputTimeseries/langzaam_g_ch1_g14_compr.mp4_body_world.csv
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/MotionTracking_complex/OutputTimeseries/koud_g_ch1_g7_compr.mp4_body_world.csv
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/MotionTracking_complex/OutputTimeseries/nijmegen_nijmegen_rennen_g_ch2_g7_compr.mp4_body_world.csv
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/MotionTracking_complex/OutputTimeseries/onweer_g_ch2_g1_compr.mp4_body_world.csv
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/MotionTracking_complex/OutputTimeseries/langsam_g_ch2_g2_compr.mp4_body_world.csv
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/MotionTracking_complex/OutputTimeseries/leise_g_ch2_g12_compr.mp4_body_world.csv
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/MotionTracking_complex/OutputTimeseries/leise_g_ch2_g1_compr.mp4_body_world.csv
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/MotionTracking_complex/OutputTimeseries/Donner_g_ch3_g10_compr.mp4_body_world.csv
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/MotionTracking_complex/OutputTimeseries/nijmegen_nijmegen_rennen_g_ch1_g13_compr.mp4_body_world.csv
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/MotionTracking_complex/OutputTimeseries/stil_g_ch1_g18_compr.mp4_body_world.csv
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/MotionTracking_complex/OutputTimeseries/Donner_g_ch2_g7_compr.mp4_body_world.csv
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/MotionTracking_complex/OutputTimeseries/onweer_g_ch1_g10_compr.mp4_body_world.csv
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/MotionTracking_complex/OutputTimeseries/kalt_g_ch3_g4_compr.mp4_body_world.csv
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/MotionTracking_complex/OutputTimeseries/lndw_lndw_rennen_g_ch3_g11_compr.mp4_body_world.csv
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/MotionTracking_complex/OutputTimeseries/lndw_lndw_rennen_g_ch2_g3_compr.mp4_body_world.csv
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/MotionTracking_complex/OutputTimeseries/lndw_lndw_rennen_g_ch1_g13_compr.mp4_body_world.csv
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/MotionTracking_complex/OutputTimeseries/kalt_g_ch2_g11_compr.mp4_body_world.csv
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/MotionTracking_complex/OutputTimeseries/langsam_g_ch3_g18_compr.mp4_body_world.csv
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/MotionTracking_complex/OutputTimeseries/Donner_g_ch1_g12_compr.mp4_body_world.csv
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/MotionTracking_complex/OutputTimeseries/langzaam_g_ch1_g18_compr.mp4_body_world.csv
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/MotionTracking_complex/OutputTimeseries/stil_g_ch2_g5_compr.mp4_body_world.csv
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/MotionTracking_complex/OutputTimeseries/nijmegen_nijmegen_rennen_g_ch1_g20_compr.mp4_body_world.csv
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/MotionTracking_complex/OutputTimeseries/Donner_g_ch3_g14_compr.mp4_body_world.csv
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/MotionTracking_complex/OutputTimeseries/nijmegen_nijmegen_rennen_g_ch1_g17_compr.mp4_body_world.csv
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/MotionTracking_complex/OutputTimeseries/lndw_lndw_rennen_g_ch3_g15_compr.mp4_body_world.csv
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/MotionTracking_complex/OutputTimeseries/onweer_g_ch1_g14_compr.mp4_body_world.csv
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/MotionTracking_complex/OutputTimeseries/Donner_g_ch2_g3_compr.mp4_body_world.csv
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/MotionTracking_complex/OutputTimeseries/leise_g_ch2_g9_compr.mp4_body_world.csv
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/MotionTracking_complex/OutputTimeseries/kalt_g_ch2_g15_compr.mp4_body_world.csv
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/MotionTracking_complex/OutputTimeseries/lndw_lndw_rennen_g_ch1_g17_compr.mp4_body_world.csv
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/MotionTracking_complex/OutputTimeseries/lndw_lndw_rennen_g_ch1_g20_compr.mp4_body_world.csv
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/MotionTracking_complex/OutputTimeseries/lndw_lndw_rennen_g_ch2_g7_compr.mp4_body_world.csv
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/MotionTracking_complex/OutputTimeseries/stil_g_ch2_g1_compr.mp4_body_world.csv
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/MotionTracking_complex/OutputTimeseries/Donner_g_ch1_g16_compr.mp4_body_world.csv
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/MotionTracking_complex/OutputTimeseries/koud_g_ch2_g5_compr.mp4_body_world.csv
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/MotionTracking_complex/OutputTimeseries/langsam_g_ch1_g0_compr.mp4_body_world.csv
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/MotionTracking_complex/OutputTimeseries/nijmegen_nijmegen_rennen_g_ch1_g5_compr.mp4_body_world.csv
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/MotionTracking_complex/OutputTimeseries/onweer_g_ch1_g3_compr.mp4_body_world.csv
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/MotionTracking_complex/OutputTimeseries/leise_g_ch1_g3_compr.mp4_body_world.csv
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/MotionTracking_complex/OutputTimeseries/Donner_g_ch2_g12_compr.mp4_body_world.csv
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/MotionTracking_complex/OutputTimeseries/lndw_lndw_rennen_g_ch2_g13_compr.mp4_body_world.csv
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/MotionTracking_complex/OutputTimeseries/lndw_lndw_rennen_g_ch3_g6_compr.mp4_body_world.csv
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/MotionTracking_complex/OutputTimeseries/langzaam_g_ch1_g7_compr.mp4_body_world.csv
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/MotionTracking_complex/OutputTimeseries/leise_g_ch3_g8_compr.mp4_body_world.csv
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/MotionTracking_complex/OutputTimeseries/kalt_g_ch1_g11_compr.mp4_body_world.csv
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/MotionTracking_complex/OutputTimeseries/Donner_g_ch3_g2_compr.mp4_body_world.csv
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/MotionTracking_complex/OutputTimeseries/kalt_g_ch3_g13_compr.mp4_body_world.csv
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/MotionTracking_complex/OutputTimeseries/kalt_g_ch2_g1_compr.mp4_body_world.csv
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/MotionTracking_complex/OutputTimeseries/Donner_g_ch1_g9_compr.mp4_body_world.csv
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/MotionTracking_complex/OutputTimeseries/Donner_g_ch2_g16_compr.mp4_body_world.csv
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/MotionTracking_complex/OutputTimeseries/leise_g_ch1_g7_compr.mp4_body_world.csv
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/MotionTracking_complex/OutputTimeseries/onweer_g_ch1_g7_compr.mp4_body_world.csv
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/MotionTracking_complex/OutputTimeseries/nijmegen_nijmegen_rennen_g_ch1_g1_compr.mp4_body_world.csv
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/MotionTracking_complex/OutputTimeseries/langsam_g_ch1_g4_compr.mp4_body_world.csv
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/MotionTracking_complex/OutputTimeseries/koud_g_ch2_g1_compr.mp4_body_world.csv
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/MotionTracking_complex/OutputTimeseries/lndw_lndw_rennen_g_ch1_g9_compr.mp4_body_world.csv
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/MotionTracking_complex/OutputTimeseries/kalt_g_ch1_g15_compr.mp4_body_world.csv
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/MotionTracking_complex/OutputTimeseries/lndw_lndw_rennen_g_ch2_g20_compr.mp4_body_world.csv
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/MotionTracking_complex/OutputTimeseries/langzaam_g_ch1_g3_compr.mp4_body_world.csv
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/MotionTracking_complex/OutputTimeseries/lndw_lndw_rennen_g_ch2_g17_compr.mp4_body_world.csv
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/MotionTracking_complex/OutputTimeseries/lndw_lndw_rennen_g_ch3_g2_compr.mp4_body_world.csv
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/MotionTracking_complex/OutputTimeseries/kalt_g_ch2_g5_compr.mp4_body_world.csv
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/MotionTracking_complex/OutputTimeseries/kalt_g_ch3_g17_compr.mp4_body_world.csv
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/MotionTracking_complex/OutputTimeseries/koud_g_ch1_g18_compr.mp4_body_world.csv
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/MotionTracking_complex/OutputTimeseries/Donner_g_ch3_g6_compr.mp4_body_world.csv
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/MotionTracking_complex/OutputTimeseries/kalt_g_ch3_g20_compr.mp4_body_world.csv
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/MotionTracking_complex/OutputTimeseries/leise_g_ch3_g18_compr.mp4_body_world.csv
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/MotionTracking_complex/OutputTimeseries/kalt_g_ch1_g19_compr.mp4_body_world.csv
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/MotionTracking_complex/OutputTimeseries/stil_g_ch1_g3_compr.mp4_body_world.csv
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/MotionTracking_complex/OutputTimeseries/langsam_g_ch3_g3_compr.mp4_body_world.csv
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/MotionTracking_complex/OutputTimeseries/leise_g_ch1_g16_compr.mp4_body_world.csv
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/MotionTracking_complex/OutputTimeseries/langsam_g_ch1_g8_compr.mp4_body_world.csv
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/MotionTracking_complex/OutputTimeseries/lndw_lndw_rennen_g_ch1_g5_compr.mp4_body_world.csv
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/MotionTracking_complex/OutputTimeseries/langsam_g_ch2_g12_compr.mp4_body_world.csv
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/MotionTracking_complex/OutputTimeseries/Donner_g_ch1_g1_compr.mp4_body_world.csv
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/MotionTracking_complex/OutputTimeseries/kalt_g_ch2_g9_compr.mp4_body_world.csv
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/MotionTracking_complex/OutputTimeseries/koud_g_ch1_g14_compr.mp4_body_world.csv
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/MotionTracking_complex/OutputTimeseries/leise_g_ch3_g14_compr.mp4_body_world.csv
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/MotionTracking_complex/OutputTimeseries/leise_g_ch1_g12_compr.mp4_body_world.csv
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/MotionTracking_complex/OutputTimeseries/langsam_g_ch3_g7_compr.mp4_body_world.csv
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/MotionTracking_complex/OutputTimeseries/stil_g_ch1_g7_compr.mp4_body_world.csv
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/MotionTracking_complex/OutputTimeseries/leise_g_ch3_g4_compr.mp4_body_world.csv
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/MotionTracking_complex/OutputTimeseries/lndw_lndw_rennen_g_ch1_g1_compr.mp4_body_world.csv
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/MotionTracking_complex/OutputTimeseries/nijmegen_nijmegen_rennen_g_ch1_g9_compr.mp4_body_world.csv
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/MotionTracking_complex/OutputTimeseries/Donner_g_ch1_g5_compr.mp4_body_world.csv
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/MotionTracking_complex/OutputTimeseries/langsam_g_ch2_g16_compr.mp4_body_world.csv
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/MotionTracking_complex/OutputTimeseries/leise_g_ch3_g10_compr.mp4_body_world.csv
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/MotionTracking_complex/OutputTimeseries/koud_g_ch1_g10_compr.mp4_body_world.csv

# %% [markdown]
# Create a dictionary of heights

# %%
cleanedfolder = curfolder + '/TS_cleaned'

dict_of_heights = {} #create empty dictionary of heights
cleanedfiles = glob.glob(cleanedfolder + '/*.csv')
nijmegen_gestures  = ['koud', 'langzaam', 'nijmegen_nijmegen_rennen', 'onweer', 'stil']

# loop to obtain the height from every file and save it in a dictionary
# decides whether it is a nijmegen height or not ?
for file in cleanedfiles:
    sample = pd.read_csv(file)
    participantID = (sample['participantID'].iloc[0])
    fileID = sample['fileID'].iloc[0]
    if any(word in fileID for word in nijmegen_gestures):
        participantID = 'n' + str(participantID)
        sample['participantID'] = participantID
    # get the height from the function
    height = obtain_height_by_ankle2D(sample)
    if math.isnan(height):
        continue
    # add the height to the participant's place in the dictionary
    if participantID not in dict_of_heights:
        dict_of_heights[participantID] = [height]
    else:
        dict_of_heights[participantID].append(height)

print(dict_of_heights)
# Out:
# {'ch3g7': [1.1817539517143585, 1.1810205586998752, 1.1766557448840236, 1.1755796434210257, 1.1668459718721127], 'ch2g12': [1.2328508612940645, 1.217641919486383, 1.234156985138629, 1.2122712770348554, 1.2199013402013377], 'ch3g19': [1.1900595411408594, 1.188493444265342, 1.204396594474019, 1.2060080860690983, 1.1868485578230434], 'ch3g12': [1.2245111429495132, 1.2126310829989093, 1.2179445544385583, 1.2260928742699235, 1.2151264193508082], 'ch1g1': [1.211636870596574, 1.2180367370575311, 1.2134824438286862, 1.2118533396062767, 1.214200114468192], 'ch1g0': [1.166831083458129, 1.1581543372147323, 1.1138632246905986, 1.133831798111422, 1.1496814424146335], 'ch2g16': [1.2351919171469727, 1.22900523666073, 1.222938258858021, 1.218316156379457, 1.2401475718324395], 'nch1g13': [1.1556880130155054, 1.1803913178920011, 1.1583815698106072, 1.1626173003696783, 1.1643578928199319], 'ch1g8': [1.2128267257933933, 1.2106405728059353, 1.1870541187961272, 1.2051526746341052, 1.135103651976165], 'ch1g14': [1.1740195196850873, 1.1615776576150685, 1.15880139189105, 1.1797089654310025, 1.1601904779081778], 'nch1g16': [1.2348212425427902, 1.2352836864104664, 1.2129349771346216, 1.2223070430318936, 1.2438751710133582], 'ch2g6': [1.1816618917646355, 1.1775321915064922, 1.1879061621868092, 1.1881093142148857, 1.1857699888540985], 'ch2g7': [1.1813691618145614, 1.2067841822144294, 1.1735316789847148, 1.2152718742998683], 'nch1g15': [1.23825098914383, 1.2424090344322694, 1.2913628000588457, 1.2394008900078117, 1.2347235294956322], 'ch3g20': [1.209215476959728, 1.2167014493977064, 1.2182326217878916, 1.2229125054102425, 1.221700344639499], 'ch1g13': [1.22653583547178, 1.2117509553439216, 1.220898550189741, 1.2320816792429068, 1.2166909882188732], 'nch1g6': [1.177853930502823, 1.2033820401251032, 1.1714436876131233, 1.177112885920145, 1.2141874447953178], 'nch1g12': [1.216442493349591, 1.238825991327224, 1.2166861736646182, 1.2330513799583698, 1.207465043394151], 'nch2g4': [1.196058529897053, 1.1816649766090161, 1.1881741280944482, 1.1880296934972923, 1.1817513394753325], 'ch1g10': [1.1919122657005834, 1.2014155130381352, 1.1836024457318597, 1.2219671429191927, 1.2301654089974827], 'nch1g17': [1.180047679458242, 1.1732986919853639, 1.1822629571747545, 1.185826308036697, 1.1877619416181011], 'ch1g5': [1.2079407976940342, 1.202468551620508, 1.2089971293860917, 1.2119127337040971, 1.215274863260966], 'ch3g16': [1.2173123631978688, 1.2196030233223951, 1.2050455347195497, 1.2057371501433474, 1.2007310270150957], 'ch1g4': [1.1984821506226884, 1.2042115568552996, 1.2096097792662097, 1.1892043923405804, 1.1846883933487369], 'ch3g3': [1.2397756039702998, 1.2430444385492054, 1.2464607128392848, 1.2449237951630558, 1.2405683610487357], 'nch1g2': [1.2156136718765773, 1.2149122227294926, 1.2010695113164336, 1.2129100791011758, 1.2142796391956183], 'ch1g17': [1.1945120641135551, 1.203854445093966, 1.2021506402740225, 1.1701566509720873, 1.2047120259579593], 'nch1g11': [1.1778879217421045, 1.1833792856662038, 1.204217452571199, 1.229842775082305, 1.2396125810502552], 'ch2g2': [1.2555866995512333, 1.2338916871430103, 1.2399686262310676, 1.2471028591599203, 1.2608470841681467], 'ch2g3': [1.226737043254831, 1.2263762809976135, 1.2255777117390796, 1.2347189667034035, 1.2181606877656899], 'ch2g9': [1.1967532146192248, 1.1947383157199813, 1.1909255293300085, 1.1978546798737337, 1.193402823152396], 'ch3g15': [1.2103232967117752, 1.1920307678613677, 1.1938729248862232, 1.1944678857935982, 1.1924693849827301], 'ch3g5': [1.1362068882587701, 1.159442633748383, 1.1604642003415595, 1.1593976362714111, 1.1504454389246788], 'ch2g11': [1.2614767624862984, 1.2048376133371637, 1.1937902324719953, 1.2054052076946686, 1.203451561424858], 'ch1g18': [1.2600520206185668, 1.252816683680315, 1.254419177404846, 1.2561170521009393, 1.256299216314068], 'ch3g11': [1.2285517222518243, 1.2526273811111446, 1.2229384659009688, 1.2399576265046932, 1.23756386739391], 'ch3g1': [1.2240525275951295, 1.230227 ...

# %% [markdown]
# Create a dictionary of average heights

# %%
# create empty dictionaries for the average heights
dict_of_means = {}
dict_of_sd = {}

# get the mean height for each participants and use this as the height
for key in dict_of_heights: 
    values = np.array(dict_of_heights[key])
    mean = np.mean(values)
    sd = np.std(values)
    dict_of_means[key] = mean
    dict_of_sd[key]= sd

print(dict_of_means)
# Out:
# {'ch3g7': np.float64(1.176371174118279), 'ch2g12': np.float64(1.2233644766310539), 'ch3g19': np.float64(1.1951612447544724), 'ch3g12': np.float64(1.2192612148015425), 'ch1g1': np.float64(1.213841901111452), 'ch1g0': np.float64(1.144472377177903), 'ch2g16': np.float64(1.229119828175524), 'nch1g13': np.float64(1.1642872187815447), 'ch1g8': np.float64(1.1901555488011453), 'ch1g14': np.float64(1.1668596025060771), 'nch1g16': np.float64(1.229844424026626), 'ch2g6': np.float64(1.1841959097053842), 'ch2g7': np.float64(1.1942392243283935), 'nch1g15': np.float64(1.2492294486276778), 'ch3g20': np.float64(1.2177524796390133), 'ch1g13': np.float64(1.2215916016934447), 'nch1g6': np.float64(1.1887959977913023), 'nch1g12': np.float64(1.2224942163387909), 'nch2g4': np.float64(1.1871357335146284), 'ch1g10': np.float64(1.2058125552774506), 'nch1g17': np.float64(1.1818395156546315), 'ch1g5': np.float64(1.2093188151331393), 'ch3g16': np.float64(1.2096858196796514), 'ch1g4': np.float64(1.197239254486703), 'ch3g3': np.float64(1.2429545823141164), 'nch1g2': np.float64(1.2117570248438596), 'ch1g17': np.float64(1.195077165282318), 'nch1g11': np.float64(1.2069880032224136), 'ch2g2': np.float64(1.2474793912506759), 'ch2g3': np.float64(1.2263141380921234), 'ch2g9': np.float64(1.194734912539069), 'ch3g15': np.float64(1.196632852047139), 'ch3g5': np.float64(1.1531913595089605), 'ch2g11': np.float64(1.2137922754829966), 'ch1g18': np.float64(1.255940830023747), 'ch3g11': np.float64(1.2363278126325081), 'ch3g1': np.float64(1.223872692890371), 'ch2g15': np.float64(1.2131451163451483), 'ch2g20': np.float64(1.2430088005352182), 'ch3g4': np.float64(1.2055177046670864), 'ch2g19': np.float64(1.2204388316292356), 'ch2g8': np.float64(1.207155763425624), 'ch3g6': np.float64(1.2262660817320015), 'nch1g5': np.float64(1.1776581523546295), 'ch1g9': np.float64(1.2078131415231745), 'nch2g3': np.float64(1.1717660480264283), 'nch1g1': np.float64(1.1498709479859255), 'ch3g2': np.float64(1.1748848079790615), 'nch1g9': np.float64(1.2125932225418612), 'nch2g7': np.float64(1.230307033256777), 'nch1g10': np.float64(1.1939229270589091), 'ch1g2': np.float64(1.2386848117683518), 'ch1g3': np.float64(1.2253834787555582), 'ch2g5': np.float64(1.1961165553680413), 'ch2g4': np.float64(1.2169694653320238), 'ch1g6': np.float64(1.2493796847587495), 'ch1g7': np.float64(1.205386235313951), 'ch3g8': np.float64(1.2237297493044585), 'nch1g14': np.float64(1.186792015793225), 'ch3g9': np.float64(1.2315054760773738), 'ch2g1': np.float64(1.227427324304936), 'ch1g12': np.float64(1.2282446956716027), 'ch1g19': np.float64(1.2247153896317113), 'ch3g14': np.float64(1.2259049103214594), 'nch1g3': np.float64(1.2154632099175529), 'ch3g13': np.float64(1.2429464930314318), 'ch1g20': np.float64(1.2303065601537517), 'nch2g5': np.float64(1.1500729437466808), 'nch1g18': np.float64(1.202134927740263), 'nch1g7': np.float64(1.2025496574413663), 'ch3g10': np.float64(1.2098763586800376), 'ch1g16': np.float64(1.2007782107532852), 'nch2g1': np.float64(1.1609592660623609), 'ch3g17': np.float64(1.2001173067122652), 'ch1g15': np.float64(1.2229846631762995), 'ch2g17': np.float64(1.2130428627491585), 'ch1g11': np.float64(1.2179868982531126), 'ch3g18': np.float64(1.1717158526184481), 'ch2g10': np.float64(1.2467395578319143), 'ch2g13': np.float64(1.2158306140887523), 'ch2g18': np.float64(1.1864499324782818), 'ch2g14': np.float64(1.2136143588657635), 'nch1g8': np.float64(1.1828481254302474), 'nch2g6': np.float64(1.2216744602085745), 'nch2g2': np.float64(1.1890525877397622), 'nch1g4': np.float64(1.2285925289493653), 'nch1g20': np.float64(1.1943050154689492), 'nch1g19': np.float64(1.1661427748673858)}

# %% [markdown]
# Normalize all data by mean heights and derive features

# %%
# loop to normalize all data based on mean height and derive features. Saves to TS_processed folder. 
for file in cleanedfiles:
    print(file)
    sample = pd.read_csv(file)

    # normalize all data based on means
    participantID = (sample['participantID'].iloc[0])
    fileID =  sample['fileID'].iloc[0]
    if any(string in fileID for string in nijmegen_gestures):
        print(fileID)
        participantID = 'n' + str(participantID)
    mean_body_length = dict_of_means[participantID]
    sample = normalize_by_body2D(sample, mean_body_length)

    # derive the kinematic feature of speed
    sr = 1/np.mean(np.diff(sample['time']))
    speedcols, sample = derive_2dspeed_smooth(cols, sample, sr)

    ## combine the arm timeseries into one for later feature extraction
    sample['ARM_TOTAL_speed2D'] = np.sqrt(sample['LEFT_WRIST_speed2D']**2 + sample['RIGHT_WRIST_speed2D']**2 + sample['LEFT_ELBOW_speed2D']**2 + sample['RIGHT_ELBOW_speed2D']**2)
    sample['LEG_TOTAL_speed2D'] = np.sqrt(sample['LEFT_ANKLE_speed2D']**2 + sample['RIGHT_ANKLE_speed2D']**2)
    #used to be legtal but I switched it
    # derive the kinematic features of vertical velocity, acceleration, jerk
    verticalcols, sample = derive_vertical_vel_smooth(sample)
    sample['ARM_TOTAL_velocity'] = np.sqrt(sample['Y_LEFT_WRIST_velocity']**2 + sample['Y_RIGHT_WRIST_velocity']**2 + sample['Y_LEFT_ELBOW_velocity']**2 + sample['Y_RIGHT_ELBOW_velocity']**2)
    sample['LEG_TOTAL_velocity'] = np.sqrt(sample['Y_LEFT_ANKLE_velocity']**2 + sample['Y_RIGHT_ANKLE_velocity']**2)
    sample = derive_accel2D_smooth(speedcols, sample)
    sample['ARM_TOTAL_accel2D'] = np.sqrt(sample['LEFT_WRIST_acceleration2D']**2 + sample['RIGHT_WRIST_acceleration2D']**2 + sample['LEFT_ELBOW_acceleration2D']**2 + sample['RIGHT_ELBOW_acceleration2D']**2)
    sample['LEG_TOTAL_accel2D'] = np.sqrt(sample['LEFT_ANKLE_acceleration2D']**2 + sample['RIGHT_ANKLE_acceleration2D']**2)
    sample = derive_jerk2D_smooth(speedcols, sample)
    sample['ARM_TOTAL_jerk2D'] = np.sqrt(sample['LEFT_WRIST_jerk2D']**2 + sample['RIGHT_WRIST_jerk2D']**2 + sample['LEFT_ELBOW_jerk2D']**2 + sample['RIGHT_ELBOW_jerk2D']**2)
    sample['LEG_TOTAL_speed2D'] = np.sqrt(sample['LEFT_ANKLE_speed2D']**2 + sample['RIGHT_ANKLE_speed2D']**2)    

    fileID = sample['fileID'][0]
    globals()[fileID] = sample
    globals()[fileID].to_csv(os.path.join(processedfolder, f'{fileID}.csv'), index=False)
# Out:
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/TS_cleaned/langsam_g_ch3_g7_compr.mp4.csv
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/TS_cleaned/Donner_g_ch2_g12_compr.mp4.csv
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/TS_cleaned/kalt_g_ch3_g19_compr.mp4.csv
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/TS_cleaned/langsam_g_ch3_g12_compr.mp4.csv
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/TS_cleaned/lndw_lndw_rennen_g_ch1_g1_compr.mp4.csv
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/TS_cleaned/leise_g_ch1_g0_compr.mp4.csv
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/TS_cleaned/lndw_lndw_rennen_g_ch2_g16_compr.mp4.csv
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/TS_cleaned/koud_g_ch1_g13_compr.mp4.csv
# koud_g_ch1_g13_compr.mp4
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/TS_cleaned/langsam_g_ch1_g8_compr.mp4.csv
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/TS_cleaned/kalt_g_ch1_g14_compr.mp4.csv
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/TS_cleaned/onweer_g_ch1_g16_compr.mp4.csv
# onweer_g_ch1_g16_compr.mp4
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/TS_cleaned/leise_g_ch2_g6_compr.mp4.csv
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/TS_cleaned/lndw_lndw_rennen_g_ch2_g7_compr.mp4.csv
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/TS_cleaned/langzaam_g_ch1_g15_compr.mp4.csv
# langzaam_g_ch1_g15_compr.mp4
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/TS_cleaned/kalt_g_ch3_g20_compr.mp4.csv
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/TS_cleaned/leise_g_ch1_g13_compr.mp4.csv
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/TS_cleaned/langzaam_g_ch1_g6_compr.mp4.csv
# langzaam_g_ch1_g6_compr.mp4
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/TS_cleaned/nijmegen_nijmegen_rennen_g_ch1_g13_compr.mp4.csv
# nijmegen_nijmegen_rennen_g_ch1_g13_compr.mp4
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/TS_cleaned/onweer_g_ch1_g12_compr.mp4.csv
# onweer_g_ch1_g12_compr.mp4
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/TS_cleaned/langzaam_g_ch2_g4_compr.mp4.csv
# langzaam_g_ch2_g4_compr.mp4
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/TS_cleaned/kalt_g_ch1_g10_compr.mp4.csv
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/TS_cleaned/koud_g_ch1_g17_compr.mp4.csv
# koud_g_ch1_g17_compr.mp4
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/TS_cleaned/lndw_lndw_rennen_g_ch2_g12_compr.mp4.csv
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/TS_cleaned/lndw_lndw_rennen_g_ch1_g5_compr.mp4.csv
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/TS_cleaned/langsam_g_ch3_g16_compr.mp4.csv
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/TS_cleaned/leise_g_ch1_g4_compr.mp4.csv
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/TS_cleaned/Donner_g_ch2_g16_compr.mp4.csv
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/TS_cleaned/langsam_g_ch3_g3_compr.mp4.csv
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/TS_cleaned/nijmegen_nijmegen_rennen_g_ch1_g17_compr.mp4.csv
# nijmegen_nijmegen_rennen_g_ch1_g17_compr.mp4
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/TS_cleaned/langzaam_g_ch1_g2_compr.mp4.csv
# langzaam_g_ch1_g2_compr.mp4
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/TS_cleaned/leise_g_ch1_g17_compr.mp4.csv
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/TS_cleaned/langzaam_g_ch1_g11_compr.mp4.csv
# langzaam_g_ch1_g11_compr.mp4
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/TS_cleaned/leise_g_ch2_g2_compr.mp4.csv
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/TS_cleaned/lndw_lndw_rennen_g_ch2_g3_compr.mp4.csv
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/TS_cleaned/Donner_g_ch2_g9_compr.mp4.csv
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/TS_cleaned/lndw_lndw_rennen_g_ch3_g15_compr.mp4.csv
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/TS_cleaned/nijmegen_nijmegen_rennen_g_ch1_g6_compr.mp4.csv
# nijmegen_nijmegen_rennen_g_ch1_g6_compr.mp4
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/TS_cleaned/stil_g_ch1_g6_compr.mp4.csv
# stil_g_ch1_g6_compr.mp4
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/TS_cleaned/kalt_g_ch3_g5_compr.mp4.csv
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/TS_cleaned/langsam_g_ch2_g11_compr.mp4.csv
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/TS_cleaned/lndw_lndw_rennen_g_ch1_g18_compr.mp4.csv
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/TS_cleaned/Donner_g_ch3_g11_compr.mp4.csv
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/TS_cleaned/stil_g_ch1_g11_compr.mp4.csv
# stil_g_ch1_g11_compr.mp4
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/TS_cleaned/Donner_g_ch3_g15_compr.mp4.csv
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/TS_cleaned/kalt_g_ch3_g1_compr.mp4.csv
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/TS_cleaned/langsam_g_ch2_g15_compr.mp4.csv
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/TS_cleaned/nijmegen_nijmegen_rennen_g_ch1_g2_compr.mp4.csv
# nijmegen_nijmegen_rennen_g_ch1_g2_compr.mp4
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/TS_cleaned/stil_g_ch1_g2_compr.mp4.csv
# stil_g_ch1_g2_compr.mp4
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/TS_cleaned/Donner_g_ch1_g18_compr.mp4.csv
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/TS_cleaned/lndw_lndw_rennen_g_ch3_g11_compr.mp4.csv
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/TS_cleaned/leise_g_ch2_g20_compr.mp4.csv
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/TS_cleaned/stil_g_ch2_g4_compr.mp4.csv
# stil_g_ch2_g4_compr.mp4
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/TS_cleaned/nijmegen_nijmegen_rennen_g_ch2_g4_compr.mp4.csv
# nijmegen_nijmegen_rennen_g_ch2_g4_compr.mp4
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/TS_cleaned/Donner_g_ch3_g4_compr.mp4.csv
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/TS_cleaned/leise_g_ch2_g19_compr.mp4.csv
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/TS_cleaned/stil_g_ch1_g15_compr.mp4.csv
# stil_g_ch1_g15_compr.mp4
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/TS_cleaned/kalt_g_ch2_g8_compr.mp4.csv
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/TS_cleaned/Donner_g_ch3_g12_compr.mp4.csv
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/TS_cleaned/langsam_g_ch2_g12_compr.mp4.csv
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/TS_cleaned/kalt_g_ch3_g6_compr.mp4.csv
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/TS_cleaned/nijmegen_nijmegen_rennen_g_ch1_g5_compr.mp4.csv
# nijmegen_nijmegen_rennen_g_ch1_g5_compr.mp4
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/TS_cleaned/kalt_g_ch2_g19_compr.mp4.csv
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/TS_cleaned/stil_g_ch1_g5_compr.mp4.csv
# stil_g_ch1_g5_compr.mp4
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/TS_cleaned/kalt_g_ch1_g9_compr.mp4.csv
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/TS_cleaned/lndw_lndw_rennen_g_ch3_g16_compr.mp4.csv
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/TS_cleaned/stil_g_ch2_g3_compr.mp4.csv
# stil_g_ch2_g3_compr.mp4
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/TS_cleaned/nijmegen_nijmegen_rennen_g_ch2_g3_compr.mp4.csv
# nijmegen_nijmegen_rennen_g_ch2_g3_compr.mp4
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/TS_cleaned/Donner_g_ch3_g3_compr.mp4.csv
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/TS_cleaned/kalt_g_ch2_g20_compr.mp4.csv
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/TS_cleaned/stil_g_ch1_g12_compr.mp4.csv
# stil_g_ch1_g12_compr.mp4
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/TS_cleaned/lndw_lndw_rennen_g_ch3_g12_compr.mp4.csv
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/TS_cleaned/nijmegen_nijmegen_rennen_g_ch1_g1_compr.mp4.csv
# nijmegen_nijmegen_rennen_g_ch1_g1_compr.mp4
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/TS_cleaned/stil_g_ch1_g1_compr.mp4.csv
# stil_g_ch1_g1_compr.mp4
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/TS_cleaned/langsam_g_ch2_g16_compr.mp4.csv
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/TS_cleaned/kalt_g_ch3_g2_compr.mp4.csv
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/TS_cleaned/Donner_g_ch3_g16_compr.mp4.csv
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/TS_cleaned/stil_g_ch1_g16_compr.mp4.csv
# stil_g_ch1_g16_compr.mp4
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/TS_cleaned/Donner_g_ch1_g8_compr.mp4.csv
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/TS_cleaned/Donner_g_ch3_g7_compr.mp4.csv
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/TS_cleaned/onweer_g_ch1_g9_compr.mp4.csv
# onweer_g_ch1_g9_compr.mp4
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/TS_cleaned/stil_g_ch2_g7_compr.mp4.csv
# stil_g_ch2_g7_compr.mp4
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/TS_cleaned/nijmegen_nijmegen_rennen_g_ch2_g7_compr.mp4.csv
# nijmegen_nijmegen_rennen_g_ch2_g7_compr.mp4
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/TS_cleaned/onweer_g_ch1_g15_compr.mp4.csv
# onweer_g_ch1_g15_compr.mp4
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/TS_cleaned/kalt_g_ch1_g17_compr.mp4.csv
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/TS_cleaned/langzaam_g_ch2_g3_compr.mp4.csv
# langzaam_g_ch2_g3_compr.mp4
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/TS_cleaned/koud_g_ch1_g10_compr.mp4.csv
# koud_g_ch1_g10_compr.mp4
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/TS_cleaned/lndw_lndw_rennen_g_ch2_g15_compr.mp4.csv
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/TS_cleaned/lndw_lndw_rennen_g_ch1_g2_compr.mp4.csv
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/TS_cleaned/langsam_g_ch3_g11_compr.mp4.csv
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/TS_cleaned/leise_g_ch1_g3_compr.mp4.csv
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/TS_cleaned/Donner_g_ch2_g11_compr.mp4.csv
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/TS_cleaned/langsam_g_ch3_g4_compr.mp4.csv
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/TS_cleaned/nijmegen_nijmegen_rennen_g_ch1_g10_compr.mp4.csv
# nijmegen_nijmegen_rennen_g_ch1_g10_compr.mp4
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/TS_cleaned/langzaam_g_ch1_g5_compr.mp4.csv
# langzaam_g_ch1_g5_compr.mp4
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/TS_cleaned/leise_g_ch1_g10_compr.mp4.csv
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/TS_cleaned/langzaam_g_ch1_g16_compr.mp4.csv
# langzaam_g_ch1_g16_compr.mp4
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/TS_cleaned/leise_g_ch2_g5_compr.mp4.csv
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/TS_cleaned/lndw_lndw_rennen_g_ch2_g4_compr.mp4.csv
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/TS_cleaned/koud_g_ch1_g9_compr.mp4.csv
# koud_g_ch1_g9_compr.mp4
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/TS_cleaned/Donner_g_ch2_g15_compr.mp4.csv
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/TS_cleaned/langsam_g_ch3_g15_compr.mp4.csv
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/TS_cleaned/lndw_lndw_rennen_g_ch1_g6_compr.mp4.csv
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/TS_cleaned/leise_g_ch1_g7_compr.mp4.csv
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/TS_cleaned/lndw_lndw_rennen_g_ch2_g11_compr.mp4.csv
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/TS_cleaned/leise_g_ch3_g8_compr.mp4.csv
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/TS_cleaned/koud_g_ch1_g14_compr.mp4.csv
# koud_g_ch1_g14_compr.mp4
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/TS_cleaned/lndw_lndw_rennen_g_ch3_g9_compr.mp4.csv
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/TS_cleaned/kalt_g_ch1_g13_compr.mp4.csv
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/TS_cleaned/langzaam_g_ch2_g7_compr.mp4.csv
# langzaam_g_ch2_g7_compr.mp4
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/TS_cleaned/leise_g_ch3_g20_compr.mp4.csv
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/TS_cleaned/langsam_g_ch1_g18_compr.mp4.csv
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/TS_cleaned/onweer_g_ch1_g11_compr.mp4.csv
# onweer_g_ch1_g11_compr.mp4
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/TS_cleaned/leise_g_ch2_g1_compr.mp4.csv
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/TS_cleaned/langzaam_g_ch1_g12_compr.mp4.csv
# langzaam_g_ch1_g12_compr.mp4
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/TS_cleaned/leise_g_ch1_g14_compr.mp4.csv
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/TS_cleaned/langzaam_g_ch1_g1_compr.mp4.csv
# langzaam_g_ch1_g1_compr.mp4
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/TS_cleaned/langsam_g_ch2_g9_compr.mp4.csv
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/TS_cleaned/nijmegen_nijmegen_rennen_g_ch1_g14_compr.mp4.csv
# nijmegen_nijmegen_rennen_g_ch1_g14_compr.mp4
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/TS_cleaned/leise_g_ch3_g19_compr.mp4.csv
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/TS_cleaned/langsam_g_ch1_g12_compr.mp4.csv
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/TS_cleaned/langsam_g_ch1_g5_compr.mp4.csv
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/TS_cleaned/kalt_g_ch1_g19_compr.mp4.csv
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/TS_cleaned/lndw_lndw_rennen_g_ch3_g3_compr.mp4.csv
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/TS_cleaned/leise_g_ch3_g2_compr.mp4.csv
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/TS_cleaned/kalt_g_ch3_g14_compr.mp4.csv
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/TS_cleaned/koud_g_ch1_g3_compr.mp4.csv
# koud_g_ch1_g3_compr.mp4
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/TS_cleaned/leise_g_ch3_g13_compr.mp4.csv
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/TS_cleaned/kalt_g_ch1_g20_compr.mp4.csv
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/TS_cleaned/langsam_g_ch2_g3_compr.mp4.csv
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/TS_cleaned/koud_g_ch2_g5_compr.mp4.csv
# koud_g_ch2_g5_compr.mp4
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/TS_cleaned/langzaam_g_ch1_g18_compr.mp4.csv
# langzaam_g_ch1_g18_compr.mp4
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/TS_cleaned/koud_g_ch1_g7_compr.mp4.csv
# koud_g_ch1_g7_compr.mp4
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/TS_cleaned/kalt_g_ch3_g10_compr.mp4.csv
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/TS_cleaned/leise_g_ch1_g9_compr.mp4.csv
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/TS_cleaned/lndw_lndw_rennen_g_ch1_g8_compr.mp4.csv
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/TS_cleaned/lndw_lndw_rennen_g_ch3_g7_compr.mp4.csv
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/TS_cleaned/leise_g_ch3_g6_compr.mp4.csv
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/TS_cleaned/langsam_g_ch1_g1_compr.mp4.csv
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/TS_cleaned/langsam_g_ch1_g16_compr.mp4.csv
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/TS_cleaned/koud_g_ch2_g1_compr.mp4.csv
# koud_g_ch2_g1_compr.mp4
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/TS_cleaned/langsam_g_ch2_g7_compr.mp4.csv
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/TS_cleaned/leise_g_ch3_g17_compr.mp4.csv
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/TS_cleaned/lndw_lndw_rennen_g_ch1_g15_compr.mp4.csv
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/TS_cleaned/onweer_g_ch2_g5_compr.mp4.csv
# onweer_g_ch2_g5_compr.mp4
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/TS_cleaned/kalt_g_ch3_g8_compr.mp4.csv
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/TS_cleaned/kalt_g_ch2_g17_compr.mp4.csv
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/TS_cleaned/Donner_g_ch1_g11_compr.mp4.csv
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/TS_cleaned/kalt_g_ch1_g7_compr.mp4.csv
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/TS_cleaned/lndw_lndw_rennen_g_ch3_g18_compr.mp4.csv
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/TS_cleaned/Donner_g_ch2_g4_compr.mp4.csv
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/TS_cleaned/onweer_g_ch1_g3_compr.mp4.csv
# onweer_g_ch1_g3_compr.mp4
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/TS_cleaned/Donner_g_ch1_g2_compr.mp4.csv
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/TS_cleaned/leise_g_ch2_g10_compr.mp4.csv
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/TS_cleaned/kalt_g_ch2_g1_compr.mp4.csv
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/TS_cleaned/kalt_g_ch1_g3_compr.mp4.csv
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/TS_cleaned/Donner_g_ch1_g15_compr.mp4.csv
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/TS_cleaned/kalt_g_ch2_g13_compr.mp4.csv
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/TS_cleaned/langsam_g_ch2_g18_compr.mp4.csv
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/TS_cleaned/onweer_g_ch2_g1_compr.mp4.csv
# onweer_g_ch2_g1_compr.mp4
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/TS_cleaned/lndw_lndw_rennen_g_ch1_g11_compr.mp4.csv
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/TS_cleaned/Donner_g_ch3_g18_compr.mp4.csv
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/TS_cleaned/kalt_g_ch2_g5_compr.mp4.csv
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/TS_cleaned/stil_g_ch1_g18_compr.mp4.csv
# stil_g_ch1_g18_compr.mp4
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/TS_cleaned/leise_g_ch2_g14_compr.mp4.csv
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/TS_cleaned/Donner_g_ch1_g6_compr.mp4.csv
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/TS_cleaned/Donner_g_ch3_g9_compr.mp4.csv
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/TS_cleaned/onweer_g_ch1_g7_compr.mp4.csv
# onweer_g_ch1_g7_compr.mp4
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/TS_cleaned/Donner_g_ch2_g7_compr.mp4.csv
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/TS_cleaned/Donner_g_ch1_g12_compr.mp4.csv
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/TS_cleaned/kalt_g_ch1_g4_compr.mp4.csv
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/TS_cleaned/stil_g_ch1_g8_compr.mp4.csv
# stil_g_ch1_g8_compr.mp4
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/TS_cleaned/kalt_g_ch2_g14_compr.mp4.csv
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/TS_cleaned/nijmegen_nijmegen_rennen_g_ch1_g8_compr.mp4.csv
# nijmegen_nijmegen_rennen_g_ch1_g8_compr.mp4
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/TS_cleaned/onweer_g_ch2_g6_compr.mp4.csv
# onweer_g_ch2_g6_compr.mp4
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/TS_cleaned/lndw_lndw_rennen_g_ch1_g16_compr.mp4.csv
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/TS_cleaned/kalt_g_ch2_g2_compr.mp4.csv
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/TS_cleaned/leise_g_ch2_g13_compr.mp4.csv
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/TS_cleaned/Donner_g_ch1_g1_compr.mp4.csv
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/TS_cleaned/lndw_lndw_rennen_g_ch1_g12_compr.mp4.csv
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/TS_cleaned/onweer_g_ch2_g2_compr.mp4.csv
# onweer_g_ch2_g2_compr.mp4
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/TS_cleaned/kalt_g_ch2_g10_compr.mp4.csv
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/TS_cleaned/kalt_g_ch1_g0_compr.mp4.csv
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/TS_cleaned/Donner_g_ch1_g16_compr.mp4.csv
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/TS_cleaned/Donner_g_ch2_g3_compr.mp4.csv
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/TS_cleaned/onweer_g_ch1_g4_compr.mp4.csv
# onweer_g_ch1_g4_compr.mp4
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/TS_cleaned/Donner_g_ch1_g5_compr.mp4.csv
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/TS_cleaned/leise_g_ch2_g17_compr.mp4.csv
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/TS_cleaned/kalt_g_ch2_g6_compr.mp4.csv
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/TS_cleaned/langsam_g_ch3_g9_compr.mp4.csv
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/TS_cleaned/kalt_g_ch3_g17_compr.mp4.csv
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/TS_cleaned/lndw_lndw_rennen_g_ch2_g18_compr.mp4.csv
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/TS_cleaned/leise_g_ch3_g1_compr.mp4.csv
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/TS_cleaned/langsam_g_ch1_g6_compr.mp4.csv
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/TS_cleaned/onweer_g_ch1_g18_compr.mp4.csv
# onweer_g_ch1_g18_compr.mp4
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/TS_cleaned/langsam_g_ch1_g11_compr.mp4.csv
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/TS_cleaned/lndw_lndw_rennen_g_ch2_g9_compr.mp4.csv
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/TS_cleaned/leise_g_ch2_g8_compr.mp4.csv
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/TS_cleaned/koud_g_ch2_g6_compr.mp4.csv
# koud_g_ch2_g6_compr.mp4
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/TS_cleaned/langzaam_g_ch1_g8_compr.mp4.csv
# langzaam_g_ch1_g8_compr.mp4
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/TS_cleaned/leise_g_ch3_g10_compr.mp4.csv
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/TS_cleaned/nijmegen_nijmegen_rennen_g_ch1_g20_compr.mp4.csv
# nijmegen_nijmegen_rennen_g_ch1_g20_compr.mp4
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/TS_cleaned/langsam_g_ch1_g15_compr.mp4.csv
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/TS_cleaned/langsam_g_ch1_g2_compr.mp4.csv
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/TS_cleaned/lndw_lndw_rennen_g_ch3_g4_compr.mp4.csv
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/TS_cleaned/koud_g_ch1_g19_compr.mp4.csv
# koud_g_ch1_g19_compr.mp4
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/TS_cleaned/leise_g_ch3_g5_compr.mp4.csv
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/TS_cleaned/langsam_g_ch3_g18_compr.mp4.csv
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/TS_cleaned/leise_g_ch1_g20_compr.mp4.csv
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/TS_cleaned/kalt_g_ch3_g13_compr.mp4.csv
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/TS_cleaned/Donner_g_ch2_g18_compr.mp4.csv
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/TS_cleaned/koud_g_ch1_g4_compr.mp4.csv
# koud_g_ch1_g4_compr.mp4
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/TS_cleaned/leise_g_ch3_g14_compr.mp4.csv
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/TS_cleaned/nijmegen_nijmegen_rennen_g_ch1_g19_compr.mp4.csv
# nijmegen_nijmegen_rennen_g_ch1_g19_compr.mp4
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/TS_cleaned/langsam_g_ch2_g4_compr.mp4.csv
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/TS_cleaned/koud_g_ch1_g20_compr.mp4.csv
# koud_g_ch1_g20_compr.mp4
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/TS_cleaned/leise_g_ch1_g19_compr.mp4.csv
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/TS_cleaned/koud_g_ch2_g2_compr.mp4.csv
# koud_g_ch2_g2_compr.mp4
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/TS_cleaned/Donner_g_ch1_g4_compr.mp4.csv
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/TS_cleaned/leise_g_ch2_g16_compr.mp4.csv
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/TS_cleaned/onweer_g_ch1_g5_compr.mp4.csv
# onweer_g_ch1_g5_compr.mp4
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/TS_cleaned/kalt_g_ch1_g1_compr.mp4.csv
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/TS_cleaned/Donner_g_ch1_g17_compr.mp4.csv
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/TS_cleaned/Donner_g_ch2_g2_compr.mp4.csv
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/TS_cleaned/lndw_lndw_rennen_g_ch1_g13_compr.mp4.csv
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/TS_cleaned/kalt_g_ch2_g11_compr.mp4.csv
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/TS_cleaned/onweer_g_ch2_g3_compr.mp4.csv
# onweer_g_ch2_g3_compr.mp4
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/TS_cleaned/onweer_g_ch1_g1_compr.mp4.csv
# onweer_g_ch1_g1_compr.mp4
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/TS_cleaned/leise_g_ch2_g12_compr.mp4.csv
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/TS_cleaned/kalt_g_ch2_g3_compr.mp4.csv
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/TS_cleaned/Donner_g_ch1_g0_compr.mp4.csv
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/TS_cleaned/onweer_g_ch2_g7_compr.mp4.csv
# onweer_g_ch2_g7_compr.mp4
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/TS_cleaned/stil_g_ch1_g9_compr.mp4.csv
# stil_g_ch1_g9_compr.mp4
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/TS_cleaned/kalt_g_ch2_g15_compr.mp4.csv
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/TS_cleaned/nijmegen_nijmegen_rennen_g_ch1_g9_compr.mp4.csv
# nijmegen_nijmegen_rennen_g_ch1_g9_compr.mp4
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/TS_cleaned/lndw_lndw_rennen_g_ch1_g17_compr.mp4.csv
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/TS_cleaned/Donner_g_ch2_g6_compr.mp4.csv
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/TS_cleaned/Donner_g_ch1_g13_compr.mp4.csv
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/TS_cleaned/kalt_g_ch1_g5_compr.mp4.csv
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/TS_cleaned/langsam_g_ch3_g20_compr.mp4.csv
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/TS_cleaned/leise_g_ch1_g18_compr.mp4.csv
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/TS_cleaned/koud_g_ch2_g3_compr.mp4.csv
# koud_g_ch2_g3_compr.mp4
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/TS_cleaned/Donner_g_ch2_g20_compr.mp4.csv
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/TS_cleaned/nijmegen_nijmegen_rennen_g_ch1_g18_compr.mp4.csv
# nijmegen_nijmegen_rennen_g_ch1_g18_compr.mp4
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/TS_cleaned/leise_g_ch3_g15_compr.mp4.csv
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/TS_cleaned/langsam_g_ch2_g5_compr.mp4.csv
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/TS_cleaned/kalt_g_ch3_g12_compr.mp4.csv
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/TS_cleaned/langsam_g_ch3_g19_compr.mp4.csv
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/TS_cleaned/koud_g_ch1_g5_compr.mp4.csv
# koud_g_ch1_g5_compr.mp4
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/TS_cleaned/Donner_g_ch2_g19_compr.mp4.csv
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/TS_cleaned/langsam_g_ch1_g3_compr.mp4.csv
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/TS_cleaned/langsam_g_ch1_g14_compr.mp4.csv
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/TS_cleaned/lndw_lndw_rennen_g_ch3_g5_compr.mp4.csv
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/TS_cleaned/koud_g_ch1_g18_compr.mp4.csv
# koud_g_ch1_g18_compr.mp4
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/TS_cleaned/leise_g_ch3_g4_compr.mp4.csv
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/TS_cleaned/langsam_g_ch2_g1_compr.mp4.csv
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/TS_cleaned/langzaam_g_ch1_g9_compr.mp4.csv
# langzaam_g_ch1_g9_compr.mp4
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/TS_cleaned/lndw_lndw_rennen_g_ch2_g20_compr.mp4.csv
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/TS_cleaned/leise_g_ch3_g11_compr.mp4.csv
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/TS_cleaned/onweer_g_ch1_g20_compr.mp4.csv
# onweer_g_ch1_g20_compr.mp4
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/TS_cleaned/lndw_lndw_rennen_g_ch2_g8_compr.mp4.csv
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/TS_cleaned/leise_g_ch2_g9_compr.mp4.csv
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/TS_cleaned/koud_g_ch2_g7_compr.mp4.csv
# koud_g_ch2_g7_compr.mp4
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/TS_cleaned/lndw_lndw_rennen_g_ch3_g1_compr.mp4.csv
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/TS_cleaned/lndw_lndw_rennen_g_ch2_g19_compr.mp4.csv
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/TS_cleaned/onweer_g_ch1_g19_compr.mp4.csv
# onweer_g_ch1_g19_compr.mp4
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/TS_cleaned/langsam_g_ch1_g10_compr.mp4.csv
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/TS_cleaned/langsam_g_ch1_g7_compr.mp4.csv
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/TS_cleaned/langsam_g_ch3_g8_compr.mp4.csv
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/TS_cleaned/koud_g_ch1_g1_compr.mp4.csv
# koud_g_ch1_g1_compr.mp4
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/TS_cleaned/kalt_g_ch3_g16_compr.mp4.csv
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/TS_cleaned/langsam_g_ch2_g6_compr.mp4.csv
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/TS_cleaned/leise_g_ch3_g16_compr.mp4.csv
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/TS_cleaned/lndw_lndw_rennen_g_ch3_g6_compr.mp4.csv
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/TS_cleaned/leise_g_ch3_g7_compr.mp4.csv
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/TS_cleaned/langsam_g_ch1_g17_compr.mp4.csv
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/TS_cleaned/langsam_g_ch1_g0_compr.mp4.csv
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/TS_cleaned/koud_g_ch1_g6_compr.mp4.csv
# koud_g_ch1_g6_compr.mp4
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/TS_cleaned/leise_g_ch1_g8_compr.mp4.csv
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/TS_cleaned/lndw_lndw_rennen_g_ch1_g9_compr.mp4.csv
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/TS_cleaned/kalt_g_ch3_g11_compr.mp4.csv
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/TS_cleaned/koud_g_ch2_g4_compr.mp4.csv
# koud_g_ch2_g4_compr.mp4
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/TS_cleaned/langzaam_g_ch1_g19_compr.mp4.csv
# langzaam_g_ch1_g19_compr.mp4
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/TS_cleaned/leise_g_ch3_g12_compr.mp4.csv
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/TS_cleaned/langsam_g_ch2_g2_compr.mp4.csv
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/TS_cleaned/kalt_g_ch3_g15_compr.mp4.csv
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/TS_cleaned/langzaam_g_ch1_g20_compr.mp4.csv
# langzaam_g_ch1_g20_compr.mp4
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/TS_cleaned/koud_g_ch1_g2_compr.mp4.csv
# koud_g_ch1_g2_compr.mp4
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/TS_cleaned/kalt_g_ch1_g18_compr.mp4.csv
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/TS_cleaned/langsam_g_ch1_g4_compr.mp4.csv
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/TS_cleaned/langsam_g_ch1_g13_compr.mp4.csv
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/TS_cleaned/lndw_lndw_rennen_g_ch3_g2_compr.mp4.csv
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/TS_cleaned/leise_g_ch3_g3_compr.mp4.csv
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/TS_cleaned/Donner_g_ch3_g8_compr.mp4.csv
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/TS_cleaned/langsam_g_ch2_g20_compr.mp4.csv
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/TS_cleaned/Donner_g_ch3_g20_compr.mp4.csv
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/TS_cleaned/onweer_g_ch1_g6_compr.mp4.csv
# onweer_g_ch1_g6_compr.mp4
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/TS_cleaned/leise_g_ch2_g15_compr.mp4.csv
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/TS_cleaned/kalt_g_ch2_g4_compr.mp4.csv
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/TS_cleaned/stil_g_ch1_g19_compr.mp4.csv
# stil_g_ch1_g19_compr.mp4
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/TS_cleaned/Donner_g_ch1_g7_compr.mp4.csv
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/TS_cleaned/langsam_g_ch2_g19_compr.mp4.csv
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/TS_cleaned/kalt_g_ch2_g12_compr.mp4.csv
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/TS_cleaned/Donner_g_ch3_g19_compr.mp4.csv
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/TS_cleaned/lndw_lndw_rennen_g_ch1_g10_compr.mp4.csv
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/TS_cleaned/stil_g_ch1_g20_compr.mp4.csv
# stil_g_ch1_g20_compr.mp4
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/TS_cleaned/Donner_g_ch2_g1_compr.mp4.csv
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/TS_cleaned/kalt_g_ch1_g2_compr.mp4.csv
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/TS_cleaned/Donner_g_ch1_g14_compr.mp4.csv
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/TS_cleaned/lndw_lndw_rennen_g_ch3_g20_compr.mp4.csv
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/TS_cleaned/Donner_g_ch1_g3_compr.mp4.csv
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/TS_cleaned/leise_g_ch2_g11_compr.mp4.csv
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/TS_cleaned/onweer_g_ch1_g2_compr.mp4.csv
# onweer_g_ch1_g2_compr.mp4
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/TS_cleaned/lndw_lndw_rennen_g_ch3_g19_compr.mp4.csv
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/TS_cleaned/Donner_g_ch1_g10_compr.mp4.csv
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/TS_cleaned/kalt_g_ch1_g6_compr.mp4.csv
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/TS_cleaned/Donner_g_ch2_g5_compr.mp4.csv
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/TS_cleaned/lndw_lndw_rennen_g_ch1_g14_compr.mp4.csv
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/TS_cleaned/kalt_g_ch2_g16_compr.mp4.csv
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/TS_cleaned/kalt_g_ch3_g9_compr.mp4.csv
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/TS_cleaned/onweer_g_ch2_g4_compr.mp4.csv
# onweer_g_ch2_g4_compr.mp4
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/TS_cleaned/Donner_g_ch3_g6_compr.mp4.csv
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/TS_cleaned/stil_g_ch2_g6_compr.mp4.csv
# stil_g_ch2_g6_compr.mp4
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/TS_cleaned/nijmegen_nijmegen_rennen_g_ch2_g6_compr.mp4.csv
# nijmegen_nijmegen_rennen_g_ch2_g6_compr.mp4
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/TS_cleaned/onweer_g_ch1_g8_compr.mp4.csv
# onweer_g_ch1_g8_compr.mp4
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/TS_cleaned/stil_g_ch1_g17_compr.mp4.csv
# stil_g_ch1_g17_compr.mp4
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/TS_cleaned/Donner_g_ch1_g9_compr.mp4.csv
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/TS_cleaned/langsam_g_ch2_g17_compr.mp4.csv
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/TS_cleaned/kalt_g_ch3_g3_compr.mp4.csv
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/TS_cleaned/Donner_g_ch3_g17_compr.mp4.csv
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/TS_cleaned/lndw_lndw_rennen_g_ch3_g13_compr.mp4.csv
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/TS_cleaned/stil_g_ch1_g13_compr.mp4.csv
# stil_g_ch1_g13_compr.mp4
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/TS_cleaned/stil_g_ch2_g2_compr.mp4.csv
# stil_g_ch2_g2_compr.mp4
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/TS_cleaned/nijmegen_nijmegen_rennen_g_ch2_g2_compr.mp4.csv
# nijmegen_nijmegen_rennen_g_ch2_g2_compr.mp4
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/TS_cleaned/Donner_g_ch3_g2_compr.mp4.csv
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/TS_cleaned/lndw_lndw_rennen_g_ch3_g17_compr.mp4.csv
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/TS_cleaned/kalt_g_ch1_g8_compr.mp4.csv
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/TS_cleaned/Donner_g_ch3_g13_compr.mp4.csv
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/TS_cleaned/nijmegen_nijmegen_rennen_g_ch1_g4_compr.mp4.csv
# nijmegen_nijmegen_rennen_g_ch1_g4_compr.mp4
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/TS_cleaned/kalt_g_ch2_g18_compr.mp4.csv
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/TS_cleaned/stil_g_ch1_g4_compr.mp4.csv
# stil_g_ch1_g4_compr.mp4
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/TS_cleaned/langsam_g_ch2_g13_compr.mp4.csv
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/TS_cleaned/kalt_g_ch3_g7_compr.mp4.csv
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/TS_cleaned/langsam_g_ch2_g8_compr.mp4.csv
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/TS_cleaned/leise_g_ch3_g18_compr.mp4.csv
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/TS_cleaned/nijmegen_nijmegen_rennen_g_ch1_g15_compr.mp4.csv
# nijmegen_nijmegen_rennen_g_ch1_g15_compr.mp4
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/TS_cleaned/langsam_g_ch1_g20_compr.mp4.csv
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/TS_cleaned/langzaam_g_ch1_g13_compr.mp4.csv
# langzaam_g_ch1_g13_compr.mp4
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/TS_cleaned/lndw_lndw_rennen_g_ch2_g1_compr.mp4.csv
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/TS_cleaned/leise_g_ch1_g15_compr.mp4.csv
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/TS_cleaned/leise_g_ch3_g9_compr.mp4.csv
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/TS_cleaned/koud_g_ch1_g15_compr.mp4.csv
# koud_g_ch1_g15_compr.mp4
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/TS_cleaned/lndw_lndw_rennen_g_ch3_g8_compr.mp4.csv
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/TS_cleaned/lndw_lndw_rennen_g_ch2_g10_compr.mp4.csv
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/TS_cleaned/langsam_g_ch1_g19_compr.mp4.csv
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/TS_cleaned/onweer_g_ch1_g10_compr.mp4.csv
# onweer_g_ch1_g10_compr.mp4
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/TS_cleaned/kalt_g_ch1_g12_compr.mp4.csv
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/TS_cleaned/langzaam_g_ch2_g6_compr.mp4.csv
# langzaam_g_ch2_g6_compr.mp4
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/TS_cleaned/Donner_g_ch2_g14_compr.mp4.csv
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/TS_cleaned/koud_g_ch1_g8_compr.mp4.csv
# koud_g_ch1_g8_compr.mp4
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/TS_cleaned/langsam_g_ch3_g1_compr.mp4.csv
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/TS_cleaned/lndw_lndw_rennen_g_ch1_g7_compr.mp4.csv
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/TS_cleaned/langsam_g_ch3_g14_compr.mp4.csv
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/TS_cleaned/leise_g_ch1_g6_compr.mp4.csv
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/TS_cleaned/leise_g_ch1_g11_compr.mp4.csv
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/TS_cleaned/leise_g_ch2_g4_compr.mp4.csv
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/TS_cleaned/lndw_lndw_rennen_g_ch2_g5_compr.mp4.csv
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/TS_cleaned/langzaam_g_ch1_g17_compr.mp4.csv
# langzaam_g_ch1_g17_compr.mp4
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/TS_cleaned/nijmegen_nijmegen_rennen_g_ch1_g11_compr.mp4.csv
# nijmegen_nijmegen_rennen_g_ch1_g11_compr.mp4
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/TS_cleaned/langzaam_g_ch1_g4_compr.mp4.csv
# langzaam_g_ch1_g4_compr.mp4
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/TS_cleaned/langsam_g_ch3_g10_compr.mp4.csv
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/TS_cleaned/lndw_lndw_rennen_g_ch1_g3_compr.mp4.csv
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/TS_cleaned/leise_g_ch1_g2_compr.mp4.csv
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/TS_cleaned/langsam_g_ch3_g5_compr.mp4.csv
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/TS_cleaned/Donner_g_ch2_g10_compr.mp4.csv
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/TS_cleaned/kalt_g_ch1_g16_compr.mp4.csv
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/TS_cleaned/langzaam_g_ch2_g2_compr.mp4.csv
# langzaam_g_ch2_g2_compr.mp4
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/TS_cleaned/onweer_g_ch1_g14_compr.mp4.csv
# onweer_g_ch1_g14_compr.mp4
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/TS_cleaned/lndw_lndw_rennen_g_ch2_g14_compr.mp4.csv
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/TS_cleaned/koud_g_ch1_g11_compr.mp4.csv
# koud_g_ch1_g11_compr.mp4
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/TS_cleaned/leise_g_ch1_g16_compr.mp4.csv
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/TS_cleaned/leise_g_ch2_g3_compr.mp4.csv
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/TS_cleaned/lndw_lndw_rennen_g_ch2_g2_compr.mp4.csv
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/TS_cleaned/langzaam_g_ch1_g10_compr.mp4.csv
# langzaam_g_ch1_g10_compr.mp4
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/TS_cleaned/nijmegen_nijmegen_rennen_g_ch1_g16_compr.mp4.csv
# nijmegen_nijmegen_rennen_g_ch1_g16_compr.mp4
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/TS_cleaned/langzaam_g_ch1_g3_compr.mp4.csv
# langzaam_g_ch1_g3_compr.mp4
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/TS_cleaned/langsam_g_ch3_g17_compr.mp4.csv
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/TS_cleaned/lndw_lndw_rennen_g_ch1_g4_compr.mp4.csv
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/TS_cleaned/leise_g_ch1_g5_compr.mp4.csv
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/TS_cleaned/langsam_g_ch3_g2_compr.mp4.csv
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/TS_cleaned/Donner_g_ch2_g17_compr.mp4.csv
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/TS_cleaned/langzaam_g_ch2_g5_compr.mp4.csv
# langzaam_g_ch2_g5_compr.mp4
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/TS_cleaned/kalt_g_ch1_g11_compr.mp4.csv
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/TS_cleaned/onweer_g_ch1_g13_compr.mp4.csv
# onweer_g_ch1_g13_compr.mp4
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/TS_cleaned/lndw_lndw_rennen_g_ch2_g13_compr.mp4.csv
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/TS_cleaned/koud_g_ch1_g16_compr.mp4.csv
# koud_g_ch1_g16_compr.mp4
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/TS_cleaned/langzaam_g_ch1_g7_compr.mp4.csv
# langzaam_g_ch1_g7_compr.mp4
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/TS_cleaned/nijmegen_nijmegen_rennen_g_ch1_g12_compr.mp4.csv
# nijmegen_nijmegen_rennen_g_ch1_g12_compr.mp4
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/TS_cleaned/langzaam_g_ch1_g14_compr.mp4.csv
# langzaam_g_ch1_g14_compr.mp4
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/TS_cleaned/leise_g_ch2_g7_compr.mp4.csv
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/TS_cleaned/lndw_lndw_rennen_g_ch2_g6_compr.mp4.csv
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/TS_cleaned/leise_g_ch1_g12_compr.mp4.csv
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/TS_cleaned/koud_g_ch1_g12_compr.mp4.csv
# koud_g_ch1_g12_compr.mp4
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/TS_cleaned/lndw_lndw_rennen_g_ch2_g17_compr.mp4.csv
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/TS_cleaned/onweer_g_ch1_g17_compr.mp4.csv
# onweer_g_ch1_g17_compr.mp4
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/TS_cleaned/langzaam_g_ch2_g1_compr.mp4.csv
# langzaam_g_ch2_g1_compr.mp4
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/TS_cleaned/kalt_g_ch1_g15_compr.mp4.csv
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/TS_cleaned/langsam_g_ch1_g9_compr.mp4.csv
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/TS_cleaned/Donner_g_ch2_g13_compr.mp4.csv
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/TS_cleaned/langsam_g_ch3_g6_compr.mp4.csv
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/TS_cleaned/lndw_lndw_rennen_g_ch1_g0_compr.mp4.csv
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/TS_cleaned/langsam_g_ch3_g13_compr.mp4.csv
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/TS_cleaned/leise_g_ch1_g1_compr.mp4.csv
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/TS_cleaned/kalt_g_ch3_g18_compr.mp4.csv
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/TS_cleaned/Donner_g_ch1_g20_compr.mp4.csv
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/TS_cleaned/stil_g_ch1_g14_compr.mp4.csv
# stil_g_ch1_g14_compr.mp4
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/TS_cleaned/kalt_g_ch2_g9_compr.mp4.csv
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/TS_cleaned/leise_g_ch2_g18_compr.mp4.csv
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/TS_cleaned/stil_g_ch2_g5_compr.mp4.csv
# stil_g_ch2_g5_compr.mp4
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/TS_cleaned/nijmegen_nijmegen_rennen_g_ch2_g5_compr.mp4.csv
# nijmegen_nijmegen_rennen_g_ch2_g5_compr.mp4
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/TS_cleaned/Donner_g_ch3_g5_compr.mp4.csv
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/TS_cleaned/lndw_lndw_rennen_g_ch3_g10_compr.mp4.csv
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/TS_cleaned/Donner_g_ch1_g19_compr.mp4.csv
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/TS_cleaned/Donner_g_ch3_g14_compr.mp4.csv
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/TS_cleaned/nijmegen_nijmegen_rennen_g_ch1_g3_compr.mp4.csv
# nijmegen_nijmegen_rennen_g_ch1_g3_compr.mp4
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/TS_cleaned/stil_g_ch1_g3_compr.mp4.csv
# stil_g_ch1_g3_compr.mp4
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/TS_cleaned/langsam_g_ch2_g14_compr.mp4.csv
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/TS_cleaned/Donner_g_ch3_g1_compr.mp4.csv
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/TS_cleaned/stil_g_ch2_g1_compr.mp4.csv
# stil_g_ch2_g1_compr.mp4
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/TS_cleaned/lndw_lndw_rennen_g_ch1_g20_compr.mp4.csv
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/TS_cleaned/nijmegen_nijmegen_rennen_g_ch2_g1_compr.mp4.csv
# nijmegen_nijmegen_rennen_g_ch2_g1_compr.mp4
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/TS_cleaned/stil_g_ch1_g10_compr.mp4.csv
# stil_g_ch1_g10_compr.mp4
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/TS_cleaned/kalt_g_ch3_g4_compr.mp4.csv
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/TS_cleaned/langsam_g_ch2_g10_compr.mp4.csv
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/TS_cleaned/nijmegen_nijmegen_rennen_g_ch1_g7_compr.mp4.csv
# nijmegen_nijmegen_rennen_g_ch1_g7_compr.mp4
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/TS_cleaned/stil_g_ch1_g7_compr.mp4.csv
# stil_g_ch1_g7_compr.mp4
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/TS_cleaned/Donner_g_ch3_g10_compr.mp4.csv
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/TS_cleaned/lndw_lndw_rennen_g_ch1_g19_compr.mp4.csv
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/TS_cleaned/Donner_g_ch2_g8_compr.mp4.csv
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/TS_cleaned/lndw_lndw_rennen_g_ch3_g14_compr.mp4.csv

# %% [markdown]
# # Functions to align data with ELAN Annotations

# %% [markdown]
# All code was modified from code written by Šárka Kadavá

# %% [markdown]
#  Define functions to parse the ELAN files

# %%
import xml.etree.ElementTree as ET

# Function to parse elan file
def parse_eaf_file(eaf_file, rel_tiers):
    tree = ET.parse(eaf_file)
    root = tree.getroot()

    annotations = []
    relevant_tiers = {rel_tiers}
    
    time_order = root.find('TIME_ORDER')
    if time_order == None: 
        print ("no time order")
        print()
        annotations.append({
                        'tier_id': 'na',
                        'annotation_id': 'na',
                        'start_time': 'na',
                        'end_time': 'na',
                        'annotation_value': None
                    })
    else:
        time_slots = {time_slot.attrib['TIME_SLOT_ID']: time_slot.attrib['TIME_VALUE'] for time_slot in time_order}


        for tier in root.findall('TIER'):
            tier_id = tier.attrib['TIER_ID']
            if tier_id in relevant_tiers:
                for annotation in tier.findall('ANNOTATION/ALIGNABLE_ANNOTATION'):
                    # Ensure required attributes are present
                    if 'TIME_SLOT_REF1' in annotation.attrib and 'TIME_SLOT_REF2' in annotation.attrib:
                        ts_ref1 = annotation.attrib['TIME_SLOT_REF1']
                        ts_ref2 = annotation.attrib['TIME_SLOT_REF2']
                        # Get annotation ID if it exists, otherwise set to None
                        ann_id = annotation.attrib.get('ANNOTATION_ID', None)
                        annotation_value = annotation.find('ANNOTATION_VALUE').text.strip()
                        annotations.append({
                            'tier_id': tier_id,
                            'annotation_id': ann_id,
                            'start_time': time_slots[ts_ref1],
                            'end_time': time_slots[ts_ref2],
                            'annotation_value': annotation_value
                        })

    return annotations

# Function to load annotations into csv
def fillAnno(TSfile, ANNOfile, colname):
    TSfile[colname] = None
    for row in ANNOfile.iterrows():
        start = float(row[1][0])
        end = float(row[1][1])
        value = str(row[1][2])
        TSfile.loc[(TSfile['time'] >= start) & (TSfile['time'] <= end), colname] = value

# %% [markdown]
# Code to align data with ELAN

# %%
# CREATE TXT FILE FOR EACH TIER FROM ELAN

################
#### arms ######
################


annofolder_manu = curfolder + '/ELAN_anno/'
print(annofolder_manu)
annofiles_manu= glob.glob(annofolder_manu + '*.eaf')

annotations_groundTruth = curfolder + '/annotations_groundTruth/'
os.makedirs(annotations_groundTruth)
arms_anno = curfolder + '/annotations_groundTruth/arms_annotations.txt'

 # skip files that we aren't including: 
toskip = [annofolder_manu + 'rennen_g_ch1_g17_compr.eaf', annofolder_manu + 'langsam_g_ch2_g8_compr.eaf']

with open(arms_anno, 'w') as f:
    for file in annofiles_manu:
        print('working on ' + file)
        # get the filename as the last element
        filename = file.split('\\')[-1]
        # replace _ELAN_tiers.eaf with ''
        filename = filename.replace('_ELAN_tiers.eaf', '')
        print('filename:')
        print(filename)
        print(toskip[0])
        if filename in toskip:
            print("this is faulty file")
            continue
        # parse the file
        annotations = parse_eaf_file(file, 'arms')
        # write the annotations
        for annotation in annotations:
            f.write(f"{annotation['start_time']}\t{annotation['end_time']}\t{annotation['annotation_value']}\t{filename}\n")

###################
#### upper body####
###################

upperbody_anno = curfolder + '/annotations_groundTruth/upperbody_annotations.txt'

with open(upperbody_anno, 'w') as f:
    for file in annofiles_manu:
        print('working on ' + file)
        # get the filename as the last element
        filename = file.split('\\')[-1]
        # replace _ELAN_tiers.eaf with ''
        filename = filename.replace('_ELAN_tiers.eaf', '')
        # parse the file
        if filename in toskip:
            print("this is faulty file")
            continue
        annotations = parse_eaf_file(file, 'upper_body')
        # write the annotations
        for annotation in annotations:
            f.write(f"{annotation['start_time']}\t{annotation['end_time']}\t{annotation['annotation_value']}\t{filename}\n")

###################
#### lower body####
###################

lowerbody_anno = curfolder + '/annotations_groundTruth/lowerbody_annotations.txt'

with open(lowerbody_anno, 'w') as f:
    for file in annofiles_manu:
        print('working on ' + file)
        # get the filename as the last element
        filename = file.split('\\')[-1]
        # replace _ELAN_tiers.eaf with ''
        filename = filename.replace('_ELAN_tiers.eaf', '')
        if filename in toskip:
            print("this is faulty file")
            continue
        # parse the file
        annotations = parse_eaf_file(file, 'lower_body')
        # write the annotations
        for annotation in annotations:
            f.write(f"{annotation['start_time']}\t{annotation['end_time']}\t{annotation['annotation_value']}\t{filename}\n")

###################
##### head ########
###################

head_anno = curfolder + '/annotations_groundTruth/head_annotations.txt'

with open(head_anno, 'w') as f:
    for file in annofiles_manu:
        print('working on ' + file)
        # get the filename as the last element
        filename = file.split('\\')[-1]
        # replace _ELAN_tiers.eaf with ''
        filename = filename.replace('_ELAN_tiers.eaf', '')
        print(filename)
        print(toskip[0])
        if filename in toskip:
            print("this is faulty file")
            continue
        # parse the file
        annotations = parse_eaf_file(file, 'head_mov')
        # write the annotations
        for annotation in annotations:
            f.write(f"{annotation['start_time']}\t{annotation['end_time']}\t{annotation['annotation_value']}\t{filename}\n")
# Out:
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/ELAN_anno/
# working on /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/ELAN_anno/Donner_g_ch3_g15_compr.eaf
# filename:
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/ELAN_anno/Donner_g_ch3_g15_compr.eaf
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/ELAN_anno/rennen_g_ch1_g17_compr.eaf
# working on /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/ELAN_anno/langsam_g_ch1_g20_compr.eaf
# filename:
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/ELAN_anno/langsam_g_ch1_g20_compr.eaf
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/ELAN_anno/rennen_g_ch1_g17_compr.eaf
# working on /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/ELAN_anno/nijmegen_nijmegen_rennen_g_ch1_g17_compr.eaf
# filename:
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/ELAN_anno/nijmegen_nijmegen_rennen_g_ch1_g17_compr.eaf
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/ELAN_anno/rennen_g_ch1_g17_compr.eaf
# working on /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/ELAN_anno/lndw_lndw_rennen_g_ch1_g20_compr.eaf
# filename:
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/ELAN_anno/lndw_lndw_rennen_g_ch1_g20_compr.eaf
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/ELAN_anno/rennen_g_ch1_g17_compr.eaf
# working on /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/ELAN_anno/leise_g_ch3_g11_compr.eaf
# filename:
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/ELAN_anno/leise_g_ch3_g11_compr.eaf
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/ELAN_anno/rennen_g_ch1_g17_compr.eaf
# working on /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/ELAN_anno/kalt_g_ch2_g5_compr.eaf
# filename:
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/ELAN_anno/kalt_g_ch2_g5_compr.eaf
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/ELAN_anno/rennen_g_ch1_g17_compr.eaf
# working on /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/ELAN_anno/stil_g_ch2_g5_compr.eaf
# filename:
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/ELAN_anno/stil_g_ch2_g5_compr.eaf
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/ELAN_anno/rennen_g_ch1_g17_compr.eaf
# working on /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/ELAN_anno/leise_g_ch3_g8_compr.eaf
# filename:
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/ELAN_anno/leise_g_ch3_g8_compr.eaf
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/ELAN_anno/rennen_g_ch1_g17_compr.eaf
# working on /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/ELAN_anno/stil_g_ch1_g6_compr.eaf
# filename:
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/ELAN_anno/stil_g_ch1_g6_compr.eaf
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/ELAN_anno/rennen_g_ch1_g17_compr.eaf
# working on /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/ELAN_anno/kalt_g_ch1_g6_compr.eaf
# filename:
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/ELAN_anno/kalt_g_ch1_g6_compr.eaf
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/ELAN_anno/rennen_g_ch1_g17_compr.eaf
# working on /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/ELAN_anno/kalt_g_ch3_g3_compr.eaf
# filename:
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/ELAN_anno/kalt_g_ch3_g3_compr.eaf
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/ELAN_anno/rennen_g_ch1_g17_compr.eaf
# working on /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/ELAN_anno/onweer_g_ch2_g6_compr.eaf
# filename:
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/ELAN_anno/onweer_g_ch2_g6_compr.eaf
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/ELAN_anno/rennen_g_ch1_g17_compr.eaf
# working on /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/ELAN_anno/lndw_lndw_rennen_g_ch1_g15_compr.eaf
# filename:
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/ELAN_anno/lndw_lndw_rennen_g_ch1_g15_compr.eaf
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/ELAN_anno/rennen_g_ch1_g17_compr.eaf
# working on /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/ELAN_anno/koud_g_ch2_g7_compr.eaf
# filename:
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/ELAN_anno/koud_g_ch2_g7_compr.eaf
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/ELAN_anno/rennen_g_ch1_g17_compr.eaf
# working on /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/ELAN_anno/Donner_g_ch2_g10_compr.eaf
# filename:
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/ELAN_anno/Donner_g_ch2_g10_compr.eaf
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/ELAN_anno/rennen_g_ch1_g17_compr.eaf
# working on /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/ELAN_anno/koud_g_ch1_g4_compr.eaf
# filename:
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/ELAN_anno/koud_g_ch1_g4_compr.eaf
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/ELAN_anno/rennen_g_ch1_g17_compr.eaf
# working on /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/ELAN_anno/onweer_g_ch1_g5_compr.eaf
# filename:
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/ELAN_anno/onweer_g_ch1_g5_compr.eaf
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/ELAN_anno/rennen_g_ch1_g17_compr.eaf
# working on /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/ELAN_anno/langsam_g_ch1_g15_compr.eaf
# filename:
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/ELAN_anno/langsam_g_ch1_g15_compr.eaf
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/ELAN_anno/rennen_g_ch1_g17_compr.eaf
# working on /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/ELAN_anno/Donner_g_ch3_g20_compr.eaf
# filename:
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/ELAN_anno/Donner_g_ch3_g20_compr.eaf
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/ELAN_anno/rennen_g_ch1_g17_compr.eaf
# working on /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/ELAN_anno/stil_g_ch1_g19_compr.eaf
# filename:
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/ELAN_anno/stil_g_ch1_g19_compr.eaf
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/ELAN_anno/rennen_g_ch1_g17_compr.eaf
# working on /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/ELAN_anno/Donner_g_ch1_g5_compr.eaf
# filename:
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/ELAN_anno/Donner_g_ch1_g5_compr.eaf
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/ELAN_anno/rennen_g_ch1_g17_compr.eaf
# working on /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/ELAN_anno/nijmegen_nijmegen_rennen_g_ch1_g8_compr.eaf
# filename:
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/ELAN_anno/nijmegen_nijmegen_rennen_g_ch1_g8_compr.eaf
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/ELAN_anno/rennen_g_ch1_g17_compr.eaf
# working on /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/ELAN_anno/Donner_g_ch2_g6_compr.eaf
# filename:
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/ELAN_anno/Donner_g_ch2_g6_compr.eaf
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/ELAN_anno/rennen_g_ch1_g17_compr.eaf
# working on /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/ELAN_anno/leise_g_ch2_g14_compr.eaf
# filename:
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/ELAN_anno/leise_g_ch2_g14_compr.eaf
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/ELAN_anno/rennen_g_ch1_g17_compr.eaf
# working on /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/ELAN_anno/kalt_g_ch3_g19_compr.eaf
# filename:
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/ELAN_anno/kalt_g_ch3_g19_compr.eaf
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/ELAN_anno/rennen_g_ch1_g17_compr.eaf
# working on /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/ELAN_anno/kalt_g_ch1_g17_compr.eaf
# filename:
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/ELAN_anno/kalt_g_ch1_g17_compr.eaf
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/ELAN_anno/rennen_g_ch1_g17_compr.eaf
# working on /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/ELAN_anno/langsam_g_ch3_g6_compr.eaf
# filename:
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/ELAN_anno/langsam_g_ch3_g6_compr.eaf
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/ELAN_anno/rennen_g_ch1_g17_compr.eaf
# working on /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/ELAN_anno/onweer_g_ch1_g16_compr.eaf
# filename:
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/ELAN_anno/onweer_g_ch1_g16_compr.eaf
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/ELAN_anno/rennen_g_ch1_g17_compr.eaf
# working on /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/ELAN_anno/langsam_g_ch1_g3_compr.eaf
# filename:
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/ELAN_anno/langsam_g_ch1_g3_compr.eaf
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/ELAN_anno/rennen_g_ch1_g17_compr.eaf
# working on /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/ELAN_anno/Donner_g_ch1_g16_compr.eaf
# filename:
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/ELAN_anno/Donner_g_ch1_g16_compr.eaf
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/ELAN_anno/rennen_g_ch1_g17_compr.eaf
# working on /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/ELAN_anno/Donner_g_ch3_g18_compr.eaf
# filename:
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/ELAN_anno/Donner_g_ch3_g18_compr.eaf
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/ELAN_anno/rennen_g_ch1_g17_compr.eaf
# working on /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/ELAN_anno/lndw_lndw_rennen_g_ch2_g13_compr.eaf
# filename:
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/ELAN_anno/lndw_lndw_rennen_g_ch2_g13_compr.eaf
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/ELAN_anno/rennen_g_ch1_g17_compr.eaf
# working on /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/ELAN_anno/langzaam_g_ch1_g10_compr.eaf
# filename:
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/ELAN_anno/langzaam_g_ch1_g10_compr.eaf
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/ELAN_anno/rennen_g_ch1_g17_compr.eaf
# working on /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/ELAN_anno/langsam_g_ch2_g13_compr.eaf
# filename:
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/ELAN_anno/langsam_g_ch2_g13_compr.eaf
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/ELAN_anno/rennen_g_ch1_g17_compr.eaf
# working on /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/ELAN_anno/leise_g_ch1_g12_compr.eaf
# filename:
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/ELAN_anno/leise_g_ch1_g12_compr.eaf
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/ELAN_anno/rennen_g_ch1_g17_compr.eaf
# working on /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/ELAN_anno/leise_g_ch3_g5_compr.eaf
# filename:
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/ELAN_anno/leise_g_ch3_g5_compr.eaf
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/ELAN_anno/rennen_g_ch1_g17_compr.eaf
# working on /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/ELAN_anno/kalt_g_ch2_g11_compr.eaf
# filename:
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/ELAN_anno/kalt_g_ch2_g11_compr.eaf
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/ELAN_anno/rennen_g_ch1_g17_compr.eaf
# working on /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/ELAN_anno/leise_g_ch1_g0_compr.eaf
# filename:
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/ELAN_anno/leise_g_ch1_g0_compr.eaf
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/ELAN_anno/rennen_g_ch1_g17_compr.eaf
# working on /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/ELAN_anno/leise_g_ch2_g3_compr.eaf
# filename:
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/ELAN_anno/leise_g_ch2_g3_compr.eaf
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/ELAN_anno/rennen_g_ch1_g17_compr.eaf
# working on /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/ELAN_anno/kalt_g_ch2_g8_compr.eaf
# filename:
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/ELAN_anno/kalt_g_ch2_g8_compr.eaf
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/ELAN_anno/rennen_g_ch1_g17_compr.eaf
# working on /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/ELAN_anno/lndw_lndw_rennen_g_ch3_g16_compr.eaf
# filename:
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/ELAN_anno/lndw_lndw_rennen_g_ch3_g16_compr.eaf
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/ELAN_anno/rennen_g_ch1_g17_compr.eaf
# working on /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/ELAN_anno/lndw_lndw_rennen_g_ch2_g1_compr.eaf
# filename:
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/ELAN_anno/lndw_lndw_rennen_g_ch2_g1_compr.eaf
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/ELAN_anno/rennen_g_ch1_g17_compr.eaf
# working on /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/ELAN_anno/onweer_g_ch1_g8_compr.eaf
# filename:
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/ELAN_anno/onweer_g_ch1_g8_compr.eaf
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/ELAN_anno/rennen_g_ch1_g17_compr.eaf
# working on /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/ELAN_anno/koud_g_ch1_g9_compr.eaf
# filename:
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/ELAN_anno/koud_g_ch1_g9_compr.eaf
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/ELAN_anno/rennen_g_ch1_g17_compr.eaf
# working on /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/ELAN_anno/lndw_lndw_rennen_g_ch1_g18_compr.eaf
# filename:
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/ELAN_anno/lndw_lndw_rennen_g_ch1_g18_compr.eaf
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/ELAN_anno/rennen_g_ch1_g17_compr.eaf
# working on /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/ELAN_anno/lndw_lndw_rennen_g_ch1_g2_compr.eaf
# filename:
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/ELAN_anno/lndw_lndw_rennen_g_ch1_g2_compr.eaf
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/ELAN_anno/rennen_g_ch1_g17_compr.eaf
# working on /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/ELAN_anno/lndw_lndw_rennen_g_ch3_g7_compr.eaf
# filename:
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/ELAN_anno/lndw_lndw_rennen_g_ch3_g7_compr.eaf
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/ELAN_anno/rennen_g_ch1_g17_compr.eaf
# working on /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/ELAN_anno/langsam_g_ch3_g16_compr.eaf
# filename:
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/ELAN_anno/langsam_g_ch3_g16_compr.eaf
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/ELAN_anno/rennen_g_ch1_g17_compr.eaf
# working on /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/ELAN_anno/stil_g_ch1_g14_compr.eaf
# filename:
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/ELAN_anno/stil_g_ch1_g14_compr.eaf
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/ELAN_anno/rennen_g_ch1_g17_compr.eaf
# working on /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/ELAN_anno/langsam_g_ch1_g18_compr.eaf
# filename:
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/ELAN_anno/langsam_g_ch1_g18_compr.eaf
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/ELAN_anno/rennen_g_ch1_g17_compr.eaf
# working on /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/ELAN_anno/leise_g_ch2_g19_compr.eaf
# filename:
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/ELAN_anno/leise_g_ch2_g19_compr.eaf
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/ELAN_anno/rennen_g_ch1_g17_compr.eaf
# working on /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/ELAN_anno/nijmegen_nijmegen_rennen_g_ch1_g5_compr.eaf
# filename:
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/ELAN_anno/nijmegen_nijmegen_rennen_g_ch1_g5_compr.eaf
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/ELAN_anno/rennen_g_ch1_g17_compr.eaf
# working on /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/ELAN_anno/nijmegen_nijmegen_rennen_g_ch2_g6_compr.eaf
# filename:
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/ELAN_anno/nijmegen_nijmegen_rennen_g_ch2_g6_compr.eaf
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/ELAN_anno/rennen_g_ch1_g17_compr.eaf
# working on /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/ELAN_anno/Donner_g_ch1_g8_compr.eaf
# filename:
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/ELAN_anno/Donner_g_ch1_g8_compr.eaf
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/ELAN_anno/rennen_g_ch1_g17_compr.eaf
# working on /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/ELAN_anno/langzaam_g_ch1_g1_compr.eaf
# filename:
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/ELAN_anno/langzaam_g_ch1_g1_compr.eaf
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/ELAN_anno/rennen_g_ch1_g17_compr.eaf
# working on /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/ELAN_anno/koud_g_ch1_g12_compr.eaf
# filename:
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/ELAN_anno/koud_g_ch1_g12_compr.eaf
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/ELAN_anno/rennen_g_ch1_g17_compr.eaf
# working on /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/ELAN_anno/kalt_g_ch3_g14_compr.eaf
# filename:
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/ELAN_anno/kalt_g_ch3_g14_compr.eaf
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/ELAN_anno/rennen_g_ch1_g17_compr.eaf
# working on /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/ELAN_anno/langzaam_g_ch2_g2_compr.eaf
# filename:
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/ELAN_anno/langzaam_g_ch2_g2_compr.eaf
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/ELAN_anno/rennen_g_ch1_g17_compr.eaf
# working on /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/ELAN_anno/langsam_g_ch1_g13_compr.eaf
# filename:
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/ELAN_anno/langsam_g_ch1_g13_compr.eaf
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/ELAN_anno/rennen_g_ch1_g17_compr.eaf
# working on /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/ELAN_anno/lndw_lndw_rennen_g_ch1_g13_compr.eaf
# filename:
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/ELAN_anno/lndw_lndw_rennen_g_ch1_g13_compr.eaf
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/ELAN_anno/rennen_g_ch1_g17_compr.eaf
# working on /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/ELAN_anno/koud_g_ch2_g1_compr.eaf
# filename:
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/ELAN_anno/koud_g_ch2_g1_compr.eaf
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/ELAN_anno/rennen_g_ch1_g17_compr.eaf
# working on /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/ELAN_anno/lndw_lndw_rennen_g_ch1_g9_compr.eaf
# filename:
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/ELAN_anno/lndw_lndw_rennen_g_ch1_g9_compr.eaf
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/ELAN_anno/rennen_g_ch1_g17_compr.eaf
# working on /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/ELAN_anno/onweer_g_ch1_g3_compr.eaf
# filename:
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/ELAN_anno/onweer_g_ch1_g3_compr.eaf
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/ELAN_anno/rennen_g_ch1_g17_compr.eaf
# working on /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/ELAN_anno/koud_g_ch1_g2_compr.eaf
# filename:
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/ELAN_anno/koud_g_ch1_g2_compr.eaf
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/ELAN_anno/rennen_g_ch1_g17_compr.eaf
# working on /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/ELAN_anno/Donner_g_ch2_g16_compr.eaf
# filename:
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/ELAN_anno/Donner_g_ch2_g16_compr.eaf
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/ELAN_anno/rennen_g_ch1_g17_compr.eaf
# working on /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/ELAN_anno/koud_g_ch1_g19_compr.eaf
# filename:
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/ELAN_anno/koud_g_ch1_g19_compr.eaf
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/ELAN_anno/rennen_g_ch1_g17_compr.eaf
# working on /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/ELAN_anno/langsam_g_ch2_g6_compr.eaf
# filename:
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/ELAN_anno/langsam_g_ch2_g6_compr.eaf
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/ELAN_anno/rennen_g_ch1_g17_compr.eaf
# working on /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/ELAN_anno/onweer_g_ch1_g10_compr.eaf
# filename:
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/ELAN_anno/onweer_g_ch1_g10_compr.eaf
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/ELAN_anno/rennen_g_ch1_g17_compr.eaf
# working on /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/ELAN_anno/langsam_g_ch1_g5_compr.eaf
# filename:
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/ELAN_anno/langsam_g_ch1_g5_compr.eaf
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/ELAN_anno/rennen_g_ch1_g17_compr.eaf
# working on /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/ELAN_anno/kalt_g_ch1_g11_compr.eaf
# filename:
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/ELAN_anno/kalt_g_ch1_g11_compr.eaf
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/ELAN_anno/rennen_g_ch1_g17_compr.eaf
# working on /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/ELAN_anno/Donner_g_ch3_g6_compr.eaf
# filename:
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/ELAN_anno/Donner_g_ch3_g6_compr.eaf
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/ELAN_anno/rennen_g_ch1_g17_compr.eaf
# working on /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/ELAN_anno/Donner_g_ch1_g3_compr.eaf
# filename:
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/ELAN_anno/Donner_g_ch1_g3_compr.eaf
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/ELAN_anno/rennen_g_ch1_g17_compr.eaf
# working on /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/ELAN_anno/leise_g_ch2_g12_compr.eaf
# filename:
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/ELAN_anno/leise_g_ch2_g12_compr.eaf
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/ELAN_anno/rennen_g_ch1_g17_compr.eaf
# working on /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/ELAN_anno/nijmegen_nijmegen_rennen_g_ch1_g11_compr.eaf
# filename:
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/ELAN_anno/nijmegen_nijmegen_rennen_g_ch1_g11_compr.eaf
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/ELAN_anno/rennen_g_ch1_g17_compr.eaf
# working on /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/ELAN_anno/langsam_g_ch2_g18_compr.eaf
# filename:
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/ELAN_anno/langsam_g_ch2_g18_compr.eaf
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/ELAN_anno/rennen_g_ch1_g17_compr.eaf
# working on /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/ELAN_anno/Donner_g_ch3_g13_compr.eaf
# filename:
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/ELAN_anno/Donner_g_ch3_g13_compr.eaf
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/ELAN_anno/rennen_g_ch1_g17_compr.eaf
# working on /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/ELAN_anno/lndw_lndw_rennen_g_ch2_g18_compr.eaf
# filename:
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/ELAN_anno/lndw_lndw_rennen_g_ch2_g18_compr.eaf
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/ELAN_anno/rennen_g_ch1_g17_compr.eaf
# working on /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/ELAN_anno/stil_g_ch2_g3_compr.eaf
# filename:
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/ELAN_anno/stil_g_ch2_g3_compr.eaf
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/ELAN_anno/rennen_g_ch1_g17_compr.eaf
# working on /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/ELAN_anno/leise_g_ch2_g8_compr.eaf
# filename:
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/ELAN_anno/leise_g_ch2_g8_compr.eaf
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/ELAN_anno/rennen_g_ch1_g17_compr.eaf
# working on /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/ELAN_anno/kalt_g_ch2_g3_compr.eaf
# filename:
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/ELAN_anno/kalt_g_ch2_g3_compr.eaf
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/ELAN_anno/rennen_g_ch1_g17_compr.eaf
# working on /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/ELAN_anno/kalt_g_ch3_g5_compr.eaf
# filename:
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/ELAN_anno/kalt_g_ch3_g5_compr.eaf
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/ELAN_anno/rennen_g_ch1_g17_compr.eaf
# working on /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/ELAN_anno/kalt_g_ch1_g0_compr.eaf
# filename:
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/ELAN_anno/kalt_g_ch1_g0_compr.eaf
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/ELAN_anno/rennen_g_ch1_g17_compr.eaf
# working on /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/ELAN_anno/leise_g_ch3_g17_compr.eaf
# filename:
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/ELAN_anno/leise_g_ch3_g17_compr.eaf
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/ELAN_anno/rennen_g_ch1_g17_compr.eaf
# working on /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/ELAN_anno/leise_g_ch1_g19_compr.eaf
# filename:
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/ELAN_anno/leise_g_ch1_g19_compr.eaf
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/ELAN_anno/rennen_g_ch1_g17_compr.eaf
# working on /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/ELAN_anno/stil_g_ch1_g12_compr.eaf
# filename:
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/ELAN_anno/stil_g_ch1_g12_compr.eaf
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/ELAN_anno/rennen_g_ch1_g17_compr.eaf
# working on /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/ELAN_anno/langsam_g_ch3_g10_compr.eaf
# filename:
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/ELAN_anno/langsam_g_ch3_g10_compr.eaf
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/ELAN_anno/rennen_g_ch1_g17_compr.eaf
# working on /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/ELAN_anno/lndw_lndw_rennen_g_ch2_g20_compr.eaf
# filename:
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/ELAN_anno/lndw_lndw_rennen_g_ch2_g20_compr.eaf
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/ELAN_anno/rennen_g_ch1_g17_compr.eaf
# working on /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/ELAN_anno/lndw_lndw_rennen_g_ch2_g7_compr.eaf
# filename:
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/ELAN_anno/lndw_lndw_rennen_g_ch2_g7_compr.eaf
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/ELAN_anno/rennen_g_ch1_g17_compr.eaf
# working on /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/ELAN_anno/langsam_g_ch2_g20_compr.eaf
# filename:
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/ELAN_anno/langsam_g_ch2_g20_compr.eaf
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/ELAN_anno/rennen_g_ch1_g17_compr.eaf
# working on /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/ELAN_anno/lndw_lndw_rennen_g_ch3_g10_compr.eaf
# filename:
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/ELAN_anno/lndw_lndw_rennen_g_ch3_g10_compr.eaf
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/ELAN_anno/rennen_g_ch1_g17_compr.eaf
# working on /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/ELAN_anno/lndw_lndw_rennen_g_ch3_g1_compr.eaf
# filename:
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/ELAN_anno/lndw_lndw_rennen_g_ch3_g1_compr.eaf
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/ELAN_anno/rennen_g_ch1_g17_compr.eaf
# working on /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/ELAN_anno/lndw_lndw_rennen_g_ch1_g4_compr.eaf
# filename:
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/ELAN_anno/lndw_lndw_rennen_g_ch1_g4_compr.eaf
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/ELAN_anno/rennen_g_ch1_g17_compr.eaf
# working on /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/ELAN_anno/langzaam_g_ch1_g7_compr.eaf
# filename:
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/ELAN_anno/langzaam_g_ch1_g7_compr.eaf
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/ELAN_anno/rennen_g_ch1_g17_compr.eaf
# working on /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/ELAN_anno/langsam_g_ch1_g8_compr.eaf
# filename:
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/ELAN_anno/langsam_g_ch1_g8_compr.eaf
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/ELAN_anno/rennen_g_ch1_g17_compr.eaf
# working on /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/ELAN_anno/langzaam_g_ch2_g4_compr.eaf
# filename:
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/ELAN_anno/langzaam_g_ch2_g4_compr.eaf
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/ELAN_anno/rennen_g_ch1_g17_compr.eaf
# working on /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/ELAN_anno/koud_g_ch1_g14_compr.eaf
# filename:
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/ELAN_anno/koud_g_ch1_g14_compr.eaf
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/ELAN_anno/rennen_g_ch1_g17_compr.eaf
# working on /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/ELAN_anno/kalt_g_ch3_g12_compr.eaf
# filename:
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/ELAN_anno/kalt_g_ch3_g12_compr.eaf
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/ELAN_anno/rennen_g_ch1_g17_compr.eaf
# working on /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/ELAN_anno/nijmegen_nijmegen_rennen_g_ch1_g3_compr.eaf
# filename:
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/ELAN_anno/nijmegen_nijmegen_rennen_g_ch1_g3_compr.eaf
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/ELAN_anno/rennen_g_ch1_g17_compr.eaf
# working on /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/ELAN_anno/langzaam_g_ch1_g16_compr.eaf
# filename:
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/ELAN_anno/langzaam_g_ch1_g16_compr.eaf
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/ELAN_anno/rennen_g_ch1_g17_compr.eaf
# working on /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/ELAN_anno/langsam_g_ch2_g15_compr.eaf
# filename:
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/ELAN_anno/langsam_g_ch2_g15_compr.eaf
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/ELAN_anno/rennen_g_ch1_g17_compr.eaf
# working on /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/ELAN_anno/Donner_g_ch1_g10_compr.eaf
# filename:
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/ELAN_anno/Donner_g_ch1_g10_compr.eaf
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/ELAN_anno/rennen_g_ch1_g17_compr.eaf
# working on /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/ELAN_anno/lndw_lndw_rennen_g_ch2_g15_compr.eaf
# filename:
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/ELAN_anno/lndw_lndw_rennen_g_ch2_g15_compr.eaf
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/ELAN_anno/rennen_g_ch1_g17_compr.eaf
# working on /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/ELAN_anno/leise_g_ch1_g6_compr.eaf
# filename:
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/ELAN_anno/leise_g_ch1_g6_compr.eaf
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/ELAN_anno/rennen_g_ch1_g17_compr.eaf
# working on /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/ELAN_anno/leise_g_ch3_g3_compr.eaf
# filename:
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/ELAN_anno/leise_g_ch3_g3_compr.eaf
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/ELAN_anno/rennen_g_ch1_g17_compr.eaf
# working on /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/ELAN_anno/kalt_g_ch2_g17_compr.eaf
# filename:
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/ELAN_anno/kalt_g_ch2_g17_compr.eaf
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/ELAN_anno/rennen_g_ch1_g17_compr.eaf
# working on /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/ELAN_anno/kalt_g_ch3_g8_compr.eaf
# filename:
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/ELAN_anno/kalt_g_ch3_g8_compr.eaf
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/ELAN_anno/rennen_g_ch1_g17_compr.eaf
# working on /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/ELAN_anno/leise_g_ch2_g5_compr.eaf
# filename:
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/ELAN_anno/leise_g_ch2_g5_compr.eaf
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/ELAN_anno/rennen_g_ch1_g17_compr.eaf
# working on /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/ELAN_anno/leise_g_ch1_g14_compr.eaf
# filename:
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/ELAN_anno/leise_g_ch1_g14_compr.eaf
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/ELAN_anno/rennen_g_ch1_g17_compr.eaf
# working on /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/ELAN_anno/leise_g_ch3_g10_compr.eaf
# filename:
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/ELAN_anno/leise_g_ch3_g10_compr.eaf
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/ELAN_anno/rennen_g_ch1_g17_compr.eaf
# working on /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/ELAN_anno/stil_g_ch2_g4_compr.eaf
# filename:
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/ELAN_anno/stil_g_ch2_g4_compr.eaf
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/ELAN_anno/rennen_g_ch1_g17_compr.eaf
# working on /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/ELAN_anno/leise_g_ch2_g20_compr.eaf
# filename:
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/ELAN_anno/leise_g_ch2_g20_compr.eaf
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/ELAN_anno/rennen_g_ch1_g17_compr.eaf
# working on /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/ELAN_anno/kalt_g_ch2_g4_compr.eaf
# filename:
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/ELAN_anno/kalt_g_ch2_g4_compr.eaf
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/ELAN_anno/rennen_g_ch1_g17_compr.eaf
# working on /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/ELAN_anno/kalt_g_ch1_g7_compr.eaf
# filename:
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/ELAN_anno/kalt_g_ch1_g7_compr.eaf
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/ELAN_anno/rennen_g_ch1_g17_compr.eaf
# working on /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/ELAN_anno/kalt_g_ch3_g2_compr.eaf
# filename:
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/ELAN_anno/kalt_g_ch3_g2_compr.eaf
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/ELAN_anno/rennen_g_ch1_g17_compr.eaf
# working on /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/ELAN_anno/leise_g_ch3_g9_compr.eaf
# filename:
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/ELAN_anno/leise_g_ch3_g9_compr.eaf
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/ELAN_anno/rennen_g_ch1_g17_compr.eaf
# working on /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/ELAN_anno/stil_g_ch1_g7_compr.eaf
# filename:
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/ELAN_anno/stil_g_ch1_g7_compr.eaf
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/ELAN_anno/rennen_g_ch1_g17_compr.eaf
# working on /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/ELAN_anno/Donner_g_ch3_g14_compr.eaf
# filename:
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/ELAN_anno/Donner_g_ch3_g14_compr.eaf
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/ELAN_anno/rennen_g_ch1_g17_compr.eaf
# working on /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/ELAN_anno/nijmegen_nijmegen_rennen_g_ch1_g16_compr.eaf
# filename:
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/ELAN_anno/nijmegen_nijmegen_rennen_g_ch1_g16_compr.eaf
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/ELAN_anno/rennen_g_ch1_g17_compr.eaf
# working on /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/ELAN_anno/Donner_g_ch1_g4_compr.eaf
# filename:
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/ELAN_anno/Donner_g_ch1_g4_compr.eaf
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/ELAN_anno/rennen_g_ch1_g17_compr.eaf
# ...
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/ELAN_anno/kalt_g_ch1_g12_compr.eaf
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/ELAN_anno/rennen_g_ch1_g17_compr.eaf
# working on /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/ELAN_anno/langsam_g_ch3_g3_compr.eaf
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/ELAN_anno/langsam_g_ch3_g3_compr.eaf
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/ELAN_anno/rennen_g_ch1_g17_compr.eaf
# working on /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/ELAN_anno/langzaam_g_ch1_g9_compr.eaf
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/ELAN_anno/langzaam_g_ch1_g9_compr.eaf
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/ELAN_anno/rennen_g_ch1_g17_compr.eaf
# working on /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/ELAN_anno/onweer_g_ch1_g13_compr.eaf
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/ELAN_anno/onweer_g_ch1_g13_compr.eaf
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/ELAN_anno/rennen_g_ch1_g17_compr.eaf
# working on /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/ELAN_anno/langsam_g_ch1_g6_compr.eaf
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/ELAN_anno/langsam_g_ch1_g6_compr.eaf
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/ELAN_anno/rennen_g_ch1_g17_compr.eaf
# working on /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/ELAN_anno/langsam_g_ch2_g5_compr.eaf
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/ELAN_anno/langsam_g_ch2_g5_compr.eaf
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/ELAN_anno/rennen_g_ch1_g17_compr.eaf
# working on /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/ELAN_anno/Donner_g_ch2_g3_compr.eaf
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/ELAN_anno/Donner_g_ch2_g3_compr.eaf
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/ELAN_anno/rennen_g_ch1_g17_compr.eaf
# working on /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/ELAN_anno/leise_g_ch2_g11_compr.eaf
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/ELAN_anno/leise_g_ch2_g11_compr.eaf
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/ELAN_anno/rennen_g_ch1_g17_compr.eaf
# working on /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/ELAN_anno/Donner_g_ch1_g0_compr.eaf
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/ELAN_anno/Donner_g_ch1_g0_compr.eaf
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/ELAN_anno/rennen_g_ch1_g17_compr.eaf
# working on /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/ELAN_anno/Donner_g_ch3_g5_compr.eaf
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/ELAN_anno/Donner_g_ch3_g5_compr.eaf
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/ELAN_anno/rennen_g_ch1_g17_compr.eaf
# working on /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/ELAN_anno/langsam_g_ch1_g10_compr.eaf
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/ELAN_anno/langsam_g_ch1_g10_compr.eaf
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/ELAN_anno/rennen_g_ch1_g17_compr.eaf
# working on /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/ELAN_anno/Donner_g_ch2_g15_compr.eaf
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/ELAN_anno/Donner_g_ch2_g15_compr.eaf
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/ELAN_anno/rennen_g_ch1_g17_compr.eaf
# working on /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/ELAN_anno/koud_g_ch1_g1_compr.eaf
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/ELAN_anno/koud_g_ch1_g1_compr.eaf
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/ELAN_anno/rennen_g_ch1_g17_compr.eaf
# working on /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/ELAN_anno/lndw_lndw_rennen_g_ch2_g9_compr.eaf
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/ELAN_anno/lndw_lndw_rennen_g_ch2_g9_compr.eaf
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/ELAN_anno/rennen_g_ch1_g17_compr.eaf
# working on /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/ELAN_anno/onweer_g_ch2_g3_compr.eaf
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/ELAN_anno/onweer_g_ch2_g3_compr.eaf
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/ELAN_anno/rennen_g_ch1_g17_compr.eaf
# working on /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/ELAN_anno/lndw_lndw_rennen_g_ch1_g10_compr.eaf
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/ELAN_anno/lndw_lndw_rennen_g_ch1_g10_compr.eaf
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/ELAN_anno/rennen_g_ch1_g17_compr.eaf
# working on /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/ELAN_anno/koud_g_ch2_g2_compr.eaf
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/ELAN_anno/koud_g_ch2_g2_compr.eaf
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/ELAN_anno/rennen_g_ch1_g17_compr.eaf
# working on /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/ELAN_anno/leise_g_ch2_g6_compr.eaf
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/ELAN_anno/leise_g_ch2_g6_compr.eaf
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/ELAN_anno/rennen_g_ch1_g17_compr.eaf
# working on /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/ELAN_anno/kalt_g_ch2_g14_compr.eaf
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/ELAN_anno/kalt_g_ch2_g14_compr.eaf
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/ELAN_anno/rennen_g_ch1_g17_compr.eaf
# working on /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/ELAN_anno/leise_g_ch1_g5_compr.eaf
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/ELAN_anno/leise_g_ch1_g5_compr.eaf
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/ELAN_anno/rennen_g_ch1_g17_compr.eaf
# working on /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/ELAN_anno/leise_g_ch3_g19_compr.eaf
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/ELAN_anno/leise_g_ch3_g19_compr.eaf
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/ELAN_anno/rennen_g_ch1_g17_compr.eaf
# working on /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/ELAN_anno/leise_g_ch1_g17_compr.eaf
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/ELAN_anno/leise_g_ch1_g17_compr.eaf
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/ELAN_anno/rennen_g_ch1_g17_compr.eaf
# working on /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/ELAN_anno/langsam_g_ch2_g16_compr.eaf
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/ELAN_anno/langsam_g_ch2_g16_compr.eaf
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/ELAN_anno/rennen_g_ch1_g17_compr.eaf
# working on /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/ELAN_anno/langzaam_g_ch1_g15_compr.eaf
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/ELAN_anno/langzaam_g_ch1_g15_compr.eaf
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/ELAN_anno/rennen_g_ch1_g17_compr.eaf
# working on /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/ELAN_anno/lndw_lndw_rennen_g_ch2_g16_compr.eaf
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/ELAN_anno/lndw_lndw_rennen_g_ch2_g16_compr.eaf
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/ELAN_anno/rennen_g_ch1_g17_compr.eaf
# working on /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/ELAN_anno/Donner_g_ch1_g13_compr.eaf
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/ELAN_anno/Donner_g_ch1_g13_compr.eaf
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/ELAN_anno/rennen_g_ch1_g17_compr.eaf
# working on /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/ELAN_anno/koud_g_ch1_g17_compr.eaf
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/ELAN_anno/koud_g_ch1_g17_compr.eaf
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/ELAN_anno/rennen_g_ch1_g17_compr.eaf
# working on /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/ELAN_anno/kalt_g_ch3_g11_compr.eaf
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/ELAN_anno/kalt_g_ch3_g11_compr.eaf
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/ELAN_anno/rennen_g_ch1_g17_compr.eaf
# working on /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/ELAN_anno/langzaam_g_ch2_g7_compr.eaf
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/ELAN_anno/langzaam_g_ch2_g7_compr.eaf
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/ELAN_anno/rennen_g_ch1_g17_compr.eaf
# working on /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/ELAN_anno/langsam_g_ch2_g8_compr.eaf
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/ELAN_anno/langsam_g_ch2_g8_compr.eaf
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/ELAN_anno/rennen_g_ch1_g17_compr.eaf
# this is faulty file
# working on /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/ELAN_anno/langzaam_g_ch1_g4_compr.eaf
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/ELAN_anno/langzaam_g_ch1_g4_compr.eaf
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/ELAN_anno/rennen_g_ch1_g17_compr.eaf
# working on /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/ELAN_anno/nijmegen_nijmegen_rennen_g_ch2_g3_compr.eaf
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/ELAN_anno/nijmegen_nijmegen_rennen_g_ch2_g3_compr.eaf
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/ELAN_anno/rennen_g_ch1_g17_compr.eaf
# working on /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/ELAN_anno/Donner_g_ch3_g8_compr.eaf
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/ELAN_anno/Donner_g_ch3_g8_compr.eaf
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/ELAN_anno/rennen_g_ch1_g17_compr.eaf
# working on /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/ELAN_anno/stil_g_ch1_g11_compr.eaf
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/ELAN_anno/stil_g_ch1_g11_compr.eaf
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/ELAN_anno/rennen_g_ch1_g17_compr.eaf
# working on /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/ELAN_anno/langsam_g_ch3_g13_compr.eaf
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/ELAN_anno/langsam_g_ch3_g13_compr.eaf
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/ELAN_anno/rennen_g_ch1_g17_compr.eaf
# working on /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/ELAN_anno/langzaam_g_ch1_g20_compr.eaf
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/ELAN_anno/langzaam_g_ch1_g20_compr.eaf
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/ELAN_anno/rennen_g_ch1_g17_compr.eaf
# working on /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/ELAN_anno/lndw_lndw_rennen_g_ch1_g7_compr.eaf
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/ELAN_anno/lndw_lndw_rennen_g_ch1_g7_compr.eaf
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/ELAN_anno/rennen_g_ch1_g17_compr.eaf
# working on /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/ELAN_anno/lndw_lndw_rennen_g_ch3_g2_compr.eaf
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/ELAN_anno/lndw_lndw_rennen_g_ch3_g2_compr.eaf
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/ELAN_anno/rennen_g_ch1_g17_compr.eaf
# working on /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/ELAN_anno/lndw_lndw_rennen_g_ch3_g13_compr.eaf
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/ELAN_anno/lndw_lndw_rennen_g_ch3_g13_compr.eaf
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/ELAN_anno/rennen_g_ch1_g17_compr.eaf
# working on /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/ELAN_anno/lndw_lndw_rennen_g_ch2_g4_compr.eaf
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/ELAN_anno/lndw_lndw_rennen_g_ch2_g4_compr.eaf
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/ELAN_anno/rennen_g_ch1_g17_compr.eaf
# working on /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/ELAN_anno/Donner_g_ch2_g18_compr.eaf
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/ELAN_anno/Donner_g_ch2_g18_compr.eaf
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/ELAN_anno/rennen_g_ch1_g17_compr.eaf

# %% [markdown]
# Merge the annotations with the data

# %%
# # ADD THE MOVEMENT ANNOTATION FROM TXTFILE TO THE DATAFRAME/CSV FILE THAT WE CREATED BY THE PROCESSING SCRIPT

# These are the annotations per tier that we just created from manual annotations
arms_anno = curfolder + '/annotations_groundTruth/arms_annotations.txt'
upperbody_anno = curfolder + '/annotations_groundTruth/upperbody_annotations.txt'
lowerbody_anno = curfolder + '/annotations_groundTruth/lowerbody_annotations.txt'
head_anno = curfolder + '/annotations_groundTruth/head_annotations.txt'

curfolder = os.getcwd()
processedfolder = curfolder + '/TS_processed/'
processedfiles = glob.glob(processedfolder + '*.csv')

movementfolder = curfolder + '/TS_movement/'
os.makedirs(movementfolder)

#videos that we need to leave out due to error so I will skip them
toskip = [processedfolder + 'rennen_g_ch1_g17_compr', processedfolder + 'langsam_g_ch2_g8_compr', processedfolder + 'langsam_g_ch2_g19_compr']

for file in processedfiles:
    print('working on ' + file)

    # TrialID
    trialid = file.split('\\')[-1].split('.')[0]

    if trialid in toskip:
        print("this is faulty file")
        continue

    trialid = trialid.replace('TS_processed', 'ELAN_anno')
    #trialid = trialid.replace('merged_', '')
    trialid = trialid + '.eaf'

    # Load the merged file
    merged = pd.read_csv(file)
    
    # Load the annotations as df
    arms = pd.read_csv(arms_anno, sep='\t', header=None)
    ub = pd.read_csv(upperbody_anno, sep='\t', header=None)
    lb = pd.read_csv(lowerbody_anno, sep='\t', header=None)
    head = pd.read_csv(head_anno, sep='\t', header=None)

    
    annos = [arms, ub, lb, head]

    # Loop over each tier and fill values into timeseries
    for anno_df in annos:
        # Get the annotations for the trialid
        anno_trial = anno_df[anno_df[3] == trialid] 
        
        if anno_trial.empty:
            print("empty")
            print('no annotations for ' + trialid)
            #add a column
            continue
        
        else:
            if anno_df.equals(arms):
                fillAnno(merged, anno_trial, 'arms')
            elif anno_df.equals(ub):
                fillAnno(merged, anno_trial, 'upper_body')
            elif anno_df.equals(lb):
                fillAnno(merged, anno_trial, 'lower_body')
            elif anno_df.equals(head):
                fillAnno(merged, anno_trial, 'head_mov')
            else:
                print('something went wrong')

    df = merged.copy()
    # check if each column exists in the dataframe
    col1 = 'arms'
    col2 = 'upper_body'
    col3 = 'lower_body'
    col4 = 'head_mov'
    # create a column if it doesn't exist. If it does, switch the labels. 
    if col1 not in df:
        df[col1] = 'no movement'
    else:
        df['arms'] = df['arms'].fillna('no movement')

    if col2 not in df:
        df[col2] = 'no movement'
    else:
        df['upper_body'] = df['upper_body'].fillna('no movement')

    if col3 not in df:
        df[col3] = 'no movement'
    else:
        df['lower_body'] = df['lower_body'].fillna('no movement')

    if col4 not in df:
        df[col4] = 'no movement'
    else:
        df['head_mov'] = df['head_mov'].fillna('no movement')

    # save the dataframe to TS movement
    fileID = trialid.replace('/ELAN_anno/', '/TS_movement/')
    print(fileID)
    globals()[fileID] = df
    globals()[fileID].to_csv(os.path.join(movementfolder, f'{fileID}.csv'), index=False)
# Out:
# working on /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/TS_processed/langsam_g_ch3_g7_compr.mp4.csv
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/TS_movement/langsam_g_ch3_g7_compr.eaf
# working on /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/TS_processed/Donner_g_ch2_g12_compr.mp4.csv
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/TS_movement/Donner_g_ch2_g12_compr.eaf
# working on /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/TS_processed/kalt_g_ch3_g19_compr.mp4.csv
# empty
# no annotations for /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/ELAN_anno/kalt_g_ch3_g19_compr.eaf
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/TS_movement/kalt_g_ch3_g19_compr.eaf
# working on /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/TS_processed/langsam_g_ch3_g12_compr.mp4.csv
# empty
# no annotations for /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/ELAN_anno/langsam_g_ch3_g12_compr.eaf
# empty
# no annotations for /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/ELAN_anno/langsam_g_ch3_g12_compr.eaf
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/TS_movement/langsam_g_ch3_g12_compr.eaf
# working on /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/TS_processed/lndw_lndw_rennen_g_ch1_g1_compr.mp4.csv
# empty
# no annotations for /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/ELAN_anno/lndw_lndw_rennen_g_ch1_g1_compr.eaf
# empty
# no annotations for /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/ELAN_anno/lndw_lndw_rennen_g_ch1_g1_compr.eaf
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/TS_movement/lndw_lndw_rennen_g_ch1_g1_compr.eaf
# working on /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/TS_processed/leise_g_ch1_g0_compr.mp4.csv
# empty
# no annotations for /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/ELAN_anno/leise_g_ch1_g0_compr.eaf
# empty
# no annotations for /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/ELAN_anno/leise_g_ch1_g0_compr.eaf
# empty
# no annotations for /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/ELAN_anno/leise_g_ch1_g0_compr.eaf
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/TS_movement/leise_g_ch1_g0_compr.eaf
# working on /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/TS_processed/lndw_lndw_rennen_g_ch2_g16_compr.mp4.csv
# empty
# no annotations for /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/ELAN_anno/lndw_lndw_rennen_g_ch2_g16_compr.eaf
# empty
# no annotations for /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/ELAN_anno/lndw_lndw_rennen_g_ch2_g16_compr.eaf
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/TS_movement/lndw_lndw_rennen_g_ch2_g16_compr.eaf
# working on /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/TS_processed/koud_g_ch1_g13_compr.mp4.csv
# empty
# no annotations for /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/ELAN_anno/koud_g_ch1_g13_compr.eaf
# empty
# no annotations for /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/ELAN_anno/koud_g_ch1_g13_compr.eaf
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/TS_movement/koud_g_ch1_g13_compr.eaf
# working on /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/TS_processed/langsam_g_ch1_g8_compr.mp4.csv
# empty
# no annotations for /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/ELAN_anno/langsam_g_ch1_g8_compr.eaf
# empty
# no annotations for /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/ELAN_anno/langsam_g_ch1_g8_compr.eaf
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/TS_movement/langsam_g_ch1_g8_compr.eaf
# working on /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/TS_processed/kalt_g_ch1_g14_compr.mp4.csv
# empty
# no annotations for /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/ELAN_anno/kalt_g_ch1_g14_compr.eaf
# empty
# no annotations for /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/ELAN_anno/kalt_g_ch1_g14_compr.eaf
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/TS_movement/kalt_g_ch1_g14_compr.eaf
# working on /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/TS_processed/onweer_g_ch1_g16_compr.mp4.csv
# empty
# no annotations for /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/ELAN_anno/onweer_g_ch1_g16_compr.eaf
# empty
# no annotations for /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/ELAN_anno/onweer_g_ch1_g16_compr.eaf
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/TS_movement/onweer_g_ch1_g16_compr.eaf
# working on /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/TS_processed/leise_g_ch2_g6_compr.mp4.csv
# empty
# no annotations for /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/ELAN_anno/leise_g_ch2_g6_compr.eaf
# empty
# no annotations for /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/ELAN_anno/leise_g_ch2_g6_compr.eaf
# empty
# no annotations for /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/ELAN_anno/leise_g_ch2_g6_compr.eaf
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/TS_movement/leise_g_ch2_g6_compr.eaf
# working on /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/TS_processed/lndw_lndw_rennen_g_ch2_g7_compr.mp4.csv
# empty
# no annotations for /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/ELAN_anno/lndw_lndw_rennen_g_ch2_g7_compr.eaf
# empty
# no annotations for /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/ELAN_anno/lndw_lndw_rennen_g_ch2_g7_compr.eaf
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/TS_movement/lndw_lndw_rennen_g_ch2_g7_compr.eaf
# working on /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/TS_processed/langzaam_g_ch1_g15_compr.mp4.csv
# empty
# no annotations for /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/ELAN_anno/langzaam_g_ch1_g15_compr.eaf
# empty
# no annotations for /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/ELAN_anno/langzaam_g_ch1_g15_compr.eaf
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/TS_movement/langzaam_g_ch1_g15_compr.eaf
# working on /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/TS_processed/kalt_g_ch3_g20_compr.mp4.csv
# empty
# no annotations for /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/ELAN_anno/kalt_g_ch3_g20_compr.eaf
# empty
# no annotations for /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/ELAN_anno/kalt_g_ch3_g20_compr.eaf
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/TS_movement/kalt_g_ch3_g20_compr.eaf
# working on /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/TS_processed/leise_g_ch1_g13_compr.mp4.csv
# empty
# no annotations for /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/ELAN_anno/leise_g_ch1_g13_compr.eaf
# empty
# no annotations for /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/ELAN_anno/leise_g_ch1_g13_compr.eaf
# empty
# no annotations for /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/ELAN_anno/leise_g_ch1_g13_compr.eaf
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/TS_movement/leise_g_ch1_g13_compr.eaf
# working on /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/TS_processed/langzaam_g_ch1_g6_compr.mp4.csv
# empty
# no annotations for /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/ELAN_anno/langzaam_g_ch1_g6_compr.eaf
# empty
# no annotations for /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/ELAN_anno/langzaam_g_ch1_g6_compr.eaf
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/TS_movement/langzaam_g_ch1_g6_compr.eaf
# working on /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/TS_processed/nijmegen_nijmegen_rennen_g_ch1_g13_compr.mp4.csv
# empty
# no annotations for /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/ELAN_anno/nijmegen_nijmegen_rennen_g_ch1_g13_compr.eaf
# empty
# no annotations for /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/ELAN_anno/nijmegen_nijmegen_rennen_g_ch1_g13_compr.eaf
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/TS_movement/nijmegen_nijmegen_rennen_g_ch1_g13_compr.eaf
# working on /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/TS_processed/onweer_g_ch1_g12_compr.mp4.csv
# empty
# no annotations for /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/ELAN_anno/onweer_g_ch1_g12_compr.eaf
# empty
# no annotations for /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/ELAN_anno/onweer_g_ch1_g12_compr.eaf
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/TS_movement/onweer_g_ch1_g12_compr.eaf
# working on /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/TS_processed/langzaam_g_ch2_g4_compr.mp4.csv
# empty
# no annotations for /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/ELAN_anno/langzaam_g_ch2_g4_compr.eaf
# empty
# no annotations for /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/ELAN_anno/langzaam_g_ch2_g4_compr.eaf
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/TS_movement/langzaam_g_ch2_g4_compr.eaf
# working on /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/TS_processed/kalt_g_ch1_g10_compr.mp4.csv
# empty
# no annotations for /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/ELAN_anno/kalt_g_ch1_g10_compr.eaf
# empty
# no annotations for /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/ELAN_anno/kalt_g_ch1_g10_compr.eaf
# empty
# no annotations for /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/ELAN_anno/kalt_g_ch1_g10_compr.eaf
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/TS_movement/kalt_g_ch1_g10_compr.eaf
# working on /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/TS_processed/koud_g_ch1_g17_compr.mp4.csv
# empty
# no annotations for /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/ELAN_anno/koud_g_ch1_g17_compr.eaf
# empty
# no annotations for /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/ELAN_anno/koud_g_ch1_g17_compr.eaf
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/TS_movement/koud_g_ch1_g17_compr.eaf
# working on /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/TS_processed/lndw_lndw_rennen_g_ch2_g12_compr.mp4.csv
# empty
# no annotations for /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/ELAN_anno/lndw_lndw_rennen_g_ch2_g12_compr.eaf
# empty
# no annotations for /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/ELAN_anno/lndw_lndw_rennen_g_ch2_g12_compr.eaf
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/TS_movement/lndw_lndw_rennen_g_ch2_g12_compr.eaf
# working on /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/TS_processed/lndw_lndw_rennen_g_ch1_g5_compr.mp4.csv
# empty
# no annotations for /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/ELAN_anno/lndw_lndw_rennen_g_ch1_g5_compr.eaf
# empty
# no annotations for /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/ELAN_anno/lndw_lndw_rennen_g_ch1_g5_compr.eaf
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/TS_movement/lndw_lndw_rennen_g_ch1_g5_compr.eaf
# working on /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/TS_processed/langsam_g_ch3_g16_compr.mp4.csv
# empty
# no annotations for /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/ELAN_anno/langsam_g_ch3_g16_compr.eaf
# empty
# no annotations for /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/ELAN_anno/langsam_g_ch3_g16_compr.eaf
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/TS_movement/langsam_g_ch3_g16_compr.eaf
# working on /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/TS_processed/leise_g_ch1_g4_compr.mp4.csv
# empty
# no annotations for /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/ELAN_anno/leise_g_ch1_g4_compr.eaf
# empty
# no annotations for /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/ELAN_anno/leise_g_ch1_g4_compr.eaf
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/TS_movement/leise_g_ch1_g4_compr.eaf
# working on /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/TS_processed/Donner_g_ch2_g16_compr.mp4.csv
# empty
# no annotations for /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/ELAN_anno/Donner_g_ch2_g16_compr.eaf
# empty
# no annotations for /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/ELAN_anno/Donner_g_ch2_g16_compr.eaf
# empty
# no annotations for /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/ELAN_anno/Donner_g_ch2_g16_compr.eaf
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/TS_movement/Donner_g_ch2_g16_compr.eaf
# working on /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/TS_processed/langsam_g_ch3_g3_compr.mp4.csv
# empty
# no annotations for /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/ELAN_anno/langsam_g_ch3_g3_compr.eaf
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/TS_movement/langsam_g_ch3_g3_compr.eaf
# working on /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/TS_processed/nijmegen_nijmegen_rennen_g_ch1_g17_compr.mp4.csv
# empty
# no annotations for /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/ELAN_anno/nijmegen_nijmegen_rennen_g_ch1_g17_compr.eaf
# empty
# no annotations for /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/ELAN_anno/nijmegen_nijmegen_rennen_g_ch1_g17_compr.eaf
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/TS_movement/nijmegen_nijmegen_rennen_g_ch1_g17_compr.eaf
# working on /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/TS_processed/langzaam_g_ch1_g2_compr.mp4.csv
# empty
# no annotations for /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/ELAN_anno/langzaam_g_ch1_g2_compr.eaf
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/TS_movement/langzaam_g_ch1_g2_compr.eaf
# working on /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/TS_processed/leise_g_ch1_g17_compr.mp4.csv
# empty
# no annotations for /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/ELAN_anno/leise_g_ch1_g17_compr.eaf
# empty
# no annotations for /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/ELAN_anno/leise_g_ch1_g17_compr.eaf
# empty
# no annotations for /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/ELAN_anno/leise_g_ch1_g17_compr.eaf
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/TS_movement/leise_g_ch1_g17_compr.eaf
# working on /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/TS_processed/langzaam_g_ch1_g11_compr.mp4.csv
# empty
# no annotations for /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/ELAN_anno/langzaam_g_ch1_g11_compr.eaf
# empty
# no annotations for /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/ELAN_anno/langzaam_g_ch1_g11_compr.eaf
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/TS_movement/langzaam_g_ch1_g11_compr.eaf
# working on /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/TS_processed/leise_g_ch2_g2_compr.mp4.csv
# empty
# no annotations for /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/ELAN_anno/leise_g_ch2_g2_compr.eaf
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/TS_movement/leise_g_ch2_g2_compr.eaf
# working on /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/TS_processed/lndw_lndw_rennen_g_ch2_g3_compr.mp4.csv
# empty
# no annotations for /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/ELAN_anno/lndw_lndw_rennen_g_ch2_g3_compr.eaf
# empty
# no annotations for /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/ELAN_anno/lndw_lndw_rennen_g_ch2_g3_compr.eaf
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/TS_movement/lndw_lndw_rennen_g_ch2_g3_compr.eaf
# working on /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/TS_processed/Donner_g_ch2_g9_compr.mp4.csv
# empty
# no annotations for /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/ELAN_anno/Donner_g_ch2_g9_compr.eaf
# empty
# no annotations for /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/ELAN_anno/Donner_g_ch2_g9_compr.eaf
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/TS_movement/Donner_g_ch2_g9_compr.eaf
# working on /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/TS_processed/lndw_lndw_rennen_g_ch3_g15_compr.mp4.csv
# empty
# no annotations for /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/ELAN_anno/lndw_lndw_rennen_g_ch3_g15_compr.eaf
# empty
# no annotations for /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/ELAN_anno/lndw_lndw_rennen_g_ch3_g15_compr.eaf
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/TS_movement/lndw_lndw_rennen_g_ch3_g15_compr.eaf
# working on /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/TS_processed/nijmegen_nijmegen_rennen_g_ch1_g6_compr.mp4.csv
# empty
# no annotations for /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/ELAN_anno/nijmegen_nijmegen_rennen_g_ch1_g6_compr.eaf
# empty
# no annotations for /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/ELAN_anno/nijmegen_nijmegen_rennen_g_ch1_g6_compr.eaf
# empty
# no annotations for /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/ELAN_anno/nijmegen_nijmegen_rennen_g_ch1_g6_compr.eaf
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/TS_movement/nijmegen_nijmegen_rennen_g_ch1_g6_compr.eaf
# working on /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/TS_processed/stil_g_ch1_g6_compr.mp4.csv
# empty
# no annotations for /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/ELAN_anno/stil_g_ch1_g6_compr.eaf
# empty
# no annotations for /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/ELAN_anno/stil_g_ch1_g6_compr.eaf
# empty
# no annotations for /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/ELAN_anno/stil_g_ch1_g6_compr.eaf
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/TS_movement/stil_g_ch1_g6_compr.eaf
# working on /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/TS_processed/kalt_g_ch3_g5_compr.mp4.csv
# empty
# no annotations for /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/ELAN_anno/kalt_g_ch3_g5_compr.eaf
# empty
# no annotations for /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/ELAN_anno/kalt_g_ch3_g5_compr.eaf
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/TS_movement/kalt_g_ch3_g5_compr.eaf
# working on /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/TS_processed/langsam_g_ch2_g11_compr.mp4.csv
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/TS_movement/langsam_g_ch2_g11_compr.eaf
# working on /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/TS_processed/lndw_lndw_rennen_g_ch1_g18_compr.mp4.csv
# empty
# no annotations for /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/ELAN_anno/lndw_lndw_rennen_g_ch1_g18_compr.eaf
# empty
# no annotations for /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/ELAN_anno/lndw_lndw_rennen_g_ch1_g18_compr.eaf
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/TS_movement/lndw_lndw_rennen_g_ch1_g18_compr.eaf
# working on /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/TS_processed/Donner_g_ch3_g11_compr.mp4.csv
# empty
# no annotations for /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/ELAN_anno/Donner_g_ch3_g11_compr.eaf
# empty
# no annotations for /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/ELAN_anno/Donner_g_ch3_g11_compr.eaf
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/TS_movement/Donner_g_ch3_g11_compr.eaf
# working on /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/TS_processed/stil_g_ch1_g11_compr.mp4.csv
# empty
# no annotations for /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/ELAN_anno/stil_g_ch1_g11_compr.eaf
# empty
# no annotations for /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/ELAN_anno/stil_g_ch1_g11_compr.eaf
# empty
# no annotations for /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/ELAN_anno/stil_g_ch1_g11_compr.eaf
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/TS_movement/stil_g_ch1_g11_compr.eaf
# working on /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/TS_processed/Donner_g_ch3_g15_compr.mp4.csv
# empty
# no annotations for /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/ELAN_anno/Donner_g_ch3_g15_compr.eaf
# empty
# no annotations for /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/ELAN_anno/Donner_g_ch3_g15_compr.eaf
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/TS_movement/Donner_g_ch3_g15_compr.eaf
# working on /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/TS_processed/kalt_g_ch3_g1_compr.mp4.csv
# empty
# no annotations for /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/ELAN_anno/kalt_g_ch3_g1_compr.eaf
# empty
# no annotations for /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/ELAN_anno/kalt_g_ch3_g1_compr.eaf
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/TS_movement/kalt_g_ch3_g1_compr.eaf
# working on /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/TS_processed/langsam_g_ch2_g15_compr.mp4.csv
# empty
# no annotations for /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/ELAN_anno/langsam_g_ch2_g15_compr.eaf
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/TS_movement/langsam_g_ch2_g15_compr.eaf
# working on /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/TS_processed/nijmegen_nijmegen_rennen_g_ch1_g2_compr.mp4.csv
# empty
# no annotations for /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/ELAN_anno/nijmegen_nijmegen_rennen_g_ch1_g2_compr.eaf
# empty
# no annotations for /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/ELAN_anno/nijmegen_nijmegen_rennen_g_ch1_g2_compr.eaf
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/TS_movement/nijmegen_nijmegen_rennen_g_ch1_g2_compr.eaf
# working on /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/TS_processed/stil_g_ch1_g2_compr.mp4.csv
# empty
# no annotations for /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/ELAN_anno/stil_g_ch1_g2_compr.eaf
# empty
# no annotations for /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/ELAN_anno/stil_g_ch1_g2_compr.eaf
# empty
# no annotations for /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/ELAN_anno/stil_g_ch1_g2_compr.eaf
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/TS_movement/stil_g_ch1_g2_compr.eaf
# working on /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/TS_processed/Donner_g_ch1_g18_compr.mp4.csv
# empty
# no annotations for /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/ELAN_anno/Donner_g_ch1_g18_compr.eaf
# empty
# no annotations for /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/ELAN_anno/Donner_g_ch1_g18_compr.eaf
# empty
# no annotations for /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/ELAN_anno/Donner_g_ch1_g18_compr.eaf
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/TS_movement/Donner_g_ch1_g18_compr.eaf
# working on /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/TS_processed/lndw_lndw_rennen_g_ch3_g11_compr.mp4.csv
# empty
# no annotations for /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/ELAN_anno/lndw_lndw_rennen_g_ch3_g11_compr.eaf
# empty
# no annotations for /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/ELAN_anno/lndw_lndw_rennen_g_ch3_g11_compr.eaf
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/TS_movement/lndw_lndw_rennen_g_ch3_g11_compr.eaf
# working on /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/TS_processed/leise_g_ch2_g20_compr.mp4.csv
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/TS_movement/leise_g_ch2_g20_compr.eaf
# working on /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/TS_processed/stil_g_ch2_g4_compr.mp4.csv
# empty
# no annotations for /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/ELAN_anno/stil_g_ch2_g4_compr.eaf
# empty
# no annotations for /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/ELAN_anno/stil_g_ch2_g4_compr.eaf
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/TS_movement/stil_g_ch2_g4_compr.eaf
# working on /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/TS_processed/nijmegen_nijmegen_rennen_g_ch2_g4_compr.mp4.csv
# empty
# no annotations for /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/ELAN_anno/nijmegen_nijmegen_rennen_g_ch2_g4_compr.eaf
# empty
# no annotations for /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/ELAN_anno/nijmegen_nijmegen_rennen_g_ch2_g4_compr.eaf
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/TS_movement/nijmegen_nijmegen_rennen_g_ch2_g4_compr.eaf
# working on /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/TS_processed/Donner_g_ch3_g4_compr.mp4.csv
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/TS_movement/Donner_g_ch3_g4_compr.eaf
# working on /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/TS_processed/leise_g_ch2_g19_compr.mp4.csv
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/TS_movement/leise_g_ch2_g19_compr.eaf
# working on /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/TS_processed/stil_g_ch1_g15_compr.mp4.csv
# empty
# no annotations for /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/ELAN_anno/stil_g_ch1_g15_compr.eaf
# empty
# no annotations for /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/ELAN_anno/stil_g_ch1_g15_compr.eaf
# empty
# no annotations for /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/ELAN_anno/stil_g_ch1_g15_compr.eaf
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/TS_movement/stil_g_ch1_g15_compr.eaf
# working on /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/TS_processed/kalt_g_ch2_g8_compr.mp4.csv
# empty
# no annotations for /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/ELAN_anno/kalt_g_ch2_g8_compr.eaf
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/TS_movement/kalt_g_ch2_g8_compr.eaf
# working on /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/TS_processed/Donner_g_ch3_g12_compr.mp4.csv
# empty
# no annotations for /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/ELAN_anno/Donner_g_ch3_g12_compr.eaf
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/TS_movement/Donner_g_ch3_g12_compr.eaf
# working on /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/TS_processed/langsam_g_ch2_g12_compr.mp4.csv
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/TS_movement/langsam_g_ch2_g12_compr.eaf
# working on /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/TS_processed/kalt_g_ch3_g6_compr.mp4.csv
# empty
# no annotations for /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/ELAN_anno/kalt_g_ch3_g6_compr.eaf
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/TS_movement/kalt_g_ch3_g6_compr.eaf
# working on /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/TS_processed/nijmegen_nijmegen_rennen_g_ch1_g5_compr.mp4.csv
# empty
# no annotations for /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/ELAN_anno/nijmegen_nijmegen_rennen_g_ch1_g5_compr.eaf
# empty
# no annotations for /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/ELAN_anno/nijmegen_nijmegen_rennen_g_ch1_g5_compr.eaf
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/TS_movement/nijmegen_nijmegen_rennen_g_ch1_g5_compr.eaf
# working on /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/TS_processed/kalt_g_ch2_g19_compr.mp4.csv
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/TS_movement/kalt_g_ch2_g19_compr.eaf
# working on /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/TS_processed/stil_g_ch1_g5_compr.mp4.csv
# empty
# no annotations for /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/ELAN_anno/stil_g_ch1_g5_compr.eaf
# empty
# no annotations for /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/ELAN_anno/stil_g_ch1_g5_compr.eaf
# empty
# no annotations for /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/ELAN_anno/stil_g_ch1_g5_compr.eaf
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/TS_movement/stil_g_ch1_g5_compr.eaf
# working on /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/TS_processed/kalt_g_ch1_g9_compr.mp4.csv
# empty
# no annotations for /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/ELAN_anno/kalt_g_ch1_g9_compr.eaf
# empty
# no annotations for /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/ELAN_anno/kalt_g_ch1_g9_compr.eaf
# empty
# no annotations for /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/ELAN_anno/kalt_g_ch1_g9_compr.eaf
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/TS_movement/kalt_g_ch1_g9_compr.eaf
# working on /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/TS_processed/lndw_lndw_rennen_g_ch3_g16_compr.mp4.csv
# empty
# no annotations for /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/ELAN_anno/lndw_lndw_rennen_g_ch3_g16_compr.eaf
# empty
# no annotations for /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/ELAN_anno/lndw_lndw_rennen_g_ch3_g16_compr.eaf
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/TS_movement/lndw_lndw_rennen_g_ch3_g16_compr.eaf
# working on /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/TS_processed/stil_g_ch2_g3_compr.mp4.csv
# empty
# no annotations for /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/ELAN_anno/stil_g_ch2_g3_compr.eaf
# empty
# no annotations for /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/ELAN_anno/stil_g_ch2_g3_compr.eaf
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/TS_movement/stil_g_ch2_g3_compr.eaf
# working on /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/TS_processed/nijmegen_nijmegen_rennen_g_ch2_g3_compr.mp4.csv
# empty
# no annotations for /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/ELAN_anno/nijmegen_nijmegen_rennen_g_ch2_g3_compr.eaf
# empty
# no annotations for /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/ELAN_anno/nijmegen_nijmegen_rennen_g_ch2_g3_compr.eaf
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/TS_movement/nijmegen_nijmegen_rennen_g_ch2_g3_compr.eaf
# working on /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/TS_processed/Donner_g_ch3_g3_compr.mp4.csv
# empty
# no annotations for /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/ELAN_anno/Donner_g_ch3_g3_compr.eaf
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/TS_movement/Donner_g_ch3_g3_compr.eaf
# working on /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/TS_processed/kalt_g_ch2_g20_compr.mp4.csv
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/TS_movement/kalt_g_ch2_g20_compr.eaf
# working on /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/TS_processed/stil_g_ch1_g12_compr.mp4.csv
# empty
# no annotations for /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/ELAN_anno/stil_g_ch1_g12_compr.eaf
# empty
# no annotations for /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/ELAN_anno/stil_g_ch1_g12_compr.eaf
# empty
# no annotations for /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/ELAN_anno/stil_g_ch1_g12_compr.eaf
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/TS_movement/stil_g_ch1_g12_compr.eaf
# working on /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/TS_processed/lndw_lndw_rennen_g_ch3_g12_compr.mp4.csv
# empty
# no annotations for /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/ELAN_anno/lndw_lndw_rennen_g_ch3_g12_compr.eaf
# empty
# no annotations for /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/ELAN_anno/lndw_lndw_rennen_g_ch3_g12_compr.eaf
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/TS_movement/lndw_lndw_rennen_g_ch3_g12_compr.eaf
# working on /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/TS_processed/nijmegen_nijmegen_rennen_g_ch1_g1_compr.mp4.csv
# empty
# no annotations for /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/ELAN_anno/nijmegen_nijmegen_rennen_g_ch1_g1_compr.eaf
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/TS_movement/nijmegen_nijmegen_rennen_g_ch1_g1_compr.eaf
# working on /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/TS_processed/stil_g_ch1_g1_compr.mp4.csv
# empty
# no annotations for /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/ELAN_anno/stil_g_ch1_g1_compr.eaf
# empty
# no annotations for /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/ELAN_anno/stil_g_ch1_g1_compr.eaf
# empty
# no annotations for /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/ELAN_anno/stil_g_ch1_g1_compr.eaf
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/TS_movement/stil_g_ch1_g1_compr.eaf
# working on /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/TS_processed/langsam_g_ch2_g16_compr.mp4.csv
# empty
# no annotations for /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/ELAN_anno/langsam_g_ch2_g16_compr.eaf
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/TS_movement/langsam_g_ch2_g16_compr.eaf
# working on /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/TS_processed/kalt_g_ch3_g2_compr.mp4.csv
# empty
# no annotations for /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/ELAN_anno/kalt_g_ch3_g2_compr.eaf
# empty
# no annotations for /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/ELAN_anno/kalt_g_ch3_g2_compr.eaf
# empty
# no annotations for /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/ELAN_anno/kalt_g_ch3_g2_compr.eaf
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/TS_movement/kalt_g_ch3_g2_compr.eaf
# working on /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/TS_processed/Donner_g_ch3_g16_compr.mp4.csv
# empty
# no annotations for /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/ELAN_anno/Donner_g_ch3_g16_compr.eaf
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/TS_movement/Donner_g_ch3_g16_compr.eaf
# working on /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/TS_processed/stil_g_ch1_g16_compr.mp4.csv
# empty
# no annotations for /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/ELAN_anno/stil_g_ch1_g16_compr.eaf
# empty
# no annotations for /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/ELAN_anno/stil_g_ch1_g16_compr.eaf
# empty
# no annotations for /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/ELAN_anno/stil_g_ch1_g16_compr.eaf
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/TS_movement/stil_g_ch1_g16_compr.eaf
# working on /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/TS_processed/Donner_g_ch1_g8_compr.mp4.csv
# empty
# no annotations for /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/ELAN_anno/Donner_g_ch1_g8_compr.eaf
# empty
# no annotations for /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/ELAN_anno/Donner_g_ch1_g8_compr.eaf
# empty
# no annotations for /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/ELAN_anno/Donner_g_ch1_g8_compr.eaf
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/TS_movement/Donner_g_ch1_g8_compr.eaf
# working on /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/TS_processed/Donner_g_ch3_g7_compr.mp4.csv
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/TS_movement/Donner_g_ch3_g7_compr.eaf
# working on /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/TS_processed/onweer_g_ch1_g9_compr.mp4.csv
# empty
# no annotations for /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/ELAN_anno/onweer_g_ch1_g9_compr.eaf
# empty
# no annotations for /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/ELAN_anno/onweer_g_ch1_g9_compr.eaf
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/TS_movement/onweer_g_ch1_g9_compr.eaf
# working on /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/TS_processed/stil_g_ch2_g7_compr.mp4.csv
# empty
# no annotations for /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/ELAN_anno/stil_g_ch2_g7_compr.eaf
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/TS_movement/stil_g_ch2_g7_compr.eaf
# working on /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/TS_processed/nijmegen_nijmegen_rennen_g_ch2_g7_compr.mp4.csv
# empty
# no annotations for /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/ELAN_anno/nijmegen_nijmegen_rennen_g_ch2_g7_compr.eaf
# empty
# no annotations for /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/ELAN_anno/nijmegen_nijmegen_rennen_g_ch2_g7_compr.eaf
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/TS_movement/nijmegen_nijmegen_rennen_g_ch2_g7_compr.eaf
# working on /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/TS_processed/onweer_g_ch1_g15_compr.mp4.csv
# empty
# no annotations for /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/ELAN_anno/onweer_g_ch1_g15_compr.eaf
# empty
# no annotations for /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/ELAN_anno/onweer_g_ch1_g15_compr.eaf
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/TS_movement/onweer_g_ch1_g15_compr.eaf
# working on /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/TS_processed/kalt_g_ch1_g17_compr.mp4.csv
# empty
# no annotations for /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/ELAN_anno/kalt_g_ch1_g17_compr.eaf
# empty
# no annotations for /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/ELAN_anno/kalt_g_ch1_g17_compr.eaf
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/TS_movement/kalt_g_ch1_g17_compr.eaf
# working on /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/TS_processed/langzaam_g_ch2_g3_compr.mp4.csv
# empty
# no annotations for /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/ELAN_anno/langzaam_g_ch2_g3_compr.eaf
# empty
# no annotations for /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/ELAN_anno/langzaam_g_ch2_g3_compr.eaf
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/TS_movement/langzaam_g_ch2_g3_compr.eaf
# working on /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/TS_processed/koud_g_ch1_g10_compr.mp4.csv
# empty
# no annotations for /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/ELAN_anno/koud_g_ch1_g10_compr.eaf
# empty
# no annotations for /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/ELAN_anno/koud_g_ch1_g10_compr.eaf
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/TS_movement/koud_g_ch1_g10_compr.eaf
# ...
# empty
# no annotations for /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/ELAN_anno/leise_g_ch1_g1_compr.eaf
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/TS_movement/leise_g_ch1_g1_compr.eaf
# working on /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/TS_processed/kalt_g_ch3_g18_compr.mp4.csv
# empty
# no annotations for /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/ELAN_anno/kalt_g_ch3_g18_compr.eaf
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/TS_movement/kalt_g_ch3_g18_compr.eaf
# working on /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/TS_processed/Donner_g_ch1_g20_compr.mp4.csv
# empty
# no annotations for /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/ELAN_anno/Donner_g_ch1_g20_compr.eaf
# empty
# no annotations for /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/ELAN_anno/Donner_g_ch1_g20_compr.eaf
# empty
# no annotations for /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/ELAN_anno/Donner_g_ch1_g20_compr.eaf
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/TS_movement/Donner_g_ch1_g20_compr.eaf
# working on /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/TS_processed/stil_g_ch1_g14_compr.mp4.csv
# empty
# no annotations for /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/ELAN_anno/stil_g_ch1_g14_compr.eaf
# empty
# no annotations for /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/ELAN_anno/stil_g_ch1_g14_compr.eaf
# empty
# no annotations for /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/ELAN_anno/stil_g_ch1_g14_compr.eaf
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/TS_movement/stil_g_ch1_g14_compr.eaf
# working on /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/TS_processed/kalt_g_ch2_g9_compr.mp4.csv
# empty
# no annotations for /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/ELAN_anno/kalt_g_ch2_g9_compr.eaf
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/TS_movement/kalt_g_ch2_g9_compr.eaf
# working on /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/TS_processed/leise_g_ch2_g18_compr.mp4.csv
# empty
# no annotations for /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/ELAN_anno/leise_g_ch2_g18_compr.eaf
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/TS_movement/leise_g_ch2_g18_compr.eaf
# working on /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/TS_processed/stil_g_ch2_g5_compr.mp4.csv
# empty
# no annotations for /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/ELAN_anno/stil_g_ch2_g5_compr.eaf
# empty
# no annotations for /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/ELAN_anno/stil_g_ch2_g5_compr.eaf
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/TS_movement/stil_g_ch2_g5_compr.eaf
# working on /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/TS_processed/nijmegen_nijmegen_rennen_g_ch2_g5_compr.mp4.csv
# empty
# no annotations for /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/ELAN_anno/nijmegen_nijmegen_rennen_g_ch2_g5_compr.eaf
# empty
# no annotations for /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/ELAN_anno/nijmegen_nijmegen_rennen_g_ch2_g5_compr.eaf
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/TS_movement/nijmegen_nijmegen_rennen_g_ch2_g5_compr.eaf
# working on /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/TS_processed/Donner_g_ch3_g5_compr.mp4.csv
# empty
# no annotations for /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/ELAN_anno/Donner_g_ch3_g5_compr.eaf
# empty
# no annotations for /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/ELAN_anno/Donner_g_ch3_g5_compr.eaf
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/TS_movement/Donner_g_ch3_g5_compr.eaf
# working on /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/TS_processed/lndw_lndw_rennen_g_ch3_g10_compr.mp4.csv
# empty
# no annotations for /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/ELAN_anno/lndw_lndw_rennen_g_ch3_g10_compr.eaf
# empty
# no annotations for /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/ELAN_anno/lndw_lndw_rennen_g_ch3_g10_compr.eaf
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/TS_movement/lndw_lndw_rennen_g_ch3_g10_compr.eaf
# working on /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/TS_processed/Donner_g_ch1_g19_compr.mp4.csv
# empty
# no annotations for /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/ELAN_anno/Donner_g_ch1_g19_compr.eaf
# empty
# no annotations for /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/ELAN_anno/Donner_g_ch1_g19_compr.eaf
# empty
# no annotations for /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/ELAN_anno/Donner_g_ch1_g19_compr.eaf
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/TS_movement/Donner_g_ch1_g19_compr.eaf
# working on /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/TS_processed/Donner_g_ch3_g14_compr.mp4.csv
# empty
# no annotations for /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/ELAN_anno/Donner_g_ch3_g14_compr.eaf
# empty
# no annotations for /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/ELAN_anno/Donner_g_ch3_g14_compr.eaf
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/TS_movement/Donner_g_ch3_g14_compr.eaf
# working on /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/TS_processed/nijmegen_nijmegen_rennen_g_ch1_g3_compr.mp4.csv
# empty
# no annotations for /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/ELAN_anno/nijmegen_nijmegen_rennen_g_ch1_g3_compr.eaf
# empty
# no annotations for /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/ELAN_anno/nijmegen_nijmegen_rennen_g_ch1_g3_compr.eaf
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/TS_movement/nijmegen_nijmegen_rennen_g_ch1_g3_compr.eaf
# working on /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/TS_processed/stil_g_ch1_g3_compr.mp4.csv
# empty
# no annotations for /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/ELAN_anno/stil_g_ch1_g3_compr.eaf
# empty
# no annotations for /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/ELAN_anno/stil_g_ch1_g3_compr.eaf
# empty
# no annotations for /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/ELAN_anno/stil_g_ch1_g3_compr.eaf
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/TS_movement/stil_g_ch1_g3_compr.eaf
# working on /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/TS_processed/langsam_g_ch2_g14_compr.mp4.csv
# empty
# no annotations for /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/ELAN_anno/langsam_g_ch2_g14_compr.eaf
# empty
# no annotations for /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/ELAN_anno/langsam_g_ch2_g14_compr.eaf
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/TS_movement/langsam_g_ch2_g14_compr.eaf
# working on /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/TS_processed/Donner_g_ch3_g1_compr.mp4.csv
# empty
# no annotations for /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/ELAN_anno/Donner_g_ch3_g1_compr.eaf
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/TS_movement/Donner_g_ch3_g1_compr.eaf
# working on /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/TS_processed/stil_g_ch2_g1_compr.mp4.csv
# empty
# no annotations for /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/ELAN_anno/stil_g_ch2_g1_compr.eaf
# empty
# no annotations for /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/ELAN_anno/stil_g_ch2_g1_compr.eaf
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/TS_movement/stil_g_ch2_g1_compr.eaf
# working on /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/TS_processed/lndw_lndw_rennen_g_ch1_g20_compr.mp4.csv
# empty
# no annotations for /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/ELAN_anno/lndw_lndw_rennen_g_ch1_g20_compr.eaf
# empty
# no annotations for /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/ELAN_anno/lndw_lndw_rennen_g_ch1_g20_compr.eaf
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/TS_movement/lndw_lndw_rennen_g_ch1_g20_compr.eaf
# working on /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/TS_processed/nijmegen_nijmegen_rennen_g_ch2_g1_compr.mp4.csv
# empty
# no annotations for /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/ELAN_anno/nijmegen_nijmegen_rennen_g_ch2_g1_compr.eaf
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/TS_movement/nijmegen_nijmegen_rennen_g_ch2_g1_compr.eaf
# working on /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/TS_processed/stil_g_ch1_g10_compr.mp4.csv
# empty
# no annotations for /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/ELAN_anno/stil_g_ch1_g10_compr.eaf
# empty
# no annotations for /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/ELAN_anno/stil_g_ch1_g10_compr.eaf
# empty
# no annotations for /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/ELAN_anno/stil_g_ch1_g10_compr.eaf
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/TS_movement/stil_g_ch1_g10_compr.eaf
# working on /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/TS_processed/kalt_g_ch3_g4_compr.mp4.csv
# empty
# no annotations for /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/ELAN_anno/kalt_g_ch3_g4_compr.eaf
# empty
# no annotations for /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/ELAN_anno/kalt_g_ch3_g4_compr.eaf
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/TS_movement/kalt_g_ch3_g4_compr.eaf
# working on /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/TS_processed/langsam_g_ch2_g10_compr.mp4.csv
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/TS_movement/langsam_g_ch2_g10_compr.eaf
# working on /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/TS_processed/nijmegen_nijmegen_rennen_g_ch1_g7_compr.mp4.csv
# empty
# no annotations for /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/ELAN_anno/nijmegen_nijmegen_rennen_g_ch1_g7_compr.eaf
# empty
# no annotations for /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/ELAN_anno/nijmegen_nijmegen_rennen_g_ch1_g7_compr.eaf
# empty
# no annotations for /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/ELAN_anno/nijmegen_nijmegen_rennen_g_ch1_g7_compr.eaf
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/TS_movement/nijmegen_nijmegen_rennen_g_ch1_g7_compr.eaf
# working on /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/TS_processed/stil_g_ch1_g7_compr.mp4.csv
# empty
# no annotations for /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/ELAN_anno/stil_g_ch1_g7_compr.eaf
# empty
# no annotations for /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/ELAN_anno/stil_g_ch1_g7_compr.eaf
# empty
# no annotations for /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/ELAN_anno/stil_g_ch1_g7_compr.eaf
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/TS_movement/stil_g_ch1_g7_compr.eaf
# working on /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/TS_processed/Donner_g_ch3_g10_compr.mp4.csv
# empty
# no annotations for /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/ELAN_anno/Donner_g_ch3_g10_compr.eaf
# empty
# no annotations for /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/ELAN_anno/Donner_g_ch3_g10_compr.eaf
# empty
# no annotations for /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/ELAN_anno/Donner_g_ch3_g10_compr.eaf
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/TS_movement/Donner_g_ch3_g10_compr.eaf
# working on /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/TS_processed/lndw_lndw_rennen_g_ch1_g19_compr.mp4.csv
# empty
# no annotations for /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/ELAN_anno/lndw_lndw_rennen_g_ch1_g19_compr.eaf
# empty
# no annotations for /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/ELAN_anno/lndw_lndw_rennen_g_ch1_g19_compr.eaf
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/TS_movement/lndw_lndw_rennen_g_ch1_g19_compr.eaf
# working on /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/TS_processed/Donner_g_ch2_g8_compr.mp4.csv
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/TS_movement/Donner_g_ch2_g8_compr.eaf
# working on /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/TS_processed/lndw_lndw_rennen_g_ch3_g14_compr.mp4.csv
# empty
# no annotations for /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/ELAN_anno/lndw_lndw_rennen_g_ch3_g14_compr.eaf
# empty
# no annotations for /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/ELAN_anno/lndw_lndw_rennen_g_ch3_g14_compr.eaf
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/TS_movement/lndw_lndw_rennen_g_ch3_g14_compr.eaf

# %% [markdown]
# # Visualization in 2D

# %%
sample2 = '/Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/TS_movement/kalt_g_ch2_g1_compr.eaf.csv'
sample2 = pd.read_csv(sample2)
movement_sample2 = sample2[sample2['head_mov'] == 'movement']
#cols = ['X_NOSE', 'Y_NOSE', 'Z_NOSE']
cols = movement_sample2.columns
cols = cols.drop(['time', 'fileID', 'participantID'])
cols = [col for col in cols if '_velocity' not in col]
cols = [col for col in cols if '_speed2D' not in col]
cols = [col for col in cols if '_speed' not in col]
cols = [col for col in cols if '_acceleration2D' not in col]
cols = [col for col in cols if '_acceleration' not in col]
cols = [col for col in cols if '_jerk2D' not in col]
cols = [col for col in cols if '_jerk' not in col]

animation2D(sample2[cols])

# %% [markdown]
# ## Graphing a column

# %%
## plotting the left wrist and right wist for Donner ch1 g1: 

current_csv = pd.read_csv("/Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/Motion_Processing_Folder/TS_processed/onweer_g_ch1_g2_compr.mp4.csv")
Y_left = current_csv['Y_LEFT_WRIST']
Y_right = current_csv['Y_RIGHT_WRIST']

plt.plot(Y_left)
plt.plot(Y_right)
plt.show()
