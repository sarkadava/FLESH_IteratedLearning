# %% [markdown]
# ## PREPARATION

# %%
import os
import glob

curfolder = os.getcwd()
print(curfolder)

# this is our mt data C:\Users\kadava\Documents\Github\FLESH_3Dtracking_new\projectdata
## MT
datafolder = curfolder + '/TS_motiontracking/'
vidfolder = curfolder + '/Videos/'
acfolder = curfolder + '/TS_acoustics/'

mttotrack = glob.glob(datafolder + 'mt*.csv', recursive=True)
bbtotrack = glob.glob(datafolder + 'bb*.csv', recursive=True)
idtotrack = glob.glob(datafolder + 'id*.csv', recursive=True)
iktotrack = glob.glob(datafolder + 'ik*.csv', recursive=True)
vidtotrack = glob.glob(vidfolder + '*.avi', recursive=True)
envtotrack = glob.glob(acfolder + 'env*.csv', recursive=True)
f0totrack = glob.glob(acfolder + 'f0*.csv', recursive=True)

print(mttotrack)
print(idtotrack)
print(vidtotrack)
print(bbtotrack)
# Out:
# e:\FLESH_ContinuousBodilyEffort\TS_processing
# ['e:\\FLESH_ContinuousBodilyEffort\\TS_processing/TS_motiontracking\\mt_0_1_0_p0.csv', 'e:\\FLESH_ContinuousBodilyEffort\\TS_processing/TS_motiontracking\\mt_0_1_18_p0.csv', 'e:\\FLESH_ContinuousBodilyEffort\\TS_processing/TS_motiontracking\\mt_0_1_19_p0.csv', 'e:\\FLESH_ContinuousBodilyEffort\\TS_processing/TS_motiontracking\\mt_0_1_1_p0.csv', 'e:\\FLESH_ContinuousBodilyEffort\\TS_processing/TS_motiontracking\\mt_0_1_20_p0.csv', 'e:\\FLESH_ContinuousBodilyEffort\\TS_processing/TS_motiontracking\\mt_0_1_21_p0.csv', 'e:\\FLESH_ContinuousBodilyEffort\\TS_processing/TS_motiontracking\\mt_0_1_22_p0.csv', 'e:\\FLESH_ContinuousBodilyEffort\\TS_processing/TS_motiontracking\\mt_0_1_23_p0.csv', 'e:\\FLESH_ContinuousBodilyEffort\\TS_processing/TS_motiontracking\\mt_0_1_24_p0.csv', 'e:\\FLESH_ContinuousBodilyEffort\\TS_processing/TS_motiontracking\\mt_0_1_25_p0.csv', 'e:\\FLESH_ContinuousBodilyEffort\\TS_processing/TS_motiontracking\\mt_0_1_26_p0.csv', 'e:\\FLESH_ContinuousBodilyEffort\\TS_processing/TS_motiontracking\\mt_0_1_2_p0.csv', 'e:\\FLESH_ContinuousBodilyEffort\\TS_processing/TS_motiontracking\\mt_0_1_36_p0.csv', 'e:\\FLESH_ContinuousBodilyEffort\\TS_processing/TS_motiontracking\\mt_0_1_37_p0.csv', 'e:\\FLESH_ContinuousBodilyEffort\\TS_processing/TS_motiontracking\\mt_0_1_38_p0.csv', 'e:\\FLESH_ContinuousBodilyEffort\\TS_processing/TS_motiontracking\\mt_0_1_39_p0.csv', 'e:\\FLESH_ContinuousBodilyEffort\\TS_processing/TS_motiontracking\\mt_0_1_3_p0.csv', 'e:\\FLESH_ContinuousBodilyEffort\\TS_processing/TS_motiontracking\\mt_0_1_40_p0.csv', 'e:\\FLESH_ContinuousBodilyEffort\\TS_processing/TS_motiontracking\\mt_0_1_41_p0.csv', 'e:\\FLESH_ContinuousBodilyEffort\\TS_processing/TS_motiontracking\\mt_0_1_42_p0.csv', 'e:\\FLESH_ContinuousBodilyEffort\\TS_processing/TS_motiontracking\\mt_0_1_43_p0.csv', 'e:\\FLESH_ContinuousBodilyEffort\\TS_processing/TS_motiontracking\\mt_0_1_44_p0.csv', 'e:\\FLESH_ContinuousBodilyEffort\\TS_processing/TS_motiontracking\\mt_0_1_4_p0.csv', 'e:\\FLESH_ContinuousBodilyEffort\\TS_processing/TS_motiontracking\\mt_0_1_5_p0.csv', 'e:\\FLESH_ContinuousBodilyEffort\\TS_processing/TS_motiontracking\\mt_0_1_6_p0.csv', 'e:\\FLESH_ContinuousBodilyEffort\\TS_processing/TS_motiontracking\\mt_0_1_7_p0.csv', 'e:\\FLESH_ContinuousBodilyEffort\\TS_processing/TS_motiontracking\\mt_0_1_8_p0.csv', 'e:\\FLESH_ContinuousBodilyEffort\\TS_processing/TS_motiontracking\\mt_0_1_tpose_0.csv', 'e:\\FLESH_ContinuousBodilyEffort\\TS_processing/TS_motiontracking\\mt_0_1_10_p1.csv', 'e:\\FLESH_ContinuousBodilyEffort\\TS_processing/TS_motiontracking\\mt_0_1_11_p1.csv', 'e:\\FLESH_ContinuousBodilyEffort\\TS_processing/TS_motiontracking\\mt_0_1_12_p1.csv', 'e:\\FLESH_ContinuousBodilyEffort\\TS_processing/TS_motiontracking\\mt_0_1_13_p1.csv', 'e:\\FLESH_ContinuousBodilyEffort\\TS_processing/TS_motiontracking\\mt_0_1_14_p1.csv', 'e:\\FLESH_ContinuousBodilyEffort\\TS_processing/TS_motiontracking\\mt_0_1_15_p1.csv', 'e:\\FLESH_ContinuousBodilyEffort\\TS_processing/TS_motiontracking\\mt_0_1_16_p1.csv', 'e:\\FLESH_ContinuousBodilyEffort\\TS_processing/TS_motiontracking\\mt_0_1_17_p1.csv', 'e:\\FLESH_ContinuousBodilyEffort\\TS_processing/TS_motiontracking\\mt_0_1_27_p1.csv', 'e:\\FLESH_ContinuousBodilyEffort\\TS_processing/TS_motiontracking\\mt_0_1_28_p1.csv', 'e:\\FLESH_ContinuousBodilyEffort\\TS_processing/TS_motiontracking\\mt_0_1_29_p1.csv', 'e:\\FLESH_ContinuousBodilyEffort\\TS_processing/TS_motiontracking\\mt_0_1_30_p1.csv', 'e:\\FLESH_ContinuousBodilyEffort\\TS_processing/TS_motiontracking\\mt_0_1_31_p1.csv', 'e:\\FLESH_ContinuousBodilyEffort\\TS_processing/TS_motiontracking\\mt_0_1_32_p1.csv', 'e:\\FLESH_ContinuousBodilyEffort\\TS_processing/TS_motiontracking\\mt_0_1_33_p1.csv', 'e:\\FLESH_ContinuousBodilyEffort\\TS_processing/TS_motiontracking\\mt_0_1_35_p1.csv', 'e:\\FLESH_ContinuousBodilyEffort\\TS_processing/TS_motiontracking\\mt_0_1_45_p1.csv', 'e:\\FLESH_ContinuousBodilyEffort\\TS_processing/TS_motiontracking\\mt_0_1_46_p1.csv', 'e:\ ...
# ['e:\\FLESH_ContinuousBodilyEffort\\TS_processing/TS_motiontracking\\id_0_1_0_p0.csv', 'e:\\FLESH_ContinuousBodilyEffort\\TS_processing/TS_motiontracking\\id_0_1_18_p0.csv', 'e:\\FLESH_ContinuousBodilyEffort\\TS_processing/TS_motiontracking\\id_0_1_19_p0.csv', 'e:\\FLESH_ContinuousBodilyEffort\\TS_processing/TS_motiontracking\\id_0_1_1_p0.csv', 'e:\\FLESH_ContinuousBodilyEffort\\TS_processing/TS_motiontracking\\id_0_1_20_p0.csv', 'e:\\FLESH_ContinuousBodilyEffort\\TS_processing/TS_motiontracking\\id_0_1_21_p0.csv', 'e:\\FLESH_ContinuousBodilyEffort\\TS_processing/TS_motiontracking\\id_0_1_22_p0.csv', 'e:\\FLESH_ContinuousBodilyEffort\\TS_processing/TS_motiontracking\\id_0_1_23_p0.csv', 'e:\\FLESH_ContinuousBodilyEffort\\TS_processing/TS_motiontracking\\id_0_1_24_p0.csv', 'e:\\FLESH_ContinuousBodilyEffort\\TS_processing/TS_motiontracking\\id_0_1_25_p0.csv', 'e:\\FLESH_ContinuousBodilyEffort\\TS_processing/TS_motiontracking\\id_0_1_26_p0.csv', 'e:\\FLESH_ContinuousBodilyEffort\\TS_processing/TS_motiontracking\\id_0_1_2_p0.csv', 'e:\\FLESH_ContinuousBodilyEffort\\TS_processing/TS_motiontracking\\id_0_1_36_p0.csv', 'e:\\FLESH_ContinuousBodilyEffort\\TS_processing/TS_motiontracking\\id_0_1_37_p0.csv', 'e:\\FLESH_ContinuousBodilyEffort\\TS_processing/TS_motiontracking\\id_0_1_38_p0.csv', 'e:\\FLESH_ContinuousBodilyEffort\\TS_processing/TS_motiontracking\\id_0_1_39_p0.csv', 'e:\\FLESH_ContinuousBodilyEffort\\TS_processing/TS_motiontracking\\id_0_1_3_p0.csv', 'e:\\FLESH_ContinuousBodilyEffort\\TS_processing/TS_motiontracking\\id_0_1_40_p0.csv', 'e:\\FLESH_ContinuousBodilyEffort\\TS_processing/TS_motiontracking\\id_0_1_41_p0.csv', 'e:\\FLESH_ContinuousBodilyEffort\\TS_processing/TS_motiontracking\\id_0_1_42_p0.csv', 'e:\\FLESH_ContinuousBodilyEffort\\TS_processing/TS_motiontracking\\id_0_1_43_p0.csv', 'e:\\FLESH_ContinuousBodilyEffort\\TS_processing/TS_motiontracking\\id_0_1_44_p0.csv', 'e:\\FLESH_ContinuousBodilyEffort\\TS_processing/TS_motiontracking\\id_0_1_4_p0.csv', 'e:\\FLESH_ContinuousBodilyEffort\\TS_processing/TS_motiontracking\\id_0_1_5_p0.csv', 'e:\\FLESH_ContinuousBodilyEffort\\TS_processing/TS_motiontracking\\id_0_1_6_p0.csv', 'e:\\FLESH_ContinuousBodilyEffort\\TS_processing/TS_motiontracking\\id_0_1_7_p0.csv', 'e:\\FLESH_ContinuousBodilyEffort\\TS_processing/TS_motiontracking\\id_0_1_8_p0.csv', 'e:\\FLESH_ContinuousBodilyEffort\\TS_processing/TS_motiontracking\\id_0_1_10_p1.csv', 'e:\\FLESH_ContinuousBodilyEffort\\TS_processing/TS_motiontracking\\id_0_1_11_p1.csv', 'e:\\FLESH_ContinuousBodilyEffort\\TS_processing/TS_motiontracking\\id_0_1_12_p1.csv', 'e:\\FLESH_ContinuousBodilyEffort\\TS_processing/TS_motiontracking\\id_0_1_13_p1.csv', 'e:\\FLESH_ContinuousBodilyEffort\\TS_processing/TS_motiontracking\\id_0_1_14_p1.csv', 'e:\\FLESH_ContinuousBodilyEffort\\TS_processing/TS_motiontracking\\id_0_1_15_p1.csv', 'e:\\FLESH_ContinuousBodilyEffort\\TS_processing/TS_motiontracking\\id_0_1_16_p1.csv', 'e:\\FLESH_ContinuousBodilyEffort\\TS_processing/TS_motiontracking\\id_0_1_17_p1.csv', 'e:\\FLESH_ContinuousBodilyEffort\\TS_processing/TS_motiontracking\\id_0_1_27_p1.csv', 'e:\\FLESH_ContinuousBodilyEffort\\TS_processing/TS_motiontracking\\id_0_1_28_p1.csv', 'e:\\FLESH_ContinuousBodilyEffort\\TS_processing/TS_motiontracking\\id_0_1_29_p1.csv', 'e:\\FLESH_ContinuousBodilyEffort\\TS_processing/TS_motiontracking\\id_0_1_30_p1.csv', 'e:\\FLESH_ContinuousBodilyEffort\\TS_processing/TS_motiontracking\\id_0_1_31_p1.csv', 'e:\\FLESH_ContinuousBodilyEffort\\TS_processing/TS_motiontracking\\id_0_1_32_p1.csv', 'e:\\FLESH_ContinuousBodilyEffort\\TS_processing/TS_motiontracking\\id_0_1_33_p1.csv', 'e:\\FLESH_ContinuousBodilyEffort\\TS_processing/TS_motiontracking\\id_0_1_35_p1.csv', 'e:\\FLESH_ContinuousBodilyEffort\\TS_processing/TS_motiontracking\\id_0_1_45_p1.csv', 'e:\\FLESH_ContinuousBodilyEffort\\TS_processing/TS_motiontracking\\id_0_1_46_p1.csv', 'e:\\FLESH_ContinuousBodilyEffort\\TS_processing/TS_motiontracking\\id_0_1_47_p1.csv', 'e:\\F ...
# ['e:\\FLESH_ContinuousBodilyEffort\\TS_processing/Videos\\0_1_0_p0.avi', 'e:\\FLESH_ContinuousBodilyEffort\\TS_processing/Videos\\0_1_18_p0.avi', 'e:\\FLESH_ContinuousBodilyEffort\\TS_processing/Videos\\0_1_19_p0.avi', 'e:\\FLESH_ContinuousBodilyEffort\\TS_processing/Videos\\0_1_1_p0.avi', 'e:\\FLESH_ContinuousBodilyEffort\\TS_processing/Videos\\0_1_20_p0.avi', 'e:\\FLESH_ContinuousBodilyEffort\\TS_processing/Videos\\0_1_21_p0.avi', 'e:\\FLESH_ContinuousBodilyEffort\\TS_processing/Videos\\0_1_22_p0.avi', 'e:\\FLESH_ContinuousBodilyEffort\\TS_processing/Videos\\0_1_23_p0.avi', 'e:\\FLESH_ContinuousBodilyEffort\\TS_processing/Videos\\0_1_24_p0.avi', 'e:\\FLESH_ContinuousBodilyEffort\\TS_processing/Videos\\0_1_25_p0.avi', 'e:\\FLESH_ContinuousBodilyEffort\\TS_processing/Videos\\0_1_26_p0.avi', 'e:\\FLESH_ContinuousBodilyEffort\\TS_processing/Videos\\0_1_2_p0.avi', 'e:\\FLESH_ContinuousBodilyEffort\\TS_processing/Videos\\0_1_36_p0.avi', 'e:\\FLESH_ContinuousBodilyEffort\\TS_processing/Videos\\0_1_37_p0.avi', 'e:\\FLESH_ContinuousBodilyEffort\\TS_processing/Videos\\0_1_38_p0.avi', 'e:\\FLESH_ContinuousBodilyEffort\\TS_processing/Videos\\0_1_39_p0.avi', 'e:\\FLESH_ContinuousBodilyEffort\\TS_processing/Videos\\0_1_3_p0.avi', 'e:\\FLESH_ContinuousBodilyEffort\\TS_processing/Videos\\0_1_40_p0.avi', 'e:\\FLESH_ContinuousBodilyEffort\\TS_processing/Videos\\0_1_41_p0.avi', 'e:\\FLESH_ContinuousBodilyEffort\\TS_processing/Videos\\0_1_42_p0.avi', 'e:\\FLESH_ContinuousBodilyEffort\\TS_processing/Videos\\0_1_43_p0.avi', 'e:\\FLESH_ContinuousBodilyEffort\\TS_processing/Videos\\0_1_44_p0.avi', 'e:\\FLESH_ContinuousBodilyEffort\\TS_processing/Videos\\0_1_4_p0.avi', 'e:\\FLESH_ContinuousBodilyEffort\\TS_processing/Videos\\0_1_5_p0.avi', 'e:\\FLESH_ContinuousBodilyEffort\\TS_processing/Videos\\0_1_6_p0.avi', 'e:\\FLESH_ContinuousBodilyEffort\\TS_processing/Videos\\0_1_7_p0.avi', 'e:\\FLESH_ContinuousBodilyEffort\\TS_processing/Videos\\0_1_8_p0.avi', 'e:\\FLESH_ContinuousBodilyEffort\\TS_processing/Videos\\0_1_tpose_0.avi', 'e:\\FLESH_ContinuousBodilyEffort\\TS_processing/Videos\\0_1_10_p1.avi', 'e:\\FLESH_ContinuousBodilyEffort\\TS_processing/Videos\\0_1_11_p1.avi', 'e:\\FLESH_ContinuousBodilyEffort\\TS_processing/Videos\\0_1_12_p1.avi', 'e:\\FLESH_ContinuousBodilyEffort\\TS_processing/Videos\\0_1_13_p1.avi', 'e:\\FLESH_ContinuousBodilyEffort\\TS_processing/Videos\\0_1_14_p1.avi', 'e:\\FLESH_ContinuousBodilyEffort\\TS_processing/Videos\\0_1_15_p1.avi', 'e:\\FLESH_ContinuousBodilyEffort\\TS_processing/Videos\\0_1_16_p1.avi', 'e:\\FLESH_ContinuousBodilyEffort\\TS_processing/Videos\\0_1_17_p1.avi', 'e:\\FLESH_ContinuousBodilyEffort\\TS_processing/Videos\\0_1_27_p1.avi', 'e:\\FLESH_ContinuousBodilyEffort\\TS_processing/Videos\\0_1_28_p1.avi', 'e:\\FLESH_ContinuousBodilyEffort\\TS_processing/Videos\\0_1_29_p1.avi', 'e:\\FLESH_ContinuousBodilyEffort\\TS_processing/Videos\\0_1_30_p1.avi', 'e:\\FLESH_ContinuousBodilyEffort\\TS_processing/Videos\\0_1_31_p1.avi', 'e:\\FLESH_ContinuousBodilyEffort\\TS_processing/Videos\\0_1_32_p1.avi', 'e:\\FLESH_ContinuousBodilyEffort\\TS_processing/Videos\\0_1_33_p1.avi', 'e:\\FLESH_ContinuousBodilyEffort\\TS_processing/Videos\\0_1_35_p1.avi', 'e:\\FLESH_ContinuousBodilyEffort\\TS_processing/Videos\\0_1_45_p1.avi', 'e:\\FLESH_ContinuousBodilyEffort\\TS_processing/Videos\\0_1_46_p1.avi', 'e:\\FLESH_ContinuousBodilyEffort\\TS_processing/Videos\\0_1_47_p1.avi', 'e:\\FLESH_ContinuousBodilyEffort\\TS_processing/Videos\\0_1_48_p1.avi', 'e:\\FLESH_ContinuousBodilyEffort\\TS_processing/Videos\\0_1_49_p1.avi', 'e:\\FLESH_ContinuousBodilyEffort\\TS_processing/Videos\\0_1_50_p1.avi', 'e:\\FLESH_ContinuousBodilyEffort\\TS_processing/Videos\\0_1_51_p1.avi', 'e:\\FLESH_ContinuousBodilyEffort\\TS_processing/Videos\\0_1_52_p1.avi', 'e:\\FLESH_ContinuousBodilyEffort\\TS_processing/Videos\\0_1_53_p1.avi', 'e:\\FLESH_ContinuousBodilyEffort\\TS_processing/Videos\\0_1_9_p1.avi', 'e:\\FLESH_ContinuousBodilyEffort\\TS_processing/Videos\\0_1_tpos ...
# ['e:\\FLESH_ContinuousBodilyEffort\\TS_processing/TS_motiontracking\\bb_0_1_1_p0.csv', 'e:\\FLESH_ContinuousBodilyEffort\\TS_processing/TS_motiontracking\\bb_0_1_10_p1.csv', 'e:\\FLESH_ContinuousBodilyEffort\\TS_processing/TS_motiontracking\\bb_0_1_18_p0.csv', 'e:\\FLESH_ContinuousBodilyEffort\\TS_processing/TS_motiontracking\\bb_0_1_2_p0.csv', 'e:\\FLESH_ContinuousBodilyEffort\\TS_processing/TS_motiontracking\\bb_0_1_8_p0.csv', 'e:\\FLESH_ContinuousBodilyEffort\\TS_processing/TS_motiontracking\\bb_0_1_9_p1.csv', 'e:\\FLESH_ContinuousBodilyEffort\\TS_processing/TS_motiontracking\\bb_0_2_111_p1.csv', 'e:\\FLESH_ContinuousBodilyEffort\\TS_processing/TS_motiontracking\\bb_0_2_112_p1.csv', 'e:\\FLESH_ContinuousBodilyEffort\\TS_processing/TS_motiontracking\\bb_0_1_0_p0.csv', 'e:\\FLESH_ContinuousBodilyEffort\\TS_processing/TS_motiontracking\\bb_0_1_3_p0.csv', 'e:\\FLESH_ContinuousBodilyEffort\\TS_processing/TS_motiontracking\\bb_0_1_4_p0.csv', 'e:\\FLESH_ContinuousBodilyEffort\\TS_processing/TS_motiontracking\\bb_0_1_5_p0.csv', 'e:\\FLESH_ContinuousBodilyEffort\\TS_processing/TS_motiontracking\\bb_0_1_6_p0.csv', 'e:\\FLESH_ContinuousBodilyEffort\\TS_processing/TS_motiontracking\\bb_0_1_7_p0.csv', 'e:\\FLESH_ContinuousBodilyEffort\\TS_processing/TS_motiontracking\\bb_0_1_11_p1.csv', 'e:\\FLESH_ContinuousBodilyEffort\\TS_processing/TS_motiontracking\\bb_0_1_12_p1.csv', 'e:\\FLESH_ContinuousBodilyEffort\\TS_processing/TS_motiontracking\\bb_0_1_13_p1.csv', 'e:\\FLESH_ContinuousBodilyEffort\\TS_processing/TS_motiontracking\\bb_0_1_14_p1.csv', 'e:\\FLESH_ContinuousBodilyEffort\\TS_processing/TS_motiontracking\\bb_0_1_15_p1.csv', 'e:\\FLESH_ContinuousBodilyEffort\\TS_processing/TS_motiontracking\\bb_0_1_16_p1.csv', 'e:\\FLESH_ContinuousBodilyEffort\\TS_processing/TS_motiontracking\\bb_0_1_17_p1.csv', 'e:\\FLESH_ContinuousBodilyEffort\\TS_processing/TS_motiontracking\\bb_0_1_19_p0.csv', 'e:\\FLESH_ContinuousBodilyEffort\\TS_processing/TS_motiontracking\\bb_0_1_20_p0.csv', 'e:\\FLESH_ContinuousBodilyEffort\\TS_processing/TS_motiontracking\\bb_0_1_21_p0.csv', 'e:\\FLESH_ContinuousBodilyEffort\\TS_processing/TS_motiontracking\\bb_0_1_22_p0.csv', 'e:\\FLESH_ContinuousBodilyEffort\\TS_processing/TS_motiontracking\\bb_0_1_23_p0.csv', 'e:\\FLESH_ContinuousBodilyEffort\\TS_processing/TS_motiontracking\\bb_0_1_24_p0.csv', 'e:\\FLESH_ContinuousBodilyEffort\\TS_processing/TS_motiontracking\\bb_0_1_25_p0.csv', 'e:\\FLESH_ContinuousBodilyEffort\\TS_processing/TS_motiontracking\\bb_0_1_26_p0.csv', 'e:\\FLESH_ContinuousBodilyEffort\\TS_processing/TS_motiontracking\\bb_0_1_27_p1.csv', 'e:\\FLESH_ContinuousBodilyEffort\\TS_processing/TS_motiontracking\\bb_0_1_28_p1.csv', 'e:\\FLESH_ContinuousBodilyEffort\\TS_processing/TS_motiontracking\\bb_0_1_29_p1.csv', 'e:\\FLESH_ContinuousBodilyEffort\\TS_processing/TS_motiontracking\\bb_0_1_30_p1.csv', 'e:\\FLESH_ContinuousBodilyEffort\\TS_processing/TS_motiontracking\\bb_0_1_31_p1.csv', 'e:\\FLESH_ContinuousBodilyEffort\\TS_processing/TS_motiontracking\\bb_0_1_32_p1.csv', 'e:\\FLESH_ContinuousBodilyEffort\\TS_processing/TS_motiontracking\\bb_0_1_33_p1.csv', 'e:\\FLESH_ContinuousBodilyEffort\\TS_processing/TS_motiontracking\\bb_0_1_34_p1.csv', 'e:\\FLESH_ContinuousBodilyEffort\\TS_processing/TS_motiontracking\\bb_0_1_35_p1.csv', 'e:\\FLESH_ContinuousBodilyEffort\\TS_processing/TS_motiontracking\\bb_0_1_36_p0.csv', 'e:\\FLESH_ContinuousBodilyEffort\\TS_processing/TS_motiontracking\\bb_0_1_37_p0.csv', 'e:\\FLESH_ContinuousBodilyEffort\\TS_processing/TS_motiontracking\\bb_0_1_38_p0.csv', 'e:\\FLESH_ContinuousBodilyEffort\\TS_processing/TS_motiontracking\\bb_0_1_39_p0.csv', 'e:\\FLESH_ContinuousBodilyEffort\\TS_processing/TS_motiontracking\\bb_0_1_40_p0.csv', 'e:\\FLESH_ContinuousBodilyEffort\\TS_processing/TS_motiontracking\\bb_0_1_41_p0.csv', 'e:\\FLESH_ContinuousBodilyEffort\\TS_processing/TS_motiontracking\\bb_0_1_42_p0.csv', 'e:\\FLESH_ContinuousBodilyEffort\\TS_processing/TS_motiontracking\\bb_0_1_43_p0.csv', 'e:\\ ...

# %% [markdown]
# ## FUNCTION TO ANIMATE MULTIMODAL SIGNALS

# %%
import tempfile
import shutil
import matplotlib.pyplot as plt


# what is the window size in seconds
window = 4

# a function that generates a plot containing two panel time series of the envelope (panel 1) and the pose time series (panel 2) with a window of 4 seconds
def plot_body_signals(body, maxbody, minbody, env, maxenv, minenv, bb, maxbb, minbb, midpoint):
    # make a temporary folder
    tempfolder = tempfile.mkdtemp()
    fig, ax = plt.subplots(3, 1, figsize=(14, 10))
    # selection 4 seconds from midpoint
    start = midpoint - window/2
    end = midpoint + window/2
    # if start is negative, set it to 0
    if start < 0:
        start = 0
    # subset the body time series and amplitude envelope based on the start and end
    body = body[(body['Time'] >= start) & (body['Time'] <= end)]
    env = env[(env['time'] >= start) & (env['time'] <= end)]
    bb = bb[(bb['time'] >= start) & (bb['time'] <= end)]
    # do a cross correlation between the envelope and the pose time series
    # recenter time
    body['Time'] = body['Time'] - midpoint
    env['time'] = env['time'] - midpoint
    bb['time'] = bb['time'] - midpoint
    # Plot the amplitude envelope
    ax[0].plot(env['time'], env['envelope'], label = 'envelope', linewidth=8, color='green')
    ax[0].legend() # show labels in legend
    ax[0].legend(prop={'size': 24})
    # Plot the pose time series with a thick line semitransparent, but different colors (black & grey)
    ax[1].plot(body['Time'], body['RWrist_speed'], label='RWrist (speed)', color='magenta', alpha=0.8, linewidth=4)
    ax[1].plot(body['Time'], body['LWrist_speed'], label='LWrist (speed)', color='darkblue', alpha=0.8, linewidth=4)
    #ax[1].set_xlabel('Time (ms)', fontsize=24)
    ax[1].legend() # show labels in legend
    ax[1].legend(prop={'size': 24})
    plt.tight_layout()
    # plot the bb
    ax[2].plot(bb['time'], bb['COPc'], label='Center of pressure (change)', color='black', alpha=0.8, linewidth=4)
    ax[2].set_xlabel('Time (ms)', fontsize=24)
    ax[2].legend() # show labels in legend
    ax[2].legend(prop={'size': 24})
    plt.tight_layout()
    # set the x axes to centered by 0 minus and plus half the window
    ax[0].set_xlim(-window/2, window/2)
    ax[1].set_xlim(-window/2, window/2)
    ax[2].set_xlim(-window/2, window/2)
    # add a vertical line in the plot at 0
    ax[0].axvline(x=0, color='r', linestyle='--', linewidth=4, alpha=0.8)
    ax[1].axvline(x=0, color='r', linestyle='--', linewidth=4, alpha=0.8)
    ax[2].axvline(x=0, color='r', linestyle='--', linewidth=4, alpha=0.8)

    # ad horizontal lines at 15 for first plot
    #ax[0].axhline(y=15, color='r', linestyle='--', linewidth=4, alpha=0.8)
    # set the y axes 
    # what is the total max and min value in env
    #maxenv = max(env['env'])
    #minenv = min(env['env'])
    ax[0].set_ylim(minenv, maxenv)
    # speed according to max value within both wrists
    #maxbody = max(body['RWrist_speed'].max(), body['LWrist_speed'].max())
    ax[1].set_ylim(minbody, maxbody) #
    # bb according to max value
    #maxbb = max(bb['COPc'].max())
    #minbb = min(bb['COPc'].min())
    ax[2].set_ylim(minbb, maxbb)
    
    # increase font size
    for a in ax:
        a.tick_params(axis='both', which='major', labelsize=24)
        a.tick_params(axis='both', which='major', width=6)
    # save the plot
    tpf = tempfolder + 'tempfig.png'
    plt.savefig(tpf )
    plt.close()
    img = cv2.imread(tpf)
    shutil.rmtree(tempfolder)
    return img

# %% [markdown]
# ## ANIMATION OF MULTIMODAL SIGNALS
#
# From https://www.envisionbox.org/embedded_AnimatingSoundMovement.html

# %%
sample_mt = mttotrack[55]
print(sample_mt)
sample_bb = bbtotrack[56]
print(sample_bb)
sample_id = idtotrack[53]
print(sample_id)

# plot RWrist_speed, COPc, and rist_flex_l_moment

# load the data
mt = pd.read_csv(sample_mt)
bb = pd.read_csv(sample_bb)
id = pd.read_csv(sample_id)

#plot them with time
plt.plot(mt['Time'], mt['RWrist_speed'], label='RWrist_speed')
#plt.plot(bb['time'], bb['COPc'], label='COPc')
plt.plot(id['time'], id['wrist_flex_l_moment'], label='RWrist_flex_l_moment')
plt.legend()
plt.show()
# Out:
# e:\FLESH_ContinuousBodilyEffort\TS_processing/TS_motiontracking\mt_0_2_0_p0.csv
# e:\FLESH_ContinuousBodilyEffort\TS_processing/TS_motiontracking\bb_0_2_0_p0.csv
# e:\FLESH_ContinuousBodilyEffort\TS_processing/TS_motiontracking\id_0_2_0_p0.csv

# %%
import tqdm
import cv2
import numpy as np
import pandas as pd
from scipy.signal import savgol_filter
import scipy

resampl_rate = 200
smooth_hz = 8

anifolder = curfolder + '/Animations/'

for file in mttotrack:
    # get the trialid
    trialid = file.split('\\')[-1].split('.')[0]
    # get rid of the mt_
    trialid = trialid[3:]
    print(trialid)

    # load it
    mt = pd.read_csv(file)

    # convert time to seconds
    mt['Time'] = mt['Time']/1000

    # get the max and min values for the speed
    maxbody = max(mt['RWrist_speed'].max(), mt['LWrist_speed'].max())
    minbody = 0

    ###### PREPARING AUDIO

    # get audio file from envtotracki with the same trialid
    envfile = [x for x in envtotrack if trialid in x][0]

    env = pd.read_csv(envfile)

    # convert time to seconds
    env['time'] = env['time']/1000

    print(env)

    # get the max and min values for the envelope
    maxenv = max(env['envelope'])
    minenv = min(env['envelope'])

    ###### PREPARING BB

    # get bb file bbtotrack with the same trialid
    bbfile = [x for x in bbtotrack if trialid in x][0]

    bb = pd.read_csv(bbfile)

    # convert time to seconds
    bb['time'] = bb['time']/1000

    
    print(bb)

    # get the max and min values for the bb
    maxbb = max(bb['COPc'])
    minbb = min(bb['COPc'])

    # PREPARE VIDEO
    
    # get the video file with the same trialid
    videofile = [x for x in vidtotrack if trialid in x][0]
    print(videofile)

    #audiofilename = inputfol + vidf.replace(".mp4", ".wav")
    #videofilenamemasked = videofilename.replace(".mp4", "_masked.mp4")
    #print(videofilenamemasked)
    # Get the amplitude envelope
    #ampv, sr = amp_envelope(audiofilename)
    # get the raw audio
    #rawaudio, sr = librosa.load(audiofilename, sr=None)


    # load the video in opencv and prepare to loop over it
    capture = cv2.VideoCapture(videofile)
    frameWidth = capture.get(cv2.CAP_PROP_FRAME_WIDTH)
    frameHeight = capture.get(cv2.CAP_PROP_FRAME_HEIGHT)
    fps = capture.get(cv2.CAP_PROP_FPS)
    # out
    fourcc = cv2.VideoWriter_fourcc(*'MP4V')
    out = cv2.VideoWriter(anifolder + '/' + trialid + '_sample_wrist_multimodal_animated.mp4', fourcc, fps, (int(frameWidth)*4, int(frameHeight)))
    # loop over the video
    # loop through the video and add the plot to the video on left upper corner in small inset
    frame_number = 0
    # with progress bar
    for i in tqdm.tqdm(range(int(capture.get(cv2.CAP_PROP_FRAME_COUNT)))):
        ret, frame = capture.read()
        if ret == True:
            img = plot_body_signals(mt, maxbody, minbody, env, maxenv, minenv, bb, maxbb, minbb, frame_number/fps)
            # resize the image
            img = cv2.resize(img, (int(frameWidth*3), int(frameHeight)))
            # lets put the plot on the right side of the frame using concat
            frame = np.concatenate([frame, img], axis=1)            
            out.write(frame)
            frame_number += 1
            # also show the frame (optional)
            #cv2.imshow('Frame', frame)
            #if cv2.waitKey(1) & 0xFF == ord('q'):
            #   break
        else:
            break
    capture.release()
    out.release()    
    cv2.destroyAllWindows()

    break
# Out:
# 0_1_0_p0
#             time  audio  envelope
# 0       0.000000    0.0  0.012199
# 1       0.000021    0.0  0.012199
# 2       0.000042    0.0  0.012199
# 3       0.000063    0.0  0.012199
# 4       0.000083    0.0  0.012199
# ...          ...    ...       ...
# 240268  5.005583    0.0  0.012200
# 240269  5.005604    0.0  0.012200
# 240270  5.005625    0.0  0.012200
# 240271  5.005646    0.0  0.012200
# 240272  5.005667    0.0  0.012200
#
# [240273 rows x 3 columns]
#           time  left_back  right_forward  right_back  left_forward     COPXc  \
# 0     0.000000   1.152663       0.783788    1.602603      1.281681  0.000412
# 1     0.002000   1.152858       0.783666    1.603292      1.281453  0.000341
# 2     0.004000   1.153067       0.783581    1.603912      1.281321  0.000278
# 3     0.006000   1.153288       0.783533    1.604472      1.281271  0.000222
# 4     0.008000   1.153520       0.783518    1.604977      1.281288  0.000175
# ...        ...        ...            ...         ...           ...       ...
# 2498  4.996131   1.161910       0.776960    1.596007      1.287195 -0.000082
# 2499  4.998131   1.161864       0.776948    1.595915      1.287148 -0.000034
# 2500  5.000131   1.161833       0.776977    1.595821      1.287066  0.000036
# 2501  5.002131   1.161822       0.777060    1.595730      1.286944  0.000133
# 2502  5.004131   1.161839       0.777211    1.595646      1.286774  0.000262
#
#          COPYc      COPc   TrialID
# 0    -0.000713  0.000823  0_1_0_p0
# 1    -0.000725  0.000802  0_1_0_p0
# 2    -0.000717  0.000769  0_1_0_p0
# 3    -0.000691  0.000726  0_1_0_p0
# 4    -0.000652  0.000675  0_1_0_p0
# ...        ...       ...       ...
# 2498  0.000062  0.000103  0_1_0_p0
# 2499  0.000063  0.000072  0_1_0_p0
# 2500  0.000065  0.000075  0_1_0_p0
# 2501  0.000070  0.000150  0_1_0_p0
# 2502  0.000077  0.000273  0_1_0_p0
#
# [2503 rows x 9 columns]
# e:\FLESH_ContinuousBodilyEffort\TS_processing/Videos\0_1_0_p0.avi
#   0%|          | 0/299 [00:00<?, ?it/s]C:\Users\kadava\AppData\Local\Temp\ipykernel_17644\2293818436.py:26: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   body['Time'] = body['Time'] - midpoint
# C:\Users\kadava\AppData\Local\Temp\ipykernel_17644\2293818436.py:27: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   env['time'] = env['time'] - midpoint
# C:\Users\kadava\AppData\Local\Temp\ipykernel_17644\2293818436.py:28: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bb['time'] = bb['time'] - midpoint
# 100%|██████████| 299/299 [01:39<00:00,  3.00it/s]

# %%
import ffmpeg

# add the audio
# load in the video again and add the audio using moviepy
for vidf in videofiles:
    print(vidf)
    # go two folders back in the directory
    #v = vidf.split('\\')[-3] + '/' + vidf.split('\\')[-2] + '/'
    # connect 0-8 element of path vidf
    v = vidf.split('\\')[:8]
    v = '/'.join(v[:4]) + '/'
    # find in v mp4 file with _animated
    animatedfile = glob.glob(v + '*_animated.mp4')[0]
    print(animatedfile)
    audiofilename = [x for x in foi_wav if '0_1_trial_35' in x][0]
    print(audiofilename)
    input_audio = ffmpeg.input(audiofilename)
    print(input_audio)
    print('Loading the video')
    input_video = ffmpeg.input(animatedfile)
    print(input_video)

    print('Combining audio and video')
    output_path = animatedfile.replace('.mp4', '_animated_audio.mp4')
    ffmpeg.concat(input_video, input_audio, v=1, a=1).output(output_path).run(overwrite_output=True)
        
    #save it
    print('Saving the video')
# Out:
# C:/Users/kadava/Documents/Github/FLESH_3Dtracking_new/projectdata\Session_0_1\P1\0_1_35_p1\pose-2d-trackingvideos\video1.avi
# C:/Users/kadava/Documents/Github/FLESH_3Dtracking_new/projectdata/Session_0_1/P1/0_1_35_p1\0_1_35_p1_sample_wrist_animated.mp4
# E:\charade_experiment_WORKSPACE\xdf_procedure\data\Data_processed\Data_trials/Audio_48\0_1_trial_35_Mic_nominal_srate48000_p1_langzaam_combinatie.wav
# input(filename='E:\\charade_experiment_WORKSPACE\\xdf_procedure\\data\\Data_processed\\Data_trials/Audio_48\\0_1_trial_35_Mic_nominal_srate48000_p1_langzaam_combinatie.wav')[None] <1de3190524b5>
# Loading the video
# input(filename='C:/Users/kadava/Documents/Github/FLESH_3Dtracking_new/projectdata/Session_0_1/P1/0_1_35_p1\\0_1_35_p1_sample_wrist_animated.mp4')[None] <c1358c19e5aa>
# Combining audio and video
# Saving the video

# %% [markdown]
# ## FUNCTION TO ANIMATE FORCES

# %%
import tempfile
import shutil
import matplotlib.pyplot as plt


# what is the window size in seconds
window = 4

# a function that generates a plot containing two panel time series of the envelope (panel 1) and the pose time series (panel 2) with a window of 4 seconds
def plot_forces(marker1, maxmarker1, minmarker1, marker2, maxmarker2, minmarker2, marker3, maxmarker3, minmarker3, marker4, maxmarker4, minmarker4, midpoint):
    # make a temporary folder
    tempfolder = tempfile.mkdtemp()
    fig, ax = plt.subplots(4, 1, figsize=(14, 10))
    # selection 4 seconds from midpoint
    start = midpoint - window/2
    end = midpoint + window/2
    # if start is negative, set it to 0
    if start < 0:
        start = 0
    # subset the body time series and amplitude envelope based on the start and end
    marker1 = marker1[(marker1['Time'] >= start) & (marker1['Time'] <= end)]
    marker2 = marker2[(marker2['time'] >= start) & (marker2['time'] <= end)]
    marker3 = marker3[(marker3['time'] >= start) & (marker3['time'] <= end)]
    marker4 = marker4[(marker4['time'] >= start) & (marker4['time'] <= end)]
    
    # do a cross correlation between the envelope and the pose time series
    # recenter time
    marker1['Time'] = marker1['Time'] - midpoint
    marker2['time'] = marker2['time'] - midpoint
    marker3['time'] = marker3['time'] - midpoint
    marker4['time'] = marker4['time'] - midpoint

    # Plot SPEED
    ax[0].plot(marker1['Time'], marker1['RElbow_speed'], label='RElbow_speed', color='magenta', alpha=0.8, linewidth=4)
    ax[0].plot(marker1['Time'], marker1['LElbow_speed'], label='LElbow_speed', color='darkblue', alpha=0.8, linewidth=4)
    ax[0].legend() # show labels in legend
    ax[0].legend(prop={'size': 24})
    plt.tight_layout()

    # Plot ARM_FLEX MOMENT
    ax[1].plot(marker2['time'], marker2['elbow_flex_r_moment'], label = 'elbow_flex_r_moment', linewidth=4, color='magenta')
    ax[1].plot(marker2['time'], marker2['elbow_flex_l_moment'], label = 'elbow_flex_l_moment', linewidth=4, color='darkblue')
    ax[1].legend() # show labels in legend
    ax[1].legend(prop={'size': 24})

    
    # Plot PELVIS
    ax[2].plot(marker3['time'], marker3['pelvis_rotation_moment'], label='pelvis_rotation_moment', color='green', alpha=0.8, linewidth=4)
    #ax[2].plot(marker3['time'], marker3['elbow_add_l_moment'], label='elbow_add_l_moment', color='darkblue', alpha=0.8, linewidth=4)
    ax[2].legend() # show labels in legend
    ax[2].legend(prop={'size': 24})
    plt.tight_layout()

    # plot NECK
    ax[3].plot(marker4['time'], marker4['neck_rotation_moment'], label='neck_rotation_moment', color='black', alpha=0.8, linewidth=4)
    #ax[3].plot(marker4['time'], marker4['elbow_rot_l_moment'], label='elbow_rot_l_moment', color='darkblue', alpha=0.8, linewidth=4)
    ax[3].set_xlabel('Time (ms)', fontsize=24)
    ax[3].legend() # show labels in legend
    ax[3].legend(prop={'size': 24})
    plt.tight_layout()

    # set the x axes to centered by 0 minus and plus half the window
    ax[0].set_xlim(-window/2, window/2)
    ax[1].set_xlim(-window/2, window/2)
    ax[2].set_xlim(-window/2, window/2)
    ax[3].set_xlim(-window/2, window/2)

    # add a vertical line in the plot at 0
    ax[0].axvline(x=0, color='r', linestyle='--', linewidth=4, alpha=0.8)
    ax[1].axvline(x=0, color='r', linestyle='--', linewidth=4, alpha=0.8)
    ax[2].axvline(x=0, color='r', linestyle='--', linewidth=4, alpha=0.8)
    ax[3].axvline(x=0, color='r', linestyle='--', linewidth=4, alpha=0.8)

    # set the y axes
    ax[0].set_ylim(minmarker1, maxmarker1) #
    ax[1].set_ylim(minmarker2, maxmarker2)
    ax[2].set_ylim(minmarker3, maxmarker3)
    ax[3].set_ylim(minmarker4, maxmarker4)
    
    # increase font size
    for a in ax:
        a.tick_params(axis='both', which='major', labelsize=24)
        a.tick_params(axis='both', which='major', width=6)
    # save the plot
    tpf = tempfolder + 'tempfig.png'
    plt.savefig(tpf )
    plt.close()
    img = cv2.imread(tpf)
    shutil.rmtree(tempfolder)
    return img

# %% [markdown]
# ## ANIMATION OF FORCES

# %%
import tqdm
import cv2
import numpy as np
import pandas as pd

anifolder = curfolder + '/Animations/'

# from mttotrack, get rid of all files with tpose in it
mttotrack = [x for x in mttotrack if 'tpose' not in x]

for file in mttotrack:
    # get the trialid
    trialid = file.split('\\')[-1].split('.')[0]
    # get rid of the mt_
    trialid = trialid[3:]
    print(trialid)

    # load it
    mt = pd.read_csv(file)

    # convert time to seconds
    mt['Time'] = mt['Time']/1000

    # get the max and min values for the speed
    maxbody = max(mt['RElbow_speed'].max(), mt['LElbow_speed'].max())
    minbody = 0

    ###### PREPARING FORCES

    # get audio file from envtotracki with the same trialid
    idfile = [x for x in idtotrack if trialid in x][0]

    id = pd.read_csv(idfile)

    # convert time to seconds
    id['time'] = id['time']/1000

    # get the max and min values for elbow flex
    maxelb = max(id['elbow_flex_r_moment'].max(), id['elbow_flex_l_moment'].max())
    minelb = min(id['elbow_flex_r_moment'].min(), id['elbow_flex_l_moment'].min())

    # get max min for pelvis 
    maxpel = max(id['pelvis_rotation_moment'])
    minpel = min(id['pelvis_rotation_moment'])

    # get max min for 
    maxneck = max(id['neck_rotation_moment'])
    minneck = min(id['neck_rotation_moment'])


    # PREPARE VIDEO
    
    # get the video file with the same trialid
    videofile = [x for x in vidtotrack if trialid in x][0]
    print(videofile)

    # load the video in opencv and prepare to loop over it
    capture = cv2.VideoCapture(videofile)
    frameWidth = capture.get(cv2.CAP_PROP_FRAME_WIDTH)
    frameHeight = capture.get(cv2.CAP_PROP_FRAME_HEIGHT)
    fps = capture.get(cv2.CAP_PROP_FPS)
    # out
    fourcc = cv2.VideoWriter_fourcc(*'MP4V')

    outputpath = anifolder + '/' + trialid + '_sample_body_forces_animated.mp4'
    # check if the file exists
    if os.path.exists(outputpath):
        print('File exists')
        continue
    else:
        out = cv2.VideoWriter(outputpath, fourcc, fps, (int(frameWidth)*4, int(frameHeight)))
        # loop over the video
        frame_number = 0
        # with progress bar
        for i in tqdm.tqdm(range(int(capture.get(cv2.CAP_PROP_FRAME_COUNT)))):
            ret, frame = capture.read()
            if ret == True:
                img = plot_forces(mt, maxbody, minbody, id, maxelb, minelb, id, maxpel, minpel, id, maxneck, minneck, frame_number/fps)
                # resize the image
                img = cv2.resize(img, (int(frameWidth*3), int(frameHeight)))
                # lets put the plot on the right side of the frame using concat
                frame = np.concatenate([frame, img], axis=1)            
                out.write(frame)
                frame_number += 1
                # also show the frame (optional)
                #cv2.imshow('Frame', frame)
                #if cv2.waitKey(1) & 0xFF == ord('q'):
                #   break
            else:
                break
        capture.release()
        out.release()    
        cv2.destroyAllWindows()

# %% [markdown]
# # ANIMATION OF ANGULAR VELOCITY

# %%
import tempfile
import shutil
import matplotlib.pyplot as plt


# what is the window size in seconds
window = 4

# a function that generates a plot containing two panel time series of the envelope (panel 1) and the pose time series (panel 2) with a window of 4 seconds
def plot_kinematics(marker1, maxmarker1, minmarker1, marker2, maxmarker2, minmarker2, marker3, maxmarker3, minmarker3, marker4, maxmarker4, minmarker4, midpoint):
    # make a temporary folder
    tempfolder = tempfile.mkdtemp()
    fig, ax = plt.subplots(4, 1, figsize=(14, 10))
    # selection 4 seconds from midpoint
    start = midpoint - window/2
    end = midpoint + window/2
    # if start is negative, set it to 0
    if start < 0:
        start = 0
    # subset the body time series and amplitude envelope based on the start and end
    marker1 = marker1[(marker1['Time'] >= start) & (marker1['Time'] <= end)]
    marker2 = marker2[(marker2['Time'] >= start) & (marker2['Time'] <= end)]
    marker3 = marker3[(marker3['time'] >= start) & (marker3['time'] <= end)]
    marker4 = marker4[(marker4['time'] >= start) & (marker4['time'] <= end)]
    
    # do a cross correlation between the envelope and the pose time series
    # recenter time
    marker1['Time'] = marker1['Time'] - midpoint
    marker2['Time'] = marker2['Time'] - midpoint
    marker3['time'] = marker3['time'] - midpoint
    marker4['time'] = marker4['time'] - midpoint

    # Plot coordinates (vertical)
    ax[0].plot(marker1['Time'], marker1['RElbow_z'], label='RElbow_z', color='magenta', alpha=0.8, linewidth=4)
    ax[0].plot(marker1['Time'], marker1['LElbow_z'], label='LElbow_z', color='darkblue', alpha=0.8, linewidth=4)
    ax[0].legend() # show labels in legend
    ax[0].legend(prop={'size': 24})
    plt.tight_layout()

    # Plot speed (as derivative of coordinates)
    ax[1].plot(marker2['Time'], marker2['RElbow_speed'], label = 'RElbow_speed', linewidth=4, color='magenta')
    ax[1].plot(marker2['Time'], marker2['LElbow_speed'], label = 'LElbow_speed', linewidth=4, color='darkblue')
    ax[1].legend() # show labels in legend
    ax[1].legend(prop={'size': 24})

    
    # Plot angular velocity
    ax[2].plot(marker3['time'], marker3['elbow_flex_r_speed'], label='elbow_flex_r_speed', color='green', alpha=0.8, linewidth=4)
    ax[2].plot(marker3['time'], marker3['elbow_flex_l_speed'], label='elbow_flex_l_speed', color='darkblue', alpha=0.8, linewidth=4)
    ax[2].legend() # show labels in legend
    ax[2].legend(prop={'size': 24})
    plt.tight_layout()

    # plot forces
    ax[3].plot(marker4['time'], marker4['elbow_flex_r_moment'], label='elbow_flex_r_moment', color='black', alpha=0.8, linewidth=4)
    ax[3].plot(marker4['time'], marker4['elbow_flex_l_moment'], label='elbow_flex_l_moment', color='darkblue', alpha=0.8, linewidth=4)
    ax[3].set_xlabel('Time (ms)', fontsize=24)
    ax[3].legend() # show labels in legend
    ax[3].legend(prop={'size': 24})
    plt.tight_layout()

    # set the x axes to centered by 0 minus and plus half the window
    ax[0].set_xlim(-window/2, window/2)
    ax[1].set_xlim(-window/2, window/2)
    ax[2].set_xlim(-window/2, window/2)
    ax[3].set_xlim(-window/2, window/2)

    # add a vertical line in the plot at 0
    ax[0].axvline(x=0, color='r', linestyle='--', linewidth=4, alpha=0.8)
    ax[1].axvline(x=0, color='r', linestyle='--', linewidth=4, alpha=0.8)
    ax[2].axvline(x=0, color='r', linestyle='--', linewidth=4, alpha=0.8)
    ax[3].axvline(x=0, color='r', linestyle='--', linewidth=4, alpha=0.8)

    # set the y axes
    ax[0].set_ylim(minmarker1, maxmarker1) #
    ax[1].set_ylim(minmarker2, maxmarker2)
    ax[2].set_ylim(minmarker3, maxmarker3)
    ax[3].set_ylim(minmarker4, maxmarker4)
    
    # increase font size
    for a in ax:
        a.tick_params(axis='both', which='major', labelsize=24)
        a.tick_params(axis='both', which='major', width=6)
    # save the plot
    tpf = tempfolder + 'tempfig.png'
    plt.savefig(tpf )
    plt.close()
    img = cv2.imread(tpf)
    shutil.rmtree(tempfolder)
    return img

# %%
mt
# Out:
#         RHip_x     RHip_y     RHip_z    RKnee_x    RKnee_y     RKnee_z  \
# 0    26.217834  35.824379 -62.507176  29.879859  44.940589 -109.944075
# 1    26.197987  36.081443 -62.732306  29.848714  45.042263 -109.988696
# 2    26.178141  36.338506 -62.957436  29.817570  45.143938 -110.033318
# 3    26.158294  36.595570 -63.182566  29.786425  45.245613 -110.077939
# 4    26.138448  36.852634 -63.407696  29.755280  45.347288 -110.122560
# ..         ...        ...        ...        ...        ...         ...
# 295  26.693468  39.831264 -68.875379  30.111726  46.224392 -111.518352
# 296  26.686530  39.836142 -68.903461  30.111196  46.274440 -111.552488
# 297  26.679592  39.841020 -68.931542  30.110667  46.324489 -111.586624
# 298  26.672653  39.845897 -68.959624  30.110137  46.374537 -111.620760
# 299  26.665715  39.850775 -68.987706  30.109608  46.424586 -111.654895
#
#       RAnkle_x   RAnkle_y    RAnkle_z  RBigToe_x  ...  LShoulder_speed  \
# 0    33.743309  46.423047 -149.586966  35.887613  ...         6.782026
# 1    33.740917  46.423592 -149.606340  35.951368  ...         6.659897
# 2    33.738524  46.424136 -149.625714  36.015124  ...         6.537767
# 3    33.736131  46.424681 -149.645089  36.078879  ...         6.415638
# 4    33.733738  46.425225 -149.664463  36.142635  ...         6.293508
# ..         ...        ...         ...        ...  ...              ...
# 295  33.519984  46.780561 -150.356616  36.530462  ...         0.157290
# 296  33.526190  46.777779 -150.358413  36.525121  ...         0.083044
# 297  33.532395  46.774997 -150.360211  36.519780  ...         0.008797
# 298  33.538600  46.772215 -150.362008  36.514439  ...        -0.065449
# 299  33.544806  46.769432 -150.363806  36.509098  ...        -0.139695
#
#      RHeel_speed  LElbow_speed  Head_speed  LBigToe_speed  RShoulder_speed  \
# 0      12.063352     14.428194    5.704749       2.893848         8.741812
# 1      11.481369     14.331234    5.834986       2.818950         8.714152
# 2      10.899385     14.234274    5.965223       2.744052         8.686492
# 3      10.317402     14.137314    6.095460       2.669154         8.658832
# 4       9.735419     14.040354    6.225697       2.594256         8.631172
# ..           ...           ...         ...            ...              ...
# 295     1.704762      2.174492    0.126078       1.096965         0.139820
# 296     1.281494      2.268919   -0.042205       1.191759         0.029945
# 297     0.858227      2.363346   -0.210489       1.286553        -0.079930
# 298     0.434960      2.457774   -0.378773       1.381347        -0.189805
# 299     0.011692      2.552201   -0.547057       1.476141        -0.299680
#
#      RSmallToe_speed  LWrist_speed  LWrist_vert_vel   TrialID
# 0           1.020543     46.095305        14.138069  0_1_0_p0
# 1           1.075547     46.292683        14.486891  0_1_0_p0
# 2           1.130552     46.490062        14.835714  0_1_0_p0
# 3           1.185557     46.687441        15.184537  0_1_0_p0
# 4           1.240562     46.884820        15.533359  0_1_0_p0
# ..               ...           ...              ...       ...
# 295         4.639748      0.610008        -0.301236  0_1_0_p0
# 296         5.043108      0.569537        -0.225710  0_1_0_p0
# 297         5.446468      0.529065        -0.150185  0_1_0_p0
# 298         5.849828      0.488593        -0.074660  0_1_0_p0
# 299         6.253188      0.448121         0.000866  0_1_0_p0
#
# [300 rows x 88 columns]

# %%
import tqdm
import cv2
import numpy as np
import pandas as pd

anifolder = curfolder + '/Animations/'

# from mttotrack, get rid of all files with tpose in it
mttotrack = [x for x in mttotrack if 'tpose' not in x]

for file in mttotrack:
    # get the trialid
    trialid = file.split('\\')[-1].split('.')[0]
    # get rid of the mt_
    trialid = trialid[3:]
    print(trialid)

    #### MT
    # load it
    mt = pd.read_csv(file)

    # convert time to seconds
    mt['Time'] = mt['Time']/1000

    # get the max and min values for the speed
    maxbody = max(mt['RElbow_z'].max(), mt['LElbow_z'].max())
    minbody = min(mt['RElbow_z'].min(), mt['LElbow_z'].min())

    maxspeed = max(mt['RElbow_speed'].max(), mt['LElbow_speed'].max())
    minspeed = 0

    #### IK
    # find ik file with the same trialid
    ikfile = [x for x in iktotrack if trialid in x][0]

    ik = pd.read_csv(ikfile)

    # convert time to seconds
    ik['time'] = ik['time']/1000

    # get the max and min values for the angular velocity
    maxangvel = max(ik['elbow_flex_r_speed'].max(), ik['elbow_flex_l_speed'].max())
    minangvel = min(ik['elbow_flex_r_speed'].min(), ik['elbow_flex_l_speed'].min()) 

    ###### PREPARING FORCES

    # get audio file from envtotracki with the same trialid
    idfile = [x for x in idtotrack if trialid in x][0]

    id = pd.read_csv(idfile)

    # convert time to seconds
    id['time'] = id['time']/1000

    # get the max and min values for elbow flex
    maxelb = max(id['elbow_flex_r_moment'].max(), id['elbow_flex_l_moment'].max())
    minelb = min(id['elbow_flex_r_moment'].min(), id['elbow_flex_l_moment'].min())

    # PREPARE VIDEO
    
    # get the video file with the same trialid
    videofile = [x for x in vidtotrack if trialid in x][0]
    print(videofile)

    # load the video in opencv and prepare to loop over it
    capture = cv2.VideoCapture(videofile)
    frameWidth = capture.get(cv2.CAP_PROP_FRAME_WIDTH)
    frameHeight = capture.get(cv2.CAP_PROP_FRAME_HEIGHT)
    fps = capture.get(cv2.CAP_PROP_FPS)
    # out
    fourcc = cv2.VideoWriter_fourcc(*'MP4V')

    outputpath = anifolder + '/' + trialid + '_sample_body_elbow_kinematics_animated.mp4'
    # check if the file exists
    if os.path.exists(outputpath):
        print('File exists')
        continue
    else:
        out = cv2.VideoWriter(outputpath, fourcc, fps, (int(frameWidth)*4, int(frameHeight)))
        # loop over the video
        frame_number = 0
        # with progress bar
        for i in tqdm.tqdm(range(int(capture.get(cv2.CAP_PROP_FRAME_COUNT)))):
            ret, frame = capture.read()
            if ret == True:
                img = plot_kinematics(mt, maxbody, minbody, mt, maxspeed, minspeed, ik, maxangvel, minangvel, id, maxelb, minelb, frame_number/fps)
                # resize the image
                img = cv2.resize(img, (int(frameWidth*3), int(frameHeight)))
                # lets put the plot on the right side of the frame using concat
                frame = np.concatenate([frame, img], axis=1)            
                out.write(frame)
                frame_number += 1
                # also show the frame (optional)
                #cv2.imshow('Frame', frame)
                #if cv2.waitKey(1) & 0xFF == ord('q'):
                #   break
            else:
                break
        capture.release()
        out.release()    
        cv2.destroyAllWindows()
# Out:
# 0_1_0_p0
# e:\FLESH_ContinuousBodilyEffort\TS_processing/Videos\0_1_0_p0.avi
#   0%|          | 0/299 [00:00<?, ?it/s]C:\Users\kadava\AppData\Local\Temp\ipykernel_19432\3279469147.py:28: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   marker1['Time'] = marker1['Time'] - midpoint
# C:\Users\kadava\AppData\Local\Temp\ipykernel_19432\3279469147.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   marker2['Time'] = marker2['Time'] - midpoint
# C:\Users\kadava\AppData\Local\Temp\ipykernel_19432\3279469147.py:30: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   marker3['time'] = marker3['time'] - midpoint
# C:\Users\kadava\AppData\Local\Temp\ipykernel_19432\3279469147.py:31: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   marker4['time'] = marker4['time'] - midpoint
# 100%|██████████| 299/299 [01:49<00:00,  2.72it/s]
# 0_1_18_p0
# e:\FLESH_ContinuousBodilyEffort\TS_processing/Videos\0_1_18_p0.avi
#   0%|          | 0/389 [00:00<?, ?it/s]C:\Users\kadava\AppData\Local\Temp\ipykernel_19432\3279469147.py:28: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   marker1['Time'] = marker1['Time'] - midpoint
# C:\Users\kadava\AppData\Local\Temp\ipykernel_19432\3279469147.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   marker2['Time'] = marker2['Time'] - midpoint
# C:\Users\kadava\AppData\Local\Temp\ipykernel_19432\3279469147.py:30: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   marker3['time'] = marker3['time'] - midpoint
# C:\Users\kadava\AppData\Local\Temp\ipykernel_19432\3279469147.py:31: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   marker4['time'] = marker4['time'] - midpoint
# 100%|██████████| 389/389 [02:21<00:00,  2.75it/s]
# 0_1_19_p0
# e:\FLESH_ContinuousBodilyEffort\TS_processing/Videos\0_1_19_p0.avi
#   0%|          | 0/352 [00:00<?, ?it/s]C:\Users\kadava\AppData\Local\Temp\ipykernel_19432\3279469147.py:28: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   marker1['Time'] = marker1['Time'] - midpoint
# C:\Users\kadava\AppData\Local\Temp\ipykernel_19432\3279469147.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   marker2['Time'] = marker2['Time'] - midpoint
# C:\Users\kadava\AppData\Local\Temp\ipykernel_19432\3279469147.py:30: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   marker3['time'] = marker3['time'] - midpoint
# C:\Users\kadava\AppData\Local\Temp\ipykernel_19432\3279469147.py:31: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   marker4['time'] = marker4['time'] - midpoint
# 100%|██████████| 352/352 [02:08<00:00,  2.73it/s]
# 0_1_1_p0
# e:\FLESH_ContinuousBodilyEffort\TS_processing/Videos\0_1_1_p0.avi
#   0%|          | 0/139 [00:00<?, ?it/s]C:\Users\kadava\AppData\Local\Temp\ipykernel_19432\3279469147.py:28: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   marker1['Time'] = marker1['Time'] - midpoint
# C:\Users\kadava\AppData\Local\Temp\ipykernel_19432\3279469147.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   marker2['Time'] = marker2['Time'] - midpoint
# C:\Users\kadava\AppData\Local\Temp\ipykernel_19432\3279469147.py:30: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   marker3['time'] = marker3['time'] - midpoint
# C:\Users\kadava\AppData\Local\Temp\ipykernel_19432\3279469147.py:31: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   marker4['time'] = marker4['time'] - midpoint
# 100%|██████████| 139/139 [00:50<00:00,  2.77it/s]
# 0_1_20_p0
# e:\FLESH_ContinuousBodilyEffort\TS_processing/Videos\0_1_20_p0.avi
#   0%|          | 0/232 [00:00<?, ?it/s]C:\Users\kadava\AppData\Local\Temp\ipykernel_19432\3279469147.py:28: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   marker1['Time'] = marker1['Time'] - midpoint
# C:\Users\kadava\AppData\Local\Temp\ipykernel_19432\3279469147.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   marker2['Time'] = marker2['Time'] - midpoint
# C:\Users\kadava\AppData\Local\Temp\ipykernel_19432\3279469147.py:30: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   marker3['time'] = marker3['time'] - midpoint
# C:\Users\kadava\AppData\Local\Temp\ipykernel_19432\3279469147.py:31: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   marker4['time'] = marker4['time'] - midpoint
# 100%|██████████| 232/232 [01:24<00:00,  2.74it/s]
# 0_1_21_p0
# e:\FLESH_ContinuousBodilyEffort\TS_processing/Videos\0_1_21_p0.avi
#   0%|          | 0/215 [00:00<?, ?it/s]C:\Users\kadava\AppData\Local\Temp\ipykernel_19432\3279469147.py:28: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   marker1['Time'] = marker1['Time'] - midpoint
# C:\Users\kadava\AppData\Local\Temp\ipykernel_19432\3279469147.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   marker2['Time'] = marker2['Time'] - midpoint
# C:\Users\kadava\AppData\Local\Temp\ipykernel_19432\3279469147.py:30: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   marker3['time'] = marker3['time'] - midpoint
# C:\Users\kadava\AppData\Local\Temp\ipykernel_19432\3279469147.py:31: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   marker4['time'] = marker4['time'] - midpoint
# 100%|██████████| 215/215 [01:13<00:00,  2.92it/s]
# 0_1_22_p0
# e:\FLESH_ContinuousBodilyEffort\TS_processing/Videos\0_1_22_p0.avi
#   0%|          | 0/274 [00:00<?, ?it/s]C:\Users\kadava\AppData\Local\Temp\ipykernel_19432\3279469147.py:28: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   marker1['Time'] = marker1['Time'] - midpoint
# C:\Users\kadava\AppData\Local\Temp\ipykernel_19432\3279469147.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   marker2['Time'] = marker2['Time'] - midpoint
# C:\Users\kadava\AppData\Local\Temp\ipykernel_19432\3279469147.py:30: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   marker3['time'] = marker3['time'] - midpoint
# C:\Users\kadava\AppData\Local\Temp\ipykernel_19432\3279469147.py:31: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   marker4['time'] = marker4['time'] - midpoint
# 100%|██████████| 274/274 [01:38<00:00,  2.77it/s]
# 0_1_23_p0
# e:\FLESH_ContinuousBodilyEffort\TS_processing/Videos\0_1_23_p0.avi
#   0%|          | 0/231 [00:00<?, ?it/s]C:\Users\kadava\AppData\Local\Temp\ipykernel_19432\3279469147.py:28: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   marker1['Time'] = marker1['Time'] - midpoint
# C:\Users\kadava\AppData\Local\Temp\ipykernel_19432\3279469147.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   marker2['Time'] = marker2['Time'] - midpoint
# C:\Users\kadava\AppData\Local\Temp\ipykernel_19432\3279469147.py:30: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   marker3['time'] = marker3['time'] - midpoint
# C:\Users\kadava\AppData\Local\Temp\ipykernel_19432\3279469147.py:31: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   marker4['time'] = marker4['time'] - midpoint
# 100%|██████████| 231/231 [01:23<00:00,  2.76it/s]
# 0_1_24_p0
# e:\FLESH_ContinuousBodilyEffort\TS_processing/Videos\0_1_24_p0.avi
#   0%|          | 0/342 [00:00<?, ?it/s]C:\Users\kadava\AppData\Local\Temp\ipykernel_19432\3279469147.py:28: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   marker1['Time'] = marker1['Time'] - midpoint
# C:\Users\kadava\AppData\Local\Temp\ipykernel_19432\3279469147.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   marker2['Time'] = marker2['Time'] - midpoint
# C:\Users\kadava\AppData\Local\Temp\ipykernel_19432\3279469147.py:30: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   marker3['time'] = marker3['time'] - midpoint
# C:\Users\kadava\AppData\Local\Temp\ipykernel_19432\3279469147.py:31: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   marker4['time'] = marker4['time'] - midpoint
# 100%|██████████| 342/342 [02:00<00:00,  2.84it/s]
# 0_1_25_p0
# e:\FLESH_ContinuousBodilyEffort\TS_processing/Videos\0_1_25_p0.avi
#   0%|          | 0/370 [00:00<?, ?it/s]C:\Users\kadava\AppData\Local\Temp\ipykernel_19432\3279469147.py:28: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   marker1['Time'] = marker1['Time'] - midpoint
# C:\Users\kadava\AppData\Local\Temp\ipykernel_19432\3279469147.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   marker2['Time'] = marker2['Time'] - midpoint
# C:\Users\kadava\AppData\Local\Temp\ipykernel_19432\3279469147.py:30: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   marker3['time'] = marker3['time'] - midpoint
# C:\Users\kadava\AppData\Local\Temp\ipykernel_19432\3279469147.py:31: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   marker4['time'] = marker4['time'] - midpoint
# 100%|██████████| 370/370 [02:18<00:00,  2.66it/s]
# 0_1_26_p0
# e:\FLESH_ContinuousBodilyEffort\TS_processing/Videos\0_1_26_p0.avi
#   0%|          | 0/249 [00:00<?, ?it/s]C:\Users\kadava\AppData\Local\Temp\ipykernel_19432\3279469147.py:28: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   marker1['Time'] = marker1['Time'] - midpoint
# C:\Users\kadava\AppData\Local\Temp\ipykernel_19432\3279469147.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   marker2['Time'] = marker2['Time'] - midpoint
# C:\Users\kadava\AppData\Local\Temp\ipykernel_19432\3279469147.py:30: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   marker3['time'] = marker3['time'] - midpoint
# C:\Users\kadava\AppData\Local\Temp\ipykernel_19432\3279469147.py:31: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   marker4['time'] = marker4['time'] - midpoint
# 100%|██████████| 249/249 [01:27<00:00,  2.84it/s]
# 0_1_2_p0
# e:\FLESH_ContinuousBodilyEffort\TS_processing/Videos\0_1_2_p0.avi
#   0%|          | 0/165 [00:00<?, ?it/s]C:\Users\kadava\AppData\Local\Temp\ipykernel_19432\3279469147.py:28: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   marker1['Time'] = marker1['Time'] - midpoint
# C:\Users\kadava\AppData\Local\Temp\ipykernel_19432\3279469147.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   marker2['Time'] = marker2['Time'] - midpoint
# C:\Users\kadava\AppData\Local\Temp\ipykernel_19432\3279469147.py:30: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   marker3['time'] = marker3['time'] - midpoint
# C:\Users\kadava\AppData\Local\Temp\ipykernel_19432\3279469147.py:31: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   marker4['time'] = marker4['time'] - midpoint
# 100%|██████████| 165/165 [01:04<00:00,  2.56it/s]
# 0_1_36_p0
# e:\FLESH_ContinuousBodilyEffort\TS_processing/Videos\0_1_36_p0.avi
#   0%|          | 0/295 [00:00<?, ?it/s]C:\Users\kadava\AppData\Local\Temp\ipykernel_19432\3279469147.py:28: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   marker1['Time'] = marker1['Time'] - midpoint
# C:\Users\kadava\AppData\Local\Temp\ipykernel_19432\3279469147.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   marker2['Time'] = marker2['Time'] - midpoint
# C:\Users\kadava\AppData\Local\Temp\ipykernel_19432\3279469147.py:30: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   marker3['time'] = marker3['time'] - midpoint
# C:\Users\kadava\AppData\Local\Temp\ipykernel_19432\3279469147.py:31: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   marker4['time'] = marker4['time'] - midpoint
# 100%|██████████| 295/295 [01:43<00:00,  2.85it/s]
# 0_1_37_p0
# e:\FLESH_ContinuousBodilyEffort\TS_processing/Videos\0_1_37_p0.avi
#   0%|          | 0/238 [00:00<?, ?it/s]C:\Users\kadava\AppData\Local\Temp\ipykernel_19432\3279469147.py:28: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   marker1['Time'] = marker1['Time'] - midpoint
# C:\Users\kadava\AppData\Local\Temp\ipykernel_19432\3279469147.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   marker2['Time'] = marker2['Time'] - midpoint
# C:\Users\kadava\AppData\Local\Temp\ipykernel_19432\3279469147.py:30: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   marker3['time'] = marker3['time'] - midpoint
# C:\Users\kadava\AppData\Local\Temp\ipykernel_19432\3279469147.py:31: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   marker4['time'] = marker4['time'] - midpoint
# 100%|██████████| 238/238 [01:22<00:00,  2.89it/s]
# 0_1_38_p0
# e:\FLESH_ContinuousBodilyEffort\TS_processing/Videos\0_1_38_p0.avi
#   0%|          | 0/322 [00:00<?, ?it/s]C:\Users\kadava\AppData\Local\Temp\ipykernel_19432\3279469147.py:28: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   marker1['Time'] = marker1['Time'] - midpoint
# C:\Users\kadava\AppData\Local\Temp\ipykernel_19432\3279469147.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   marker2['Time'] = marker2['Time'] - midpoint
# C:\Users\kadava\AppData\Local\Temp\ipykernel_19432\3279469147.py:30: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   marker3['time'] = marker3['time'] - midpoint
# C:\Users\kadava\AppData\Local\Temp\ipykernel_19432\3279469147.py:31: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   marker4['time'] = marker4['time'] - midpoint
# 100%|██████████| 322/322 [02:04<00:00,  2.59it/s]
# 0_1_39_p0
# e:\FLESH_ContinuousBodilyEffort\TS_processing/Videos\0_1_39_p0.avi
#   0%|          | 0/427 [00:00<?, ?it/s]C:\Users\kadava\AppData\Local\Temp\ipykernel_19432\3279469147.py:28: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   marker1['Time'] = marker1['Time'] - midpoint
# C:\Users\kadava\AppData\Local\Temp\ipykernel_19432\3279469147.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   marker2['Time'] = marker2['Time'] - midpoint
# C:\Users\kadava\AppData\Local\Temp\ipykernel_19432\3279469147.py:30: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   marker3['time'] = marker3['time'] - midpoint
# C:\Users\kadava\AppData\Local\Temp\ipykernel_19432\3279469147.py:31: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   marker4['time'] = marker4['time'] - midpoint
# 100%|██████████| 427/427 [02:32<00:00,  2.79it/s]
# 0_1_3_p0
# e:\FLESH_ContinuousBodilyEffort\TS_processing/Videos\0_1_3_p0.avi
#   0%|          | 0/533 [00:00<?, ?it/s]C:\Users\kadava\AppData\Local\Temp\ipykernel_19432\3279469147.py:28: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   marker1['Time'] = marker1['Time'] - midpoint
# C:\Users\kadava\AppData\Local\Temp\ipykernel_19432\3279469147.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   marker2['Time'] = marker2['Time'] - midpoint
# C:\Users\kadava\AppData\Local\Temp\ipykernel_19432\3279469147.py:30: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   marker3['time'] = marker3['time'] - midpoint
# C:\Users\kadava\AppData\Local\Temp\ipykernel_19432\3279469147.py:31: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   marker4['time'] = marker4['time'] - midpoint
# 100%|██████████| 533/533 [03:22<00:00,  2.64it/s]
# 0_1_40_p0
# e:\FLESH_ContinuousBodilyEffort\TS_processing/Videos\0_1_40_p0.avi
#   0%|          | 0/182 [00:00<?, ?it/s]C:\Users\kadava\AppData\Local\Temp\ipykernel_19432\3279469147.py:28: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   marker1['Time'] = marker1['Time'] - midpoint
# C:\Users\kadava\AppData\Local\Temp\ipykernel_19432\3279469147.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   marker2['Time'] = marker2['Time'] - midpoint
# C:\Users\kadava\AppData\Local\Temp\ipykernel_19432\3279469147.py:30: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   marker3['time'] = marker3['time'] - midpoint
# C:\Users\kadava\AppData\Local\Temp\ipykernel_19432\3279469147.py:31: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   marker4['time'] = marker4['time'] - midpoint
# 100%|██████████| 182/182 [01:02<00:00,  2.91it/s]
# 0_1_41_p0
# e:\FLESH_ContinuousBodilyEffort\TS_processing/Videos\0_1_41_p0.avi
#   0%|          | 0/364 [00:00<?, ?it/s]C:\Users\kadava\AppData\Local\Temp\ipykernel_19432\3279469147.py:28: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   marker1['Time'] = marker1['Time'] - midpoint
# C:\Users\kadava\AppData\Local\Temp\ipykernel_19432\3279469147.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   marker2['Time'] = marker2['Time'] - midpoint
# C:\Users\kadava\AppData\Local\Temp\ipykernel_19432\3279469147.py:30: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   marker3['time'] = marker3['time'] - midpoint
# C:\Users\kadava\AppData\Local\Temp\ipykernel_19432\3279469147.py:31: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   marker4['time'] = marker4['time'] - midpoint
# 100%|██████████| 364/364 [02:06<00:00,  2.88it/s]
# 0_1_42_p0
# e:\FLESH_ContinuousBodilyEffort\TS_processing/Videos\0_1_42_p0.avi
#   0%|          | 0/265 [00:00<?, ?it/s]C:\Users\kadava\AppData\Local\Temp\ipykernel_19432\3279469147.py:28: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   marker1['Time'] = marker1['Time'] - midpoint
# C:\Users\kadava\AppData\Local\Temp\ipykernel_19432\3279469147.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   marker2['Time'] = marker2['Time'] - midpoint
# C:\Users\kadava\AppData\Local\Temp\ipykernel_19432\3279469147.py:30: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   marker3['time'] = marker3['time'] - midpoint
# C:\Users\kadava\AppData\Local\Temp\ipykernel_19432\3279469147.py:31: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   marker4['time'] = marker4['time'] - midpoint
# 100%|██████████| 265/265 [02:00<00:00,  2.20it/s]
# 0_1_43_p0
# e:\FLESH_ContinuousBodilyEffort\TS_processing/Videos\0_1_43_p0.avi
#   0%|          | 0/253 [00:00<?, ?it/s]C:\Users\kadava\AppData\Local\Temp\ipykernel_19432\3279469147.py:28: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   marker1['Time'] = marker1['Time'] - midpoint
# C:\Users\kadava\AppData\Local\Temp\ipykernel_19432\3279469147.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   marker2['Time'] = marker2['Time'] - midpoint
# C:\Users\kadava\AppData\Local\Temp\ipykernel_19432\3279469147.py:30: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   marker3['time'] = marker3['time'] - midpoint
# C:\Users\kadava\AppData\Local\Temp\ipykernel_19432\3279469147.py:31: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   marker4['time'] = marker4['time'] - midpoint
# 100%|██████████| 253/253 [01:30<00:00,  2.80it/s]
# 0_1_44_p0
# e:\FLESH_ContinuousBodilyEffort\TS_processing/Videos\0_1_44_p0.avi
#   0%|          | 0/333 [00:00<?, ?it/s]C:\Users\kadava\AppData\Local\Temp\ipykernel_19432\3279469147.py:28: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   marker1['Time'] = marker1['Time'] - midpoint
# C:\Users\kadava\AppData\Local\Temp\ipykernel_19432\3279469147.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   marker2['Time'] = marker2['Time'] - midpoint
# C:\Users\kadava\AppData\Local\Temp\ipykernel_19432\3279469147.py:30: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   marker3['time'] = marker3['time'] - midpoint
# C:\Users\kadava\AppData\Local\Temp\ipykernel_19432\3279469147.py:31: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   marker4['time'] = marker4['time'] - midpoint
# 100%|██████████| 333/333 [01:59<00:00,  2.79it/s]
# 0_1_4_p0
# e:\FLESH_ContinuousBodilyEffort\TS_processing/Videos\0_1_4_p0.avi
#   0%|          | 0/276 [00:00<?, ?it/s]C:\Users\kadava\AppData\Local\Temp\ipykernel_19432\3279469147.py:28: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   marker1['Time'] = marker1['Time'] - midpoint
# C:\Users\kadava\AppData\Local\Temp\ipykernel_19432\3279469147.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   marker2['Time'] = marker2['Time'] - midpoint
# C:\Users\kadava\AppData\Local\Temp\ipykernel_19432\3279469147.py:30: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   marker3['time'] = marker3['time'] - midpoint
# C:\Users\kadava\AppData\Local\Temp\ipykernel_19432\3279469147.py:31: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   marker4['time'] = marker4['time'] - midpoint
# 100%|██████████| 276/276 [01:37<00:00,  2.83it/s]
# 0_1_5_p0
# e:\FLESH_ContinuousBodilyEffort\TS_processing/Videos\0_1_5_p0.avi
#   0%|          | 0/175 [00:00<?, ?it/s]C:\Users\kadava\AppData\Local\Temp\ipykernel_19432\3279469147.py:28: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   marker1['Time'] = marker1['Time'] - midpoint
# C:\Users\kadava\AppData\Local\Temp\ipykernel_19432\3279469147.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   marker2['Time'] = marker2['Time'] - midpoint
# C:\Users\kadava\AppData\Local\Temp\ipykernel_19432\3279469147.py:30: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   marker3['time'] = marker3['time'] - midpoint
# C:\Users\kadava\AppData\Local\Temp\ipykernel_19432\3279469147.py:31: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   marker4['time'] = marker4['time'] - midpoint
# 100%|██████████| 175/175 [01:01<00:00,  2.84it/s]
# 0_1_6_p0
# e:\FLESH_ContinuousBodilyEffort\TS_processing/Videos\0_1_6_p0.avi
#   0%|          | 0/223 [00:00<?, ?it/s]C:\Users\kadava\AppData\Local\Temp\ipykernel_19432\3279469147.py:28: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   marker1['Time'] = marker1['Time'] - midpoint
# C:\Users\kadava\AppData\Local\Temp\ipykernel_19432\3279469147.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   marker2['Time'] = marker2['Time'] - midpoint
# C:\Users\kadava\AppData\Local\Temp\ipykernel_19432\3279469147.py:30: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   marker3['time'] = marker3['time'] - midpoint
# C:\Users\kadava\AppData\Local\Temp\ipykernel_19432\3279469147.py:31: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   marker4['time'] = marker4['time'] - midpoint
# 100%|██████████| 223/223 [02:15<00:00,  1.65it/s]
# 0_1_7_p0
# e:\FLESH_ContinuousBodilyEffort\TS_processing/Videos\0_1_7_p0.avi
#   0%|          | 0/226 [00:00<?, ?it/s]C:\Users\kadava\AppData\Local\Temp\ipykernel_19432\3279469147.py:28: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   marker1['Time'] = marker1['Time'] - midpoint
# C:\Users\kadava\AppData\Local\Temp\ipykernel_19432\3279469147.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   marker2['Time'] = marker2['Time'] - midpoint
# C:\Users\kadava\AppData\Local\Temp\ipykernel_19432\3279469147.py:30: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   marker3['time'] = marker3['time'] - midpoint
# C:\Users\kadava\AppData\Local\Temp\ipykernel_19432\3279469147.py:31: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   marker4['time'] = marker4['time'] - midpoint
# 100%|██████████| 226/226 [01:19<00:00,  2.84it/s]
# 0_1_8_p0
# e:\FLESH_ContinuousBodilyEffort\TS_processing/Videos\0_1_8_p0.avi
#   0%|          | 0/170 [00:00<?, ?it/s]C:\Users\kadava\AppData\Local\Temp\ipykernel_19432\3279469147.py:28: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   marker1['Time'] = marker1['Time'] - midpoint
# C:\Users\kadava\AppData\Local\Temp\ipykernel_19432\3279469147.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   marker2['Time'] = marker2['Time'] - midpoint
# C:\Users\kadava\AppData\Local\Temp\ipykernel_19432\3279469147.py:30: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   marker3['time'] = marker3['time'] - midpoint
# C:\Users\kadava\AppData\Local\Temp\ipykernel_19432\3279469147.py:31: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# ...
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   marker3['time'] = marker3['time'] - midpoint
# C:\Users\kadava\AppData\Local\Temp\ipykernel_19432\3279469147.py:31: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   marker4['time'] = marker4['time'] - midpoint
# 100%|██████████| 226/226 [01:18<00:00,  2.88it/s]
# 0_1_31_p1
# e:\FLESH_ContinuousBodilyEffort\TS_processing/Videos\0_1_31_p1.avi
#   0%|          | 0/230 [00:00<?, ?it/s]C:\Users\kadava\AppData\Local\Temp\ipykernel_19432\3279469147.py:28: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   marker1['Time'] = marker1['Time'] - midpoint
# C:\Users\kadava\AppData\Local\Temp\ipykernel_19432\3279469147.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   marker2['Time'] = marker2['Time'] - midpoint
# C:\Users\kadava\AppData\Local\Temp\ipykernel_19432\3279469147.py:30: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   marker3['time'] = marker3['time'] - midpoint
# C:\Users\kadava\AppData\Local\Temp\ipykernel_19432\3279469147.py:31: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   marker4['time'] = marker4['time'] - midpoint
# 100%|██████████| 230/230 [06:17<00:00,  1.64s/it]
# 0_1_32_p1
# e:\FLESH_ContinuousBodilyEffort\TS_processing/Videos\0_1_32_p1.avi
#   0%|          | 0/299 [00:00<?, ?it/s]C:\Users\kadava\AppData\Local\Temp\ipykernel_19432\3279469147.py:28: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   marker1['Time'] = marker1['Time'] - midpoint
# C:\Users\kadava\AppData\Local\Temp\ipykernel_19432\3279469147.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   marker2['Time'] = marker2['Time'] - midpoint
# C:\Users\kadava\AppData\Local\Temp\ipykernel_19432\3279469147.py:30: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   marker3['time'] = marker3['time'] - midpoint
# C:\Users\kadava\AppData\Local\Temp\ipykernel_19432\3279469147.py:31: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   marker4['time'] = marker4['time'] - midpoint
# 100%|██████████| 299/299 [01:46<00:00,  2.81it/s]
# 0_1_33_p1
# e:\FLESH_ContinuousBodilyEffort\TS_processing/Videos\0_1_33_p1.avi
#   0%|          | 0/333 [00:00<?, ?it/s]C:\Users\kadava\AppData\Local\Temp\ipykernel_19432\3279469147.py:28: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   marker1['Time'] = marker1['Time'] - midpoint
# C:\Users\kadava\AppData\Local\Temp\ipykernel_19432\3279469147.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   marker2['Time'] = marker2['Time'] - midpoint
# C:\Users\kadava\AppData\Local\Temp\ipykernel_19432\3279469147.py:30: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   marker3['time'] = marker3['time'] - midpoint
# C:\Users\kadava\AppData\Local\Temp\ipykernel_19432\3279469147.py:31: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   marker4['time'] = marker4['time'] - midpoint
# 100%|██████████| 333/333 [01:58<00:00,  2.81it/s]
# 0_1_35_p1
# e:\FLESH_ContinuousBodilyEffort\TS_processing/Videos\0_1_35_p1.avi
#   0%|          | 0/310 [00:00<?, ?it/s]C:\Users\kadava\AppData\Local\Temp\ipykernel_19432\3279469147.py:28: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   marker1['Time'] = marker1['Time'] - midpoint
# C:\Users\kadava\AppData\Local\Temp\ipykernel_19432\3279469147.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   marker2['Time'] = marker2['Time'] - midpoint
# C:\Users\kadava\AppData\Local\Temp\ipykernel_19432\3279469147.py:30: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   marker3['time'] = marker3['time'] - midpoint
# C:\Users\kadava\AppData\Local\Temp\ipykernel_19432\3279469147.py:31: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   marker4['time'] = marker4['time'] - midpoint
# 100%|██████████| 310/310 [01:52<00:00,  2.75it/s]
# 0_1_45_p1
# e:\FLESH_ContinuousBodilyEffort\TS_processing/Videos\0_1_45_p1.avi
#   0%|          | 0/261 [00:00<?, ?it/s]C:\Users\kadava\AppData\Local\Temp\ipykernel_19432\3279469147.py:28: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   marker1['Time'] = marker1['Time'] - midpoint
# C:\Users\kadava\AppData\Local\Temp\ipykernel_19432\3279469147.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   marker2['Time'] = marker2['Time'] - midpoint
# C:\Users\kadava\AppData\Local\Temp\ipykernel_19432\3279469147.py:30: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   marker3['time'] = marker3['time'] - midpoint
# C:\Users\kadava\AppData\Local\Temp\ipykernel_19432\3279469147.py:31: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   marker4['time'] = marker4['time'] - midpoint
# 100%|██████████| 261/261 [01:32<00:00,  2.82it/s]
# 0_1_46_p1
# e:\FLESH_ContinuousBodilyEffort\TS_processing/Videos\0_1_46_p1.avi
#   0%|          | 0/339 [00:00<?, ?it/s]C:\Users\kadava\AppData\Local\Temp\ipykernel_19432\3279469147.py:28: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   marker1['Time'] = marker1['Time'] - midpoint
# C:\Users\kadava\AppData\Local\Temp\ipykernel_19432\3279469147.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   marker2['Time'] = marker2['Time'] - midpoint
# C:\Users\kadava\AppData\Local\Temp\ipykernel_19432\3279469147.py:30: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   marker3['time'] = marker3['time'] - midpoint
# C:\Users\kadava\AppData\Local\Temp\ipykernel_19432\3279469147.py:31: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   marker4['time'] = marker4['time'] - midpoint
# 100%|██████████| 339/339 [01:59<00:00,  2.83it/s]
# 0_1_47_p1
# e:\FLESH_ContinuousBodilyEffort\TS_processing/Videos\0_1_47_p1.avi
#   0%|          | 0/350 [00:00<?, ?it/s]C:\Users\kadava\AppData\Local\Temp\ipykernel_19432\3279469147.py:28: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   marker1['Time'] = marker1['Time'] - midpoint
# C:\Users\kadava\AppData\Local\Temp\ipykernel_19432\3279469147.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   marker2['Time'] = marker2['Time'] - midpoint
# C:\Users\kadava\AppData\Local\Temp\ipykernel_19432\3279469147.py:30: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   marker3['time'] = marker3['time'] - midpoint
# C:\Users\kadava\AppData\Local\Temp\ipykernel_19432\3279469147.py:31: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   marker4['time'] = marker4['time'] - midpoint
# 100%|██████████| 350/350 [02:03<00:00,  2.83it/s]
# 0_1_48_p1
# e:\FLESH_ContinuousBodilyEffort\TS_processing/Videos\0_1_48_p1.avi
#   0%|          | 0/353 [00:00<?, ?it/s]C:\Users\kadava\AppData\Local\Temp\ipykernel_19432\3279469147.py:28: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   marker1['Time'] = marker1['Time'] - midpoint
# C:\Users\kadava\AppData\Local\Temp\ipykernel_19432\3279469147.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   marker2['Time'] = marker2['Time'] - midpoint
# C:\Users\kadava\AppData\Local\Temp\ipykernel_19432\3279469147.py:30: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   marker3['time'] = marker3['time'] - midpoint
# C:\Users\kadava\AppData\Local\Temp\ipykernel_19432\3279469147.py:31: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   marker4['time'] = marker4['time'] - midpoint
#  52%|█████▏    | 185/353 [01:05<00:59,  2.82it/s]
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# Cell In[13], line 86
#      84 ret, frame = capture.read()
#      85 if ret == True:
# ---> 86     img = plot_kinematics(mt, maxbody, minbody, mt, maxspeed, minspeed, ik, maxangvel, minangvel, id, maxelb, minelb, frame_number/fps)
#      87     # resize the image
#      88     img = cv2.resize(img, (int(frameWidth*3), int(frameHeight)))
#
# Cell In[9], line 88, in plot_kinematics(marker1, maxmarker1, minmarker1, marker2, maxmarker2, minmarker2, marker3, maxmarker3, minmarker3, marker4, maxmarker4, minmarker4, midpoint)
#      86 plt.savefig(tpf )
#      87 plt.close()
# ---> 88 img = cv2.imread(tpf)
#      89 shutil.rmtree(tempfolder)
#      90 return img
#
# error: OpenCV(4.10.0) D:\a\opencv-python\opencv-python\opencv\modules\core\src\alloc.cpp:73: error: (-4:Insufficient memory) Failed to allocate 4200000 bytes in function 'cv::OutOfMemoryError'
