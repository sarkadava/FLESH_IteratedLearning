# %% [markdown]
# # STATISTICS

# %%
import os
import glob
import pandas as pd
import numpy as np
import math
#import pyentrp


#import antropy as ant
#import pyentrp

#from pyentrp import entropy as ent

import scipy
import matplotlib.pyplot as plt
import matplotlib.pyplot as plt

import math

import xml.etree.ElementTree as ET

import seaborn as sns
import seaborn.objects as so

curfolder = os.getcwd()
print(curfolder)

flesh_folder = os.path.dirname(curfolder)
features = flesh_folder + '/Feature_Extraction_folder/feature_extraction_with2d.csv'

#features = curfolder + '/feature_extraction_with2d.csv'
features = pd.read_csv(features)
# Out:
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/StatisticsFolder

# %% [markdown]
# # Normalize all the feature data

# %%
from sklearn.preprocessing import StandardScaler
normed_features = features.copy()
normed_features = normed_features.replace([np.inf, -np.inf], 0)
normed_features
normed_features[normed_features.columns[32:]] = StandardScaler().fit_transform(normed_features[normed_features.columns[32:]])

# %% [markdown]
# # SeaBorn Plots

# %%
import seaborn as sns
import seaborn.objects as so
sns.scatterplot(data=normed_features, x="generation_number", y="total_gesture_space2D", hue="gesture")
# Out:
# <Axes: xlabel='generation_number', ylabel='total_gesture_space2D'>

# %% [markdown]
# # UMAP

# %%
import umap
reducer = umap.UMAP()

# %%
# THIS IS JUST TO ADDRESS THE KALT G0 ISSUE. IT MUST GO LATER ON
normed_features[normed_features.columns[32:]] = normed_features[normed_features.columns[32:]].fillna(0)

# %%
# create embeddings
embedding = reducer.fit_transform(normed_features[normed_features.columns[32:]])
embedding.shape
embeddings = pd.DataFrame(embedding)
features["X_embeddings"] = embeddings.iloc[:, 0]
features["Y_embeddings"] = embeddings.iloc[:, 1]
normed_features["X_embeddings"] = embeddings.iloc[:, 0]
normed_features["Y_embeddings"] = embeddings.iloc[:, 1]
# Out:
# /opt/anaconda3/envs/umap_env/lib/python3.11/site-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(

# %%
plt.scatter(
    embedding[:, 0],
    embedding[:, 1],
plt.gca().set_aspect('equal', 'datalim'))

# %% [markdown]
# Graph a specific gesture and its embeddings:

# %%
# graph a specific gesture and its differen't chains
specific = normed_features[normed_features['gesture'] == 'Donner']
sns.scatterplot(data=specific, x="X_embeddings", y="Y_embeddings", hue="gesture_chain")
# Out:
# <Axes: xlabel='X_embeddings', ylabel='Y_embeddings'>

# %% [markdown]
# graph all gestures and their embeddings:

# %%
sns.scatterplot(data=normed_features, x="X_embeddings", y="Y_embeddings", hue="gesture")
# Out:
# <Axes: xlabel='X_embeddings', ylabel='Y_embeddings'>

# %% [markdown]
# # Set g0 for ch2 and 3

# %%
fix_row = normed_features[normed_features['fileID'] == "leise_g_ch1_g0_compr.mp4"].copy()
fix_row["fileID"] = "leise_g_ch2_g0_compr.mp4"
fix_row["chainID"] = "ch2g0"
fix_row["chain_number"] = 2
fix_row["gesture_chain"] = 'leise_g_ch2'
normed_features = pd.concat([normed_features, fix_row], ignore_index=True)
#normed_features.loc[len(normed_features)]

fix_row = normed_features[normed_features['fileID'] == "leise_g_ch1_g0_compr.mp4"].copy()
fix_row["fileID"] = "leise_g_ch3_g0_compr.mp4"
fix_row["chainID"] = "ch3g0"
fix_row["chain_number"] = 3
fix_row["gesture_chain"] = 'leise_g_ch3'
normed_features = pd.concat([normed_features, fix_row], ignore_index=True)

fix_row = normed_features[normed_features['fileID'] == "langsam_g_ch1_g0_compr.mp4"].copy()
fix_row["fileID"] = "langsam_g_ch2_g0_compr.mp4"
fix_row["chainID"] = "ch2g0"
fix_row["chain_number"] = 2
fix_row["gesture_chain"] = 'langsam_g_ch2'
normed_features = pd.concat([normed_features, fix_row], ignore_index=True)

fix_row = normed_features[normed_features['fileID'] == "langsam_g_ch1_g0_compr.mp4"].copy()
fix_row["fileID"] = "langsam_g_ch3_g0_compr.mp4"
fix_row["chainID"] = "ch3g0"
fix_row["chain_number"] = 3
fix_row["gesture_chain"] = 'langsam_g_ch3'
normed_features = pd.concat([normed_features, fix_row], ignore_index=True)

fix_row = normed_features[normed_features['fileID'] == "rennen_g_ch1_g0_compr.mp4"].copy()
fix_row["fileID"] = "rennen_g_ch2_g0_compr.mp4"
fix_row["chainID"] = "ch2g0"
fix_row["chain_number"] = 2
fix_row["gesture_chain"] = 'rennen_g_ch2'
normed_features = pd.concat([normed_features, fix_row], ignore_index=True)

fix_row = normed_features[normed_features['fileID'] == "rennen_g_ch1_g0_compr.mp4"].copy()
fix_row["fileID"] = "rennen_g_ch3_g0_compr.mp4"
fix_row["chainID"] = "ch3g0"
fix_row["chain_number"] = 3
fix_row["gesture_chain"] = 'rennen_g_ch3'
normed_features = pd.concat([normed_features, fix_row], ignore_index=True)

fix_row = normed_features[normed_features['fileID'] == "Donner_g_ch1_g0_compr.mp4"].copy()
fix_row["fileID"] = "Donner_g_ch2_g0_compr.mp4"
fix_row["chainID"] = "ch2g0"
fix_row["chain_number"] = 2
fix_row["gesture_chain"] = 'Donner_g_ch2'
normed_features = pd.concat([normed_features, fix_row], ignore_index=True)

fix_row = normed_features[normed_features['fileID'] == "Donner_g_ch1_g0_compr.mp4"].copy()
fix_row["fileID"] = "Donner_g_ch3_g0_compr.mp4"
fix_row["chainID"] = "ch3g0"
fix_row["chain_number"] = 2
fix_row["gesture_chain"] = 'Donner_g_ch3'
normed_features = pd.concat([normed_features, fix_row], ignore_index=True)

fix_row = normed_features[normed_features['fileID'] == "kalt_g_ch1_g0_compr.mp4"].copy()
fix_row["fileID"] = "kalt_g_ch2_g0_compr.mp4"
fix_row["chainID"] = "ch2g0"
fix_row["chain_number"] = 2
fix_row["gesture_chain"] = 'kalt_g_ch2'
normed_features = pd.concat([normed_features, fix_row], ignore_index=True)

fix_row = normed_features[normed_features['fileID'] == "kalt_g_ch1_g0_compr.mp4"].copy()
fix_row["fileID"] = "kalt_g_ch3_g0_compr.mp4"
fix_row["chainID"] = "ch3g0"
fix_row["chain_number"] = 2
fix_row["gesture_chain"] = 'kalt_g_ch3'
normed_features = pd.concat([normed_features, fix_row], ignore_index=True)

# %%
normed_features
# Out:
#      participantID   Age    BirthPlace            Gender NativeLanguages  \
# 0               52  21.0        Berlin    Man / Männlich         Deutsch
# 1               23  35.0  Deutschland   Woman / Weiblich        Deutsch
# 2                0   NaN           NaN               NaN             NaN
# 3               16  27.0   Deutschland    Man / Männlich        Deutsch
# 4               30  45.0       Dresden  Woman / Weiblich         Deutsch
# ..             ...   ...           ...               ...             ...
# 308              0   NaN           NaN               NaN             NaN
# 309              0   NaN           NaN               NaN             NaN
# 310              0   NaN           NaN               NaN             NaN
# 311              0   NaN           NaN               NaN             NaN
# 312              0   NaN           NaN               NaN             NaN
#
#      NumOfNativeLanguages                                    Other Languages  \
# 0                     1.0      Englisch- sehr gut, Italienisch - grundlegend
# 1                     1.0  English (fluent), French (advanced), Italian (...
# 2                     NaN                                                NaN
# 3                     1.0                                            English
# 4                     1.0                                           Englisch
# ..                    ...                                                ...
# 308                   NaN                                                NaN
# 309                   NaN                                                NaN
# 310                   NaN                                                NaN
# 311                   NaN                                                NaN
# 312                   NaN                                                NaN
#
#      TotalLanguages  Extroversion                            Hand  ...  \
# 0               3.0          53.0  Right-handed / Rechtshänder*in  ...
# 1               4.0          43.0  Right-handed / Rechtshänder*in  ...
# 2               NaN           NaN                             NaN  ...
# 3               2.0          30.0  Right-handed / Rechtshänder*in  ...
# 4               2.0          51.0  Right-handed / Rechtshänder*in  ...
# ..              ...           ...                             ...  ...
# 308             NaN           NaN                             NaN  ...
# 309             NaN           NaN                             NaN  ...
# 310             NaN           NaN                             NaN  ...
# 311             NaN           NaN                             NaN  ...
# 312             NaN           NaN                             NaN  ...
#
#     right_knee_entropy2D left_knee_entropy2D  right_ankle_entropy2D  \
# 0               0.897487            0.865501               0.676895
# 1               0.836842            0.726559               0.722606
# 2              -1.190243           -1.191379              -1.191595
# 3               0.947593            0.660366               1.020308
# 4               0.634586            0.563262               0.749603
# ..                   ...                 ...                    ...
# 308             0.928139            0.848104               1.038584
# 309             0.961436            0.792356               1.069855
# 310             0.961436            0.792356               1.069855
# 311            -1.190243           -1.191379              -1.191595
# 312            -1.190243           -1.191379              -1.191595
#
#      left_ankle_entropy2D total_body_entropy2D right_wrist_variability2D  \
# 0                0.549502             0.774978                 -0.273554
# 1                0.514650             0.599787                  1.541944
# 2               -1.191335            -0.943956                  0.121890
# 3                1.026474             0.921748                  0.055815
# 4                0.647490             0.505570                  0.920212
# ..                    ...                  ...                       ...
# 308              0.979449             1.088923                 -0.741788
# 309              0.796514             0.986017                 -0.735528
# 310              0.796514             0.986017                 -0.735528
# 311             -1.191335            -0.943956                  0.121890
# 312             -1.191335            -0.943956                  0.121890
#
#      left_wrist_variability2D  total_body_variability2D  X_embeddings  \
# 0                   -0.047810                 -0.198938     -4.431239
# 1                    1.062462                  1.599221     -2.315073
# 2                   -0.785199                 -0.397381     16.057255
# 3                   -0.038724                  0.011376     -3.158298
# 4                    0.311214                  0.759835     -2.677363
# ..                        ...                       ...           ...
# 308                 -0.670805                 -0.865573     -3.890631
# 309                 -0.418067                 -0.709372     -3.160261
# 310                 -0.418067                 -0.709372     -3.160261
# 311                 -0.785199                 -0.397381     16.057255
# 312                 -0.785199                 -0.397381     16.057255
#
#      Y_embeddings
# 0        0.259631
# 1        3.242649
# 2        5.577348
# 3        0.649270
# 4        0.733918
# ..            ...
# 308      3.642599
# 309      3.855260
# 310      3.855260
# 311      5.577348
# 312      5.577348
#
# [313 rows x 47 columns]

# %% [markdown]
# # Save Normed Features Dataframe with Embeddings

# %%
globals()["normed_features"] = normed_features
globals()["normed_features"].to_csv(os.path.join(curfolder, f'{"normed_features"}.csv'), index=False)

# %% [markdown]
# # Euclidean Distances

# %% [markdown]
# Comparing Two Vectors

# %%
# make sure to put normalized vectors into this function. 
def calculate_distances(feature_vector1, feature_vector2):
    squared_diff =np.square(feature_vector1-feature_vector2)
    sum_squared_diff = np.sum(squared_diff)
    eucl_distance = math.sqrt(sum_squared_diff)
    return eucl_distance

# feed in the dataframe that contains just the vector of features.
def calculate_distances_to_all(target_segment_index, array):
    target_segment = array[target_segment_index]
    distances = np.empty(array.shape[0])
    i = 0
    for row in array:
        distances[i] = calculate_distances(target_segment, row)
        i = i+1
    return distances

# %% [markdown]
# Comparing all vectors to each other and saving in a dataframe

# %%
interseg_dist = np.empty(normed_features[normed_features.columns[32:60]].shape)
interseg_dist = pd.DataFrame(interseg_dist)
interseg_dist = pd.DataFrame()
#make individual id for each segment
df_of_vectors = normed_features[normed_features.columns[32:60]].copy()
df_of_vectors = df_of_vectors.to_numpy()


# calculate distance between each segment
for i in range (normed_features[normed_features.columns[32:60]].shape[0]):
    id = normed_features.loc[i, 'fileID']
    interseg_dist_vector = calculate_distances_to_all(i, df_of_vectors)
    #interseg_dist_vector = interseg_dist_vector.reshape(1, -1)
    interseg_dist = interseg_dist.rename(index={i: id})
    interseg_dist = interseg_dist.rename(columns={i: id})
    interseg_dist[id] = interseg_dist_vector
    index = interseg_dist.index

# IS THIS FINE? 
interseg_dist.to_csv('interseg_dist.csv', index=True)

# %% [markdown]
# # Open the Distance Folder and Do Statistics

# %%
interseg_dist = pd.read_csv(os.path.join(curfolder, 'interseg_dist.csv')).set_index('Unnamed: 0')
normed_features = pd.read_csv(os.path.join(curfolder, 'normed_features.csv'))

# %% [markdown]
# ## How does the efficiency measure of gesture space change over the a chain?

# %% [markdown]
# Donner:

# %%
sns.scatterplot(data=normed_features[normed_features["gesture"] == 'Donner'], x="generation_number", y="total_gesture_space2D", hue = 'gesture_chain')
# Out:
# <Axes: xlabel='generation_number', ylabel='total_gesture_space2D'>

# %%
sns.regplot(data=normed_features[normed_features["gesture_chain"] == 'Donner_g_ch3'], x="generation_number", y="total_gesture_space2D", order =1)
# Out:
# <Axes: xlabel='generation_number', ylabel='total_gesture_space2D'>

# %% [markdown]
# Leise:

# %%
sns.regplot(data=normed_features[normed_features["gesture_chain"] == 'kalt_g_ch3'], x="generation_number", y="total_gesture_space2D", order =1)
# Out:
# <Axes: xlabel='generation_number', ylabel='total_gesture_space2D'>

# %%
sns.lineplot(data=normed_features[normed_features["gesture_chain"] == 'kalt_g_ch3'], x="generation_number", y="total_gesture_space2D", hue = 'gesture_chain')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 sns.lineplot(data=normed_features[normed_features["gesture_chain"] == 'kalt_g_ch3'], x="generation_number", y="total_gesture_space2D", hue = 'gesture_chain')
#
# File c:\ProgramData\anaconda3\Lib\site-packages\seaborn\relational.py:645, in lineplot(data, x, y, hue, size, style, units, palette, hue_order, hue_norm, sizes, size_order, size_norm, dashes, markers, style_order, estimator, errorbar, n_boot, seed, orient, sort, err_style, err_kws, legend, ci, ax, **kwargs)
#     642 color = kwargs.pop("color", kwargs.pop("c", None))
#     643 kwargs["color"] = _default_color(ax.plot, hue, color, kwargs)
# --> 645 p.plot(ax, kwargs)
#     646 return ax
#
# File c:\ProgramData\anaconda3\Lib\site-packages\seaborn\relational.py:489, in _LinePlotter.plot(self, ax, kws)
#     486 if self.err_style == "band":
#     488     func = {"x": ax.fill_between, "y": ax.fill_betweenx}[orient]
# --> 489     func(
#     490         sub_data[orient],
#     491         sub_data[f"{other}min"], sub_data[f"{other}max"],
#     492         color=line_color, **err_kws
#     493     )
#     495 elif self.err_style == "bars":
#     497     error_param = {
#     498         f"{other}err": (
#     499             sub_data[other] - sub_data[f"{other}min"],
#     500             sub_data[f"{other}max"] - sub_data[other],
#     501         )
#     502     }
#
# File c:\ProgramData\anaconda3\Lib\site-packages\matplotlib\__init__.py:1446, in _preprocess_data.<locals>.inner(ax, data, *args, **kwargs)
#    1443 @functools.wraps(func)
#    1444 def inner(ax, *args, data=None, **kwargs):
#    1445     if data is None:
# -> 1446         return func(ax, *map(sanitize_sequence, args), **kwargs)
#    1448     bound = new_sig.bind(ax, *args, **kwargs)
#    1449     auto_label = (bound.arguments.get(label_namer)
#    1450                   or bound.kwargs.get(label_namer))
#
# File c:\ProgramData\anaconda3\Lib\site-packages\matplotlib\axes\_axes.py:5425, in Axes.fill_between(self, x, y1, y2, where, interpolate, step, **kwargs)
#    5423 def fill_between(self, x, y1, y2=0, where=None, interpolate=False,
#    5424                  step=None, **kwargs):
# -> 5425     return self._fill_between_x_or_y(
#    5426         "x", x, y1, y2,
#    5427         where=where, interpolate=interpolate, step=step, **kwargs)
#
# File c:\ProgramData\anaconda3\Lib\site-packages\matplotlib\axes\_axes.py:5330, in Axes._fill_between_x_or_y(self, ind_dir, ind, dep1, dep2, where, interpolate, step, **kwargs)
#    5326         kwargs["facecolor"] = \
#    5327             self._get_patches_for_fill.get_next_color()
#    5329 # Handle united data, such as dates
# -> 5330 ind, dep1, dep2 = map(
#    5331     ma.masked_invalid, self._process_unit_info(
#    5332         [(ind_dir, ind), (dep_dir, dep1), (dep_dir, dep2)], kwargs))
#    5334 for name, array in [
#    5335         (ind_dir, ind), (f"{dep_dir}1", dep1), (f"{dep_dir}2", dep2)]:
#    5336     if array.ndim > 1:
#
# File ~\AppData\Roaming\Python\Python311\site-packages\numpy\ma\core.py:2360, in masked_invalid(a, copy)
#    2332 def masked_invalid(a, copy=True):
#    2333     """
#    2334     Mask an array where invalid values occur (NaNs or infs).
#    2335
#    (...)
#    2357
#    2358     """
# -> 2360     return masked_where(~(np.isfinite(getdata(a))), a, copy=copy)
#
# TypeError: ufunc 'isfinite' not supported for the input types, and the inputs could not be safely coerced to any supported types according to the casting rule ''safe''

# %%
sns.scatterplot(data=normed_features[normed_features["gesture"] == 'leise'], x="generation_number", y="total_gesture_space2D", hue = 'gesture_chain')
# Out:
# <Axes: xlabel='generation_number', ylabel='total_gesture_space2D'>

# %% [markdown]
# kalt

# %%
sns.scatterplot(data=normed_features[normed_features["gesture"] == 'kalt'], x="generation_number", y="total_gesture_space2D", hue = 'gesture_chain')
# Out:
# <Axes: xlabel='generation_number', ylabel='total_gesture_space2D'>

# %% [markdown]
# langsam:

# %%
sns.scatterplot(data=normed_features[normed_features["gesture"] == 'langsam'], x="generation_number", y="total_gesture_space2D", hue = 'gesture_chain')
# Out:
# <Axes: xlabel='generation_number', ylabel='total_gesture_space2D'>

# %% [markdown]
# rennen:

# %%
sns.scatterplot(data=normed_features[normed_features["gesture"] == 'rennen'], x="generation_number", y="total_gesture_space2D", hue = 'gesture_chain')
# Out:
# <Axes: xlabel='generation_number', ylabel='total_gesture_space2D'>

# %% [markdown]
# # Does a bigger difference in age lead to a bigger difference in gesture? Does a bigger difference in extroversion lead to a bigger difference in gesture?

# %%
#interseg_dist = pd.read_csv(os.path.join(curfolder, 'interseg_dist.csv')).set_index('Unnamed: 0')
#normed_features = pd.read_csv(os.path.join(curfolder, 'normed_features.csv'))

#interseg_dist = interseg_dist.rename(index={0: 'rennen_g_ch3_g12_compr.mp4'})
print(interseg_dist.head)
# Out:
# <bound method NDFrame.head of                             rennen_g_ch3_g12_compr.mp4  \
# Unnamed: 0
# 0                                             0.000000
# Donner_g_ch2_g3_compr.mp4                     5.620696
# kalt_g_ch1_g0_compr.mp4                      21.612999
# Donner_g_ch1_g16_compr.mp4                    1.771918
# kalt_g_ch2_g10_compr.mp4                      2.920471
# ...                                                ...
# rennen_g_ch3_g0_compr.mp4                     4.946181
# Donner_g_ch2_g0_compr.mp4                     5.352762
# Donner_g_ch3_g0_compr.mp4                     5.352762
# kalt_g_ch2_g0_compr.mp4                      21.612999
# kalt_g_ch3_g0_compr.mp4                      21.612999
#
#                             Donner_g_ch2_g3_compr.mp4  \
# Unnamed: 0
# 0                                            5.620696
# Donner_g_ch2_g3_compr.mp4                    0.000000
# kalt_g_ch1_g0_compr.mp4                     19.441014
# Donner_g_ch1_g16_compr.mp4                   4.577146
# kalt_g_ch2_g10_compr.mp4                     3.494003
# ...                                               ...
# rennen_g_ch3_g0_compr.mp4                    5.281372
# Donner_g_ch2_g0_compr.mp4                    4.124969
# Donner_g_ch3_g0_compr.mp4                    4.124969
# kalt_g_ch2_g0_compr.mp4                     19.441014
# kalt_g_ch3_g0_compr.mp4                     19.441014
#
#                             kalt_g_ch1_g0_compr.mp4  \
# Unnamed: 0
# 0                                         21.612999
# Donner_g_ch2_g3_compr.mp4                 19.441014
# kalt_g_ch1_g0_compr.mp4                    0.000000
# Donner_g_ch1_g16_compr.mp4                20.399877
# kalt_g_ch2_g10_compr.mp4                  19.871940
# ...                                             ...
# rennen_g_ch3_g0_compr.mp4                 20.914253
# Donner_g_ch2_g0_compr.mp4                 20.186771
# Donner_g_ch3_g0_compr.mp4                 20.186771
# kalt_g_ch2_g0_compr.mp4                    0.000000
# kalt_g_ch3_g0_compr.mp4                    0.000000
#
#                             Donner_g_ch1_g16_compr.mp4  \
# Unnamed: 0
# 0                                             1.771918
# Donner_g_ch2_g3_compr.mp4                     4.577146
# kalt_g_ch1_g0_compr.mp4                      20.399877
# Donner_g_ch1_g16_compr.mp4                    0.000000
# kalt_g_ch2_g10_compr.mp4                      2.110678
# ...                                                ...
# rennen_g_ch3_g0_compr.mp4                     4.882429
# Donner_g_ch2_g0_compr.mp4                     4.750630
# Donner_g_ch3_g0_compr.mp4                     4.750630
# kalt_g_ch2_g0_compr.mp4                      20.399877
# kalt_g_ch3_g0_compr.mp4                      20.399877
#
#                             kalt_g_ch2_g10_compr.mp4  \
# Unnamed: 0
# 0                                           2.920471
# Donner_g_ch2_g3_compr.mp4                   3.494003
# kalt_g_ch1_g0_compr.mp4                    19.871940
# Donner_g_ch1_g16_compr.mp4                  2.110678
# kalt_g_ch2_g10_compr.mp4                    0.000000
# ...                                              ...
# rennen_g_ch3_g0_compr.mp4                   5.042327
# Donner_g_ch2_g0_compr.mp4                   4.831708
# Donner_g_ch3_g0_compr.mp4                   4.831708
# kalt_g_ch2_g0_compr.mp4                    19.871940
# kalt_g_ch3_g0_compr.mp4                    19.871940
#
#                             rennen_g_ch1_g0_compr.mp4  \
# Unnamed: 0
# 0                                            4.946181
# Donner_g_ch2_g3_compr.mp4                    5.281372
# kalt_g_ch1_g0_compr.mp4                     20.914253
# Donner_g_ch1_g16_compr.mp4                   4.882429
# kalt_g_ch2_g10_compr.mp4                     5.042327
# ...                                               ...
# rennen_g_ch3_g0_compr.mp4                    0.000000
# Donner_g_ch2_g0_compr.mp4                    2.191529
# Donner_g_ch3_g0_compr.mp4                    2.191529
# kalt_g_ch2_g0_compr.mp4                     20.914253
# kalt_g_ch3_g0_compr.mp4                     20.914253
#
#                             leise_g_ch2_g17_compr.mp4  \
# Unnamed: 0
# 0                                           16.845757
# Donner_g_ch2_g3_compr.mp4                   14.457976
# kalt_g_ch1_g0_compr.mp4                      7.904955
# Donner_g_ch1_g16_compr.mp4                  15.747717
# kalt_g_ch2_g10_compr.mp4                    14.705194
# ...                                               ...
# rennen_g_ch3_g0_compr.mp4                   16.759779
# Donner_g_ch2_g0_compr.mp4                   16.171875
# Donner_g_ch3_g0_compr.mp4                   16.171875
# kalt_g_ch2_g0_compr.mp4                      7.904955
# kalt_g_ch3_g0_compr.mp4                      7.904955
#
#                             kalt_g_ch2_g6_compr.mp4  \
# Unnamed: 0
# 0                                         21.509709
# Donner_g_ch2_g3_compr.mp4                 19.460794
# kalt_g_ch1_g0_compr.mp4                    1.308212
# Donner_g_ch1_g16_compr.mp4                20.349097
# kalt_g_ch2_g10_compr.mp4                  19.842068
# ...                                             ...
# rennen_g_ch3_g0_compr.mp4                 20.732422
# Donner_g_ch2_g0_compr.mp4                 20.101127
# Donner_g_ch3_g0_compr.mp4                 20.101127
# kalt_g_ch2_g0_compr.mp4                    1.308212
# kalt_g_ch3_g0_compr.mp4                    1.308212
#
#                             Donner_g_ch1_g5_compr.mp4  \
# Unnamed: 0
# 0                                            4.488123
# Donner_g_ch2_g3_compr.mp4                    3.477519
# kalt_g_ch1_g0_compr.mp4                     19.380139
# Donner_g_ch1_g16_compr.mp4                   3.098892
# kalt_g_ch2_g10_compr.mp4                     2.996341
# ...                                               ...
# rennen_g_ch3_g0_compr.mp4                    6.602121
# Donner_g_ch2_g0_compr.mp4                    5.617583
# Donner_g_ch3_g0_compr.mp4                    5.617583
# kalt_g_ch2_g0_compr.mp4                     19.380139
# kalt_g_ch3_g0_compr.mp4                     19.380139
#
#                             rennen_g_ch2_g6_compr.mp4  ...  \
# Unnamed: 0                                             ...
# 0                                            2.749647  ...
# Donner_g_ch2_g3_compr.mp4                    7.072210  ...
# kalt_g_ch1_g0_compr.mp4                     23.516501  ...
# Donner_g_ch1_g16_compr.mp4                   3.989841  ...
# kalt_g_ch2_g10_compr.mp4                     5.212802  ...
# ...                                               ...  ...
# rennen_g_ch3_g0_compr.mp4                    4.806724  ...
# Donner_g_ch2_g0_compr.mp4                    5.706667  ...
# Donner_g_ch3_g0_compr.mp4                    5.706667  ...
# kalt_g_ch2_g0_compr.mp4                     23.516501  ...
# kalt_g_ch3_g0_compr.mp4                     23.516501  ...
#
#                             leise_g_ch2_g0_compr.mp4  \
# Unnamed: 0
# 0                                          16.930135
# Donner_g_ch2_g3_compr.mp4                  15.043475
# kalt_g_ch1_g0_compr.mp4                     5.780688
# Donner_g_ch1_g16_compr.mp4                 15.839794
# kalt_g_ch2_g10_compr.mp4                   15.120431
# ...                                              ...
# rennen_g_ch3_g0_compr.mp4                  16.594233
# Donner_g_ch2_g0_compr.mp4                  15.972660
# Donner_g_ch3_g0_compr.mp4                  15.972660
# kalt_g_ch2_g0_compr.mp4                     5.780688
# kalt_g_ch3_g0_compr.mp4                     5.780688
#
#                             leise_g_ch3_g0_compr.mp4  \
# Unnamed: 0
# 0                                          16.930135
# Donner_g_ch2_g3_compr.mp4                  15.043475
# kalt_g_ch1_g0_compr.mp4                     5.780688
# Donner_g_ch1_g16_compr.mp4                 15.839794
# kalt_g_ch2_g10_compr.mp4                   15.120431
# ...                                              ...
# rennen_g_ch3_g0_compr.mp4                  16.594233
# Donner_g_ch2_g0_compr.mp4                  15.972660
# Donner_g_ch3_g0_compr.mp4                  15.972660
# kalt_g_ch2_g0_compr.mp4                     5.780688
# kalt_g_ch3_g0_compr.mp4                     5.780688
#
#                             langsam_g_ch2_g0_compr.mp4  \
# Unnamed: 0
# 0                                             2.081495
# Donner_g_ch2_g3_compr.mp4                     5.886359
# kalt_g_ch1_g0_compr.mp4                      22.495862
# Donner_g_ch1_g16_compr.mp4                    2.851474
# kalt_g_ch2_g10_compr.mp4                      4.197776
# ...                                                ...
# rennen_g_ch3_g0_compr.mp4                     4.275888
# Donner_g_ch2_g0_compr.mp4                     4.792465
# Donner_g_ch3_g0_compr.mp4                     4.792465
# kalt_g_ch2_g0_compr.mp4                      22.495862
# kalt_g_ch3_g0_compr.mp4                      22.495862
#
#                             langsam_g_ch3_g0_compr.mp4  \
# Unnamed: 0
# 0                                             2.081495
# Donner_g_ch2_g3_compr.mp4                     5.886359
# kalt_g_ch1_g0_compr.mp4                      22.495862
# Donner_g_ch1_g16_compr.mp4                    2.851474
# kalt_g_ch2_g10_compr.mp4                      4.197776
# ...                                                ...
# rennen_g_ch3_g0_compr.mp4                     4.275888
# Donner_g_ch2_g0_compr.mp4                     4.792465
# Donner_g_ch3_g0_compr.mp4                     4.792465
# kalt_g_ch2_g0_compr.mp4                      22.495862
# kalt_g_ch3_g0_compr.mp4                      22.495862
#
#                             rennen_g_ch2_g0_compr.mp4  \
# Unnamed: 0
# 0                                            4.946181
# Donner_g_ch2_g3_compr.mp4                    5.281372
# kalt_g_ch1_g0_compr.mp4                     20.914253
# Donner_g_ch1_g16_compr.mp4                   4.882429
# kalt_g_ch2_g10_compr.mp4                     5.042327
# ...                                               ...
# rennen_g_ch3_g0_compr.mp4                    0.000000
# Donner_g_ch2_g0_compr.mp4                    2.191529
# Donner_g_ch3_g0_compr.mp4                    2.191529
# kalt_g_ch2_g0_compr.mp4                     20.914253
# kalt_g_ch3_g0_compr.mp4                     20.914253
#
#                             rennen_g_ch3_g0_compr.mp4  \
# Unnamed: 0
# 0                                            4.946181
# Donner_g_ch2_g3_compr.mp4                    5.281372
# kalt_g_ch1_g0_compr.mp4                     20.914253
# Donner_g_ch1_g16_compr.mp4                   4.882429
# kalt_g_ch2_g10_compr.mp4                     5.042327
# ...                                               ...
# rennen_g_ch3_g0_compr.mp4                    0.000000
# Donner_g_ch2_g0_compr.mp4                    2.191529
# Donner_g_ch3_g0_compr.mp4                    2.191529
# kalt_g_ch2_g0_compr.mp4                     20.914253
# kalt_g_ch3_g0_compr.mp4                     20.914253
#
#                             Donner_g_ch2_g0_compr.mp4  \
# Unnamed: 0
# 0                                            5.352762
# Donner_g_ch2_g3_compr.mp4                    4.124969
# kalt_g_ch1_g0_compr.mp4                     20.186771
# Donner_g_ch1_g16_compr.mp4                   4.750630
# kalt_g_ch2_g10_compr.mp4                     4.831708
# ...                                               ...
# rennen_g_ch3_g0_compr.mp4                    2.191529
# Donner_g_ch2_g0_compr.mp4                    0.000000
# Donner_g_ch3_g0_compr.mp4                    0.000000
# kalt_g_ch2_g0_compr.mp4                     20.186771
# kalt_g_ch3_g0_compr.mp4                     20.186771
#
#                             Donner_g_ch3_g0_compr.mp4  \
# Unnamed: 0
# 0                                            5.352762
# Donner_g_ch2_g3_compr.mp4                    4.124969
# kalt_g_ch1_g0_compr.mp4                     20.186771
# Donner_g_ch1_g16_compr.mp4                   4.750630
# kalt_g_ch2_g10_compr.mp4                     4.831708
# ...                                               ...
# rennen_g_ch3_g0_compr.mp4                    2.191529
# Donner_g_ch2_g0_compr.mp4                    0.000000
# Donner_g_ch3_g0_compr.mp4                    0.000000
# kalt_g_ch2_g0_compr.mp4                     20.186771
# kalt_g_ch3_g0_compr.mp4                     20.186771
#
#                             kalt_g_ch2_g0_compr.mp4  kalt_g_ch3_g0_compr.mp4
# Unnamed: 0
# 0                                         21.612999                21.612999
# Donner_g_ch2_g3_compr.mp4                 19.441014                19.441014
# kalt_g_ch1_g0_compr.mp4                    0.000000                 0.000000
# Donner_g_ch1_g16_compr.mp4                20.399877                20.399877
# kalt_g_ch2_g10_compr.mp4                  19.871940                19.871940
# ...                                             ...                      ...
# rennen_g_ch3_g0_compr.mp4                 20.914253                20.914253
# Donner_g_ch2_g0_compr.mp4                 20.186771                20.186771
# Donner_g_ch3_g0_compr.mp4                 20.186771                20.186771
# kalt_g_ch2_g0_compr.mp4                    0.000000                 0.000000
# kalt_g_ch3_g0_compr.mp4                    0.000000                 0.000000
#
# [313 rows x 313 columns]>

# %%
normed_features

# %%
interseg_dist

# %%
# creates two arrays to track the x and y values (diff in age vs distance between gestures)
big_df = pd.DataFrame(index=range(60), columns=['participantID', 'generation_number', 'chain_number', 'chainID', 'age', 'extrovert', 'diff_in_age', 'diff_in_extrovert', 
                               'diff_in_gesture_space_Donner', 'diff_in_entropy_Donner', 'diff_in_variability_Donner',
                               'diff_in_gesture_space_kalt', 'diff_in_entropy_kalt', 'diff_in_variability_kalt',
                                 'diff_in_gesture_space_langsam', 'diff_in_entropy_langsam','diff_in_variability_langsam',
                                   'diff_in_gesture_space_leise', 'diff_in_entropy_leise', 'diff_in_variability_leise',
                                     'diff_in_gesture_space_rennen','diff_in_entropy_rennen', 'diff_in_variability_rennen',
                                       'diff_in_gesture_space_mean', 'diff_in_entropy_mean', 'diff_in_variability_mean', 
                                       'total_dist_Donner', 'total_dist_kalt' , 'total_dist_langsam', 'total_dist_leise', 'total_dist_rennen', 'total_dist_mean'])
big_df['participantID'] = big_df.index

# rename row zero which got messed up in the interseg_dist matrix
interseg_dist = interseg_dist.rename(index={str(0): 'rennen_g_ch3_g12_compr.mp4'})
for i in range(interseg_dist.shape[0]-1):

    # get the current gesture
    curr_gesture = interseg_dist.index[i]

    # get the row of features of the current gesture and aspects of the gesture
    curr_features_row = normed_features[normed_features['fileID'] == curr_gesture]
    print(curr_features_row)
    gesture = curr_features_row["gesture"].iloc[0]
    generation_number = curr_features_row["generation_number"].iloc[0]
    generation_number = generation_number.astype(int)

    # if the current gesture is seed zero, go to the next iteration
    if generation_number == 0:
        continue
    chain_number = curr_features_row["chain_number"].iloc[0]
    chain_number =chain_number.astype(int)
    chainID = curr_features_row["chainID"].iloc[0]
    participantID_curr = curr_features_row["participantID"].iloc[0]

    # get the previous gesture
    previous_gesture = gesture + "_g_ch" + str(chain_number) + "_g" + str((generation_number)-1) + "_compr.mp4"

    # if either of the gestures are the ones we don't have video for, skip this iteration
    if curr_gesture == "rennen_g_ch1_g17_compr.mp4" or curr_gesture == "langsam_g_ch2_g8_compr.mp4" or previous_gesture== "rennen_g_ch1_g17_compr.mp4" or previous_gesture == "langsam_g_ch2_g8_compr.mp4":
        continue

    prev_features_row = normed_features[normed_features['fileID'] == previous_gesture]

    ## adding information about the current gesture:
    big_df.loc[participantID_curr, 'generation_number'] = generation_number
    big_df.loc[participantID_curr, 'chain_number'] = chain_number
    big_df.loc[participantID_curr, 'chainID'] = chainID


    #### COMPARING DISTANCES ######
    # get the overall distances between the two gestures and add it to the correct cell 
    distance = interseg_dist.loc[previous_gesture, curr_gesture]
    big_df.loc[participantID_curr, 'total_dist_' + gesture] =distance
    # get the difference between gesture spaces
    gesture_space_diff = abs(curr_features_row["total_gesture_space2D"].iloc[0] - prev_features_row["total_gesture_space2D"].iloc[0])
    big_df.loc[participantID_curr, 'diff_in_gesture_space_' + gesture] =gesture_space_diff
     # get the difference between entrophies
    entropy_diff = abs(curr_features_row["total_body_entropy2D"].iloc[0] - prev_features_row["total_body_entropy2D"].iloc[0])
    big_df.loc[participantID_curr, 'diff_in_entropy_' + gesture] = entropy_diff
    # # get the difference between variabilities
    variability_diff = abs(curr_features_row["total_body_variability2D"].iloc[0] - prev_features_row["total_body_variability2D"].iloc[0])
    big_df.loc[participantID_curr, 'diff_in_variability_' + gesture] = variability_diff    

    ### COMPARING DEMOGRAPHICS ######
    #ignore the ones that we don't have participant data for
    if participantID_curr == 17 or participantID_curr == 40 or participantID_curr == 20 or participantID_curr == 21 or participantID_curr == 22 or participantID_curr == 26:
        continue

    # if age hasn't been filled in yet:
    if (big_df[big_df['participantID'] == participantID_curr]['diff_in_age']).isna:
        #get the distance between the ages
        previous_age = prev_features_row["Age"].iloc[0]
        curr_age = curr_features_row["Age"].iloc[0]
        # if we don't know the ages, skip this iteration
        if math.isnan(previous_age) or math.isnan(curr_age):
            continue
    #get the difference in ages
        diff_in_age = int(abs(curr_age - previous_age))
        big_df.loc[participantID_curr, 'diff_in_age'] = diff_in_age
        big_df.loc[participantID_curr, 'age'] = curr_age

    #get the difference in extroversion
    if (big_df[big_df['participantID'] == participantID_curr]['diff_in_extrovert']).isna:
        previous_extrovert = prev_features_row["Extroversion"].iloc[0]
        curr_extrovert = curr_features_row["Extroversion"].iloc[0]
        # if we don't know the extroversion, skip this iteration
        if math.isnan(previous_extrovert) or math.isnan(curr_extrovert):
            continue
        #get the difference in extroversion
        diff_in_extrovert = int(abs(curr_extrovert - previous_extrovert))
        big_df.loc[participantID_curr, 'diff_in_extrovert'] = diff_in_extrovert
        big_df.loc[participantID_curr, 'extrovert'] = curr_extrovert

    ### store demographic information in this big dataframe so that I can see whether youger people change their gestures more than older people


# FINDING THE MEANS
big_df['diff_in_gesture_space_mean'] = big_df[['diff_in_gesture_space_Donner', 'diff_in_gesture_space_kalt', 'diff_in_gesture_space_langsam', 'diff_in_gesture_space_leise', 'diff_in_gesture_space_rennen']].mean(axis=1)
big_df['diff_in_entropy_mean'] = big_df[['diff_in_entropy_Donner', 'diff_in_entropy_kalt', 'diff_in_entropy_langsam', 'diff_in_entropy_leise', 'diff_in_entropy_rennen']].mean(axis=1)
big_df['diff_in_variability_mean'] = big_df[['diff_in_variability_Donner', 'diff_in_variability_kalt', 'diff_in_variability_langsam', 'diff_in_variability_leise', 'diff_in_variability_rennen']].mean(axis=1)
big_df['total_dist_mean'] = big_df[['total_dist_Donner', 'total_dist_kalt', 'total_dist_langsam', 'total_dist_leise', 'total_dist_rennen']].mean(axis=1)
# Out:
#    participantID   Age BirthPlace          Gender NativeLanguages  \
# 0             52  21.0     Berlin  Man / Männlich         Deutsch
#
#    NumOfNativeLanguages                                Other Languages  \
# 0                   1.0  Englisch- sehr gut, Italienisch - grundlegend
#
#    TotalLanguages  Extroversion                            Hand  ...  \
# 0             3.0          53.0  Right-handed / Rechtshänder*in  ...
#
#   right_knee_entropy2D left_knee_entropy2D  right_ankle_entropy2D  \
# 0             0.897487            0.865501               0.676895
#
#    left_ankle_entropy2D total_body_entropy2D right_wrist_variability2D  \
# 0              0.549502             0.774978                 -0.273554
#
#    left_wrist_variability2D  total_body_variability2D  X_embeddings  \
# 0                  -0.04781                 -0.198938     -4.431239
#
#    Y_embeddings
# 0      0.259631
#
# [1 rows x 47 columns]
#    participantID   Age    BirthPlace            Gender NativeLanguages  \
# 1             23  35.0  Deutschland   Woman / Weiblich        Deutsch
#
#    NumOfNativeLanguages                                    Other Languages  \
# 1                   1.0  English (fluent), French (advanced), Italian (...
#
#    TotalLanguages  Extroversion                            Hand  ...  \
# 1             4.0          43.0  Right-handed / Rechtshänder*in  ...
#
#   right_knee_entropy2D left_knee_entropy2D  right_ankle_entropy2D  \
# 1             0.836842            0.726559               0.722606
#
#    left_ankle_entropy2D total_body_entropy2D right_wrist_variability2D  \
# 1               0.51465             0.599787                  1.541944
#
#    left_wrist_variability2D  total_body_variability2D  X_embeddings  \
# 1                  1.062462                  1.599221     -2.315072
#
#    Y_embeddings
# 1      3.242649
#
# [1 rows x 47 columns]
#    participantID  Age BirthPlace Gender NativeLanguages  NumOfNativeLanguages  \
# 2              0  NaN        NaN    NaN             NaN                   NaN
#
#   Other Languages  TotalLanguages  Extroversion Hand  ...  \
# 2             NaN             NaN           NaN  NaN  ...
#
#   right_knee_entropy2D left_knee_entropy2D  right_ankle_entropy2D  \
# 2            -1.190243           -1.191379              -1.191595
#
#    left_ankle_entropy2D total_body_entropy2D right_wrist_variability2D  \
# 2             -1.191335            -0.943956                   0.12189
#
#    left_wrist_variability2D  total_body_variability2D  X_embeddings  \
# 2                 -0.785199                 -0.397381     16.057255
#
#    Y_embeddings
# 2      5.577348
#
# [1 rows x 47 columns]
#    participantID   Age   BirthPlace          Gender NativeLanguages  \
# 3             16  27.0  Deutschland  Man / Männlich        Deutsch
#
#    NumOfNativeLanguages Other Languages  TotalLanguages  Extroversion  \
# 3                   1.0         English             2.0          30.0
#
#                              Hand  ... right_knee_entropy2D  \
# 3  Right-handed / Rechtshänder*in  ...             0.947593
#
#   left_knee_entropy2D  right_ankle_entropy2D  left_ankle_entropy2D  \
# 3            0.660366               1.020308              1.026474
#
#   total_body_entropy2D right_wrist_variability2D  left_wrist_variability2D  \
# 3             0.921748                  0.055815                 -0.038724
#
#    total_body_variability2D  X_embeddings  Y_embeddings
# 3                  0.011376     -3.158298       0.64927
#
# [1 rows x 47 columns]
#    participantID   Age BirthPlace            Gender NativeLanguages  \
# 4             30  45.0    Dresden  Woman / Weiblich         Deutsch
#
#    NumOfNativeLanguages Other Languages  TotalLanguages  Extroversion  \
# 4                   1.0        Englisch             2.0          51.0
#
#                              Hand  ... right_knee_entropy2D  \
# 4  Right-handed / Rechtshänder*in  ...             0.634586
#
#   left_knee_entropy2D  right_ankle_entropy2D  left_ankle_entropy2D  \
# 4            0.563262               0.749603               0.64749
#
#   total_body_entropy2D right_wrist_variability2D  left_wrist_variability2D  \
# 4              0.50557                  0.920212                  0.311214
#
#    total_body_variability2D  X_embeddings  Y_embeddings
# 4                  0.759835     -2.677363      0.733918
#
# [1 rows x 47 columns]
#    participantID  Age BirthPlace Gender NativeLanguages  NumOfNativeLanguages  \
# 5              0  NaN        NaN    NaN             NaN                   NaN
#
#   Other Languages  TotalLanguages  Extroversion Hand  ...  \
# 5             NaN             NaN           NaN  NaN  ...
#
#   right_knee_entropy2D left_knee_entropy2D  right_ankle_entropy2D  \
# 5             0.928139            0.848104               1.038584
#
#    left_ankle_entropy2D total_body_entropy2D right_wrist_variability2D  \
# 5              0.979449             1.088923                 -0.741788
#
#    left_wrist_variability2D  total_body_variability2D  X_embeddings  \
# 5                 -0.670805                 -0.865573     -3.890631
#
#    Y_embeddings
# 5      3.642599
#
# [1 rows x 47 columns]
#    participantID   Age  BirthPlace            Gender          NativeLanguages  \
# 6             37  52.0  Österreich  Woman / Weiblich  Österreichisch, deutsch
#
#    NumOfNativeLanguages      Other Languages  TotalLanguages  Extroversion  \
# 6                   2.0  Englisch (fließend)             3.0          74.0
#
#                              Hand  ... right_knee_entropy2D  \
# 6  Right-handed / Rechtshänder*in  ...            -1.190243
#
#   left_knee_entropy2D  right_ankle_entropy2D  left_ankle_entropy2D  \
# 6           -1.191379              -1.191595             -1.191335
#
#   total_body_entropy2D right_wrist_variability2D  left_wrist_variability2D  \
# 6             -1.54903                  3.511944                 -0.863823
#
#    total_body_variability2D  X_embeddings  Y_embeddings
# 6                  1.663542     10.304903      4.050094
#
# [1 rows x 47 columns]
#    participantID  Age BirthPlace Gender NativeLanguages  NumOfNativeLanguages  \
# 7             26  NaN        NaN    NaN             NaN                   NaN
#
#   Other Languages  TotalLanguages  Extroversion Hand  ...  \
# 7             NaN             NaN           NaN  NaN  ...
#
#   right_knee_entropy2D left_knee_entropy2D  right_ankle_entropy2D  \
# 7            -1.190243           -1.191379              -1.191595
#
#    left_ankle_entropy2D total_body_entropy2D right_wrist_variability2D  \
# 7             -1.191335            -0.888295                 -0.411021
#
#    left_wrist_variability2D  total_body_variability2D  X_embeddings  \
# 7                 -0.392429                 -0.492107     15.867526
#
#    Y_embeddings
# 7      5.910772
#
# [1 rows x 47 columns]
#    participantID   Age BirthPlace          Gender NativeLanguages  \
# 8              5  59.0    Berlin   Man / Männlich         Deutsch
#
#    NumOfNativeLanguages Other Languages  TotalLanguages  Extroversion  \
# 8                   1.0        Englisch             2.0          66.0
#
#                              Hand  ... right_knee_entropy2D  \
# 8  Right-handed / Rechtshänder*in  ...             0.745919
#
#   left_knee_entropy2D  right_ankle_entropy2D  left_ankle_entropy2D  \
# 8            0.554081               0.986281               0.81044
#
#   total_body_entropy2D right_wrist_variability2D  left_wrist_variability2D  \
# 8             0.777355                   0.60026                  1.482059
#
#    total_body_variability2D  X_embeddings  Y_embeddings
# 8                  1.266442     -1.846965      0.873052
#
# [1 rows x 47 columns]
#    participantID  Age BirthPlace Gender NativeLanguages  NumOfNativeLanguages  \
# 9             26  NaN        NaN    NaN             NaN                   NaN
#
#   Other Languages  TotalLanguages  Extroversion Hand  ...  \
# 9             NaN             NaN           NaN  NaN  ...
#
#   right_knee_entropy2D left_knee_entropy2D  right_ankle_entropy2D  \
# 9             0.788167            0.991425               0.882031
#
#    left_ankle_entropy2D total_body_entropy2D right_wrist_variability2D  \
# 9              0.934272             1.032435                 -0.755562
#
#    left_wrist_variability2D  total_body_variability2D  X_embeddings  \
# 9                 -0.658609                 -0.866789     -6.547802
#
#    Y_embeddings
# 9       1.33362
#
# [1 rows x 47 columns]
#     participantID   Age BirthPlace          Gender  \
# 10             34  14.0     Berlin  Man / Männlich
#
#                               NativeLanguages  NumOfNativeLanguages  \
# 10  Schweizerdeutsch, deutsch, österreichisch                   3.0
#
#                                    Other Languages  TotalLanguages  \
# 10  Englisch (Grundkenntnisse), Deutsch (fließend)             5.0
#
#     Extroversion                            Hand  ... right_knee_entropy2D  \
# 10          61.0  Right-handed / Rechtshänder*in  ...             0.709858
#
#    left_knee_entropy2D  right_ankle_entropy2D  left_ankle_entropy2D  \
# 10            0.869313               0.661716              0.806074
#
#    total_body_entropy2D right_wrist_variability2D  left_wrist_variability2D  \
# 10             0.524616                 -0.087578                 -0.863823
#
#     total_body_variability2D  X_embeddings  Y_embeddings
# 10                 -0.575032     -4.398429      1.256781
#
# [1 rows x 47 columns]
#     participantID   Age BirthPlace            Gender NativeLanguages  \
# 11              4  60.0     Berlin  Woman / Weiblich        Deutsch
#
#     NumOfNativeLanguages                                    Other Languages  \
# 11                   1.0  Englisch fließend und französisch Grundkenntni...
#
#     TotalLanguages  Extroversion                            Hand  ...  \
# 11             3.0          86.0  Right-handed / Rechtshänder*in  ...
#
#    right_knee_entropy2D left_knee_entropy2D  right_ankle_entropy2D  \
# 11              0.93114            0.945117               0.692317
#
#     left_ankle_entropy2D total_body_entropy2D right_wrist_variability2D  \
# 11              0.789213             0.956748                  -0.78382
#
#     left_wrist_variability2D  total_body_variability2D  X_embeddings  \
# 11                 -0.704497                 -0.912016     -5.887436
#
#     Y_embeddings
# 11      1.806315
#
# [1 rows x 47 columns]
#     participantID   Age        BirthPlace          Gender NativeLanguages  \
# 12             12  25.0  Hamburg, Germany  Man / Männlich          German
#
#     NumOfNativeLanguages                                    Other Languages  \
# 12                   1.0  English (fluent), Spanish (fluent), French (ba...
#
#     TotalLanguages  Extroversion                            Hand  ...  \
# 12             4.0          55.0  Right-handed / Rechtshänder*in  ...
#
#    right_knee_entropy2D left_knee_entropy2D  right_ankle_entropy2D  \
# 12             0.788323            0.479571               0.552266
#
#     left_ankle_entropy2D total_body_entropy2D right_wrist_variability2D  \
# 12              1.029325             0.723992                  0.998053
#
#     left_wrist_variability2D  total_body_variability2D  X_embeddings  \
# 12                  1.054192                  1.255987     -1.795553
#
#     Y_embeddings
# 12      0.816317
#
# [1 rows x 47 columns]
#     participantID   Age BirthPlace            Gender NativeLanguages  \
# 13              4  60.0     Berlin  Woman / Weiblich        Deutsch
#
#     NumOfNativeLanguages                                    Other Languages  \
# 13                   1.0  Englisch fließend und französisch Grundkenntni...
#
#     TotalLanguages  Extroversion                            Hand  ...  \
# 13             3.0          86.0  Right-handed / Rechtshänder*in  ...
#
#    right_knee_entropy2D left_knee_entropy2D  right_ankle_entropy2D  \
# 13              1.04804            0.882353               0.757203
#
#     left_ankle_entropy2D total_body_entropy2D right_wrist_variability2D  \
# 13              0.854853             0.700454                  0.430674
#
#     left_wrist_variability2D  total_body_variability2D  X_embeddings  \
# 13                  0.375205                   0.49395     -2.956279
#
#     Y_embeddings
# 13      0.691017
#
# [1 rows x 47 columns]
#     participantID   Age BirthPlace            Gender NativeLanguages  \
# 14             27  13.0    Berlin   Woman / Weiblich  German, French
#
#     NumOfNativeLanguages              Other Languages  TotalLanguages  \
# 14                   2.0  English Estonian. Esperanto             5.0
#
#     Extroversion                            Hand  ... right_knee_entropy2D  \
# 14          73.0  Right-handed / Rechtshänder*in  ...             0.874173
#
#    left_knee_entropy2D  right_ankle_entropy2D  left_ankle_entropy2D  \
# 14            1.034521               0.845599              0.913732
#
#    total_body_entropy2D right_wrist_variability2D  left_wrist_variability2D  \
# 14             0.885172                  0.187158                  0.706907
#
#     total_body_variability2D  X_embeddings  Y_embeddings
# 14                  0.542399     -2.519251      3.425908
#
# [1 rows x 47 columns]
#     participantID   Age BirthPlace          Gender    NativeLanguages  \
# 15             56  21.0     Berlin  Man / Männlich  Deutsch, Englisch
#
#     NumOfNativeLanguages Other Languages  TotalLanguages  Extroversion  \
# 15                   2.0             non             2.0          80.0
#
#                               Hand  ... right_knee_entropy2D  \
# 15  Right-handed / Rechtshänder*in  ...             0.734915
#
#    left_knee_entropy2D  right_ankle_entropy2D  left_ankle_entropy2D  \
# 15            0.349041               0.349254              0.368304
#
#    total_body_entropy2D right_wrist_variability2D  left_wrist_variability2D  \
# 15             0.513293                 -0.816661                 -0.626273
#
#     total_body_variability2D  X_embeddings  Y_embeddings
# 15                   -0.8853     -5.656449      1.550805
#
# [1 rows x 47 columns]
#     participantID  Age BirthPlace Gender NativeLanguages  \
# 16             22  NaN        NaN    NaN             NaN
#
#     NumOfNativeLanguages Other Languages  TotalLanguages  Extroversion Hand  \
# 16                   NaN             NaN             NaN           NaN  NaN
#
#     ... right_knee_entropy2D left_knee_entropy2D  right_ankle_entropy2D  \
# 16  ...             0.694183            0.752767               0.477058
#
#     left_ankle_entropy2D total_body_entropy2D right_wrist_variability2D  \
# 16              0.390674             0.699472                 -0.521943
#
#     left_wrist_variability2D  total_body_variability2D  X_embeddings  \
# 16                 -0.087021                 -0.377042     -4.171503
#
#     Y_embeddings
# 16      3.436747
#
# [1 rows x 47 columns]
#     participantID   Age  BirthPlace            Gender NativeLanguages  \
# 17              1  26.0  Osnabrück   Woman / Weiblich          German
#
#     NumOfNativeLanguages                     Other Languages  TotalLanguages  \
# 17                   1.0  Englisch (fluent), Spanish (basic)             3.0
#
#     Extroversion                            Hand  ... right_knee_entropy2D  \
# 17          40.0  Right-handed / Rechtshänder*in  ...            -1.190243
#
#    left_knee_entropy2D  right_ankle_entropy2D  left_ankle_entropy2D  \
# 17           -1.191379              -1.191595             -1.191335
#
#    total_body_entropy2D right_wrist_variability2D  left_wrist_variability2D  \
# 17            -0.874528                 -0.031002                 -0.863823
#
#     total_body_variability2D  X_embeddings  Y_embeddings
# 17                 -0.539847     16.273052      5.196209
#
# [1 rows x 47 columns]
#     participantID  Age BirthPlace Gender NativeLanguages  \
# 18             22  NaN        NaN    NaN             NaN
#
#     NumOfNativeLanguages Other Languages  TotalLanguages  Extroversion Hand  \
# 18                   NaN             NaN             NaN           NaN  NaN
#
#     ... right_knee_entropy2D left_knee_entropy2D  right_ankle_entropy2D  \
# 18  ...             0.939077            0.966447               0.973441
#
#     left_ankle_entropy2D total_body_entropy2D right_wrist_variability2D  \
# 18              0.961539             0.582145                  2.541416
#
#     left_wrist_variability2D  total_body_variability2D  X_embeddings  \
# 18                  2.965036                  3.367351     -0.963793
#
#     Y_embeddings
# 18      0.167994
#
# [1 rows x 47 columns]
#     participantID   Age  BirthPlace          Gender NativeLanguages  \
# 19             33  55.0  Westfalen   Man / Männlich         Deutsch
#
#     NumOfNativeLanguages    Other Languages  TotalLanguages  Extroversion  \
# 19                   1.0  Englisch schlecht             2.0          80.0
#
#                               Hand  ... right_knee_entropy2D  \
# 19  Right-handed / Rechtshänder*in  ...             0.986788
#
#    left_knee_entropy2D  right_ankle_entropy2D  left_ankle_entropy2D  \
# 19            0.738178                0.90237              1.046012
#
#    total_body_entropy2D right_wrist_variability2D  left_wrist_variability2D  \
# 19             0.437739                  0.724957                 -0.863823
#
#     total_body_variability2D  X_embeddings  Y_embeddings
# 19                 -0.069709     -4.184326      1.379697
#
# [1 rows x 47 columns]
#     participantID  Age BirthPlace            Gender NativeLanguages  \
# 20             38  9.0     Berlin  Woman / Weiblich         Deutsch
#
#     NumOfNativeLanguages Other Languages  TotalLanguages  Extroversion  \
# 20                   1.0   English basic             2.0          48.0
#
#                             Hand  ... right_knee_entropy2D  \
# 20  Left-handed / Linkshänder*in  ...             0.651302
#
#    left_knee_entropy2D  right_ankle_entropy2D  left_ankle_entropy2D  \
# 20            0.829025               0.578644              0.724545
#
#    total_body_entropy2D right_wrist_variability2D  left_wrist_variability2D  \
# 20             0.815075                  0.112265                 -0.013873
#
#     total_body_variability2D  X_embeddings  Y_embeddings
# 20                  0.061458     -2.856517      3.014857
#
# [1 rows x 47 columns]
#     participantID   Age    BirthPlace          Gender NativeLanguages  \
# 21             58  28.0  Deutschland   Man / Männlich        Deutsch
#
#     NumOfNativeLanguages      Other Languages  TotalLanguages  Extroversion  \
# 21                   1.0  Englisch (fließend)             2.0          60.0
#
#                               Hand  ... right_knee_entropy2D  \
# 21  Right-handed / Rechtshänder*in  ...             1.023829
#
#    left_knee_entropy2D  right_ankle_entropy2D  left_ankle_entropy2D  \
# 21            0.958847               0.921119              0.690554
#
#    total_body_entropy2D right_wrist_variability2D  left_wrist_variability2D  \
# 21             1.013339                 -0.155806                 -0.019694
#
#     total_body_variability2D  X_embeddings  Y_embeddings
# 21                 -0.108766     -3.588171      3.713395
#
# [1 rows x 47 columns]
#     participantID  Age BirthPlace Gender NativeLanguages  \
# 22             20  NaN        NaN    NaN             NaN
#
#     NumOfNativeLanguages Other Languages  TotalLanguages  Extroversion Hand  \
# 22                   NaN             NaN             NaN           NaN  NaN
#
#     ... right_knee_entropy2D left_knee_entropy2D  right_ankle_entropy2D  \
# 22  ...            -1.190243           -1.191379              -1.191595
#
#     left_ankle_entropy2D total_body_entropy2D right_wrist_variability2D  \
# 22             -1.191335            -1.498542                  3.532096
#
#     left_wrist_variability2D  total_body_variability2D  X_embeddings  \
# 22                 -0.863823                  1.676074     10.283503
#
#     Y_embeddings
# 22      3.973279
#
# [1 rows x 47 columns]
#     participantID   Age BirthPlace            Gender NativeLanguages  \
# 23             53  32.0    Germany  Woman / Weiblich          German
#
#     NumOfNativeLanguages                         Other Languages  \
# 23                   1.0  English (fließend), Deutsch (fließend)
#
#     TotalLanguages  Extroversion                            Hand  ...  \
# 23             3.0          50.0  Right-handed / Rechtshänder*in  ...
#
#    right_knee_entropy2D left_knee_entropy2D  right_ankle_entropy2D  \
# 23            -1.190243           -1.191379              -1.191595
#
#     left_ankle_entropy2D total_body_entropy2D right_wrist_variability2D  \
# 23             -1.191335            -1.076695                  1.017517
#
#     left_wrist_variability2D  total_body_variability2D  X_embeddings  \
# 23                  1.484393                  1.527344     17.448841
#
#     Y_embeddings
# 23      7.456617
#
# [1 rows x 47 columns]
#     participantID   Age BirthPlace            Gender NativeLanguages  \
# 24             45  43.0     Brazil  Woman / Weiblich      Portuguese
#
#     NumOfNativeLanguages                                    Other Languages  \
# 24                   1.0  English (fluent), German (fluent), Italian (ba...
#
#     TotalLanguages  Extroversion                            Hand  ...  \
# 24             4.0          50.0  Right-handed / Rechtshänder*in  ...
#
#    right_knee_entropy2D left_knee_entropy2D  right_ankle_entropy2D  \
# 24            -1.190243           -1.191379              -1.191595
#
#     left_ankle_entropy2D total_body_entropy2D right_wrist_variability2D  \
# 24             -1.191335            -1.547073                  3.469885
#
#     left_wrist_variability2D  total_body_variability2D  X_embeddings  \
# 24                 -0.863823                  1.637385     10.273959
#
#     Y_embeddings
# 24      4.014841
#
# [1 rows x 47 columns]
#     participantID   Age BirthPlace            Gender NativeLanguages  \
# 25             15  44.0      Bünde  Woman / Weiblich         Deutsch
#
#     NumOfNativeLanguages                                    Other Languages  \
# 25                   1.0  English (fluent), French (Fluent), Spanish (ba...
#
#     TotalLanguages  Extroversion                            Hand  ...  \
# 25             5.0          70.0  Right-handed / Rechtshänder*in  ...
#
#    right_knee_entropy2D left_knee_entropy2D  right_ankle_entropy2D  \
# 25              0.91985            0.566439               0.630247
#
#     left_ankle_entropy2D total_body_entropy2D right_wrist_variability2D  \
# 25              0.532377              0.80192                  0.232906
#
#     left_wrist_variability2D  total_body_variability2D  X_embeddings  \
# 25                  0.396688                  0.383903     -2.689553
#
#     Y_embeddings
# 25       0.21254
#
# [1 rows x 47 columns]
#     participantID   Age        BirthPlace            Gender NativeLanguages  \
# 26             31  36.0  Germany, dessau   Woman / Weiblich         German
#
#     NumOfNativeLanguages                                    Other Languages  \
# 26                   1.0  English (fluent), Swedish (good), Italian (bas...
#
#     TotalLanguages  Extroversion                            Hand  ...  \
# 26             5.0          12.0  Right-handed / Rechtshänder*in  ...
#
#    right_knee_entropy2D left_knee_entropy2D  right_ankle_entropy2D  \
# 26             0.939043            0.898377               1.001129
#
#     left_ankle_entropy2D total_body_entropy2D right_wrist_variability2D  \
# 26              0.826451             0.993888                 -0.728221
#
#     left_wrist_variability2D  total_body_variability2D  X_embeddings  \
# 26                  -0.62718                 -0.830845      -5.37942
#
#     Y_embeddings
# 26      2.447803
#
# [1 rows x 47 columns]
#     participantID   Age  BirthPlace                            Gender  \
# 27              2  24.0  Regensburg  Prefer not to say / Keine Angabe
#
#    NativeLanguages  NumOfNativeLanguages  \
# 27         Deutsch                   1.0
#
#                                       Other Languages  TotalLanguages  \
# 27  English (fluent), French (fluent), Spanish (go...             7.0
#
#     Extroversion                            Hand  ... right_knee_entropy2D  \
# 27          17.0  Right-handed / Rechtshänder*in  ...             0.967182
#
#    left_knee_entropy2D  right_ankle_entropy2D  left_ankle_entropy2D  \
# 27            0.762496               0.895082              0.936134
#
#    total_body_entropy2D right_wrist_variability2D  left_wrist_variability2D  \
# 27             0.933764                 -0.529895                 -0.535655
#
#     total_body_variability2D  X_embeddings  Y_embeddings
# 27                 -0.652349     -5.801771      0.887696
#
# [1 rows x 47 columns]
#     participantID   Age BirthPlace            Gender NativeLanguages  \
# 28             19  57.0   Leipzig   Woman / Weiblich        Deutsch
#
#     NumOfNativeLanguages Other Languages  TotalLanguages  Extroversion  \
# 28                   1.0       Englisch              2.0          39.0
#
#                               Hand  ... right_knee_entropy2D  \
# 28  Right-handed / Rechtshänder*in  ...            -1.190243
#
#    left_knee_entropy2D  right_ankle_entropy2D  left_ankle_entropy2D  \
# 28           -1.191379              -1.191595             -1.191335
#
#    total_body_entropy2D right_wrist_variability2D  left_wrist_variability2D  \
# 28            -1.483164                  1.444558                 -0.863823
#
#     total_body_variability2D  X_embeddings  Y_embeddings
# 28                  0.377817     10.689983      4.245043
#
# [1 rows x 47 columns]
#     participantID   Age BirthPlace            Gender NativeLanguages  \
# 29             24  66.0     Berlin  Woman / Weiblich         Deutsch
#
#     NumOfNativeLanguages                                    Other Languages  \
# 29                   1.0  English(fluent), French (basic),Russian (basic...
#
#     TotalLanguages  Extroversion                            Hand  ...  \
# 29             5.0          60.0  Right-handed / Rechtshänder*in  ...
#
#    right_knee_entropy2D left_knee_entropy2D  right_ankle_entropy2D  \
# 29             0.980615            0.939496                0.89745
#
#     left_ankle_entropy2D total_body_entropy2D right_wrist_variability2D  \
# 29              1.008535             0.823454                  0.225379
#
#     left_wrist_variability2D  total_body_variability2D  X_embeddings  \
# 29                  2.999258                  1.947612     -1.232862
#
#     Y_embeddings
# 29      0.199682
#
# [1 rows x 47 columns]
#     participantID   Age BirthPlace                    Gender NativeLanguages  \
# 30             54  26.0    Berlin   Non-binary / Nicht-binär         German
#
#     NumOfNativeLanguages    Other Languages  TotalLanguages  Extroversion  \
# 30                   1.0  Englisch (Basic)              2.0          70.0
#
#                               Hand  ... right_knee_entropy2D  \
# 30  Right-handed / Rechtshänder*in  ...             0.717604
#
#    left_knee_entropy2D  right_ankle_entropy2D  left_ankle_entropy2D  \
# 30            0.794745               0.666573              0.648359
#
#    total_body_entropy2D right_wrist_variability2D  left_wrist_variability2D  \
# 30             0.147808                 -0.962553                 -0.863823
#
#     total_body_variability2D  X_embeddings  Y_embeddings
# 30                 -1.119186     -4.236439      1.642811
#
# [1 rows x 47 columns]
#     participantID   Age BirthPlace            Gender NativeLanguages  \
# 31              6  24.0      China  Woman / Weiblich         Chinese
#
#     NumOfNativeLanguages                              Other Languages  \
# 31                   1.0  English - fluent, German - basic knowledge
#
#     TotalLanguages  Extroversion                            Hand  ...  \
# 31             3.0          71.0  Right-handed / Rechtshänder*in  ...
#
#    right_knee_entropy2D left_knee_entropy2D  right_ankle_entropy2D  \
# 31             0.897292            0.823723               1.010555
#
#     left_ankle_entropy2D total_body_entropy2D right_wrist_variability2D  \
# 31              0.936712              0.98409                  0.109048
#
#     left_wrist_variability2D  total_body_variability2D  X_embeddings  \
# 31                  0.440894                  0.333514      -2.68917
#
#     Y_embeddings
# 31      0.121991
#
# [1 rows x 47 columns]
#     participantID   Age BirthPlace            Gender NativeLanguages  \
# 32             11  25.0  Kolumbien  Woman / Weiblich        Spanisch
#
#     NumOfNativeLanguages                                    Other Languages  \
# 32                   1.0  English (fluent), german (fluent), italian (ba...
#
#     TotalLanguages  Extroversion                            Hand  ...  \
# 32             4.0          76.0  Right-handed / Rechtshänder*in  ...
#
#    right_knee_entropy2D left_knee_entropy2D  right_ankle_entropy2D  \
# 32              0.62339            0.920944               0.825651
#
#     left_ankle_entropy2D total_body_entropy2D right_wrist_variability2D  \
# 32              0.785903             0.011261                 -0.962553
#
#     left_wrist_variability2D  total_body_variability2D  X_embeddings  \
# 32                 -0.863823                 -1.119186     -4.235578
#
#     Y_embeddings
# 32      1.717333
#
# [1 rows x 47 columns]
#     participantID   Age BirthPlace          Gender  \
# 33             35  15.0     Berlin  Man / Männlich
#
#                                NativeLanguages  NumOfNativeLanguages  \
# 33  Deutsch, Bayrischer Akzent( Niedeerbayern)                   2.0
#
#                                    Other Languages  TotalLanguages  \
# 33  English(fließend) Französisch(gute Kenntnisse)             4.0
#
#     Extroversion                            Hand  ... right_knee_entropy2D  \
# 33          43.0  Right-handed / Rechtshänder*in  ...             0.620753
#
#    left_knee_entropy2D  right_ankle_entropy2D  left_ankle_entropy2D  \
# 33            0.513367               0.858382               0.74411
#
#    total_body_entropy2D right_wrist_variability2D  left_wrist_variability2D  \
# 33             0.819826                 -0.145607                  0.033774
#
#     total_body_variability2D  X_embeddings  Y_embeddings
# 33                 -0.070201      -2.80102      1.406656
#
# [1 rows x 47 columns]
#     participantID   Age  BirthPlace            Gender NativeLanguages  \
# 34             41  29.0  Salzgitter  Woman / Weiblich         Deutsch
#
#     NumOfNativeLanguages                   Other Languages  TotalLanguages  \
# 34                   1.0  English (fluent), Spanish (good)             3.0
#
#     Extroversion                            Hand  ... right_knee_entropy2D  \
# 34          50.0  Right-handed / Rechtshänder*in  ...            -1.190243
#
#    left_knee_entropy2D  right_ankle_entropy2D  left_ankle_entropy2D  \
# 34           -1.191379              -1.191595             -1.191335
#
#    total_body_entropy2D right_wrist_variability2D  left_wrist_variability2D  \
# 34            -1.356407                  0.411866                 -0.863823
#
#     total_body_variability2D  X_embeddings  Y_embeddings
# 34                 -0.264423     11.253452      4.051279
#
# [1 rows x 47 columns]
#     participantID   Age    BirthPlace            Gender NativeLanguages  \
# 35             57  50.0  Deutschland   Woman / Weiblich        Deutsch
#
#     NumOfNativeLanguages      Other Languages  TotalLanguages  Extroversion  \
# 35                   1.0  Englisch (fließend)             2.0          30.0
#
#                               Hand  ... right_knee_entropy2D  \
# 35  Right-handed / Rechtshänder*in  ...              0.19095
#
#    left_knee_entropy2D  right_ankle_entropy2D  left_ankle_entropy2D  \
# 35            0.634538               0.680275              0.898165
#
#    total_body_entropy2D right_wrist_variability2D  left_wrist_variability2D  \
# 35             0.344085                  1.917467                  2.256625
#
#     total_body_variability2D  X_embeddings  Y_embeddings
# 35                  2.552402      -0.98009      0.155074
#
# [1 rows x 47 columns]
#     participantID   Age   BirthPlace          Gender NativeLanguages  \
# 36             49  50.0  Düsseldorf   Man / Männlich         Deutsch
#
#     NumOfNativeLanguages                             Other Languages  \
# 36                   1.0  English (fluent), French (Grundkenntnisse)
#
#     TotalLanguages  Extroversion                            Hand  ...  \
# 36             3.0          80.0  Right-handed / Rechtshänder*in  ...
#
#    right_knee_entropy2D left_knee_entropy2D  right_ankle_entropy2D  \
# 36             0.911474            0.757531               0.560242
#
#     left_ankle_entropy2D total_body_entropy2D right_wrist_variability2D  \
# 36              0.561658             0.841397                 -0.174798
#
#     left_wrist_variability2D  total_body_variability2D  X_embeddings  \
# 36                  0.555634                  0.226134     -2.530209
#
#     Y_embeddings
# 36      1.088113
#
# [1 rows x 47 columns]
#     participantID   Age    BirthPlace          Gender NativeLanguages  \
# 37             50  62.0  Deutschland   Man / Männlich        deutsch
#
#     NumOfNativeLanguages Other Languages  TotalLanguages  Extroversion  \
# 37                   1.0       Englisch              2.0          75.0
#
#                               Hand  ... right_knee_entropy2D  \
# 37  Right-handed / Rechtshänder*in  ...            -1.190243
#
#    left_knee_entropy2D  right_ankle_entropy2D  left_ankle_entropy2D  \
# 37           -1.191379              -1.191595             -1.191335
#
#    total_body_entropy2D right_wrist_variability2D  left_wrist_variability2D  \
# 37            -1.533387                 -0.962553                 -0.863823
#
#     total_body_variability2D  X_embeddings  Y_embeddings
# 37                 -1.119186     13.590626      3.843047
#
# [1 rows x 47 columns]
#     participantID   Age BirthPlace            Gender NativeLanguages  \
# 38             28  80.0   chemnitz  Woman / Weiblich        Deutsch
#
#     NumOfNativeLanguages Other Languages  TotalLanguages  Extroversion  \
# 38                   1.0          Keine              1.0          80.0
#
#                               Hand  ... right_knee_entropy2D  \
# 38  Right-handed / Rechtshänder*in  ...            -1.190243
#
#    left_knee_entropy2D  right_ankle_entropy2D  left_ankle_entropy2D  \
# 38           -1.191379              -1.191595             -1.191335
#
#    total_body_entropy2D right_wrist_variability2D  left_wrist_variability2D  \
# 38            -1.394694                 -0.962553                 -0.863823
#
#     total_body_variability2D  X_embeddings  Y_embeddings
# 38                 -1.119186     12.890301      3.920754
#
# [1 rows x 47 columns]
#     participantID   Age  BirthPlace            Gender NativeLanguages  \
# 39              1  26.0  Osnabrück   Woman / Weiblich          German
#
#     NumOfNativeLanguages                     Other Languages  TotalLanguages  \
# 39                   1.0  Englisch (fluent), Spanish (basic)             3.0
#
#     Extroversion                            Hand  ... right_knee_entropy2D  \
# 39          40.0  Right-handed / Rechtshänder*in  ...             0.885121
#
#    left_knee_entropy2D  right_ankle_entropy2D  left_ankle_entropy2D  \
# 39            0.992016               0.737415              0.984587
#
#    total_body_entropy2D right_wrist_variability2D  left_wrist_variability2D  \
# 39              0.95893                  -0.67492                 -0.454067
#
#     total_body_variability2D  X_embeddings  Y_embeddings
# 39                 -0.693374     -6.124279      0.766337
#
# [1 rows x 47 columns]
#     participantID   Age BirthPlace            Gender NativeLanguages  \
# 40             32  24.0     Berlin  Woman / Weiblich         Deutsch
#
#     NumOfNativeLanguages                                    Other Languages  \
# 40                   1.0  Englisch - fließend, Deutsche Gebärdensprache ...
#
#     TotalLanguages  Extroversion                            Hand  ...  \
# 40             4.0          41.0  Right-handed / Rechtshänder*in  ...
#
#    right_knee_entropy2D left_knee_entropy2D  right_ankle_entropy2D  \
# 40             0.755343            0.508509               0.909213
#
#     left_ankle_entropy2D total_body_entropy2D right_wrist_variability2D  \
# 40              0.877099             0.902313                 -0.828687
#
#     left_wrist_variability2D  total_body_variability2D  X_embeddings  \
# 40                 -0.580182                 -0.865003     -6.459575
#
#     Y_embeddings
# 40      1.312987
#
# [1 rows x 47 columns]
#     participantID   Age   BirthPlace          Gender NativeLanguages  \
# 41             16  27.0  Deutschland  Man / Männlich        Deutsch
#
#     NumOfNativeLanguages Other Languages  TotalLanguages  Extroversion  \
# 41                   1.0         English             2.0          30.0
#
#                               Hand  ... right_knee_entropy2D  \
# 41  Right-handed / Rechtshänder*in  ...             0.897346
#
#    left_knee_entropy2D  right_ankle_entropy2D  left_ankle_entropy2D  \
# 41            1.000538               0.921733              1.004285
#
#    total_body_entropy2D right_wrist_variability2D  left_wrist_variability2D  \
# 41             0.979991                  0.576841                  0.579856
#
#     total_body_variability2D  X_embeddings  Y_embeddings
# 41                  0.708182      -2.42331      3.129961
#
# [1 rows x 47 columns]
#     participantID   Age BirthPlace            Gender NativeLanguages  \
# 42             46  26.0     Weimar  Woman / Weiblich         German
#
#     NumOfNativeLanguages                  Other Languages  TotalLanguages  \
# 42                   1.0  English (fluent), Spanish (B1)              3.0
#
#     Extroversion                            Hand  ... right_knee_entropy2D  \
# 42          75.0  Right-handed / Rechtshänder*in  ...            -1.190243
#
#    left_knee_entropy2D  right_ankle_entropy2D  left_ankle_entropy2D  \
# 42           -1.191379              -1.191595             -1.191335
#
#    total_body_entropy2D right_wrist_variability2D  left_wrist_variability2D  \
# 42            -1.217901                  0.894314                  1.184956
#
#     total_body_variability2D  X_embeddings  Y_embeddings
# 42                  1.270273     17.635736      7.303985
#
# [1 rows x 47 columns]
#     participantID   Age    BirthPlace          Gender NativeLanguages  \
# 43             50  62.0  Deutschland   Man / Männlich        deutsch
#
#     NumOfNativeLanguages Other Languages  TotalLanguages  Extroversion  \
# 43                   1.0       Englisch              2.0          75.0
#
#                               Hand  ... right_knee_entropy2D  \
# 43  Right-handed / Rechtshänder*in  ...            -1.190243
#
#    left_knee_entropy2D  right_ankle_entropy2D  left_ankle_entropy2D  \
# 43           -1.191379              -1.191595             -1.191335
#
#    total_body_entropy2D right_wrist_variability2D  left_wrist_variability2D  \
# 43            -1.055431                  0.449327                  0.664881
#
#     total_body_variability2D  X_embeddings  Y_embeddings
# 43                  0.680118     17.668726       6.50418
#
# [1 rows x 47 columns]
#     participantID   Age BirthPlace            Gender NativeLanguages  \
# 44              9  58.0    Berlin   Woman / Weiblich         Deutsch
#
#     NumOfNativeLanguages Other Languages  TotalLanguages  Extroversion  \
# 44                   1.0              No             1.0          50.0
#
#                             Hand  ... right_knee_entropy2D  \
# 44  Left-handed / Linkshänder*in  ...            -1.190243
#
#    left_knee_entropy2D  right_ankle_entropy2D  left_ankle_entropy2D  \
# 44           -1.191379              -1.191595             -1.191335
#
#    total_body_entropy2D right_wrist_variability2D  left_wrist_variability2D  \
# 44            -1.476518                 -0.962553                  2.839739
#
#     total_body_variability2D  X_embeddings  Y_embeddings
# 44                  1.112695     17.410856      6.852731
#
# [1 rows x 47 columns]
#     participantID   Age    BirthPlace            Gender NativeLanguages  \
# 45             57  50.0  Deutschland   Woman / Weiblich        Deutsch
#
#     NumOfNativeLanguages      Other Languages  TotalLanguages  Extroversion  \
# 45                   1.0  Englisch (fließend)             2.0          30.0
#
#                               Hand  ... right_knee_entropy2D  \
# 45  Right-handed / Rechtshänder*in  ...            -1.190243
#
#    left_knee_entropy2D  right_ankle_entropy2D  left_ankle_entropy2D  \
# 45           -1.191379              -1.191595             -1.191335
#
#    total_body_entropy2D right_wrist_variability2D  left_wrist_variability2D  \
# 45            -1.444818                 -0.962553                 -0.863823
#
#     total_body_variability2D  X_embeddings  Y_embeddings
# 45                 -1.119186     13.202564       4.05369
#
# [1 rows x 47 columns]
#     participantID   Age BirthPlace            Gender NativeLanguages  \
# 46             27  13.0    Berlin   Woman / Weiblich  German, French
#
#     NumOfNativeLanguages              Other Languages  TotalLanguages  \
# 46                   2.0  English Estonian. Esperanto             5.0
#
#     Extroversion                            Hand  ... right_knee_entropy2D  \
# 46          73.0  Right-handed / Rechtshänder*in  ...             0.930111
#
#    left_knee_entropy2D  right_ankle_entropy2D  left_ankle_entropy2D  \
# 46            0.902122                0.99121              0.851275
#
#    total_body_entropy2D right_wrist_variability2D  left_wrist_variability2D  \
# 46              0.98493                  0.426979                  1.137432
#
#     total_body_variability2D  X_embeddings  Y_embeddings
# 46                  0.950994     -2.482085      3.410909
#
# [1 rows x 47 columns]
#     participantID   Age BirthPlace                    Gender NativeLanguages  \
# 47             54  26.0    Berlin   Non-binary / Nicht-binär         German
#
#     NumOfNativeLanguages    Other Languages  TotalLanguages  Extroversion  \
# 47                   1.0  Englisch (Basic)              2.0          70.0
#
#                               Hand  ... right_knee_entropy2D  \
# 47  Right-handed / Rechtshänder*in  ...            -1.190243
#
#    left_knee_entropy2D  right_ankle_entropy2D  left_ankle_entropy2D  \
# 47           -1.191379              -1.191595             -1.191335
#
#    total_body_entropy2D right_wrist_variability2D  left_wrist_variability2D  \
# 47            -1.223376                  1.343417                  1.626231
#
#     total_body_variability2D  X_embeddings  Y_embeddings
# 47                    1.8155     17.501732      7.555829
#
# [1 rows x 47 columns]
#     participantID   Age BirthPlace          Gender     NativeLanguages  \
# 48             42  35.0   chisinau  Man / Männlich  Deutsch, Russisch
#
#     NumOfNativeLanguages                                  Other Languages  \
# 48                   2.0  englisch (fließend), spanisch (Grundkenntnisse)
#
#     TotalLanguages  Extroversion                            Hand  ...  \
# 48             4.0          30.0  Right-handed / Rechtshänder*in  ...
#
#    right_knee_entropy2D left_knee_entropy2D  right_ankle_entropy2D  \
# 48            -1.190243           -1.191379              -1.191595
#
#     left_ankle_entropy2D total_body_entropy2D right_wrist_variability2D  \
# 48             -1.191335            -1.304155                 -0.962553
#
#     left_wrist_variability2D  total_body_variability2D  X_embeddings  \
# 48                 -0.863823                 -1.119186     12.401952
#
#     Y_embeddings
# 48      4.034561
#
# [1 rows x 47 columns]
#     participantID   Age BirthPlace          Gender NativeLanguages  \
# 49             36  15.0       2008  Man / Männlich         Deutsch
#
#     NumOfNativeLanguages                            Other Languages  \
# 49                   1.0  English(fluent), french (basic knowledge)
#
#     TotalLanguages  Extroversion                            Hand  ...  \
# 49             3.0          45.0  Right-handed / Rechtshänder*in  ...
#
#    right_knee_entropy2D left_knee_entropy2D  right_ankle_entropy2D  \
# 49             0.527085            0.604625               0.385563
#
#     left_ankle_entropy2D total_body_entropy2D right_wrist_variability2D  \
# 49               0.78779             0.717654                 -0.473314
#
#     left_wrist_variability2D  total_body_variability2D  X_embeddings  \
# 49                 -0.591918                 -0.651066     -3.391347
#
#     Y_embeddings
# 49      1.507491
#
# [1 rows x 47 columns]
#     participantID   Age        BirthPlace          Gender NativeLanguages  \
# 50             12  25.0  Hamburg, Germany  Man / Männlich          German
#
#     NumOfNativeLanguages                                    Other Languages  \
# 50                   1.0  English (fluent), Spanish (fluent), French (ba...
#
#     TotalLanguages  Extroversion                            Hand  ...  \
# 50             4.0          55.0  Right-handed / Rechtshänder*in  ...
#
#    right_knee_entropy2D left_knee_entropy2D  right_ankle_entropy2D  \
# 50             0.900617            0.863078               0.762921
#
#     left_ankle_entropy2D total_body_entropy2D right_wrist_variability2D  \
# 50              0.688202             0.916692                 -0.288782
#
#     left_wrist_variability2D  total_body_variability2D  X_embeddings  \
# 50                 -0.097935                 -0.238615     -4.464653
#
#     Y_embeddings
# 50      0.328271
#
# [1 rows x 47 columns]
#     participantID   Age BirthPlace          Gender NativeLanguages  \
# 51              5  59.0    Berlin   Man / Männlich         Deutsch
#
#     NumOfNativeLanguages Other Languages  TotalLanguages  Extroversion  \
# 51                   1.0        Englisch             2.0          66.0
#
#                               Hand  ... right_knee_entropy2D  \
# 51  Right-handed / Rechtshänder*in  ...              0.94124
#
#    left_knee_entropy2D  right_ankle_entropy2D  left_ankle_entropy2D  \
# 51            1.021457               1.019585              1.014005
#
#    total_body_entropy2D right_wrist_variability2D  left_wrist_variability2D  \
# 51             1.036109                  0.774978                  0.751992
#
#     total_body_variability2D  X_embeddings  Y_embeddings
# 51                  0.935139     -1.918393      0.498718
#
# [1 rows x 47 columns]
#     participantID   Age BirthPlace            Gender NativeLanguages  \
# 52             19  57.0   Leipzig   Woman / Weiblich        Deutsch
#
#     NumOfNativeLanguages Other Languages  TotalLanguages  Extroversion  \
# 52                   1.0       Englisch              2.0          39.0
#
#                               Hand  ... right_knee_entropy2D  \
# 52  Right-handed / Rechtshänder*in  ...            -1.190243
#
#    left_knee_entropy2D  right_ankle_entropy2D  left_ankle_entropy2D  \
# 52           -1.191379              -1.191595             -1.191335
#
#    total_body_entropy2D right_wrist_variability2D  left_wrist_variability2D  \
# 52            -0.985111                  0.338789                  0.334106
#
#     total_body_variability2D  X_embeddings  Y_embeddings
# 52                  0.412038     17.636112      6.477522
#
# [1 rows x 47 columns]
#     participantID   Age    BirthPlace            Gender NativeLanguages  \
# 53             23  35.0  Deutschland   Woman / Weiblich        Deutsch
#
#     NumOfNativeLanguages                                    Other Languages  \
# 53                   1.0  English (fluent), French (advanced), Italian (...
#
#     TotalLanguages  Extroversion                            Hand  ...  \
# 53             4.0          43.0  Right-handed / Rechtshänder*in  ...
#
#    right_knee_entropy2D left_knee_entropy2D  right_ankle_entropy2D  \
# 53             0.945602            0.999429               0.639979
#
#     left_ankle_entropy2D total_body_entropy2D right_wrist_variability2D  \
# ...
#
#      ... right_knee_entropy2D left_knee_entropy2D  right_ankle_entropy2D  \
# 293  ...             0.582067            0.636143               0.832174
#
#      left_ankle_entropy2D total_body_entropy2D right_wrist_variability2D  \
# 293              0.751845             0.845697                 -0.274834
#
#      left_wrist_variability2D  total_body_variability2D  X_embeddings  \
# 293                 -0.104422                  -0.23385     -2.557746
#
#      Y_embeddings
# 293      4.615791
#
# [1 rows x 47 columns]
#      participantID   Age BirthPlace          Gender NativeLanguages  \
# 294             60  35.0    Germany  Man / Männlich          German
#
#      NumOfNativeLanguages   Other Languages  TotalLanguages  Extroversion  \
# 294                   1.0  English (fluent)             2.0          85.0
#
#                                Hand  ... right_knee_entropy2D  \
# 294  Right-handed / Rechtshänder*in  ...             0.724824
#
#     left_knee_entropy2D  right_ankle_entropy2D  left_ankle_entropy2D  \
# 294            0.495981               0.680452               0.73736
#
#     total_body_entropy2D right_wrist_variability2D  left_wrist_variability2D  \
# 294             0.735558                  1.511335                  0.891928
#
#      total_body_variability2D  X_embeddings  Y_embeddings
# 294                  1.477416     -1.727948      0.601459
#
# [1 rows x 47 columns]
#      participantID   Age BirthPlace            Gender NativeLanguages  \
# 295             18  19.0     Berlin  Woman / Weiblich         Deutsch
#
#      NumOfNativeLanguages Other Languages  TotalLanguages  Extroversion  \
# 295                   1.0       Englisch              2.0          64.0
#
#                                Hand  ... right_knee_entropy2D  \
# 295  Right-handed / Rechtshänder*in  ...            -1.190243
#
#     left_knee_entropy2D  right_ankle_entropy2D  left_ankle_entropy2D  \
# 295           -1.191379              -1.191595             -1.191335
#
#     total_body_entropy2D right_wrist_variability2D  left_wrist_variability2D  \
# 295            -1.381828                 -0.962553                 -0.863823
#
#      total_body_variability2D  X_embeddings  Y_embeddings
# 295                 -1.119186     12.670993      3.902176
#
# [1 rows x 47 columns]
#      participantID   Age BirthPlace            Gender NativeLanguages  \
# 296             44  28.0      Italy  Woman / Weiblich     Italienisch
#
#      NumOfNativeLanguages                                    Other Languages  \
# 296                   1.0  Deutsch (fließend), Englisch (fließend), Spani...
#
#      TotalLanguages  Extroversion                            Hand  ...  \
# 296             5.0          46.0  Right-handed / Rechtshänder*in  ...
#
#     right_knee_entropy2D left_knee_entropy2D  right_ankle_entropy2D  \
# 296            -1.190243           -1.191379              -1.191595
#
#      left_ankle_entropy2D total_body_entropy2D right_wrist_variability2D  \
# 296             -1.191335            -1.222716                  -0.51581
#
#      left_wrist_variability2D  total_body_variability2D  X_embeddings  \
# 296                 -0.863823                 -0.841353     11.948956
#
#      Y_embeddings
# 296      4.159967
#
# [1 rows x 47 columns]
#      participantID   Age BirthPlace            Gender NativeLanguages  \
# 297              3  32.0    Germany  Woman / Weiblich         Deutsch
#
#      NumOfNativeLanguages                    Other Languages  TotalLanguages  \
# 297                   1.0  English (fluent), Japanese(basic)             3.0
#
#      Extroversion                            Hand  ... right_knee_entropy2D  \
# 297          60.0  Right-handed / Rechtshänder*in  ...             0.941322
#
#     left_knee_entropy2D  right_ankle_entropy2D  left_ankle_entropy2D  \
# 297            0.967406               0.951938              0.960023
#
#     total_body_entropy2D right_wrist_variability2D  left_wrist_variability2D  \
# 297             1.073755                 -0.681693                 -0.567303
#
#      total_body_variability2D  X_embeddings  Y_embeddings
# 297                 -0.765825     -5.984145      1.489404
#
# [1 rows x 47 columns]
#      participantID   Age BirthPlace          Gender NativeLanguages  \
# 298             14  11.0     Berlin  Man / Männlich         Deutsch
#
#      NumOfNativeLanguages   Other Languages  TotalLanguages  Extroversion  \
# 298                   1.0  Englisch (basic)             2.0          40.0
#
#                                Hand  ... right_knee_entropy2D  \
# 298  Right-handed / Rechtshänder*in  ...             1.013765
#
#     left_knee_entropy2D  right_ankle_entropy2D  left_ankle_entropy2D  \
# 298            0.843963               1.023032              0.932066
#
#     total_body_entropy2D right_wrist_variability2D  left_wrist_variability2D  \
# 298              1.01854                  0.233997                  0.840023
#
#      total_body_variability2D  X_embeddings  Y_embeddings
# 298                  0.651749     -2.125537      0.155477
#
# [1 rows x 47 columns]
#      participantID   Age BirthPlace            Gender NativeLanguages  \
# 299             30  45.0    Dresden  Woman / Weiblich         Deutsch
#
#      NumOfNativeLanguages Other Languages  TotalLanguages  Extroversion  \
# 299                   1.0        Englisch             2.0          51.0
#
#                                Hand  ... right_knee_entropy2D  \
# 299  Right-handed / Rechtshänder*in  ...             0.882019
#
#     left_knee_entropy2D  right_ankle_entropy2D  left_ankle_entropy2D  \
# 299            0.930929               0.904669                0.8196
#
#     total_body_entropy2D right_wrist_variability2D  left_wrist_variability2D  \
# 299              0.96471                 -0.537949                 -0.285391
#
#      total_body_variability2D  X_embeddings  Y_embeddings
# 299                 -0.506541     -4.035168      3.575601
#
# [1 rows x 47 columns]
#      participantID   Age BirthPlace            Gender NativeLanguages  \
# 300             39  39.0     Berlin  Woman / Weiblich        Deutsch
#
#      NumOfNativeLanguages                 Other Languages  TotalLanguages  \
# 300                   1.0  English fluent, Spanisch basic             3.0
#
#      Extroversion                          Hand  ... right_knee_entropy2D  \
# 300          41.0  Left-handed / Linkshänder*in  ...             0.891698
#
#     left_knee_entropy2D  right_ankle_entropy2D  left_ankle_entropy2D  \
# 300            0.925209               0.808129              0.782617
#
#     total_body_entropy2D right_wrist_variability2D  left_wrist_variability2D  \
# 300             0.885317                 -0.579611                 -0.031941
#
#      total_body_variability2D  X_embeddings  Y_embeddings
# 300                 -0.379714     -3.127035      3.883377
#
# [1 rows x 47 columns]
#      participantID   Age BirthPlace          Gender NativeLanguages  \
# 301             52  21.0     Berlin  Man / Männlich         Deutsch
#
#      NumOfNativeLanguages                                Other Languages  \
# 301                   1.0  Englisch- sehr gut, Italienisch - grundlegend
#
#      TotalLanguages  Extroversion                            Hand  ...  \
# 301             3.0          53.0  Right-handed / Rechtshänder*in  ...
#
#     right_knee_entropy2D left_knee_entropy2D  right_ankle_entropy2D  \
# 301            -1.190243           -1.191379              -1.191595
#
#      left_ankle_entropy2D total_body_entropy2D right_wrist_variability2D  \
# 301             -1.191335            -1.344573                  2.514572
#
#      left_wrist_variability2D  total_body_variability2D  X_embeddings  \
# 301                  2.965817                  3.351128     17.708149
#
#      Y_embeddings
# 301      7.788176
#
# [1 rows x 47 columns]
#      participantID   Age         BirthPlace            Gender NativeLanguages  \
# 302             59  27.0  Deutschland, Gera  Woman / Weiblich         Deutsch
#
#      NumOfNativeLanguages                                    Other Languages  \
# 302                   1.0  Englisch (gute Kenntnisse), französisch (Grund...
#
#      TotalLanguages  Extroversion                            Hand  ...  \
# 302             3.0          40.0  Right-handed / Rechtshänder*in  ...
#
#     right_knee_entropy2D left_knee_entropy2D  right_ankle_entropy2D  \
# 302              0.98111            0.761556               0.996431
#
#      left_ankle_entropy2D total_body_entropy2D right_wrist_variability2D  \
# 302              0.902484             0.945362                  0.568412
#
#      left_wrist_variability2D  total_body_variability2D  X_embeddings  \
# 302                  1.117311                  1.026826     -1.846957
#
#      Y_embeddings
# 302      0.342172
#
# [1 rows x 47 columns]
#      participantID  Age BirthPlace Gender NativeLanguages  \
# 303              0  NaN        NaN    NaN             NaN
#
#      NumOfNativeLanguages Other Languages  TotalLanguages  Extroversion Hand  \
# 303                   NaN             NaN             NaN           NaN  NaN
#
#      ... right_knee_entropy2D left_knee_entropy2D  right_ankle_entropy2D  \
# 303  ...            -1.190243           -1.191379              -1.191595
#
#      left_ankle_entropy2D total_body_entropy2D right_wrist_variability2D  \
# 303             -1.191335            -1.416082                  0.405659
#
#      left_wrist_variability2D  total_body_variability2D  X_embeddings  \
# 303                 -0.863823                 -0.268284     11.117295
#
#      Y_embeddings
# 303      4.166809
#
# [1 rows x 47 columns]
#      participantID  Age BirthPlace Gender NativeLanguages  \
# 304              0  NaN        NaN    NaN             NaN
#
#      NumOfNativeLanguages Other Languages  TotalLanguages  Extroversion Hand  \
# 304                   NaN             NaN             NaN           NaN  NaN
#
#      ... right_knee_entropy2D left_knee_entropy2D  right_ankle_entropy2D  \
# 304  ...            -1.190243           -1.191379              -1.191595
#
#      left_ankle_entropy2D total_body_entropy2D right_wrist_variability2D  \
# 304             -1.191335            -1.416082                  0.405659
#
#      left_wrist_variability2D  total_body_variability2D  X_embeddings  \
# 304                 -0.863823                 -0.268284     11.117295
#
#      Y_embeddings
# 304      4.166809
#
# [1 rows x 47 columns]
#      participantID  Age BirthPlace Gender NativeLanguages  \
# 305              0  NaN        NaN    NaN             NaN
#
#      NumOfNativeLanguages Other Languages  TotalLanguages  Extroversion Hand  \
# 305                   NaN             NaN             NaN           NaN  NaN
#
#      ... right_knee_entropy2D left_knee_entropy2D  right_ankle_entropy2D  \
# 305  ...             0.896754            1.056168               0.931474
#
#      left_ankle_entropy2D total_body_entropy2D right_wrist_variability2D  \
# 305              0.949104             1.073017                  -0.35304
#
#      left_wrist_variability2D  total_body_variability2D  X_embeddings  \
# 305                 -0.586641                 -0.573087     -5.535115
#
#      Y_embeddings
# 305      1.595626
#
# [1 rows x 47 columns]
#      participantID  Age BirthPlace Gender NativeLanguages  \
# 306              0  NaN        NaN    NaN             NaN
#
#      NumOfNativeLanguages Other Languages  TotalLanguages  Extroversion Hand  \
# 306                   NaN             NaN             NaN           NaN  NaN
#
#      ... right_knee_entropy2D left_knee_entropy2D  right_ankle_entropy2D  \
# 306  ...             0.896754            1.056168               0.931474
#
#      left_ankle_entropy2D total_body_entropy2D right_wrist_variability2D  \
# 306              0.949104             1.073017                  -0.35304
#
#      left_wrist_variability2D  total_body_variability2D  X_embeddings  \
# 306                 -0.586641                 -0.573087     -5.535115
#
#      Y_embeddings
# 306      1.595626
#
# [1 rows x 47 columns]
#      participantID  Age BirthPlace Gender NativeLanguages  \
# 307              0  NaN        NaN    NaN             NaN
#
#      NumOfNativeLanguages Other Languages  TotalLanguages  Extroversion Hand  \
# 307                   NaN             NaN             NaN           NaN  NaN
#
#      ... right_knee_entropy2D left_knee_entropy2D  right_ankle_entropy2D  \
# 307  ...             0.928139            0.848104               1.038584
#
#      left_ankle_entropy2D total_body_entropy2D right_wrist_variability2D  \
# 307              0.979449             1.088923                 -0.741788
#
#      left_wrist_variability2D  total_body_variability2D  X_embeddings  \
# 307                 -0.670805                 -0.865573     -3.890631
#
#      Y_embeddings
# 307      3.642599
#
# [1 rows x 47 columns]
#      participantID  Age BirthPlace Gender NativeLanguages  \
# 308              0  NaN        NaN    NaN             NaN
#
#      NumOfNativeLanguages Other Languages  TotalLanguages  Extroversion Hand  \
# 308                   NaN             NaN             NaN           NaN  NaN
#
#      ... right_knee_entropy2D left_knee_entropy2D  right_ankle_entropy2D  \
# 308  ...             0.928139            0.848104               1.038584
#
#      left_ankle_entropy2D total_body_entropy2D right_wrist_variability2D  \
# 308              0.979449             1.088923                 -0.741788
#
#      left_wrist_variability2D  total_body_variability2D  X_embeddings  \
# 308                 -0.670805                 -0.865573     -3.890631
#
#      Y_embeddings
# 308      3.642599
#
# [1 rows x 47 columns]
#      participantID  Age BirthPlace Gender NativeLanguages  \
# 309              0  NaN        NaN    NaN             NaN
#
#      NumOfNativeLanguages Other Languages  TotalLanguages  Extroversion Hand  \
# 309                   NaN             NaN             NaN           NaN  NaN
#
#      ... right_knee_entropy2D left_knee_entropy2D  right_ankle_entropy2D  \
# 309  ...             0.961436            0.792356               1.069855
#
#      left_ankle_entropy2D total_body_entropy2D right_wrist_variability2D  \
# 309              0.796514             0.986017                 -0.735528
#
#      left_wrist_variability2D  total_body_variability2D  X_embeddings  \
# 309                 -0.418067                 -0.709372     -3.160261
#
#      Y_embeddings
# 309       3.85526
#
# [1 rows x 47 columns]
#      participantID  Age BirthPlace Gender NativeLanguages  \
# 310              0  NaN        NaN    NaN             NaN
#
#      NumOfNativeLanguages Other Languages  TotalLanguages  Extroversion Hand  \
# 310                   NaN             NaN             NaN           NaN  NaN
#
#      ... right_knee_entropy2D left_knee_entropy2D  right_ankle_entropy2D  \
# 310  ...             0.961436            0.792356               1.069855
#
#      left_ankle_entropy2D total_body_entropy2D right_wrist_variability2D  \
# 310              0.796514             0.986017                 -0.735528
#
#      left_wrist_variability2D  total_body_variability2D  X_embeddings  \
# 310                 -0.418067                 -0.709372     -3.160261
#
#      Y_embeddings
# 310       3.85526
#
# [1 rows x 47 columns]
#      participantID  Age BirthPlace Gender NativeLanguages  \
# 311              0  NaN        NaN    NaN             NaN
#
#      NumOfNativeLanguages Other Languages  TotalLanguages  Extroversion Hand  \
# 311                   NaN             NaN             NaN           NaN  NaN
#
#      ... right_knee_entropy2D left_knee_entropy2D  right_ankle_entropy2D  \
# 311  ...            -1.190243           -1.191379              -1.191595
#
#      left_ankle_entropy2D total_body_entropy2D right_wrist_variability2D  \
# 311             -1.191335            -0.943956                   0.12189
#
#      left_wrist_variability2D  total_body_variability2D  X_embeddings  \
# 311                 -0.785199                 -0.397381     16.057255
#
#      Y_embeddings
# 311      5.577348
#
# [1 rows x 47 columns]

# %%
big_df
# Out:
#     participantID generation_number chain_number chainID   age extrovert  \
# 0             0.0               NaN          NaN     NaN   NaN       NaN
# 1             1.0                 1            1   ch1g1   NaN       NaN
# 2             2.0                 2            1   ch1g2  24.0      17.0
# 3             3.0                 3            1   ch1g3  32.0      60.0
# 4             4.0                 4            1   ch1g4  60.0      86.0
# ..            ...               ...          ...     ...   ...       ...
# 56           56.0                16            3  ch3g16  21.0      80.0
# 57           57.0                17            3  ch3g17  50.0      30.0
# 58           58.0                18            3  ch3g18  28.0      60.0
# 59           59.0                19            3  ch3g19  27.0      40.0
# 60            NaN                20            3  ch3g20  35.0      85.0
#
#    diff_in_age diff_in_extrovert diff_in_gesture_space_Donner  \
# 0          NaN               NaN                          NaN
# 1          NaN               NaN                     0.737688
# 2            2                23                     0.276513
# 3            8                43                     0.231724
# 4           28                26                     1.458954
# ..         ...               ...                          ...
# 56           1                50                     0.198595
# 57          29                50                     0.011056
# 58          22                30                     0.875646
# 59           1                20                       0.2591
# 60           8                45                     0.822399
#
#    diff_in_entropy_Donner  ... diff_in_variability_rennen  \
# 0                     NaN  ...                        NaN
# 1                1.860545  ...                   0.035431
# 2                0.047161  ...                    0.11818
# 3                1.918169  ...                   0.186364
# 4                0.065033  ...                   0.013691
# ..                    ...  ...                        ...
# 56               0.056406  ...                   0.568328
# 57               0.057718  ...                   0.050418
# 58               1.612547  ...                   0.037271
# 59               1.706765  ...                   0.014935
# 60               0.380522  ...                    0.06157
#
#    diff_in_gesture_space_mean diff_in_entropy_mean diff_in_variability_mean  \
# 0                         NaN                  NaN                      NaN
# 1                    0.487447             0.422144                  0.37959
# 2                    0.127323             0.049867                 0.724077
# 3                    0.385347             0.465025                 0.636728
# 4                    0.687772             0.718496                  0.28144
# ..                        ...                  ...                      ...
# 56                   0.262935             1.159826                 1.626505
# 57                   0.184466             0.433727                 0.973597
# 58                   0.400435             0.368982                 0.932075
# 59                   0.335134             1.033039                  1.38997
# 60                   0.367445             0.492895                 0.663853
#
#    total_dist_Donner total_dist_kalt total_dist_langsam total_dist_leise  \
# 0                NaN             NaN                NaN              NaN
# 1          20.151713        1.670208           1.423867         2.706066
# 2           1.480858        5.794046           0.708995          0.34637
# 3          19.974749        2.508555           0.860451         2.491099
# 4           1.840685        21.94616           3.846642        17.037509
# ..               ...             ...                ...              ...
# 56           1.09916       20.071282          23.831434        18.303893
# 57          0.933256         2.05356           1.170885        18.111433
# 58         21.269982        1.020603           4.757972         3.620078
# 59         20.838212       17.154052           5.381934        16.008339
# 60          2.222442        5.514053           1.306928        18.522889
#
#    total_dist_rennen total_dist_mean
# 0                NaN             NaN
# 1           4.962181        6.182807
# 2           0.391746        1.744403
# 3            0.96241        5.359453
# 4           0.613282        9.056855
# ..               ...             ...
# 56          2.243367       13.109827
# 57          0.915992        4.637025
# 58          2.641678        6.662063
# 59          2.619581       12.400424
# 60          1.638291         5.84092
#
# [61 rows x 32 columns]

# %% [markdown]
# Graph diff in age vs gesture distance

# %% [markdown]
# # THIS GRAPH ANSWERS THE QUESTION: DOES AGE AFFECT HOW MUCH YOU CHANGE THE GESTURE?

# %%
sns.scatterplot(data=big_df, x="age", y="diff_in_gesture_space_mean")
# Out:
# <Axes: xlabel='age', ylabel='diff_in_gesture_space_mean'>

# %%
import matplotlib.pyplot as plt
import numpy as np

plt.plot(diff_in_age_array, diff_in_dist_array, 'o')
plt.show()

# %% [markdown]
# Graph diff in extroversion vs gesture distance

# %%
import matplotlib.pyplot as plt
import numpy as np

plt.plot(diff_in_extrovert_array, diff_in_dist_array, 'o')
plt.show()

# %% [markdown]
# # Does age correlate with gesture size? (Should I separate this graph by gesture type?)

# %%
sns.scatterplot(data=normed_features, x="Q2", y="total_gesture_space2D", hue = 'gesture')
# Out:
# <Axes: xlabel='Q2', ylabel='total_gesture_space2D'>

# %% [markdown]
# # Does extroversion correlate with gesture size?

# %% [markdown]
# rennen:

# %%
sns.scatterplot(data=normed_features[normed_features["gesture"] == 'leise'], x="Q7_16", y="total_gesture_space2D")
# Out:
# <Axes: xlabel='Q7_16', ylabel='total_gesture_space2D'>

# %% [markdown]
# leise:

# %%
sns.scatterplot(data=normed_features[normed_features["gesture"] == 'leise'], x="Q7_16", y="total_gesture_space2D")
# Out:
# <Axes: xlabel='Q7_16', ylabel='total_gesture_space2D'>

# %% [markdown]
# langsam:

# %%
sns.scatterplot(data=normed_features[normed_features["gesture"] == 'langsam'], x="Q7_16", y="total_gesture_space2D")
# Out:
# <Axes: xlabel='Q7_16', ylabel='total_gesture_space2D'>

# %% [markdown]
# Donner:

# %%
sns.scatterplot(data=normed_features[normed_features["gesture"] == 'Donner'], x="Q7_16", y="total_gesture_space2D")
# Out:
# <Axes: xlabel='Q7_16', ylabel='total_gesture_space2D'>

# %% [markdown]
# Kalt:

# %%
sns.scatterplot(data=normed_features[normed_features["gesture"] == 'kalt'], x="Q7_16", y="total_gesture_space2D")
# Out:
# <Axes: xlabel='Q7_16', ylabel='total_gesture_space2D'>
