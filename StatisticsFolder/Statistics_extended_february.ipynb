# %% [markdown]
# # STATISTICS

# %%
# import libraries
import os
import glob
import pandas as pd
import numpy as np
import math
import scipy
import matplotlib.pyplot as plt
import math
import xml.etree.ElementTree as ET
import seaborn as sns
import seaborn.objects as so
from sklearn.preprocessing import StandardScaler
import umap

curfolder = os.getcwd()
print(curfolder)

flesh_folder = os.path.dirname(curfolder)
features = flesh_folder + '/Feature_Extraction_folder/feature_extraction_with2d_february.csv'

features = pd.read_csv(features)

features
# Out:
# /Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/StatisticsFolder
#      participantID   Age          BirthPlace            Gender  \
# 0               23  35.0        Deutschland   Woman / Weiblich
# 1                0   NaN                 NaN               NaN
# 2               16  27.0         Deutschland    Man / Männlich
# 3               22  32.0  Delft, Netherlands         Man / Man
# 4               30  45.0             Dresden  Woman / Weiblich
# ..             ...   ...                 ...               ...
# 432             14  11.0              Berlin    Man / Männlich
# 433              5  25.0                1998         Man / Man
# 434             39  39.0              Berlin  Woman / Weiblich
# 435             52  21.0              Berlin    Man / Männlich
# 436             59  27.0   Deutschland, Gera  Woman / Weiblich
#
#       NativeLanguages  NumOfNativeLanguages  \
# 0            Deutsch                    1.0
# 1                 NaN                   NaN
# 2            Deutsch                    1.0
# 3    Dutch and Polish                   NaN
# 4             Deutsch                   1.0
# ..                ...                   ...
# 432           Deutsch                   1.0
# 433           Italian                   NaN
# 434          Deutsch                    1.0
# 435           Deutsch                   1.0
# 436           Deutsch                   1.0
#
#                                        Other Languages  TotalLanguages  \
# 0    English (fluent), French (advanced), Italian (...             4.0
# 1                                                  NaN             NaN
# 2                                              English             2.0
# 3    English (fluent), French (good knowledge), Ger...             5.0
# 4                                             Englisch             2.0
# ..                                                 ...             ...
# 432                                   Englisch (basic)             2.0
# 433   English (fluent), Spanish (good), Arabic (basic)             4.0
# 434                     English fluent, Spanisch basic             3.0
# 435      Englisch- sehr gut, Italienisch - grundlegend             3.0
# 436  Englisch (gute Kenntnisse), französisch (Grund...             3.0
#
#      Extroversion                            Hand  ... right_knee_SpeedRange  \
# 0            43.0  Right-handed / Rechtshänder*in  ...              0.000059
# 1             NaN                             NaN  ...              0.000000
# 2            30.0  Right-handed / Rechtshänder*in  ...              0.000046
# 3            91.0     Right-handed / Rechtshandig  ...              0.000000
# 4            51.0  Right-handed / Rechtshänder*in  ...              0.000080
# ..            ...                             ...  ...                   ...
# 432          40.0  Right-handed / Rechtshänder*in  ...              0.000110
# 433          71.0     Right-handed / Rechtshandig  ...              0.000000
# 434          41.0    Left-handed / Linkshänder*in  ...              0.000180
# 435          53.0  Right-handed / Rechtshänder*in  ...              0.000000
# 436          40.0  Right-handed / Rechtshänder*in  ...              0.000095
#
#     left_knee_SpeedRange  right_wrist_AccelRange  left_wrist_AccelRange  \
# 0               0.000054                0.000084               0.000089
# 1               0.000000                0.000094               0.000067
# 2               0.000052                0.000179               0.000186
# 3               0.000000                0.000012               0.000125
# 4               0.000091                0.000082               0.000081
# ..                   ...                     ...                    ...
# 432             0.000165                0.000036               0.000025
# 433             0.000000                0.000117               0.000089
# 434             0.000276                0.000175               0.000181
# 435             0.000000                0.000176               0.000172
# 436             0.000144                0.000133               0.000043
#
#     right_knee_AccelRange left_knee_AccelRange right_wrist_SpeedIntegral  \
# 0                0.000009             0.000009                  0.073015
# 1                0.000000             0.000000                  0.032305
# 2                0.000009             0.000011                  0.160841
# 3                0.000000             0.000000                  0.010280
# 4                0.000007             0.000013                  0.052000
# ..                    ...                  ...                       ...
# 432              0.000015             0.000017                  0.070999
# 433              0.000000             0.000000                  0.137715
# 434              0.000051             0.000093                  0.144251
# 435              0.000000             0.000000                  0.042284
# 436              0.000012             0.000016                  0.189240
#
#      left_wrist_SpeedIntegral  right_knee_SpeedIntegral  \
# 0                    0.079426                  0.002551
# 1                    0.029311                  0.000000
# 2                    0.169384                  0.007596
# 3                    0.097070                  0.000000
# 4                    0.060269                  0.010345
# ..                        ...                       ...
# 432                  0.074483                  0.038290
# 433                  0.106934                  0.000000
# 434                  0.151697                  0.030786
# 435                  0.040495                  0.000000
# 436                  0.141326                  0.039458
#
#      left_knee_SpeedIntegral
# 0                   0.003209
# 1                   0.000000
# 2                   0.007968
# 3                   0.000000
# 4                   0.008786
# ..                       ...
# 432                 0.042910
# 433                 0.000000
# 434                 0.039501
# 435                 0.000000
# 436                 0.048360
#
# [437 rows x 61 columns]

# %% [markdown]
# ## Finding the correlations between columns

# %%
cols_to_compare = features.columns[17:]
corr_df = features[cols_to_compare]

# %%
import seaborn as sns
import matplotlib.pyplot as plt
cols_to_compare = features.columns[17:]
corr_df = features[cols_to_compare]

pearson_corr = corr_df.corr(method='pearson')
print(pearson_corr)

sns.heatmap(pearson_corr, annot=True, cmap='coolwarm')
plt.title("Pearson Correlation Heatmap")
plt.show()

pearson_corr
# Out:
#                                 left_wrist_space2D  right_wrist_space2D  \
# left_wrist_space2D                        1.000000             0.820869
# right_wrist_space2D                       0.820869             1.000000
# left_knee_space2D                         0.003511            -0.114195
# right_knee_space2D                        0.049443            -0.050991
# nose_space2D                              0.166728             0.125997
# total_arm_boundingbox2D                   0.560525             0.489661
# total_lower_body_boundingbox2D           -0.002246            -0.082806
# left_arm_entropy                          0.824283             0.648197
# right_arm_entropy                         0.686033             0.799507
# left_wrist_entropy                        0.706071             0.792736
# total_arm_entropy2Daggregated             0.047563            -0.097291
# left_wrist_variability2D                  0.515798             0.396054
# right_wrist_variability2D                 0.366571             0.424538
# left_knee_variability2D                   0.086334             0.011751
# right_knee_variability2D                  0.124247             0.025823
# left_wrist_submovements                   0.575078             0.450583
# right_wrist_submovements                  0.474537             0.471121
# left_knee_submovements                   -0.103657            -0.219340
# right_wrist_SpeedAVG                      0.356036             0.426269
# left_wrist_SpeedAVG                       0.532781             0.316639
# left_knee_SpeedAVG                       -0.055577            -0.171680
# right_knee_SpeedAVG                      -0.101070            -0.226675
# right_wrist_AccelAVG                     -0.219101            -0.252638
# left_wrist_AccelAVG                      -0.215417            -0.177097
# right_knee_AccelAVG                      -0.126242            -0.115734
# left_knee_AccelAVG                       -0.174326            -0.163404
# right_wrist_SpeedSD                       0.290141             0.494294
# left_wrist_SpeedSD                        0.587604             0.338251
# right_knee_SpeedSD                       -0.028676            -0.129373
# left_knee_SpeedSD                        -0.090314            -0.210945
# right_wrist_AccelSD                       0.041405            -0.024174
# left_wrist_AccelSD                        0.039673            -0.079224
# right_wrist_SpeedRange                    0.364108             0.499480
# left_wrist_SpeedRange                     0.568546             0.311859
# right_knee_SpeedRange                    -0.054241            -0.158904
# left_knee_SpeedRange                     -0.108180            -0.225992
# right_wrist_AccelRange                    0.205769             0.267958
# left_wrist_AccelRange                     0.309295             0.100125
# right_knee_AccelRange                    -0.096622            -0.195316
# left_knee_AccelRange                     -0.141599            -0.254304
# right_wrist_SpeedIntegral                 0.252374             0.229743
# left_wrist_SpeedIntegral                  0.380862             0.173414
# right_knee_SpeedIntegral                 -0.049849            -0.156824
# left_knee_SpeedIntegral                  -0.088611            -0.200224
#
#                                 left_knee_space2D  right_knee_space2D  \
# left_wrist_space2D                       0.003511            0.049443
# right_wrist_space2D                     -0.114195           -0.050991
# left_knee_space2D                        1.000000            0.907970
# right_knee_space2D                       0.907970            1.000000
# nose_space2D                             0.371599            0.438909
# total_arm_boundingbox2D                  0.203076            0.287417
# total_lower_body_boundingbox2D           0.858906            0.851494
# left_arm_entropy                         0.155220            0.161500
# right_arm_entropy                        0.051177            0.073559
# left_wrist_entropy                       0.073494            0.094048
# total_arm_entropy2Daggregated            0.431845            0.391129
# left_wrist_variability2D                 0.113118            0.108554
# right_wrist_variability2D               -0.044129           -0.028911
# left_knee_variability2D                  0.624844            0.540709
# right_knee_variability2D                 0.690195            0.649515
# left_wrist_submovements                  0.319200            0.285266
# right_wrist_submovements                 0.331672            0.310465
# left_knee_submovements                   0.665222            0.566847
# right_wrist_SpeedAVG                    -0.063400            0.017299
# left_wrist_SpeedAVG                      0.132004            0.187892
# left_knee_SpeedAVG                       0.792563            0.851597
# right_knee_SpeedAVG                      0.845086            0.801591
# right_wrist_AccelAVG                     0.039564            0.039661
# left_wrist_AccelAVG                      0.018372            0.026623
# right_knee_AccelAVG                      0.123345            0.169133
# left_knee_AccelAVG                       0.131222            0.133340
# right_wrist_SpeedSD                     -0.336289           -0.229592
# left_wrist_SpeedSD                      -0.037731            0.024137
# right_knee_SpeedSD                       0.785597            0.869256
# left_knee_SpeedSD                        0.865176            0.824402
# right_wrist_AccelSD                      0.404808            0.454990
# left_wrist_AccelSD                       0.404594            0.431650
# right_wrist_SpeedRange                  -0.212722           -0.110203
# left_wrist_SpeedRange                    0.056568            0.104602
# right_knee_SpeedRange                    0.802762            0.875410
# left_knee_SpeedRange                     0.879267            0.824786
# right_wrist_AccelRange                  -0.115712            0.001626
# left_wrist_AccelRange                    0.043703            0.102904
# right_knee_AccelRange                    0.671787            0.746307
# left_knee_AccelRange                     0.741054            0.710829
# right_wrist_SpeedIntegral                0.259087            0.290220
# left_wrist_SpeedIntegral                 0.390258            0.396958
# right_knee_SpeedIntegral                 0.842082            0.847637
# left_knee_SpeedIntegral                  0.869202            0.790010
#
#                                 nose_space2D  total_arm_boundingbox2D  \
# left_wrist_space2D                  0.166728                 0.560525
# right_wrist_space2D                 0.125997                 0.489661
# left_knee_space2D                   0.371599                 0.203076
# right_knee_space2D                  0.438909                 0.287417
# nose_space2D                        1.000000                 0.419839
# total_arm_boundingbox2D             0.419839                 1.000000
# total_lower_body_boundingbox2D      0.371548                 0.256238
# left_arm_entropy                    0.176031                 0.309102
# right_arm_entropy                   0.098782                 0.226272
# left_wrist_entropy                  0.109285                 0.255618
# total_arm_entropy2Daggregated       0.134584                 0.166725
# left_wrist_variability2D            0.101297                 0.175972
# right_wrist_variability2D           0.005764                 0.096062
# left_knee_variability2D             0.168327                 0.037005
# right_knee_variability2D            0.199212                 0.091125
# left_wrist_submovements             0.161004                 0.215071
# right_wrist_submovements            0.128357                 0.167861
# left_knee_submovements              0.095182                -0.049825
# right_wrist_SpeedAVG                0.161607                 0.567750
# left_wrist_SpeedAVG                 0.183949                 0.545345
# left_knee_SpeedAVG                  0.304857                 0.121625
# right_knee_SpeedAVG                 0.287943                 0.098837
# right_wrist_AccelAVG               -0.079200                -0.085740
# left_wrist_AccelAVG                -0.045958                -0.073723
# right_knee_AccelAVG                 0.091712                -0.013940
# left_knee_AccelAVG                  0.022198                -0.094322
# right_wrist_SpeedSD                 0.077896                 0.427654
# left_wrist_SpeedSD                  0.164515                 0.515140
# right_knee_SpeedSD                  0.319622                 0.179000
# left_knee_SpeedSD                   0.318016                 0.129771
# right_wrist_AccelSD                 0.163596                 0.158499
# left_wrist_AccelSD                  0.133785                 0.117778
# right_wrist_SpeedRange              0.161925                 0.573310
# left_wrist_SpeedRange               0.224476                 0.566098
# right_knee_SpeedRange               0.313160                 0.166102
# left_knee_SpeedRange                0.315597                 0.119251
# right_wrist_AccelRange              0.102211                 0.348016
# left_wrist_AccelRange               0.127766                 0.342136
# right_knee_AccelRange               0.261033                 0.104493
# left_knee_AccelRange                0.254807                 0.065296
# right_wrist_SpeedIntegral           0.199923                 0.589668
# left_wrist_SpeedIntegral            0.203695                 0.511551
# right_knee_SpeedIntegral            0.301600                 0.117282
# left_knee_SpeedIntegral             0.274838                 0.086329
#
#                                 total_lower_body_boundingbox2D  \
# left_wrist_space2D                                   -0.002246
# right_wrist_space2D                                  -0.082806
# left_knee_space2D                                     0.858906
# right_knee_space2D                                    0.851494
# nose_space2D                                          0.371548
# total_arm_boundingbox2D                               0.256238
# total_lower_body_boundingbox2D                        1.000000
# left_arm_entropy                                      0.132407
# right_arm_entropy                                     0.066545
# left_wrist_entropy                                    0.085584
# total_arm_entropy2Daggregated                         0.320061
# left_wrist_variability2D                              0.103216
# right_wrist_variability2D                            -0.025191
# left_knee_variability2D                               0.448735
# right_knee_variability2D                              0.530534
# left_wrist_submovements                               0.307181
# right_wrist_submovements                              0.345267
# left_knee_submovements                                0.505258
# right_wrist_SpeedAVG                                 -0.035172
# left_wrist_SpeedAVG                                   0.104004
# left_knee_SpeedAVG                                    0.674062
# right_knee_SpeedAVG                                   0.683492
# right_wrist_AccelAVG                                  0.053487
# left_wrist_AccelAVG                                   0.038212
# right_knee_AccelAVG                                   0.150528
# left_knee_AccelAVG                                    0.117614
# right_wrist_SpeedSD                                  -0.240885
# left_wrist_SpeedSD                                   -0.050716
# right_knee_SpeedSD                                    0.700041
# left_knee_SpeedSD                                     0.707194
# right_wrist_AccelSD                                   0.272359
# left_wrist_AccelSD                                    0.259595
# right_wrist_SpeedRange                               -0.150992
# left_wrist_SpeedRange                                 0.019825
# right_knee_SpeedRange                                 0.735943
# left_knee_SpeedRange                                  0.739359
# right_wrist_AccelRange                               -0.076611
# left_wrist_AccelRange                                 0.018697
# right_knee_AccelRange                                 0.604902
# left_knee_AccelRange                                  0.602285
# right_wrist_SpeedIntegral                             0.247022
# left_wrist_SpeedIntegral                              0.340660
# right_knee_SpeedIntegral                              0.776973
# left_knee_SpeedIntegral                               0.774926
#
#                                 left_arm_entropy  right_arm_entropy  \
# left_wrist_space2D                      0.824283           0.686033
# right_wrist_space2D                     0.648197           0.799507
# left_knee_space2D                       0.155220           0.051177
# right_knee_space2D                      0.161500           0.073559
# nose_space2D                            0.176031           0.098782
# total_arm_boundingbox2D                 0.309102           0.226272
# total_lower_body_boundingbox2D          0.132407           0.066545
# left_arm_entropy                        1.000000           0.837299
# right_arm_entropy                       0.837299           1.000000
# left_wrist_entropy                      0.856393           0.993173
# total_arm_entropy2Daggregated           0.140210           0.033439
# left_wrist_variability2D                0.607150           0.499558
# right_wrist_variability2D               0.412837           0.465395
# left_knee_variability2D                 0.223474           0.147267
# right_knee_variability2D                0.274949           0.189435
# left_wrist_submovements                 0.829182           0.717688
# right_wrist_submovements                0.704488           0.751485
# left_knee_submovements                  0.038836          -0.071888
# right_wrist_SpeedAVG                    0.141905           0.188596
# left_wrist_SpeedAVG                     0.338703           0.145380
# left_knee_SpeedAVG                      0.003674          -0.103588
# right_knee_SpeedAVG                    -0.029369          -0.147254
# right_wrist_AccelAVG                   -0.176492          -0.215642
# left_wrist_AccelAVG                    -0.194088          -0.171932
# right_knee_AccelAVG                    -0.084815          -0.075533
# left_knee_AccelAVG                     -0.122807          -0.123454
# right_wrist_SpeedSD                     0.045978           0.192886
# left_wrist_SpeedSD                      0.365000           0.151010
# right_knee_SpeedSD                      0.021180          -0.074266
# left_knee_SpeedSD                      -0.021551          -0.138862
# right_wrist_AccelSD                    -0.038282          -0.104989
# left_wrist_AccelSD                     -0.033600          -0.161404
# right_wrist_SpeedRange                  0.112660           0.198496
# left_wrist_SpeedRange                   0.352933           0.126164
# right_knee_SpeedRange                   0.005924          -0.092362
# left_knee_SpeedRange                   -0.025343          -0.137973
# right_wrist_AccelRange                  0.027257           0.059332
# left_wrist_AccelRange                   0.159934          -0.044568
# right_knee_AccelRange                  -0.072469          -0.168182
# left_knee_AccelRange                   -0.100354          -0.212325
# right_wrist_SpeedIntegral               0.139884           0.107416
# left_wrist_SpeedIntegral                0.289917           0.109545
# right_knee_SpeedIntegral                0.085551          -0.006532
# left_knee_SpeedIntegral                 0.060196          -0.035803
#
#                                 left_wrist_entropy  ...  \
# left_wrist_space2D                        0.706071  ...
# right_wrist_space2D                       0.792736  ...
# left_knee_space2D                         0.073494  ...
# right_knee_space2D                        0.094048  ...
# nose_space2D                              0.109285  ...
# total_arm_boundingbox2D                   0.255618  ...
# total_lower_body_boundingbox2D            0.085584  ...
# left_arm_entropy                          0.856393  ...
# right_arm_entropy                         0.993173  ...
# left_wrist_entropy                        1.000000  ...
# total_arm_entropy2Daggregated             0.091273  ...
# left_wrist_variability2D                  0.495444  ...
# right_wrist_variability2D                 0.443848  ...
# left_knee_variability2D                   0.150673  ...
# right_knee_variability2D                  0.198994  ...
# left_wrist_submovements                   0.741301  ...
# right_wrist_submovements                  0.766449  ...
# left_knee_submovements                   -0.050000  ...
# right_wrist_SpeedAVG                      0.216337  ...
# left_wrist_SpeedAVG                       0.186318  ...
# left_knee_SpeedAVG                       -0.080480  ...
# right_knee_SpeedAVG                      -0.122055  ...
# right_wrist_AccelAVG                     -0.208935  ...
# left_wrist_AccelAVG                      -0.162493  ...
# right_knee_AccelAVG                      -0.079948  ...
# left_knee_AccelAVG                       -0.126365  ...
# right_wrist_SpeedSD                       0.176239  ...
# left_wrist_SpeedSD                        0.171766  ...
# right_knee_SpeedSD                       -0.053150  ...
# left_knee_SpeedSD                        -0.114930  ...
# right_wrist_AccelSD                      -0.088856  ...
# left_wrist_AccelSD                       -0.141809  ...
# right_wrist_SpeedRange                    0.194267  ...
# left_wrist_SpeedRange                     0.150264  ...
# right_knee_SpeedRange                    -0.069843  ...
# left_knee_SpeedRange                     -0.113941  ...
# right_wrist_AccelRange                    0.062127  ...
# left_wrist_AccelRange                    -0.022051  ...
# right_knee_AccelRange                    -0.146209  ...
# left_knee_AccelRange                     -0.188616  ...
# right_wrist_SpeedIntegral                 0.140349  ...
# left_wrist_SpeedIntegral                  0.149507  ...
# right_knee_SpeedIntegral                  0.017910  ...
# left_knee_SpeedIntegral                  -0.010647  ...
#
#                                 right_knee_SpeedRange  left_knee_SpeedRange  \
# left_wrist_space2D                          -0.054241             -0.108180
# right_wrist_space2D                         -0.158904             -0.225992
# left_knee_space2D                            0.802762              0.879267
# right_knee_space2D                           0.875410              0.824786
# nose_space2D                                 0.313160              0.315597
# total_arm_boundingbox2D                      0.166102              0.119251
# total_lower_body_boundingbox2D               0.735943              0.739359
# left_arm_entropy                             0.005924             -0.025343
# right_arm_entropy                           -0.092362             -0.137973
# left_wrist_entropy                          -0.069843             -0.113941
# total_arm_entropy2Daggregated                0.428940              0.457317
# left_wrist_variability2D                    -0.012754             -0.024805
# right_wrist_variability2D                   -0.125848             -0.147258
# left_knee_variability2D                      0.411121              0.468595
# right_knee_variability2D                     0.531385              0.552656
# left_wrist_submovements                      0.115291              0.122958
# right_wrist_submovements                     0.133204              0.117976
# left_knee_submovements                       0.551244              0.644772
# right_wrist_SpeedAVG                         0.086504              0.018624
# left_wrist_SpeedAVG                          0.258414              0.221538
# left_knee_SpeedAVG                           0.957558              0.895453
# right_knee_SpeedAVG                          0.894722              0.946291
# right_wrist_AccelAVG                         0.035694              0.047886
# left_wrist_AccelAVG                          0.046702              0.045346
# right_knee_AccelAVG                          0.186033              0.156918
# left_knee_AccelAVG                           0.179050              0.180014
# right_wrist_SpeedSD                         -0.210720             -0.294019
# left_wrist_SpeedSD                           0.055115              0.017641
# right_knee_SpeedSD                           0.985130              0.884824
# left_knee_SpeedSD                            0.907055              0.982470
# right_wrist_AccelSD                          0.613488              0.572652
# left_wrist_AccelSD                           0.591465              0.575554
# right_wrist_SpeedRange                      -0.095648             -0.170150
# left_wrist_SpeedRange                        0.144866              0.120494
# right_knee_SpeedRange                        1.000000              0.902635
# left_knee_SpeedRange                         0.902635              1.000000
# right_wrist_AccelRange                       0.126717              0.031667
# left_wrist_AccelRange                        0.234478              0.192237
# right_knee_AccelRange                        0.955718              0.846006
# left_knee_AccelRange                         0.864976              0.945994
# right_wrist_SpeedIntegral                    0.297777              0.272202
# left_wrist_SpeedIntegral                     0.401539              0.406681
# right_knee_SpeedIntegral                     0.851121              0.839683
# left_knee_SpeedIntegral                      0.773877              0.853428
#
#                                 right_wrist_AccelRange  left_wrist_AccelRange  \
# left_wrist_space2D                            0.205769               0.309295
# right_wrist_space2D                           0.267958               0.100125
# left_knee_space2D                            -0.115712               0.043703
# right_knee_space2D                            0.001626               0.102904
# nose_space2D                                  0.102211               0.127766
# total_arm_boundingbox2D                       0.348016               0.342136
# total_lower_body_boundingbox2D               -0.076611               0.018697
# left_arm_entropy                              0.027257               0.159934
# right_arm_entropy                             0.059332              -0.044568
# left_wrist_entropy                            0.062127              -0.022051
# total_arm_entropy2Daggregated                 0.071870               0.267345
# left_wrist_variability2D                      0.005021               0.085923
# right_wrist_variability2D                     0.054385              -0.041181
# left_knee_variability2D                      -0.195783              -0.082927
# right_knee_variability2D                     -0.131850              -0.042789
# left_wrist_submovements                      -0.055821               0.033617
# right_wrist_submovements                     -0.014569              -0.096153
# left_knee_submovements                       -0.126095               0.090208
# right_wrist_SpeedAVG                          0.729047               0.452793
# left_wrist_SpeedAVG                           0.488633               0.766333
# left_knee_SpeedAVG                            0.120767               0.255627
# right_knee_SpeedAVG                           0.055955               0.224189
# right_wrist_AccelAVG                         -0.078762              -0.105810
# left_wrist_AccelAVG                           0.001864              -0.066069
# right_knee_AccelAVG                           0.014497              -0.018232
# left_knee_AccelAVG                           -0.028495               0.033418
# right_wrist_SpeedSD                           0.711700               0.275764
# left_wrist_SpeedSD                            0.434343               0.788844
# right_knee_SpeedSD                            0.134909               0.230227
# left_knee_SpeedSD                             0.048572               0.200079
# right_wrist_AccelSD                           0.473962               0.476800
# left_wrist_AccelSD                            0.357566               0.573131
# right_wrist_SpeedRange                        0.772021               0.386950
# left_wrist_SpeedRange                         0.444884               0.833681
# right_knee_SpeedRange                         0.126717               0.234478
# left_knee_SpeedRange                          0.031667               0.192237
# right_wrist_AccelRange                        1.000000               0.585753
# left_wrist_AccelRange                         0.585753               1.000000
# right_knee_AccelRange                         0.183559               0.295822
# left_knee_AccelRange                          0.112309               0.263703
# right_wrist_SpeedIntegral                     0.499268               0.358785
# left_wrist_SpeedIntegral                      0.309316               0.568703
# right_knee_SpeedIntegral                     -0.013499               0.107194
# left_knee_SpeedIntegral                      -0.078713               0.062772
#
#                                 right_knee_AccelRange  left_knee_AccelRange  \
# left_wrist_space2D                          -0.096622             -0.141599
# right_wrist_space2D                         -0.195316             -0.254304
# left_knee_space2D                            0.671787              0.741054
# right_knee_space2D                           0.746307              0.710829
# nose_space2D                                 0.261033              0.254807
# total_arm_boundingbox2D                      0.104493              0.065296
# total_lower_body_boundingbox2D               0.604902              0.602285
# left_arm_entropy                            -0.072469             -0.100354
# right_arm_entropy                           -0.168182             -0.212325
# left_wrist_entropy                          -0.146209             -0.188616
# total_arm_entropy2Daggregated                0.415492              0.439196
# left_wrist_variability2D                    -0.074818             -0.083194
# right_wrist_variability2D                   -0.167817             -0.183735
# left_knee_variability2D                      0.313466              0.349360
# right_knee_variability2D                     0.406885              0.437627
# left_wrist_submovements                      0.026332              0.032385
# right_wrist_submovements                     0.036995              0.021477
# left_knee_submovements                       0.521758              0.602210
# right_wrist_SpeedAVG                         0.108074              0.050543
# left_wrist_SpeedAVG                          0.268515              0.240307
# left_knee_SpeedAVG                           0.919606              0.857735
# right_knee_SpeedAVG                          0.849724              0.905246
# right_wrist_AccelAVG                         0.027394              0.037304
# left_wrist_AccelAVG                          0.055515              0.037703
# right_knee_AccelAVG                          0.186228              0.139221
# left_knee_AccelAVG                           0.196709              0.173599
# right_wrist_SpeedSD                         -0.185875             -0.254549
# left_wrist_SpeedSD                           0.065791              0.040481
# right_knee_SpeedSD                           0.937396              0.838150
# left_knee_SpeedSD                            0.847771              0.928369
# right_wrist_AccelSD                          0.636318              0.620091
# left_wrist_AccelSD                           0.623881              0.624209
# right_wrist_SpeedRange                      -0.077195             -0.134536
# left_wrist_SpeedRange                        0.162817              0.151435
# right_knee_SpeedRange                        0.955718              0.864976
# left_knee_SpeedRange                         0.846006              0.945994
# right_wrist_AccelRange                       0.183559              0.112309
# left_wrist_AccelRange                        0.295822              0.263703
# right_knee_AccelRange                        1.000000              0.874696
# left_knee_AccelRange                         0.874696              1.000000
# right_wrist_SpeedIntegral                    0.276717              0.245690
# left_wrist_SpeedIntegral                     0.373935              0.370252
# right_knee_SpeedIntegral                     0.775815              0.751624
# left_knee_SpeedIntegral                      0.693170              0.757424
#
#                                 right_wrist_SpeedIntegral  \
# left_wrist_space2D                               0.252374
# right_wrist_space2D                              0.229743
# left_knee_space2D                                0.259087
# right_knee_space2D                               0.290220
# nose_space2D                                     0.199923
# total_arm_boundingbox2D                          0.589668
# total_lower_body_boundingbox2D                   0.247022
# left_arm_entropy                                 0.139884
# right_arm_entropy                                0.107416
# left_wrist_entropy                               0.140349
# total_arm_entropy2Daggregated                    0.437877
# left_wrist_variability2D                         0.044707
# right_wrist_variability2D                       -0.022250
# left_knee_variability2D                          0.098363
# right_knee_variability2D                         0.177471
# left_wrist_submovements                          0.197769
# right_wrist_submovements                         0.202618
# left_knee_submovements                           0.307881
# right_wrist_SpeedAVG                             0.682781
# left_wrist_SpeedAVG                              0.502785
# left_knee_SpeedAVG                               0.294734
# right_knee_SpeedAVG                              0.283214
# right_wrist_AccelAVG                             0.007567
# left_wrist_AccelAVG                              0.042146
# right_knee_AccelAVG                             -0.016731
# left_knee_AccelAVG                              -0.060013
# right_wrist_SpeedSD                              0.383247
# left_wrist_SpeedSD                               0.323412
# right_knee_SpeedSD                               0.280238
# left_knee_SpeedSD                                0.259858
# right_wrist_AccelSD                              0.421307
# left_wrist_AccelSD                               0.339885
# right_wrist_SpeedRange                           0.540668
# left_wrist_SpeedRange                            0.399109
# right_knee_SpeedRange                            0.297777
# left_knee_SpeedRange                             0.272202
# right_wrist_AccelRange                           0.499268
# left_wrist_AccelRange                            0.358785
# right_knee_AccelRange                            0.276717
# left_knee_AccelRange                             0.245690
# right_wrist_SpeedIntegral                        1.000000
# left_wrist_SpeedIntegral                         0.782189
# right_knee_SpeedIntegral                         0.414430
# left_knee_SpeedIntegral                          0.397921
#
#                                 left_wrist_SpeedIntegral  \
# left_wrist_space2D                              0.380862
# right_wrist_space2D                             0.173414
# left_knee_space2D                               0.390258
# right_knee_space2D                              0.396958
# nose_space2D                                    0.203695
# total_arm_boundingbox2D                         0.511551
# total_lower_body_boundingbox2D                  0.340660
# left_arm_entropy                                0.289917
# right_arm_entropy                               0.109545
# left_wrist_entropy                              0.149507
# total_arm_entropy2Daggregated                   0.503093
# left_wrist_variability2D                        0.147791
# right_wrist_variability2D                      -0.005706
# left_knee_variability2D                         0.201981
# right_knee_variability2D                        0.269897
# left_wrist_submovements                         0.320844
# right_wrist_submovements                        0.219711
# left_knee_submovements                          0.453389
# right_wrist_SpeedAVG                            0.424939
# left_wrist_SpeedAVG                             0.737419
# left_knee_SpeedAVG                              0.424749
# right_knee_SpeedAVG                             0.428514
# right_wrist_AccelAVG                           -0.010655
# left_wrist_AccelAVG                            -0.012941
# right_knee_AccelAVG                            -0.049513
# left_knee_AccelAVG                             -0.051813
# right_wrist_SpeedSD                             0.090558
# left_wrist_SpeedSD                              0.562760
# right_knee_SpeedSD                              0.376035
# left_knee_SpeedSD                               0.394965
# right_wrist_AccelSD                             0.460566
# left_wrist_AccelSD                              0.508382
# right_wrist_SpeedRange                          0.258622
# left_wrist_SpeedRange                           0.645614
# right_knee_SpeedRange                           0.401539
# left_knee_SpeedRange                            0.406681
# right_wrist_AccelRange                          0.309316
# left_wrist_AccelRange                           0.568703
# right_knee_AccelRange                           0.373935
# left_knee_AccelRange                            0.370252
# right_wrist_SpeedIntegral                       0.782189
# left_wrist_SpeedIntegral                        1.000000
# right_knee_SpeedIntegral                        0.525803
# left_knee_SpeedIntegral                         0.523295
#
#                                 right_knee_SpeedIntegral  \
# left_wrist_space2D                             -0.049849
# right_wrist_space2D                            -0.156824
# left_knee_space2D                               0.842082
# right_knee_space2D                              0.847637
# nose_space2D                                    0.301600
# total_arm_boundingbox2D                         0.117282
# total_lower_body_boundingbox2D                  0.776973
# left_arm_entropy                                0.085551
# right_arm_entropy                              -0.006532
# left_wrist_entropy                              0.017910
# total_arm_entropy2Daggregated                   0.446718
# left_wrist_variability2D                        0.068138
# right_wrist_variability2D                      -0.070888
# left_knee_variability2D                         0.517930
# right_knee_variability2D                        0.601202
# left_wrist_submovements                         0.287167
# right_wrist_submovements                        0.310087
# left_knee_submovements                          0.748899
# right_wrist_SpeedAVG                           -0.013992
# left_wrist_SpeedAVG                             0.158170
# left_knee_SpeedAVG                              0.850332
# right_knee_SpeedAVG                             0.816430
# right_wrist_AccelAVG                            0.084904
# left_wrist_AccelAVG                             0.067190
# right_knee_AccelAVG                             0.117264
# left_knee_AccelAVG                              0.097267
# right_wrist_SpeedSD                            -0.309497
# left_wrist_SpeedSD                             -0.052412
# right_knee_SpeedSD                              0.826484
# left_knee_SpeedSD                               0.811114
# right_wrist_AccelSD                             0.460341
# left_wrist_AccelSD                              0.455726
# right_wrist_SpeedRange                         -0.187000
# left_wrist_SpeedRange                           0.046100
# right_knee_SpeedRange                           0.851121
# left_knee_SpeedRange                            0.839683
# right_wrist_AccelRange                         -0.013499
# left_wrist_AccelRange                           0.107194
# right_knee_AccelRange                           0.775815
# left_knee_AccelRange                            0.751624
# right_wrist_SpeedIntegral                       0.414430
# left_wrist_SpeedIntegral                        0.525803
# right_knee_SpeedIntegral                        1.000000
# left_knee_SpeedIntegral                         0.955983
#
#                                 left_knee_SpeedIntegral
# left_wrist_space2D                            -0.088611
# right_wrist_space2D                           -0.200224
# left_knee_space2D                              0.869202
# right_knee_space2D                             0.790010
# nose_space2D                                   0.274838
# total_arm_boundingbox2D                        0.086329
# total_lower_body_boundingbox2D                 0.774926
# left_arm_entropy                               0.060196
# right_arm_entropy                             -0.035803
# left_wrist_entropy                            -0.010647
# total_arm_entropy2Daggregated                  0.461227
# left_wrist_variability2D                       0.051971
# right_wrist_variability2D                     -0.085948
# left_knee_variability2D                        0.528371
# right_knee_variability2D                       0.591355
# left_wrist_submovements                        0.274199
# right_wrist_submovements                       0.291252
# left_knee_submovements                         0.796615
# right_wrist_SpeedAVG                          -0.054977
# left_wrist_SpeedAVG                            0.126426
# left_knee_SpeedAVG                             0.775557
# right_knee_SpeedAVG                            0.834114
# right_wrist_AccelAVG                           0.086408
# left_wrist_AccelAVG                            0.063264
# right_knee_AccelAVG                            0.097633
# left_knee_AccelAVG                             0.103799
# right_wrist_SpeedSD                           -0.356682
# left_wrist_SpeedSD                            -0.083733
# right_knee_SpeedSD                             0.736640
# left_knee_SpeedSD                              0.823158
# right_wrist_AccelSD                            0.418079
# left_wrist_AccelSD                             0.420415
# right_wrist_SpeedRange                        -0.234703
# left_wrist_SpeedRange                          0.019638
# right_knee_SpeedRange                          0.773877
# left_knee_SpeedRange                           0.853428
# right_wrist_AccelRange                        -0.078713
# left_wrist_AccelRange                          0.062772
# right_knee_AccelRange                          0.693170
# left_knee_AccelRange                           0.757424
# right_wrist_SpeedIntegral                      0.397921
# left_wrist_SpeedIntegral                       0.523295
# right_knee_SpeedIntegral                       0.955983
# left_knee_SpeedIntegral                        1.000000
#
# [44 rows x 44 columns]
#                                 left_wrist_space2D  right_wrist_space2D  \
# left_wrist_space2D                        1.000000             0.820869
# right_wrist_space2D                       0.820869             1.000000
# left_knee_space2D                         0.003511            -0.114195
# right_knee_space2D                        0.049443            -0.050991
# nose_space2D                              0.166728             0.125997
# total_arm_boundingbox2D                   0.560525             0.489661
# total_lower_body_boundingbox2D           -0.002246            -0.082806
# left_arm_entropy                          0.824283             0.648197
# right_arm_entropy                         0.686033             0.799507
# left_wrist_entropy                        0.706071             0.792736
# total_arm_entropy2Daggregated             0.047563            -0.097291
# left_wrist_variability2D                  0.515798             0.396054
# right_wrist_variability2D                 0.366571             0.424538
# left_knee_variability2D                   0.086334             0.011751
# right_knee_variability2D                  0.124247             0.025823
# left_wrist_submovements                   0.575078             0.450583
# right_wrist_submovements                  0.474537             0.471121
# left_knee_submovements                   -0.103657            -0.219340
# right_wrist_SpeedAVG                      0.356036             0.426269
# left_wrist_SpeedAVG                       0.532781             0.316639
# left_knee_SpeedAVG                       -0.055577            -0.171680
# right_knee_SpeedAVG                      -0.101070            -0.226675
# right_wrist_AccelAVG                     -0.219101            -0.252638
# left_wrist_AccelAVG                      -0.215417            -0.177097
# right_knee_AccelAVG                      -0.126242            -0.115734
# left_knee_AccelAVG                       -0.174326            -0.163404
# right_wrist_SpeedSD                       0.290141             0.494294
# left_wrist_SpeedSD                        0.587604             0.338251
# right_knee_SpeedSD                       -0.028676            -0.129373
# left_knee_SpeedSD                        -0.090314            -0.210945
# right_wrist_AccelSD                       0.041405            -0.024174
# left_wrist_AccelSD                        0.039673            -0.079224
# right_wrist_SpeedRange                    0.364108             0.499480
# left_wrist_SpeedRange                     0.568546             0.311859
# right_knee_SpeedRange                    -0.054241            -0.158904
# left_knee_SpeedRange                     -0.108180            -0.225992
# right_wrist_AccelRange                    0.205769             0.267958
# left_wrist_AccelRange                     0.309295             0.100125
# right_knee_AccelRange                    -0.096622            -0.195316
# left_knee_AccelRange                     -0.141599            -0.254304
# right_wrist_SpeedIntegral                 0.252374             0.229743
# left_wrist_SpeedIntegral                  0.380862             0.173414
# right_knee_SpeedIntegral                 -0.049849            -0.156824
# left_knee_SpeedIntegral                  -0.088611            -0.200224
#
#                                 left_knee_space2D  right_knee_space2D  \
# left_wrist_space2D                       0.003511            0.049443
# right_wrist_space2D                     -0.114195           -0.050991
# left_knee_space2D                        1.000000            0.907970
# right_knee_space2D                       0.907970            1.000000
# nose_space2D                             0.371599            0.438909
# total_arm_boundingbox2D                  0.203076            0.287417
# total_lower_body_boundingbox2D           0.858906            0.851494
# left_arm_entropy                         0.155220            0.161500
# right_arm_entropy                        0.051177            0.073559
# left_wrist_entropy                       0.073494            0.094048
# total_arm_entropy2Daggregated            0.431845            0.391129
# left_wrist_variability2D                 0.113118            0.108554
# right_wrist_variability2D               -0.044129           -0.028911
# left_knee_variability2D                  0.624844            0.540709
# right_knee_variability2D                 0.690195            0.649515
# left_wrist_submovements                  0.319200            0.285266
# right_wrist_submovements                 0.331672            0.310465
# left_knee_submovements                   0.665222            0.566847
# right_wrist_SpeedAVG                    -0.063400            0.017299
# left_wrist_SpeedAVG                      0.132004            0.187892
# left_knee_SpeedAVG                       0.792563            0.851597
# right_knee_SpeedAVG                      0.845086            0.801591
# right_wrist_AccelAVG                     0.039564            0.039661
# left_wrist_AccelAVG                      0.018372            0.026623
# right_knee_AccelAVG                      0.123345            0.169133
# left_knee_AccelAVG                       0.131222            0.133340
# right_wrist_SpeedSD                     -0.336289           -0.229592
# left_wrist_SpeedSD                      -0.037731            0.024137
# right_knee_SpeedSD                       0.785597            0.869256
# left_knee_SpeedSD                        0.865176            0.824402
# right_wrist_AccelSD                      0.404808            0.454990
# left_wrist_AccelSD                       0.404594            0.431650
# right_wrist_SpeedRange                  -0.212722           -0.110203
# left_wrist_SpeedRange                    0.056568            0.104602
# right_knee_SpeedRange                    0.802762            0.875410
# left_knee_SpeedRange                     0.879267            0.824786
# right_wrist_AccelRange                  -0.115712            0.001626
# left_wrist_AccelRange                    0.043703            0.102904
# right_knee_AccelRange                    0.671787            0.746307
# left_knee_AccelRange                     0.741054            0.710829
# right_wrist_SpeedIntegral                0.259087            0.290220
# left_wrist_SpeedIntegral                 0.390258            0.396958
# right_knee_SpeedIntegral                 0.842082            0.847637
# left_knee_SpeedIntegral                  0.869202            0.790010
#
#                                 nose_space2D  total_arm_boundingbox2D  \
# left_wrist_space2D                  0.166728                 0.560525
# right_wrist_space2D                 0.125997                 0.489661
# left_knee_space2D                   0.371599                 0.203076
# right_knee_space2D                  0.438909                 0.287417
# nose_space2D                        1.000000                 0.419839
# total_arm_boundingbox2D             0.419839                 1.000000
# total_lower_body_boundingbox2D      0.371548                 0.256238
# left_arm_entropy                    0.176031                 0.309102
# right_arm_entropy                   0.098782                 0.226272
# left_wrist_entropy                  0.109285                 0.255618
# total_arm_entropy2Daggregated       0.134584                 0.166725
# left_wrist_variability2D            0.101297                 0.175972
# right_wrist_variability2D           0.005764                 0.096062
# ...
# right_knee_AccelAVG                           0.014497              -0.018232
# left_knee_AccelAVG                           -0.028495               0.033418
# right_wrist_SpeedSD                           0.711700               0.275764
# left_wrist_SpeedSD                            0.434343               0.788844
# right_knee_SpeedSD                            0.134909               0.230227
# left_knee_SpeedSD                             0.048572               0.200079
# right_wrist_AccelSD                           0.473962               0.476800
# left_wrist_AccelSD                            0.357566               0.573131
# right_wrist_SpeedRange                        0.772021               0.386950
# left_wrist_SpeedRange                         0.444884               0.833681
# right_knee_SpeedRange                         0.126717               0.234478
# left_knee_SpeedRange                          0.031667               0.192237
# right_wrist_AccelRange                        1.000000               0.585753
# left_wrist_AccelRange                         0.585753               1.000000
# right_knee_AccelRange                         0.183559               0.295822
# left_knee_AccelRange                          0.112309               0.263703
# right_wrist_SpeedIntegral                     0.499268               0.358785
# left_wrist_SpeedIntegral                      0.309316               0.568703
# right_knee_SpeedIntegral                     -0.013499               0.107194
# left_knee_SpeedIntegral                      -0.078713               0.062772
#
#                                 right_knee_AccelRange  left_knee_AccelRange  \
# left_wrist_space2D                          -0.096622             -0.141599
# right_wrist_space2D                         -0.195316             -0.254304
# left_knee_space2D                            0.671787              0.741054
# right_knee_space2D                           0.746307              0.710829
# nose_space2D                                 0.261033              0.254807
# total_arm_boundingbox2D                      0.104493              0.065296
# total_lower_body_boundingbox2D               0.604902              0.602285
# left_arm_entropy                            -0.072469             -0.100354
# right_arm_entropy                           -0.168182             -0.212325
# left_wrist_entropy                          -0.146209             -0.188616
# total_arm_entropy2Daggregated                0.415492              0.439196
# left_wrist_variability2D                    -0.074818             -0.083194
# right_wrist_variability2D                   -0.167817             -0.183735
# left_knee_variability2D                      0.313466              0.349360
# right_knee_variability2D                     0.406885              0.437627
# left_wrist_submovements                      0.026332              0.032385
# right_wrist_submovements                     0.036995              0.021477
# left_knee_submovements                       0.521758              0.602210
# right_wrist_SpeedAVG                         0.108074              0.050543
# left_wrist_SpeedAVG                          0.268515              0.240307
# left_knee_SpeedAVG                           0.919606              0.857735
# right_knee_SpeedAVG                          0.849724              0.905246
# right_wrist_AccelAVG                         0.027394              0.037304
# left_wrist_AccelAVG                          0.055515              0.037703
# right_knee_AccelAVG                          0.186228              0.139221
# left_knee_AccelAVG                           0.196709              0.173599
# right_wrist_SpeedSD                         -0.185875             -0.254549
# left_wrist_SpeedSD                           0.065791              0.040481
# right_knee_SpeedSD                           0.937396              0.838150
# left_knee_SpeedSD                            0.847771              0.928369
# right_wrist_AccelSD                          0.636318              0.620091
# left_wrist_AccelSD                           0.623881              0.624209
# right_wrist_SpeedRange                      -0.077195             -0.134536
# left_wrist_SpeedRange                        0.162817              0.151435
# right_knee_SpeedRange                        0.955718              0.864976
# left_knee_SpeedRange                         0.846006              0.945994
# right_wrist_AccelRange                       0.183559              0.112309
# left_wrist_AccelRange                        0.295822              0.263703
# right_knee_AccelRange                        1.000000              0.874696
# left_knee_AccelRange                         0.874696              1.000000
# right_wrist_SpeedIntegral                    0.276717              0.245690
# left_wrist_SpeedIntegral                     0.373935              0.370252
# right_knee_SpeedIntegral                     0.775815              0.751624
# left_knee_SpeedIntegral                      0.693170              0.757424
#
#                                 right_wrist_SpeedIntegral  \
# left_wrist_space2D                               0.252374
# right_wrist_space2D                              0.229743
# left_knee_space2D                                0.259087
# right_knee_space2D                               0.290220
# nose_space2D                                     0.199923
# total_arm_boundingbox2D                          0.589668
# total_lower_body_boundingbox2D                   0.247022
# left_arm_entropy                                 0.139884
# right_arm_entropy                                0.107416
# left_wrist_entropy                               0.140349
# total_arm_entropy2Daggregated                    0.437877
# left_wrist_variability2D                         0.044707
# right_wrist_variability2D                       -0.022250
# left_knee_variability2D                          0.098363
# right_knee_variability2D                         0.177471
# left_wrist_submovements                          0.197769
# right_wrist_submovements                         0.202618
# left_knee_submovements                           0.307881
# right_wrist_SpeedAVG                             0.682781
# left_wrist_SpeedAVG                              0.502785
# left_knee_SpeedAVG                               0.294734
# right_knee_SpeedAVG                              0.283214
# right_wrist_AccelAVG                             0.007567
# left_wrist_AccelAVG                              0.042146
# right_knee_AccelAVG                             -0.016731
# left_knee_AccelAVG                              -0.060013
# right_wrist_SpeedSD                              0.383247
# left_wrist_SpeedSD                               0.323412
# right_knee_SpeedSD                               0.280238
# left_knee_SpeedSD                                0.259858
# right_wrist_AccelSD                              0.421307
# left_wrist_AccelSD                               0.339885
# right_wrist_SpeedRange                           0.540668
# left_wrist_SpeedRange                            0.399109
# right_knee_SpeedRange                            0.297777
# left_knee_SpeedRange                             0.272202
# right_wrist_AccelRange                           0.499268
# left_wrist_AccelRange                            0.358785
# right_knee_AccelRange                            0.276717
# left_knee_AccelRange                             0.245690
# right_wrist_SpeedIntegral                        1.000000
# left_wrist_SpeedIntegral                         0.782189
# right_knee_SpeedIntegral                         0.414430
# left_knee_SpeedIntegral                          0.397921
#
#                                 left_wrist_SpeedIntegral  \
# left_wrist_space2D                              0.380862
# right_wrist_space2D                             0.173414
# left_knee_space2D                               0.390258
# right_knee_space2D                              0.396958
# nose_space2D                                    0.203695
# total_arm_boundingbox2D                         0.511551
# total_lower_body_boundingbox2D                  0.340660
# left_arm_entropy                                0.289917
# right_arm_entropy                               0.109545
# left_wrist_entropy                              0.149507
# total_arm_entropy2Daggregated                   0.503093
# left_wrist_variability2D                        0.147791
# right_wrist_variability2D                      -0.005706
# left_knee_variability2D                         0.201981
# right_knee_variability2D                        0.269897
# left_wrist_submovements                         0.320844
# right_wrist_submovements                        0.219711
# left_knee_submovements                          0.453389
# right_wrist_SpeedAVG                            0.424939
# left_wrist_SpeedAVG                             0.737419
# left_knee_SpeedAVG                              0.424749
# right_knee_SpeedAVG                             0.428514
# right_wrist_AccelAVG                           -0.010655
# left_wrist_AccelAVG                            -0.012941
# right_knee_AccelAVG                            -0.049513
# left_knee_AccelAVG                             -0.051813
# right_wrist_SpeedSD                             0.090558
# left_wrist_SpeedSD                              0.562760
# right_knee_SpeedSD                              0.376035
# left_knee_SpeedSD                               0.394965
# right_wrist_AccelSD                             0.460566
# left_wrist_AccelSD                              0.508382
# right_wrist_SpeedRange                          0.258622
# left_wrist_SpeedRange                           0.645614
# right_knee_SpeedRange                           0.401539
# left_knee_SpeedRange                            0.406681
# right_wrist_AccelRange                          0.309316
# left_wrist_AccelRange                           0.568703
# right_knee_AccelRange                           0.373935
# left_knee_AccelRange                            0.370252
# right_wrist_SpeedIntegral                       0.782189
# left_wrist_SpeedIntegral                        1.000000
# right_knee_SpeedIntegral                        0.525803
# left_knee_SpeedIntegral                         0.523295
#
#                                 right_knee_SpeedIntegral  \
# left_wrist_space2D                             -0.049849
# right_wrist_space2D                            -0.156824
# left_knee_space2D                               0.842082
# right_knee_space2D                              0.847637
# nose_space2D                                    0.301600
# total_arm_boundingbox2D                         0.117282
# total_lower_body_boundingbox2D                  0.776973
# left_arm_entropy                                0.085551
# right_arm_entropy                              -0.006532
# left_wrist_entropy                              0.017910
# total_arm_entropy2Daggregated                   0.446718
# left_wrist_variability2D                        0.068138
# right_wrist_variability2D                      -0.070888
# left_knee_variability2D                         0.517930
# right_knee_variability2D                        0.601202
# left_wrist_submovements                         0.287167
# right_wrist_submovements                        0.310087
# left_knee_submovements                          0.748899
# right_wrist_SpeedAVG                           -0.013992
# left_wrist_SpeedAVG                             0.158170
# left_knee_SpeedAVG                              0.850332
# right_knee_SpeedAVG                             0.816430
# right_wrist_AccelAVG                            0.084904
# left_wrist_AccelAVG                             0.067190
# right_knee_AccelAVG                             0.117264
# left_knee_AccelAVG                              0.097267
# right_wrist_SpeedSD                            -0.309497
# left_wrist_SpeedSD                             -0.052412
# right_knee_SpeedSD                              0.826484
# left_knee_SpeedSD                               0.811114
# right_wrist_AccelSD                             0.460341
# left_wrist_AccelSD                              0.455726
# right_wrist_SpeedRange                         -0.187000
# left_wrist_SpeedRange                           0.046100
# right_knee_SpeedRange                           0.851121
# left_knee_SpeedRange                            0.839683
# right_wrist_AccelRange                         -0.013499
# left_wrist_AccelRange                           0.107194
# right_knee_AccelRange                           0.775815
# left_knee_AccelRange                            0.751624
# right_wrist_SpeedIntegral                       0.414430
# left_wrist_SpeedIntegral                        0.525803
# right_knee_SpeedIntegral                        1.000000
# left_knee_SpeedIntegral                         0.955983
#
#                                 left_knee_SpeedIntegral
# left_wrist_space2D                            -0.088611
# right_wrist_space2D                           -0.200224
# left_knee_space2D                              0.869202
# right_knee_space2D                             0.790010
# nose_space2D                                   0.274838
# total_arm_boundingbox2D                        0.086329
# total_lower_body_boundingbox2D                 0.774926
# left_arm_entropy                               0.060196
# right_arm_entropy                             -0.035803
# left_wrist_entropy                            -0.010647
# total_arm_entropy2Daggregated                  0.461227
# left_wrist_variability2D                       0.051971
# right_wrist_variability2D                     -0.085948
# left_knee_variability2D                        0.528371
# right_knee_variability2D                       0.591355
# left_wrist_submovements                        0.274199
# right_wrist_submovements                       0.291252
# left_knee_submovements                         0.796615
# right_wrist_SpeedAVG                          -0.054977
# left_wrist_SpeedAVG                            0.126426
# left_knee_SpeedAVG                             0.775557
# right_knee_SpeedAVG                            0.834114
# right_wrist_AccelAVG                           0.086408
# left_wrist_AccelAVG                            0.063264
# right_knee_AccelAVG                            0.097633
# left_knee_AccelAVG                             0.103799
# right_wrist_SpeedSD                           -0.356682
# left_wrist_SpeedSD                            -0.083733
# right_knee_SpeedSD                             0.736640
# left_knee_SpeedSD                              0.823158
# right_wrist_AccelSD                            0.418079
# left_wrist_AccelSD                             0.420415
# right_wrist_SpeedRange                        -0.234703
# left_wrist_SpeedRange                          0.019638
# right_knee_SpeedRange                          0.773877
# left_knee_SpeedRange                           0.853428
# right_wrist_AccelRange                        -0.078713
# left_wrist_AccelRange                          0.062772
# right_knee_AccelRange                          0.693170
# left_knee_AccelRange                           0.757424
# right_wrist_SpeedIntegral                      0.397921
# left_wrist_SpeedIntegral                       0.523295
# right_knee_SpeedIntegral                       0.955983
# left_knee_SpeedIntegral                        1.000000
#
# [44 rows x 44 columns]

# %%
## code to print all of the high correlation pairs (written with the help of chatgpt)
upper = pearson_corr.where(np.triu(np.ones(pearson_corr.shape), k=1).astype(bool))

# Stack and filter
high_corr_pairs = (
    upper.stack()
         .reset_index()
         .rename(columns={'level_0': 'var1', 'level_1': 'var2', 0: 'correlation'})
)

high_corr_pairs = high_corr_pairs[high_corr_pairs['correlation'] > 0.7]

print(high_corr_pairs)
# Out:
#                           var1                      var2  correlation
# 0           left_wrist_space2D       right_wrist_space2D     0.820869
# 6           left_wrist_space2D          left_arm_entropy     0.824283
# 8           left_wrist_space2D        left_wrist_entropy     0.706071
# 49         right_wrist_space2D         right_arm_entropy     0.799507
# 50         right_wrist_space2D        left_wrist_entropy     0.792736
# ..                         ...                       ...          ...
# 934      right_knee_AccelRange  right_knee_SpeedIntegral     0.775815
# 938       left_knee_AccelRange  right_knee_SpeedIntegral     0.751624
# 939       left_knee_AccelRange   left_knee_SpeedIntegral     0.757424
# 940  right_wrist_SpeedIntegral  left_wrist_SpeedIntegral     0.782189
# 945   right_knee_SpeedIntegral   left_knee_SpeedIntegral     0.955983
#
# [105 rows x 3 columns]

# %% [markdown]
# # Normalize all the feature data for dimensionality reduction

# %%
normed_features = features.copy()
# remove the entropy measures that calculate each arm separately
#normed_features = normed_features.drop(['total_body_entropy2D', 'total_body_variability2D'], axis=1)
normed_features2 = normed_features.copy()
normed_features
# normalizes all the features


normed_features2[normed_features2.columns[17:]] = StandardScaler().fit_transform(normed_features[normed_features.columns[17:]])
cols_to_embed = normed_features2.columns[17:]
normed_features2 = normed_features2[cols_to_embed].dropna()

normed_features2
# Out:
#      left_wrist_space2D  right_wrist_space2D  left_knee_space2D  \
# 0              2.151143             1.862101          -0.395224
# 1              0.665307             0.637747          -0.799404
# 2              1.110651             0.988887          -0.275745
# 3             -0.745031            -0.872094          -0.799404
# 4              0.647927             0.517925           0.469506
# ..                  ...                  ...                ...
# 432            0.114251             0.015992           1.577625
# 433           -0.745031            -0.872094          -0.799404
# 434            1.452319             1.190200           3.146563
# 435            0.402909             0.338617          -0.799404
# 436            0.490480             0.760235           1.847060
#
#      right_knee_space2D  nose_space2D  total_arm_boundingbox2D  \
# 0             -0.387815      1.026762                 0.871537
# 1             -0.735189     -0.430502                -0.359150
# 2             -0.059908     -0.430502                 0.719809
# 3             -0.735189      3.850067                 0.460685
# 4              0.709103      0.558987                -0.074618
# ..                  ...           ...                      ...
# 432            1.113797     -0.430502                -0.188814
# 433           -0.735189     -0.430502                 0.554461
# 434            1.762974      1.447916                 2.040190
# 435           -0.735189     -0.430502                -0.168610
# 436            1.131206     -0.430502                 0.016075
#
#      total_lower_body_boundingbox2D  left_arm_entropy  right_arm_entropy  \
# 0                         -0.323823          1.016457           0.922758
# 1                         -0.531887          1.001974           1.042363
# 2                         -0.396148          1.473903           1.233485
# 3                         -0.531887         -0.853692          -0.994127
# 4                         -0.265502          0.884335           0.854930
# ..                              ...               ...                ...
# 432                        1.796614          1.430588           1.322538
# 433                       -0.531887         -0.853692          -0.994127
# 434                        0.977137          1.327584           1.135461
# 435                       -0.531887          0.266859          -0.078545
# 436                        0.923915          1.462468           1.274452
#
#      left_wrist_entropy  ...  right_knee_SpeedRange  left_knee_SpeedRange  \
# 0              0.941591  ...              -0.062077             -0.166706
# 1              1.108093  ...              -0.748506             -0.816918
# 2              1.282659  ...              -0.207144             -0.192480
# 3             -0.963771  ...              -0.748506             -0.816918
# 4              0.809146  ...               0.181203              0.269792
# ..                  ...  ...                    ...                   ...
# 432            1.464867  ...               0.540318              1.155139
# 433           -0.963771  ...              -0.748506             -0.816918
# 434            1.209216  ...               1.355320              2.481842
# 435           -0.195748  ...              -0.748506             -0.816918
# 436            1.353351  ...               0.360889              0.908758
#
#      right_wrist_AccelRange  left_wrist_AccelRange  right_knee_AccelRange  \
# 0                 -0.212432               0.049534              -0.224351
# 1                 -0.018768              -0.349856              -0.683755
# 2                  1.648288               1.783791              -0.183422
# 3                 -1.632252               0.680376              -0.683755
# 4                 -0.250711              -0.103530              -0.318834
# ..                      ...                    ...                    ...
# 432               -1.164021              -1.089928               0.098917
# 433                0.426437               0.051391              -0.683755
# 434                1.567879               1.680937               2.038525
# 435                1.587021               1.523365              -0.683755
# 436                0.741867              -0.777827              -0.032475
#
#      left_knee_AccelRange  right_wrist_SpeedIntegral  \
# 0               -0.257840                   0.062721
# 1               -0.763425                  -0.815956
# 2               -0.115141                   1.958306
# 3               -0.763425                  -1.291342
# 4                0.008950                  -0.390864
# ..                    ...                        ...
# 432              0.222450                   0.019207
# 433             -0.763425                   1.459162
# 434              4.646961                   1.600241
# 435             -0.763425                  -0.600580
# 436              0.184283                   2.571265
#
#      left_wrist_SpeedIntegral  right_knee_SpeedIntegral  \
# 0                    0.335752                 -0.517004
# 1                   -0.710864                 -0.720855
# 2                    2.214436                 -0.113788
# 3                    0.704237                 -0.720855
# 4                   -0.064328                  0.105947
# ..                        ...                       ...
# 432                  0.232528                  2.339334
# 433                  0.910236                 -0.720855
# 434                  1.845073                  1.739656
# 435                 -0.477288                 -0.720855
# 436                  1.628485                  2.432703
#
#      left_knee_SpeedIntegral
# 0                  -0.494927
# 1                  -0.735929
# 2                  -0.137455
# 3                  -0.735929
# 4                  -0.076062
# ..                       ...
# 432                 2.486929
# 433                -0.735929
# 434                 2.230899
# 435                -0.735929
# 436                 2.896264
#
# [437 rows x 44 columns]

# %% [markdown]
# # Dimensionality Reduction with UMAP

# %%
# call dimensionality reduction package
reducer = umap.UMAP()

# create embeddings
embedding = reducer.fit_transform(normed_features2[normed_features2.columns[17:]])
embedding.shape
embeddings = pd.DataFrame(embedding)

# add embeddings to the dataframe
features["X_embeddings"] = embeddings.iloc[:, 0]
features["Y_embeddings"] = embeddings.iloc[:, 1]
normed_features["X_embeddings"] = embeddings.iloc[:, 0]
normed_features["Y_embeddings"] = embeddings.iloc[:, 1]

# %% [markdown]
# Plot all gesture embeddings:

# %%
sns.scatterplot(data=normed_features, x="X_embeddings", y="Y_embeddings", hue="gesture")
# Out:
# <Axes: xlabel='X_embeddings', ylabel='Y_embeddings'>

# %% [markdown]
# # Set generation zero for chain 2 and chain 3

# %%
# set generation zero for leise chain 2
fix_row = normed_features[normed_features['fileID'] == "leise_g_ch1_g0_compr.mp4"].copy()
fix_row["fileID"] = "leise_g_ch2_g0_compr.mp4"
fix_row["chainID"] = "ch2g0"
fix_row["chain_number"] = 2
fix_row["gesture_chain"] = 'leise_g_ch2'
normed_features = pd.concat([normed_features, fix_row], ignore_index=True)

# set generation zero for leise chain 3
fix_row = normed_features[normed_features['fileID'] == "leise_g_ch1_g0_compr.mp4"].copy()
fix_row["fileID"] = "leise_g_ch3_g0_compr.mp4"
fix_row["chainID"] = "ch3g0"
fix_row["chain_number"] = 3
fix_row["gesture_chain"] = 'leise_g_ch3'
normed_features = pd.concat([normed_features, fix_row], ignore_index=True)

# set generation zero for langsam chain 2
fix_row = normed_features[normed_features['fileID'] == "langsam_g_ch1_g0_compr.mp4"].copy()
fix_row["fileID"] = "langsam_g_ch2_g0_compr.mp4"
fix_row["chainID"] = "ch2g0"
fix_row["chain_number"] = 2
fix_row["gesture_chain"] = 'langsam_g_ch2'
normed_features = pd.concat([normed_features, fix_row], ignore_index=True)

# set generation zero for langsam chain 3
fix_row = normed_features[normed_features['fileID'] == "langsam_g_ch1_g0_compr.mp4"].copy()
fix_row["fileID"] = "langsam_g_ch3_g0_compr.mp4"
fix_row["chainID"] = "ch3g0"
fix_row["chain_number"] = 3
fix_row["gesture_chain"] = 'langsam_g_ch3'
normed_features = pd.concat([normed_features, fix_row], ignore_index=True)

# set generation zero for rennen chain 2
fix_row = normed_features[normed_features['fileID'] == "lndw_lndw_rennen_g_ch1_g0_compr.mp4"].copy()
fix_row["fileID"] = "rennen_g_ch2_g0_compr.mp4"
fix_row["chainID"] = "ch2g0"
fix_row["chain_number"] = 2
fix_row["gesture_chain"] = 'rennen_g_ch2'
normed_features = pd.concat([normed_features, fix_row], ignore_index=True)

# set generation zero for rennen chain 3
fix_row = normed_features[normed_features['fileID'] == "lndw_lndw_rennen_g_ch1_g0_compr.mp4"].copy()
fix_row["fileID"] = "rennen_g_ch3_g0_compr.mp4"
fix_row["chainID"] = "ch3g0"
fix_row["chain_number"] = 3
fix_row["gesture_chain"] = 'rennen_g_ch3'
normed_features = pd.concat([normed_features, fix_row], ignore_index=True)

# set generation zero for Donner chain 2
fix_row = normed_features[normed_features['fileID'] == "Donner_g_ch1_g0_compr.mp4"].copy()
fix_row["fileID"] = "Donner_g_ch2_g0_compr.mp4"
fix_row["chainID"] = "ch2g0"
fix_row["chain_number"] = 2
fix_row["gesture_chain"] = 'Donner_g_ch2'
normed_features = pd.concat([normed_features, fix_row], ignore_index=True)

# set generation zero for Donner chain 3
fix_row = normed_features[normed_features['fileID'] == "Donner_g_ch1_g0_compr.mp4"].copy()
fix_row["fileID"] = "Donner_g_ch3_g0_compr.mp4"
fix_row["chainID"] = "ch3g0"
fix_row["chain_number"] = 3
fix_row["gesture_chain"] = 'Donner_g_ch3'
normed_features = pd.concat([normed_features, fix_row], ignore_index=True)

# set generation zero for kalt chain 2
fix_row = normed_features[normed_features['fileID'] == "kalt_g_ch1_g0_compr.mp4"].copy()
fix_row["fileID"] = "kalt_g_ch2_g0_compr.mp4"
fix_row["chainID"] = "ch2g0"
fix_row["chain_number"] = 2
fix_row["gesture_chain"] = 'kalt_g_ch2'
normed_features = pd.concat([normed_features, fix_row], ignore_index=True)

# set generation zero for kalt chain 3
fix_row = normed_features[normed_features['fileID'] == "kalt_g_ch1_g0_compr.mp4"].copy()
fix_row["fileID"] = "kalt_g_ch3_g0_compr.mp4"
fix_row["chainID"] = "ch3g0"
fix_row["chain_number"] = 3
fix_row["gesture_chain"] = 'kalt_g_ch3'
normed_features = pd.concat([normed_features, fix_row], ignore_index=True)

five = normed_features[normed_features['fileID'] == 'kalt_g_ch3_g0_compr.mp4']

normed_features
# Out:
#      participantID   Age          BirthPlace            Gender  \
# 0               23  35.0        Deutschland   Woman / Weiblich
# 1                0   NaN                 NaN               NaN
# 2               16  27.0         Deutschland    Man / Männlich
# 3               22  32.0  Delft, Netherlands         Man / Man
# 4               30  45.0             Dresden  Woman / Weiblich
# ..             ...   ...                 ...               ...
# 442              0   NaN                 NaN               NaN
# 443              0   NaN                 NaN               NaN
# 444              0   NaN                 NaN               NaN
# 445              0   NaN                 NaN               NaN
# 446              0   NaN                 NaN               NaN
#
#       NativeLanguages  NumOfNativeLanguages  \
# 0            Deutsch                    1.0
# 1                 NaN                   NaN
# 2            Deutsch                    1.0
# 3    Dutch and Polish                   NaN
# 4             Deutsch                   1.0
# ..                ...                   ...
# 442               NaN                   NaN
# 443               NaN                   NaN
# 444               NaN                   NaN
# 445               NaN                   NaN
# 446               NaN                   NaN
#
#                                        Other Languages  TotalLanguages  \
# 0    English (fluent), French (advanced), Italian (...             4.0
# 1                                                  NaN             NaN
# 2                                              English             2.0
# 3    English (fluent), French (good knowledge), Ger...             5.0
# 4                                             Englisch             2.0
# ..                                                 ...             ...
# 442                                                NaN             NaN
# 443                                                NaN             NaN
# 444                                                NaN             NaN
# 445                                                NaN             NaN
# 446                                                NaN             NaN
#
#      Extroversion                            Hand  ... right_wrist_AccelRange  \
# 0            43.0  Right-handed / Rechtshänder*in  ...               0.000084
# 1             NaN                             NaN  ...               0.000094
# 2            30.0  Right-handed / Rechtshänder*in  ...               0.000179
# 3            91.0     Right-handed / Rechtshandig  ...               0.000012
# 4            51.0  Right-handed / Rechtshänder*in  ...               0.000082
# ..            ...                             ...  ...                    ...
# 442           NaN                             NaN  ...               0.000052
# 443           NaN                             NaN  ...               0.000150
# 444           NaN                             NaN  ...               0.000150
# 445           NaN                             NaN  ...               0.000094
# 446           NaN                             NaN  ...               0.000094
#
#     left_wrist_AccelRange  right_knee_AccelRange  left_knee_AccelRange  \
# 0                0.000089               0.000009              0.000009
# 1                0.000067               0.000000              0.000000
# 2                0.000186               0.000009              0.000011
# 3                0.000125               0.000000              0.000000
# 4                0.000081               0.000007              0.000013
# ..                    ...                    ...                   ...
# 442              0.000083               0.000017              0.000027
# 443              0.000127               0.000019              0.000021
# 444              0.000127               0.000019              0.000021
# 445              0.000067               0.000000              0.000000
# 446              0.000067               0.000000              0.000000
#
#     right_wrist_SpeedIntegral left_wrist_SpeedIntegral  \
# 0                    0.073015                 0.079426
# 1                    0.032305                 0.029311
# 2                    0.160841                 0.169384
# 3                    0.010280                 0.097070
# 4                    0.052000                 0.060269
# ..                        ...                      ...
# 442                  0.033526                 0.046712
# 443                  0.087211                 0.066902
# 444                  0.087211                 0.066902
# 445                  0.032305                 0.029311
# 446                  0.032305                 0.029311
#
#     right_knee_SpeedIntegral  left_knee_SpeedIntegral  X_embeddings  \
# 0                   0.002551                 0.003209     12.227211
# 1                   0.000000                 0.000000      7.437744
# 2                   0.007596                 0.007968     13.373139
# 3                   0.000000                 0.000000      5.912247
# 4                   0.010345                 0.008786     11.754339
# ..                       ...                      ...           ...
# 442                 0.006082                 0.007133     13.261251
# 443                 0.005707                 0.007932     12.493334
# 444                 0.005707                 0.007932     12.493334
# 445                 0.000000                 0.000000      7.437744
# 446                 0.000000                 0.000000      7.437744
#
#      Y_embeddings
# 0       15.598193
# 1       16.080709
# 2       16.011000
# 3       15.450927
# 4       12.864773
# ..            ...
# 442     12.877107
# 443     15.478951
# 444     15.478951
# 445     16.080709
# 446     16.080709
#
# [447 rows x 63 columns]

# %%
# set generation zero of chain 1 for koud
fix_row = normed_features[normed_features['fileID'] == "kalt_g_ch1_g0_compr.mp4"].copy()
fix_row["fileID"] = "koud_g_ch1_g0_compr.mp4"
fix_row["chainID"] = "ch1g0"
fix_row["chain_number"] = 1
fix_row["gesture_chain"] = 'koud_g_ch3'
normed_features = pd.concat([normed_features, fix_row], ignore_index=True)

# set generation zero of chain 2 for koud
fix_row = normed_features[normed_features['fileID'] == "kalt_g_ch1_g0_compr.mp4"].copy()
fix_row["fileID"] = "koud_g_ch2_g0_compr.mp4"
fix_row["chainID"] = "ch2g0"
fix_row["chain_number"] = 2
fix_row["gesture_chain"] = 'koud_g_ch2'
normed_features = pd.concat([normed_features, fix_row], ignore_index=True)


# set generation zero of chain 1 for langzaam
fix_row = normed_features[normed_features['fileID'] == "langsam_g_ch1_g0_compr.mp4"].copy()
fix_row["fileID"] = "langzaam_g_ch1_g0_compr.mp4"
fix_row["chainID"] = "ch1g0"
fix_row["chain_number"] = 1
fix_row["gesture_chain"] = 'langzaam_g_ch1'
normed_features = pd.concat([normed_features, fix_row], ignore_index=True)

# set generation zero of chain 2 for langzaam
fix_row = normed_features[normed_features['fileID'] == "langsam_g_ch1_g0_compr.mp4"].copy()
fix_row["fileID"] = "langzaam_g_ch2_g0_compr.mp4"
fix_row["chainID"] = "ch2g0"
fix_row["chain_number"] = 2
fix_row["gesture_chain"] = 'langzaam_g_ch2'
normed_features = pd.concat([normed_features, fix_row], ignore_index=True)


# set generation zero of chain 1 for nijmegen_nijmegen_rennen
fix_row = normed_features[normed_features['fileID'] == "lndw_lndw_rennen_g_ch1_g0_compr.mp4"].copy()
fix_row["fileID"] = "nijmegen_nijmegen_rennen_g_ch1_g0_compr.mp4"
fix_row["chainID"] = "ch1g0"
fix_row["chain_number"] = 1
fix_row["gesture_chain"] = 'nijmegen_nijmegen_rennen_g_ch1'
normed_features = pd.concat([normed_features, fix_row], ignore_index=True)

# set generation zero of chain 2 for nijmegen_nijmegen_rennen
fix_row = normed_features[normed_features['fileID'] == "lndw_lndw_rennen_g_ch1_g0_compr.mp4"].copy()
fix_row["fileID"] = "nijmegen_nijmegen_rennen_g_ch1_g0_compr.mp4"
fix_row["chainID"] = "ch2g0"
fix_row["chain_number"] = 2
fix_row["gesture_chain"] = 'nijmegen_nijmegen_rennen_g_ch2'
normed_features = pd.concat([normed_features, fix_row], ignore_index=True)

# set generation zero of chain 1 for onweer
fix_row = normed_features[normed_features['fileID'] == "Donner_g_ch1_g0_compr.mp4"].copy()
fix_row["fileID"] = "onweer_g_ch1_g0_compr.mp4"
fix_row["chainID"] = "ch1g0"
fix_row["chain_number"] = 1
fix_row["gesture_chain"] = 'onweer_g_ch1'
normed_features = pd.concat([normed_features, fix_row], ignore_index=True)

# set generation zero of chain 2 for onweer
fix_row = normed_features[normed_features['fileID'] == "Donner_g_ch1_g0_compr.mp4"].copy()
fix_row["fileID"] = "onweer_g_ch2_g0_compr.mp4"
fix_row["chainID"] = "ch2g0"
fix_row["chain_number"] = 2
fix_row["gesture_chain"] = 'onweer_g_ch2'
normed_features = pd.concat([normed_features, fix_row], ignore_index=True)

# set generation zero of chain 1 for stil
fix_row = normed_features[normed_features['fileID'] == "leise_g_ch1_g0_compr.mp4"].copy()
fix_row["fileID"] = "stil_g_ch1_g0_compr.mp4"
fix_row["chainID"] = "ch1g0"
fix_row["chain_number"] = 1
fix_row["gesture_chain"] = 'stil_g_ch1'
normed_features = pd.concat([normed_features, fix_row], ignore_index=True)

# set generation zero of chain 1 for stil
fix_row = normed_features[normed_features['fileID'] == "leise_g_ch1_g0_compr.mp4"].copy()
fix_row["fileID"] = "stil_g_ch2_g0_compr.mp4"
fix_row["chainID"] = "ch2g0"
fix_row["chain_number"] = 2
fix_row["gesture_chain"] = 'stil_g_ch2'
normed_features = pd.concat([normed_features, fix_row], ignore_index=True)

# %% [markdown]
# # Save Normed Features Dataframe with Embeddings

# %%
normed_features
# Out:
#      participantID   Age          BirthPlace            Gender  \
# 0               23  35.0        Deutschland   Woman / Weiblich
# 1                0   NaN                 NaN               NaN
# 2               16  27.0         Deutschland    Man / Männlich
# 3               22  32.0  Delft, Netherlands         Man / Man
# 4               30  45.0             Dresden  Woman / Weiblich
# ..             ...   ...                 ...               ...
# 452              0   NaN                 NaN               NaN
# 453              0   NaN                 NaN               NaN
# 454              0   NaN                 NaN               NaN
# 455              0   NaN                 NaN               NaN
# 456              0   NaN                 NaN               NaN
#
#       NativeLanguages  NumOfNativeLanguages  \
# 0            Deutsch                    1.0
# 1                 NaN                   NaN
# 2            Deutsch                    1.0
# 3    Dutch and Polish                   NaN
# 4             Deutsch                   1.0
# ..                ...                   ...
# 452               NaN                   NaN
# 453               NaN                   NaN
# 454               NaN                   NaN
# 455               NaN                   NaN
# 456               NaN                   NaN
#
#                                        Other Languages  TotalLanguages  \
# 0    English (fluent), French (advanced), Italian (...             4.0
# 1                                                  NaN             NaN
# 2                                              English             2.0
# 3    English (fluent), French (good knowledge), Ger...             5.0
# 4                                             Englisch             2.0
# ..                                                 ...             ...
# 452                                                NaN             NaN
# 453                                                NaN             NaN
# 454                                                NaN             NaN
# 455                                                NaN             NaN
# 456                                                NaN             NaN
#
#      Extroversion                            Hand  ... right_wrist_AccelRange  \
# 0            43.0  Right-handed / Rechtshänder*in  ...               0.000084
# 1             NaN                             NaN  ...               0.000094
# 2            30.0  Right-handed / Rechtshänder*in  ...               0.000179
# 3            91.0     Right-handed / Rechtshandig  ...               0.000012
# 4            51.0  Right-handed / Rechtshänder*in  ...               0.000082
# ..            ...                             ...  ...                    ...
# 452           NaN                             NaN  ...               0.000052
# 453           NaN                             NaN  ...               0.000150
# 454           NaN                             NaN  ...               0.000150
# 455           NaN                             NaN  ...               0.000094
# 456           NaN                             NaN  ...               0.000094
#
#     left_wrist_AccelRange  right_knee_AccelRange  left_knee_AccelRange  \
# 0                0.000089               0.000009              0.000009
# 1                0.000067               0.000000              0.000000
# 2                0.000186               0.000009              0.000011
# 3                0.000125               0.000000              0.000000
# 4                0.000081               0.000007              0.000013
# ..                    ...                    ...                   ...
# 452              0.000083               0.000017              0.000027
# 453              0.000127               0.000019              0.000021
# 454              0.000127               0.000019              0.000021
# 455              0.000025               0.000000              0.000000
# 456              0.000025               0.000000              0.000000
#
#     right_wrist_SpeedIntegral left_wrist_SpeedIntegral  \
# 0                    0.073015                 0.079426
# 1                    0.032305                 0.029311
# 2                    0.160841                 0.169384
# 3                    0.010280                 0.097070
# 4                    0.052000                 0.060269
# ..                        ...                      ...
# 452                  0.033526                 0.046712
# 453                  0.087211                 0.066902
# 454                  0.087211                 0.066902
# 455                  0.039195                 0.003566
# 456                  0.039195                 0.003566
#
#     right_knee_SpeedIntegral  left_knee_SpeedIntegral  X_embeddings  \
# 0                   0.002551                 0.003209     12.227211
# 1                   0.000000                 0.000000      7.437744
# 2                   0.007596                 0.007968     13.373139
# 3                   0.000000                 0.000000      5.912247
# 4                   0.010345                 0.008786     11.754339
# ..                       ...                      ...           ...
# 452                 0.006082                 0.007133     13.261251
# 453                 0.005707                 0.007932     12.493334
# 454                 0.005707                 0.007932     12.493334
# 455                 0.000000                 0.000000      7.683412
# 456                 0.000000                 0.000000      7.683412
#
#      Y_embeddings
# 0       15.598193
# 1       16.080709
# 2       16.011000
# 3       15.450927
# 4       12.864773
# ..            ...
# 452     12.877107
# 453     15.478951
# 454     15.478951
# 455     11.633258
# 456     11.633258
#
# [457 rows x 63 columns]

# %%
globals()["normed_features"] = normed_features
globals()["normed_features"].to_csv(os.path.join(curfolder, f'{"normed_features_february"}.csv'), index=False)

# %% [markdown]
# # Euclidean Distances between Gestures

# %% [markdown]
# Compare one vector to others

# %%
# returns the euclidean distance between two normalized gesutre vectors
def calculate_distances(feature_vector1, feature_vector2):
    squared_diff =np.square(feature_vector1-feature_vector2)
    sum_squared_diff = np.sum(squared_diff)
    eucl_distance = math.sqrt(sum_squared_diff)
    return eucl_distance

# returns the distance between one gesture to every other gesture
def calculate_distances_to_all(target_segment_index, array):
    target_segment = array[target_segment_index]
    distances = np.empty(array.shape[0])
    i = 0
    for row in array:
        distances[i] = calculate_distances(target_segment, row)
        i = i+1
    return distances

# %%
normed_features.columns[17:61]
# Out:
# Index(['left_wrist_space2D', 'right_wrist_space2D', 'left_knee_space2D',
#        'right_knee_space2D', 'nose_space2D', 'total_arm_boundingbox2D',
#        'total_lower_body_boundingbox2D', 'left_arm_entropy',
#        'right_arm_entropy', 'left_wrist_entropy',
#        'total_arm_entropy2Daggregated', 'left_wrist_variability2D',
#        'right_wrist_variability2D', 'left_knee_variability2D',
#        'right_knee_variability2D', 'left_wrist_submovements',
#        'right_wrist_submovements', 'left_knee_submovements',
#        'right_wrist_SpeedAVG', 'left_wrist_SpeedAVG', 'left_knee_SpeedAVG',
#        'right_knee_SpeedAVG', 'right_wrist_AccelAVG', 'left_wrist_AccelAVG',
#        'right_knee_AccelAVG', 'left_knee_AccelAVG', 'right_wrist_SpeedSD',
#        'left_wrist_SpeedSD', 'right_knee_SpeedSD', 'left_knee_SpeedSD',
#        'right_wrist_AccelSD', 'left_wrist_AccelSD', 'right_wrist_SpeedRange',
#        'left_wrist_SpeedRange', 'right_knee_SpeedRange',
#        'left_knee_SpeedRange', 'right_wrist_AccelRange',
#        'left_wrist_AccelRange', 'right_knee_AccelRange',
#        'left_knee_AccelRange', 'right_wrist_SpeedIntegral',
#        'left_wrist_SpeedIntegral', 'right_knee_SpeedIntegral',
#        'left_knee_SpeedIntegral'],
#       dtype='object')

# %% [markdown]
# Comparing all vectors to each other and saving in a dataframe

# %%
# This code was modified from code written by Šárka Kadavá

## why do we start at 32 for this?
interseg_dist = np.empty(normed_features[normed_features.columns[17:61]].shape)
interseg_dist = pd.DataFrame(interseg_dist)
interseg_dist = pd.DataFrame()

#make individual id for each segment
df_of_vectors = normed_features[normed_features.columns[17:61]].copy()
df_of_vectors = df_of_vectors.to_numpy()

# calculate distance between each segment
for i in range (normed_features[normed_features.columns[17:61]].shape[0]):
    id = normed_features.loc[i, 'fileID']
    interseg_dist_vector = calculate_distances_to_all(i, df_of_vectors)
    interseg_dist = interseg_dist.rename(index={i: id})
    interseg_dist = interseg_dist.rename(columns={i: id})
    interseg_dist[id] = interseg_dist_vector
    index = interseg_dist.index

# save to dataframe
interseg_dist.to_csv('interseg_dist_extended.csv', index=True)
interseg_dist = pd.read_csv(os.path.join(curfolder, 'interseg_dist_extended.csv')).set_index('Unnamed: 0')

interseg_dist
# Out:
#                                              Donner_g_ch2_g3_compr.mp4  \
# Unnamed: 0
# 0                                                             0.000000
# kalt_g_ch1_g0_compr.mp4                                    1673.694224
# Donner_g_ch1_g16_compr.mp4                                 1067.786642
# onweer_g_ch2_g2_compr.mp4                                  1731.736304
# kalt_g_ch2_g10_compr.mp4                                    979.567397
# ...                                                                ...
# nijmegen_nijmegen_rennen_g_ch1_g0_compr.mp4                1685.910570
# onweer_g_ch1_g0_compr.mp4                                  1448.749879
# onweer_g_ch2_g0_compr.mp4                                  1448.749879
# stil_g_ch1_g0_compr.mp4                                    1232.869793
# stil_g_ch2_g0_compr.mp4                                    1232.869793
#
#                                              kalt_g_ch1_g0_compr.mp4  \
# Unnamed: 0
# 0                                                        1673.694224
# kalt_g_ch1_g0_compr.mp4                                     0.000000
# Donner_g_ch1_g16_compr.mp4                                645.644905
# onweer_g_ch2_g2_compr.mp4                                  63.965660
# kalt_g_ch2_g10_compr.mp4                                 2461.465680
# ...                                                              ...
# nijmegen_nijmegen_rennen_g_ch1_g0_compr.mp4               441.769029
# onweer_g_ch1_g0_compr.mp4                                 263.066743
# onweer_g_ch2_g0_compr.mp4                                 263.066743
# stil_g_ch1_g0_compr.mp4                                   858.714308
# stil_g_ch2_g0_compr.mp4                                   858.714308
#
#                                              Donner_g_ch1_g16_compr.mp4  \
# Unnamed: 0
# 0                                                           1067.786642
# kalt_g_ch1_g0_compr.mp4                                      645.644905
# Donner_g_ch1_g16_compr.mp4                                     0.000000
# onweer_g_ch2_g2_compr.mp4                                    702.660440
# kalt_g_ch2_g10_compr.mp4                                    1884.974193
# ...                                                                 ...
# nijmegen_nijmegen_rennen_g_ch1_g0_compr.mp4                  665.622735
# onweer_g_ch1_g0_compr.mp4                                    427.582256
# onweer_g_ch2_g0_compr.mp4                                    427.582256
# stil_g_ch1_g0_compr.mp4                                      554.960603
# stil_g_ch2_g0_compr.mp4                                      554.960603
#
#                                              onweer_g_ch2_g2_compr.mp4  \
# Unnamed: 0
# 0                                                          1731.736304
# kalt_g_ch1_g0_compr.mp4                                      63.965660
# Donner_g_ch1_g16_compr.mp4                                  702.660440
# onweer_g_ch2_g2_compr.mp4                                     0.000000
# kalt_g_ch2_g10_compr.mp4                                   2509.860855
# ...                                                                ...
# nijmegen_nijmegen_rennen_g_ch1_g0_compr.mp4                 437.113548
# onweer_g_ch1_g0_compr.mp4                                   307.164723
# onweer_g_ch2_g0_compr.mp4                                   307.164723
# stil_g_ch1_g0_compr.mp4                                     916.681563
# stil_g_ch2_g0_compr.mp4                                     916.681563
#
#                                              kalt_g_ch2_g10_compr.mp4  \
# Unnamed: 0
# 0                                                          979.567397
# kalt_g_ch1_g0_compr.mp4                                   2461.465680
# Donner_g_ch1_g16_compr.mp4                                1884.974193
# onweer_g_ch2_g2_compr.mp4                                 2509.860855
# kalt_g_ch2_g10_compr.mp4                                     0.000000
# ...                                                               ...
# nijmegen_nijmegen_rennen_g_ch1_g0_compr.mp4               2377.675354
# onweer_g_ch1_g0_compr.mp4                                 2210.317005
# onweer_g_ch2_g0_compr.mp4                                 2210.317005
# stil_g_ch1_g0_compr.mp4                                   2168.300957
# stil_g_ch2_g0_compr.mp4                                   2168.300957
#
#                                              lndw_lndw_rennen_g_ch1_g12_compr.mp4  \
# Unnamed: 0
# 0                                                                     1670.783251
# kalt_g_ch1_g0_compr.mp4                                                359.766159
# Donner_g_ch1_g16_compr.mp4                                             642.878111
# onweer_g_ch2_g2_compr.mp4                                              354.033992
# kalt_g_ch2_g10_compr.mp4                                              2371.600162
# ...                                                                           ...
# nijmegen_nijmegen_rennen_g_ch1_g0_compr.mp4                            172.014377
# onweer_g_ch1_g0_compr.mp4                                              315.688760
# onweer_g_ch2_g0_compr.mp4                                              315.688760
# stil_g_ch1_g0_compr.mp4                                                982.672536
# stil_g_ch2_g0_compr.mp4                                                982.672536
#
#                                              leise_g_ch2_g17_compr.mp4  \
# Unnamed: 0
# 0                                                          1662.413752
# kalt_g_ch1_g0_compr.mp4                                    2375.140383
# Donner_g_ch1_g16_compr.mp4                                 1921.294220
# onweer_g_ch2_g2_compr.mp4                                  2433.336660
# kalt_g_ch2_g10_compr.mp4                                   2397.582758
# ...                                                                ...
# nijmegen_nijmegen_rennen_g_ch1_g0_compr.mp4                2472.285568
# onweer_g_ch1_g0_compr.mp4                                  2281.865837
# onweer_g_ch2_g0_compr.mp4                                  2281.865837
# stil_g_ch1_g0_compr.mp4                                    1516.668788
# stil_g_ch2_g0_compr.mp4                                    1516.668788
#
#                                              kalt_g_ch2_g6_compr.mp4  \
# Unnamed: 0
# 0                                                        1318.396310
# kalt_g_ch1_g0_compr.mp4                                   385.086354
# Donner_g_ch1_g16_compr.mp4                                394.843685
# onweer_g_ch2_g2_compr.mp4                                 441.801402
# kalt_g_ch2_g10_compr.mp4                                 2129.478402
# ...                                                              ...
# nijmegen_nijmegen_rennen_g_ch1_g0_compr.mp4               621.495590
# onweer_g_ch1_g0_compr.mp4                                 252.888190
# onweer_g_ch2_g0_compr.mp4                                 252.888190
# stil_g_ch1_g0_compr.mp4                                   704.496536
# stil_g_ch2_g0_compr.mp4                                   704.496536
#
#                                              Donner_g_ch1_g5_compr.mp4  \
# Unnamed: 0
# 0                                                           457.573026
# kalt_g_ch1_g0_compr.mp4                                    1459.383078
# Donner_g_ch1_g16_compr.mp4                                  839.734316
# onweer_g_ch2_g2_compr.mp4                                  1511.327549
# kalt_g_ch2_g10_compr.mp4                                   1076.743244
# ...                                                                ...
# nijmegen_nijmegen_rennen_g_ch1_g0_compr.mp4                1371.805347
# onweer_g_ch1_g0_compr.mp4                                  1210.083123
# onweer_g_ch2_g0_compr.mp4                                  1210.083123
# stil_g_ch1_g0_compr.mp4                                    1144.662578
# stil_g_ch2_g0_compr.mp4                                    1144.662578
#
#                                              onweer_g_ch1_g4_compr.mp4  ...  \
# Unnamed: 0                                                              ...
# 0                                                          1731.736269  ...
# kalt_g_ch1_g0_compr.mp4                                      63.964696  ...
# Donner_g_ch1_g16_compr.mp4                                  702.660481  ...
# onweer_g_ch2_g2_compr.mp4                                     0.252039  ...
# kalt_g_ch2_g10_compr.mp4                                   2509.860800  ...
# ...                                                                ...  ...
# nijmegen_nijmegen_rennen_g_ch1_g0_compr.mp4                 437.113642  ...
# onweer_g_ch1_g0_compr.mp4                                   307.164796  ...
# onweer_g_ch2_g0_compr.mp4                                   307.164796  ...
# stil_g_ch1_g0_compr.mp4                                     916.681365  ...
# stil_g_ch2_g0_compr.mp4                                     916.681365  ...
#
#                                              kalt_g_ch3_g0_compr.mp4  \
# Unnamed: 0
# 0                                                        1673.694224
# kalt_g_ch1_g0_compr.mp4                                     0.000000
# Donner_g_ch1_g16_compr.mp4                                645.644905
# onweer_g_ch2_g2_compr.mp4                                  63.965660
# kalt_g_ch2_g10_compr.mp4                                 2461.465680
# ...                                                              ...
# nijmegen_nijmegen_rennen_g_ch1_g0_compr.mp4               441.769029
# onweer_g_ch1_g0_compr.mp4                                 263.066743
# onweer_g_ch2_g0_compr.mp4                                 263.066743
# stil_g_ch1_g0_compr.mp4                                   858.714308
# stil_g_ch2_g0_compr.mp4                                   858.714308
#
#                                              koud_g_ch1_g0_compr.mp4  \
# Unnamed: 0
# 0                                                        1673.694224
# kalt_g_ch1_g0_compr.mp4                                     0.000000
# Donner_g_ch1_g16_compr.mp4                                645.644905
# onweer_g_ch2_g2_compr.mp4                                  63.965660
# kalt_g_ch2_g10_compr.mp4                                 2461.465680
# ...                                                              ...
# nijmegen_nijmegen_rennen_g_ch1_g0_compr.mp4               441.769029
# onweer_g_ch1_g0_compr.mp4                                 263.066743
# onweer_g_ch2_g0_compr.mp4                                 263.066743
# stil_g_ch1_g0_compr.mp4                                   858.714308
# stil_g_ch2_g0_compr.mp4                                   858.714308
#
#                                              koud_g_ch2_g0_compr.mp4  \
# Unnamed: 0
# 0                                                        1673.694224
# kalt_g_ch1_g0_compr.mp4                                     0.000000
# Donner_g_ch1_g16_compr.mp4                                645.644905
# onweer_g_ch2_g2_compr.mp4                                  63.965660
# kalt_g_ch2_g10_compr.mp4                                 2461.465680
# ...                                                              ...
# nijmegen_nijmegen_rennen_g_ch1_g0_compr.mp4               441.769029
# onweer_g_ch1_g0_compr.mp4                                 263.066743
# onweer_g_ch2_g0_compr.mp4                                 263.066743
# stil_g_ch1_g0_compr.mp4                                   858.714308
# stil_g_ch2_g0_compr.mp4                                   858.714308
#
#                                              langzaam_g_ch1_g0_compr.mp4  \
# Unnamed: 0
# 0                                                            1145.716646
# kalt_g_ch1_g0_compr.mp4                                       670.359157
# Donner_g_ch1_g16_compr.mp4                                    266.534303
# onweer_g_ch2_g2_compr.mp4                                     715.491358
# kalt_g_ch2_g10_compr.mp4                                     1875.949042
# ...                                                                  ...
# nijmegen_nijmegen_rennen_g_ch1_g0_compr.mp4                   621.063161
# onweer_g_ch1_g0_compr.mp4                                     448.035911
# onweer_g_ch2_g0_compr.mp4                                     448.035911
# stil_g_ch1_g0_compr.mp4                                       724.630521
# stil_g_ch2_g0_compr.mp4                                       724.630521
#
#                                              langzaam_g_ch2_g0_compr.mp4  \
# Unnamed: 0
# 0                                                            1145.716646
# kalt_g_ch1_g0_compr.mp4                                       670.359157
# Donner_g_ch1_g16_compr.mp4                                    266.534303
# onweer_g_ch2_g2_compr.mp4                                     715.491358
# kalt_g_ch2_g10_compr.mp4                                     1875.949042
# ...                                                                  ...
# nijmegen_nijmegen_rennen_g_ch1_g0_compr.mp4                   621.063161
# onweer_g_ch1_g0_compr.mp4                                     448.035911
# onweer_g_ch2_g0_compr.mp4                                     448.035911
# stil_g_ch1_g0_compr.mp4                                       724.630521
# stil_g_ch2_g0_compr.mp4                                       724.630521
#
#                                              nijmegen_nijmegen_rennen_g_ch1_g0_compr.mp4  \
# Unnamed: 0
# 0                                                                            1685.910570
# kalt_g_ch1_g0_compr.mp4                                                       441.769029
# Donner_g_ch1_g16_compr.mp4                                                    665.622735
# onweer_g_ch2_g2_compr.mp4                                                     437.113548
# kalt_g_ch2_g10_compr.mp4                                                     2377.675354
# ...                                                                                  ...
# nijmegen_nijmegen_rennen_g_ch1_g0_compr.mp4                                     0.000000
# onweer_g_ch1_g0_compr.mp4                                                     376.525976
# onweer_g_ch2_g0_compr.mp4                                                     376.525976
# stil_g_ch1_g0_compr.mp4                                                      1015.565600
# stil_g_ch2_g0_compr.mp4                                                      1015.565600
#
#                                              onweer_g_ch1_g0_compr.mp4  \
# Unnamed: 0
# 0                                                          1448.749879
# kalt_g_ch1_g0_compr.mp4                                     263.066743
# Donner_g_ch1_g16_compr.mp4                                  427.582256
# onweer_g_ch2_g2_compr.mp4                                   307.164723
# kalt_g_ch2_g10_compr.mp4                                   2210.317005
# ...                                                                ...
# nijmegen_nijmegen_rennen_g_ch1_g0_compr.mp4                 376.525976
# onweer_g_ch1_g0_compr.mp4                                     0.000000
# onweer_g_ch2_g0_compr.mp4                                     0.000000
# stil_g_ch1_g0_compr.mp4                                     793.725290
# stil_g_ch2_g0_compr.mp4                                     793.725290
#
#                                              onweer_g_ch2_g0_compr.mp4  \
# Unnamed: 0
# 0                                                          1448.749879
# kalt_g_ch1_g0_compr.mp4                                     263.066743
# Donner_g_ch1_g16_compr.mp4                                  427.582256
# onweer_g_ch2_g2_compr.mp4                                   307.164723
# kalt_g_ch2_g10_compr.mp4                                   2210.317005
# ...                                                                ...
# nijmegen_nijmegen_rennen_g_ch1_g0_compr.mp4                 376.525976
# onweer_g_ch1_g0_compr.mp4                                     0.000000
# onweer_g_ch2_g0_compr.mp4                                     0.000000
# stil_g_ch1_g0_compr.mp4                                     793.725290
# stil_g_ch2_g0_compr.mp4                                     793.725290
#
#                                              stil_g_ch1_g0_compr.mp4  \
# Unnamed: 0
# 0                                                        1232.869793
# kalt_g_ch1_g0_compr.mp4                                   858.714308
# Donner_g_ch1_g16_compr.mp4                                554.960603
# onweer_g_ch2_g2_compr.mp4                                 916.681563
# kalt_g_ch2_g10_compr.mp4                                 2168.300957
# ...                                                              ...
# nijmegen_nijmegen_rennen_g_ch1_g0_compr.mp4              1015.565600
# onweer_g_ch1_g0_compr.mp4                                 793.725290
# onweer_g_ch2_g0_compr.mp4                                 793.725290
# stil_g_ch1_g0_compr.mp4                                     0.000000
# stil_g_ch2_g0_compr.mp4                                     0.000000
#
#                                              stil_g_ch2_g0_compr.mp4
# Unnamed: 0
# 0                                                        1232.869793
# kalt_g_ch1_g0_compr.mp4                                   858.714308
# Donner_g_ch1_g16_compr.mp4                                554.960603
# onweer_g_ch2_g2_compr.mp4                                 916.681563
# kalt_g_ch2_g10_compr.mp4                                 2168.300957
# ...                                                              ...
# nijmegen_nijmegen_rennen_g_ch1_g0_compr.mp4              1015.565600
# onweer_g_ch1_g0_compr.mp4                                 793.725290
# onweer_g_ch2_g0_compr.mp4                                 793.725290
# stil_g_ch1_g0_compr.mp4                                     0.000000
# stil_g_ch2_g0_compr.mp4                                     0.000000
#
# [457 rows x 456 columns]

# %%
normed_features.columns
# Out:
# Index(['participantID', 'Age', 'BirthPlace', 'Gender', 'NativeLanguages',
#        'NumOfNativeLanguages', 'Other Languages', 'TotalLanguages',
#        'Extroversion', 'Hand', 'fileID', 'chainID', 'generation_number',
#        'chain_number', 'gesture', 'gesture_chain', 'event',
#        'ARM_TOTAL_speed2D_mean', 'ARM_TOTAL_speed2D_sd',
#        'ARM_TOTAL_speed2D_range', 'LEG_TOTAL_speed2D_mean',
#        'LEG_TOTAL_speed2D_sd', 'LEG_TOTAL_speed2D_range', 'left_index_space2D',
#        'left_wrist_space2D', 'left_elbow_space2D', 'total_left_arm_space2D',
#        'right_index_space2D', 'right_wrist_space2D', 'right_elbow_space2D',
#        'total_right_arm_space2D', 'left_ankle_space2D', 'left_knee_space2D',
#        'total_left_leg_space2D', 'right_ankle_space2D', 'right_knee_space2D',
#        'total_right_leg_space2D', 'nose_space2D', 'total_head_space2D',
#        'total_gesture_space2D', 'right_wrist_entropy2D',
#        'left_wrist_entropy2D', 'right_knee_entropy2D', 'left_knee_entropy2D',
#        'right_ankle_entropy2D', 'left_ankle_entropy2D', 'total_body_entropy2D',
#        'total_body_entropy2Daggregated', 'right_wrist_variability2D',
#        'left_wrist_variability2D', 'total_body_variability2D',
#        'total_body_variability2Daggregated', 'total_arm_boundingbox2D',
#        'right_wrist_intermittency', 'left_wrist_intermittency',
#        'right_elbow_intermittency', 'left_elbow_intermittency',
#        'right_shoulder_imtermittency', 'left_shoulder_intermittency',
#        'total_body_intermittency', 'total_arms_time', 'total_legs_time',
#        'total_time', 'RIGHT_WRIST_SpeedAVG', 'LEFT_WRIST_SpeedAVG',
#        'RIGHT_WRIST_AccelAVG', 'LEFT_WRIST_AccelAVG', 'RIGHT_WRIST_SpeedSD',
#        'LEFT_WRIST_SpeedSD', 'RIGHT_WRIST_AccelSD', 'X_embeddings',
#        'Y_embeddings'],
#       dtype='object')

# %% [markdown]
# # Create dataframe which compares participant gestures to previous participant gestures

# %%
big_df = pd.DataFrame(index=range(61), columns=['participantID', 'generation_number', 'chain_number', 'chainID', 'age', 'extrovert', 'TotalLanguages', 'Gender', 'NumOfNativeLanguages', 'diff_in_age', 'diff_in_extrovert', 'diff_in_gender', 'diff_in_TotalNativeLanguages', 'diff_in_TotalLanguages',
                               'diff_in_gesture_space_Donner', 'diff_in_entropy_Donner', 'diff_in_variability_Donner',
                               'diff_in_gesture_space_kalt', 'diff_in_entropy_kalt', 'diff_in_variability_kalt',
                                 'diff_in_gesture_space_langsam', 'diff_in_entropy_langsam','diff_in_variability_langsam',
                                   'diff_in_gesture_space_leise', 'diff_in_entropy_leise', 'diff_in_variability_leise',
                                     'diff_in_gesture_space_rennen','diff_in_entropy_rennen', 'diff_in_variability_rennen',
                                       'diff_in_gesture_space_mean', 'diff_in_entropy_mean', 'diff_in_variability_mean', 
                                       'total_dist_Donner', 'total_dist_kalt' , 'total_dist_langsam', 'total_dist_leise', 'total_dist_rennen', 'total_dist_mean'])
big_df['participantID'] = big_df.index

# rename row zero which got messed up in the interseg_dist matrix
interseg_dist = interseg_dist.rename(index={str(0): 'rennen_g_ch3_g12_compr.mp4'})
for i in range(interseg_dist.shape[0]-1):

    # get the current gesture
    curr_gesture = interseg_dist.index[i]

    # get the row of features of the current gesture and aspects of the gesture
    curr_features_row = normed_features[normed_features['fileID'] == curr_gesture]

normed_features
# Out:
#      participantID   Age          BirthPlace            Gender  \
# 0               23  35.0        Deutschland   Woman / Weiblich
# 1                0   NaN                 NaN               NaN
# 2               16  27.0         Deutschland    Man / Männlich
# 3               22  32.0  Delft, Netherlands         Man / Man
# 4               30  45.0             Dresden  Woman / Weiblich
# ..             ...   ...                 ...               ...
# 452              0   NaN                 NaN               NaN
# 453              0   NaN                 NaN               NaN
# 454              0   NaN                 NaN               NaN
# 455              0   NaN                 NaN               NaN
# 456              0   NaN                 NaN               NaN
#
#       NativeLanguages  NumOfNativeLanguages  \
# 0            Deutsch                    1.0
# 1                 NaN                   NaN
# 2            Deutsch                    1.0
# 3    Dutch and Polish                   NaN
# 4             Deutsch                   1.0
# ..                ...                   ...
# 452               NaN                   NaN
# 453               NaN                   NaN
# 454               NaN                   NaN
# 455               NaN                   NaN
# 456               NaN                   NaN
#
#                                        Other Languages  TotalLanguages  \
# 0    English (fluent), French (advanced), Italian (...             4.0
# 1                                                  NaN             NaN
# 2                                              English             2.0
# 3    English (fluent), French (good knowledge), Ger...             5.0
# 4                                             Englisch             2.0
# ..                                                 ...             ...
# 452                                                NaN             NaN
# 453                                                NaN             NaN
# 454                                                NaN             NaN
# 455                                                NaN             NaN
# 456                                                NaN             NaN
#
#      Extroversion                            Hand  ... right_wrist_AccelRange  \
# 0            43.0  Right-handed / Rechtshänder*in  ...               0.000084
# 1             NaN                             NaN  ...               0.000094
# 2            30.0  Right-handed / Rechtshänder*in  ...               0.000179
# 3            91.0     Right-handed / Rechtshandig  ...               0.000012
# 4            51.0  Right-handed / Rechtshänder*in  ...               0.000082
# ..            ...                             ...  ...                    ...
# 452           NaN                             NaN  ...               0.000052
# 453           NaN                             NaN  ...               0.000150
# 454           NaN                             NaN  ...               0.000150
# 455           NaN                             NaN  ...               0.000094
# 456           NaN                             NaN  ...               0.000094
#
#     left_wrist_AccelRange  right_knee_AccelRange  left_knee_AccelRange  \
# 0                0.000089               0.000009              0.000009
# 1                0.000067               0.000000              0.000000
# 2                0.000186               0.000009              0.000011
# 3                0.000125               0.000000              0.000000
# 4                0.000081               0.000007              0.000013
# ..                    ...                    ...                   ...
# 452              0.000083               0.000017              0.000027
# 453              0.000127               0.000019              0.000021
# 454              0.000127               0.000019              0.000021
# 455              0.000025               0.000000              0.000000
# 456              0.000025               0.000000              0.000000
#
#     right_wrist_SpeedIntegral left_wrist_SpeedIntegral  \
# 0                    0.073015                 0.079426
# 1                    0.032305                 0.029311
# 2                    0.160841                 0.169384
# 3                    0.010280                 0.097070
# 4                    0.052000                 0.060269
# ..                        ...                      ...
# 452                  0.033526                 0.046712
# 453                  0.087211                 0.066902
# 454                  0.087211                 0.066902
# 455                  0.039195                 0.003566
# 456                  0.039195                 0.003566
#
#     right_knee_SpeedIntegral  left_knee_SpeedIntegral  X_embeddings  \
# 0                   0.002551                 0.003209     12.227211
# 1                   0.000000                 0.000000      7.437744
# 2                   0.007596                 0.007968     13.373139
# 3                   0.000000                 0.000000      5.912247
# 4                   0.010345                 0.008786     11.754339
# ..                       ...                      ...           ...
# 452                 0.006082                 0.007133     13.261251
# 453                 0.005707                 0.007932     12.493334
# 454                 0.005707                 0.007932     12.493334
# 455                 0.000000                 0.000000      7.683412
# 456                 0.000000                 0.000000      7.683412
#
#      Y_embeddings
# 0       15.598193
# 1       16.080709
# 2       16.011000
# 3       15.450927
# 4       12.864773
# ..            ...
# 452     12.877107
# 453     15.478951
# 454     15.478951
# 455     11.633258
# 456     11.633258
#
# [457 rows x 63 columns]

# %%
interseg_dist = pd.read_csv(os.path.join(curfolder, 'interseg_dist_extended.csv')).set_index('Unnamed: 0')
nijmegen_gestures  = ['koud', 'langzaam', 'nijmegen_nijmegen_rennen', 'onweer', 'stil']
translation_dictionary = {"koud": "kalt", "langzaam": "langsam", "nijmegen_nijmegen_rennen": "rennen", "onweer": "Donner", "stil": "leise"}
big_df = pd.DataFrame(index=range(130), columns=['participantID', 'generation_number', 'chain_number', 'chainID', 'event','age', 'extrovert', 'TotalLanguages', 'Gender', 'NumOfNativeLanguages', 'diff_in_age', 'diff_in_extrovert', 'diff_in_gender', 'diff_in_TotalNativeLanguages', 'diff_in_TotalLanguages',
                               ])
big_df['participantID'] = big_df.index

interseg_dist = interseg_dist.rename(index={str(0): 'rennen_g_ch3_g12_compr.mp4'})
#normed_features = normed_features.drop(437)
interseg_dist = interseg_dist.loc[interseg_dist.index.notna()]


for i in range(1, interseg_dist.shape[0]-2):
    print(i)

    # get the current gesture
    curr_gesture = interseg_dist.index[i]

    # get the row of features of the current gesture and aspects of the gesture
    curr_features_row = normed_features[normed_features['fileID'] == curr_gesture]
    gesture = curr_features_row["gesture"].iloc[0]
    generation_number = curr_features_row["generation_number"].iloc[0]
    generation_number = generation_number.astype(int)

    # if the current gesture is seed zero, go to the next iteration
    if generation_number == 0:
        continue
    chain_number = curr_features_row["chain_number"].iloc[0]
    chain_number =chain_number.astype(int)
    chainID = curr_features_row["chainID"].iloc[0]
    participantID_curr = curr_features_row["participantID"].iloc[0]
    #get the event
    event = curr_features_row["event"].iloc[0]
    ## if 
    # get the previous gesture
    previous_gesture = gesture + "_g_ch" + str(chain_number) + "_g" + str((generation_number)-1) + "_compr.mp4"
    print(gesture)
    print(previous_gesture)
    ### GET THE ENDING FOR THE EVENT IN THE PREVIOUS GESTURE
    if curr_gesture == "rennen_g_ch1_g17_compr.mp4" or curr_gesture == "langsam_g_ch2_g8_compr.mp4" or curr_gesture == "langsam_g_ch2_g19_compr.mp4" or previous_gesture== "rennen_g_ch1_g17_compr.mp4" or previous_gesture == "langsam_g_ch2_g8_compr.mp4" or previous_gesture== "langsam_g_ch2_g19_compr.mp4" or previous_gesture == 'koud_g_ch2_g0_compr.mp4' or previous_gesture == "onweer_g_ch2_g0_compr.mp4" or previous_gesture == 'Donner_g_ch2_g3_compr.mp4' or previous_gesture == 'nijmegen_nijmegen_rennen_g_ch1_g0_compr.mp4' or previous_gesture == 'stil_g_ch1_g0_compr.mp4' or previous_gesture == "langzaam_g_ch1_g0_compr.mp4" or previous_gesture == "kalt_g_ch2_g7_compr.mp4" or previous_gesture == "langzaam_g_ch2_g0_compr.mp4" or previous_gesture == "stil_g_ch2_g0_compr.mp4" or previous_gesture == "nijmegen_nijmegen_rennen_g_ch2_g0_compr.mp4" or previous_gesture == "lndw_lndw_rennen_g_ch2_g0_compr.mp4" or previous_gesture == "onweer_g_ch1_g0_compr.mp4" or previous_gesture == "koud_g_ch1_g0_compr.mp4" or previous_gesture == "lndw_lndw_rennen_g_ch3_g0_compr.mp4":
        continue
    
    # get the previous gesture in the correct event (nijmegen or lndw)
    prev_features_row = normed_features[
    (normed_features['fileID'] == previous_gesture) &
    (normed_features['event'] == event)]

    if event == 'nijmegen':
        participantID_curr = (participantID_curr)+60
        gesture = translation_dictionary[gesture]
    if event == 'lndw':
        if gesture == 'lndw_lndw_rennen':
            gesture = 'rennen'
    big_df.loc[participantID_curr, 'generation_number'] = generation_number
    big_df.loc[participantID_curr, 'chain_number'] = chain_number
    big_df.loc[participantID_curr, 'chainID'] = chainID
    big_df.loc[participantID_curr, 'event'] = event
    

    distance = interseg_dist.loc[previous_gesture, curr_gesture]
    big_df.loc[participantID_curr, 'total_dist_' + gesture] =distance
    participant_ages = big_df.loc[big_df['participantID'] == participantID_curr, 'age']

    if not participant_ages.empty and pd.isna(participant_ages.iloc[0]):
        #get the distance between the ages
        previous_age = prev_features_row["Age"].iloc[0]
        curr_age = curr_features_row["Age"].iloc[0]
        big_df.loc[participantID_curr, 'age'] = curr_age
        # if we don't know the ages, skip this iteration
        if math.isnan(previous_age) or math.isnan(curr_age):
            continue
    #get the difference in ages
        diff_in_age = int(abs(curr_age - previous_age))
        big_df.loc[participantID_curr, 'diff_in_age'] = diff_in_age

    participant_ext = big_df.loc[big_df['participantID'] == participantID_curr, 'extrovert']

    if not participant_ext.empty and pd.isna(participant_ext.iloc[0]):
    #get the difference in extroversion
    #if pd.isna(big_df.loc[big_df['participantID'] == participantID_curr, 'extrovert'].iloc[0]):
        previous_extrovert = prev_features_row["Extroversion"].iloc[0]
        curr_extrovert = curr_features_row["Extroversion"].iloc[0]
        big_df.loc[participantID_curr, 'extrovert'] = curr_extrovert
        # if we don't know the extroversion, skip this iteration
        if math.isnan(previous_extrovert) or math.isnan(curr_extrovert):
            continue
        #get the difference in extroversion
        diff_in_extrovert = int(abs(curr_extrovert - previous_extrovert))
        big_df.loc[participantID_curr, 'diff_in_extrovert'] = diff_in_extrovert

    participant_lang = big_df.loc[big_df['participantID'] == participantID_curr, 'TotalLanguages']

    if not participant_lang.empty and pd.isna(participant_lang.iloc[0]):
    #if pd.isna(big_df.loc[big_df['participantID'] == participantID_curr, 'TotalLanguages'].iloc[0]):
        #get the distance between the ages
        previous_langs = prev_features_row["TotalLanguages"].iloc[0]
        curr_langs = curr_features_row["TotalLanguages"].iloc[0]
        big_df.loc[participantID_curr, 'TotalLanguages'] = curr_langs
        # if we don't know the ages, skip this iteration
        if math.isnan(previous_langs) or math.isnan(curr_langs):
            continue
    #get the difference in ages
        diff_in_TotalLanguages = int(abs(curr_langs - previous_langs))
        big_df.loc[participantID_curr, 'diff_in_TotalLanguages'] = diff_in_TotalLanguages

    #if pd.isna(big_df.loc[big_df['participantID'] == participantID_curr, 'NumOfNativeLanguages'].iloc[0]):
    participant_numlang = big_df.loc[big_df['participantID'] == participantID_curr, 'NumOfNativeLanguages']

    if not participant_numlang.empty and pd.isna(participant_numlang.iloc[0]):
        #get the distance between the ages
        previous_Nlangs = prev_features_row["NumOfNativeLanguages"].iloc[0]
        curr_Nlangs = curr_features_row["NumOfNativeLanguages"].iloc[0]
        big_df.loc[participantID_curr, 'NumOfNativeLanguages'] = curr_Nlangs
        # if we don't know the ages, skip this iteration
        if math.isnan(previous_Nlangs) or math.isnan(curr_Nlangs):
            continue
    #get the difference in native languages
        diff_in_TotalNativeLanguages = int(abs(curr_Nlangs - previous_Nlangs))
        big_df.loc[participantID_curr, 'diff_in_TotalNativeLanguages'] = diff_in_TotalNativeLanguages

    #if pd.isna(big_df.loc[big_df['participantID'] == participantID_curr, 'Gender'].iloc[0]):
    participant_gender = big_df.loc[big_df['participantID'] == participantID_curr, 'Gender']

    if not participant_gender.empty and pd.isna(participant_gender.iloc[0]):
        #get the distance between the ages
        previous_gender = prev_features_row["Gender"].iloc[0]
        curr_gender = curr_features_row["Gender"].iloc[0]
        big_df.loc[participantID_curr, 'Gender'] = curr_gender
        # if we don't know the ages, skip this iteration
        if math.isnan(previous_Nlangs) or math.isnan(curr_Nlangs):
            continue
    #get the difference in gender (0 means no difference, 1 means difference)
        diff_in_Gender = int(previous_gender != curr_gender)
        big_df.loc[participantID_curr, 'diff_in_gender'] = diff_in_Gender

"""
    # get the difference between gesture spaces and the current gesture space
    gesture_space_diff = abs(curr_features_row["total_gesture_space2D"].iloc[0] - prev_features_row["total_gesture_space2D"].iloc[0])
    big_df.loc[participantID_curr, 'diff_in_gesture_space_' + gesture] =gesture_space_diff
    big_df.loc[participantID_curr, 'gesture_space_' + gesture] = curr_features_row["total_gesture_space2D"].iloc[0]
     # get the difference between entrophies and the current entropy
    entropy_diff = abs(curr_features_row["total_body_entropy2Daggregated"].iloc[0] - prev_features_row["total_body_entropy2Daggregated"].iloc[0])
    big_df.loc[participantID_curr, 'diff_in_entropy_' + gesture] = entropy_diff
    big_df.loc[participantID_curr, 'entropy_' + gesture] = curr_features_row["total_body_entropy2Daggregated"].iloc[0]
    # # get the difference between variabilities and the current variabilities
    variability_diff = abs(curr_features_row["total_body_variability2Daggregated"].iloc[0] - prev_features_row["total_body_variability2Daggregated"].iloc[0])
    big_df.loc[participantID_curr, 'diff_in_variability_' + gesture] = variability_diff
    big_df.loc[participantID_curr, 'variability_' + gesture] = curr_features_row["total_body_variability2Daggregated"].iloc[0]     
    ## get the difference betweeen bounding boxes and the current bounding boxes
    bounding_box_diff = abs(curr_features_row["total_arm_boundingbox2D"].iloc[0] - prev_features_row["total_arm_boundingbox2D"].iloc[0])
    big_df.loc[participantID_curr, 'diff_in_arm_bounding_box_' + gesture] = bounding_box_diff
    big_df.loc[participantID_curr, 'arm_bounding_box_' + gesture] = curr_features_row["total_arm_boundingbox2D"].iloc[0]

    ## get the difference between intermittency and the current intermittency
    intermittency_diff = abs(curr_features_row["total_body_intermittency"].iloc[0] - prev_features_row["total_body_intermittency"].iloc[0])
    big_df.loc[participantID_curr, 'diff_in_intermittency_' + gesture] = intermittency_diff
    big_df.loc[participantID_curr, 'total_body_intermittency_' + gesture] = curr_features_row["total_body_intermittency"].iloc[0]

    ## get the difference between time and the current time
    time_diff = abs(curr_features_row["total_time"].iloc[0] - prev_features_row["total_time"].iloc[0])
    big_df.loc[participantID_curr, 'diff_in_time_' + gesture] = time_diff
    big_df.loc[participantID_curr, 'time_' + gesture] = curr_features_row["total_time"].iloc[0]
"""
    
big_df

# Saving to Csv File
globals()["big_df"] = big_df
globals()["big_df"].to_csv(os.path.join(curfolder, f'{"gesture_to_prev_gesture_extended_february"}.csv'), index=False)

interseg_dist
curr_gesture
big_df
# Out:
# 1
# 2
# Donner
# Donner_g_ch1_g15_compr.mp4
# 3
# onweer
# onweer_g_ch2_g1_compr.mp4
# 4
# kalt
# kalt_g_ch2_g9_compr.mp4
# 5
# lndw_lndw_rennen
# lndw_lndw_rennen_g_ch1_g11_compr.mp4
# 6
# leise
# leise_g_ch2_g16_compr.mp4
# 7
# kalt
# kalt_g_ch2_g5_compr.mp4
# 8
# Donner
# Donner_g_ch1_g4_compr.mp4
# 9
# onweer
# onweer_g_ch1_g3_compr.mp4
# 10
# lndw_lndw_rennen
# lndw_lndw_rennen_g_ch1_g15_compr.mp4
# 11
# kalt
# kalt_g_ch2_g13_compr.mp4
# 12
# stil
# stil_g_ch1_g7_compr.mp4
# 13
# nijmegen_nijmegen_rennen
# nijmegen_nijmegen_rennen_g_ch1_g7_compr.mp4
# 14
# onweer
# onweer_g_ch2_g5_compr.mp4
# 15
# Donner
# Donner_g_ch1_g11_compr.mp4
# 16
# kalt
# kalt_g_ch1_g3_compr.mp4
# 17
# Donner
# Donner_g_ch2_g6_compr.mp4
# 18
# Donner
# Donner_g_ch1_g0_compr.mp4
# 19
# kalt
# kalt_g_ch2_g1_compr.mp4
# 20
# leise
# leise_g_ch2_g12_compr.mp4
# 21
# Donner
# Donner_g_ch2_g17_compr.mp4
# 22
# koud
# koud_g_ch1_g3_compr.mp4
# 23
# langsam
# langsam_g_ch3_g17_compr.mp4
# 24
# leise
# leise_g_ch1_g19_compr.mp4
# 25
# kalt
# kalt_g_ch3_g12_compr.mp4
# 26
# lndw_lndw_rennen
# lndw_lndw_rennen_g_ch3_g3_compr.mp4
# 27
# leise
# leise_g_ch3_g4_compr.mp4
# 28
# koud
# koud_g_ch1_g18_compr.mp4
# 29
# langsam
# langsam_g_ch1_g14_compr.mp4
# 30
# nijmegen_nijmegen_rennen
# nijmegen_nijmegen_rennen_g_ch1_g19_compr.mp4
# 31
# langsam
# langsam_g_ch1_g1_compr.mp4
# 32
# leise
# leise_g_ch1_g18_compr.mp4
# 33
# koud
# koud_g_ch2_g1_compr.mp4
# 34
# langsam
# langsam_g_ch2_g3_compr.mp4
# 35
# koud
# koud_g_ch1_g19_compr.mp4
# 36
# leise
# leise_g_ch3_g13_compr.mp4
# 37
# nijmegen_nijmegen_rennen
# nijmegen_nijmegen_rennen_g_ch1_g18_compr.mp4
# 38
# langsam
# langsam_g_ch1_g5_compr.mp4
# 39
# langsam
# langsam_g_ch1_g10_compr.mp4
# 40
# onweer
# onweer_g_ch1_g17_compr.mp4
# 41
# lndw_lndw_rennen
# lndw_lndw_rennen_g_ch2_g17_compr.mp4
# 42
# leise
# leise_g_ch3_g0_compr.mp4
# 43
# kalt
# kalt_g_ch3_g16_compr.mp4
# 44
# langsam
# langsam_g_ch3_g8_compr.mp4
# 45
# leise
# leise_g_ch3_g9_compr.mp4
# 46
# langzaam
# langzaam_g_ch1_g7_compr.mp4
# 47
# koud
# koud_g_ch2_g5_compr.mp4
# 48
# lndw_lndw_rennen
# lndw_lndw_rennen_g_ch2_g8_compr.mp4
# 49
# leise
# leise_g_ch2_g7_compr.mp4
# 50
# langsam
# langsam_g_ch1_g0_compr.mp4
# 51
# langsam
# langsam_g_ch1_g15_compr.mp4
# 52
# lndw_lndw_rennen
# lndw_lndw_rennen_g_ch3_g6_compr.mp4
# 53
# leise
# leise_g_ch3_g5_compr.mp4
# 54
# kalt
# kalt_g_ch3_g9_compr.mp4
# 55
# leise
# leise_g_ch1_g8_compr.mp4
# 56
# lndw_lndw_rennen
# lndw_lndw_rennen_g_ch1_g7_compr.mp4
# 57
# koud
# koud_g_ch1_g6_compr.mp4
# 58
# leise
# leise_g_ch3_g16_compr.mp4
# 59
# langsam
# langsam_g_ch2_g6_compr.mp4
# 60
# koud
# koud_g_ch2_g0_compr.mp4
# 61
# koud
# koud_g_ch1_g2_compr.mp4
# 62
# kalt
# kalt_g_ch3_g13_compr.mp4
# 63
# lndw_lndw_rennen
# lndw_lndw_rennen_g_ch3_g2_compr.mp4
# 64
# leise
# leise_g_ch3_g1_compr.mp4
# 65
# langsam
# langsam_g_ch1_g11_compr.mp4
# 66
# langsam
# langsam_g_ch1_g4_compr.mp4
# 67
# kalt
# kalt_g_ch1_g18_compr.mp4
# 68
# langzaam
# langzaam_g_ch1_g17_compr.mp4
# 69
# koud
# koud_g_ch2_g4_compr.mp4
# 70
# langsam
# langsam_g_ch2_g2_compr.mp4
# 71
# leise
# leise_g_ch3_g12_compr.mp4
# 72
# kalt
# kalt_g_ch1_g19_compr.mp4
# 73
# lndw_lndw_rennen
# lndw_lndw_rennen_g_ch1_g10_compr.mp4
# 74
# Donner
# Donner_g_ch3_g17_compr.mp4
# 75
# kalt
# kalt_g_ch2_g12_compr.mp4
# 76
# onweer
# onweer_g_ch2_g0_compr.mp4
# 77
# langsam
# langsam_g_ch2_g17_compr.mp4
# 78
# kalt
# kalt_g_ch1_g2_compr.mp4
# 79
# Donner
# Donner_g_ch1_g14_compr.mp4
# 80
# onweer
# onweer_g_ch1_g6_compr.mp4
# 81
# Donner
# Donner_g_ch3_g8_compr.mp4
# 82
# Donner
# Donner_g_ch1_g5_compr.mp4
# 83
# stil
# stil_g_ch1_g17_compr.mp4
# 84
# kalt
# kalt_g_ch2_g4_compr.mp4
# 85
# leise
# leise_g_ch2_g13_compr.mp4
# 86
# Donner
# Donner_g_ch2_g3_compr.mp4
# 87
# Donner
# Donner_g_ch1_g10_compr.mp4
# 88
# kalt
# kalt_g_ch1_g6_compr.mp4
# 89
# lndw_lndw_rennen
# lndw_lndw_rennen_g_ch3_g17_compr.mp4
# 90
# onweer
# onweer_g_ch2_g4_compr.mp4
# 91
# kalt
# kalt_g_ch3_g7_compr.mp4
# 92
# kalt
# kalt_g_ch2_g16_compr.mp4
# 93
# lndw_lndw_rennen
# lndw_lndw_rennen_g_ch1_g14_compr.mp4
# 94
# leise
# leise_g_ch2_g9_compr.mp4
# 95
# kalt
# kalt_g_ch2_g0_compr.mp4
# 96
# Donner
# Donner_g_ch1_g1_compr.mp4
# 97
# onweer
# onweer_g_ch1_g2_compr.mp4
# 98
# Donner
# Donner_g_ch3_g15_compr.mp4
# 99
# nijmegen_nijmegen_rennen
# nijmegen_nijmegen_rennen_g_ch1_g0_compr.mp4
# 100
# stil
# stil_g_ch1_g0_compr.mp4
# 101
# kalt
# kalt_g_ch3_g1_compr.mp4
# 102
# langsam
# langsam_g_ch2_g15_compr.mp4
# 103
# lndw_lndw_rennen
# lndw_lndw_rennen_g_ch3_g11_compr.mp4
# 104
# onweer
# onweer_g_ch1_g8_compr.mp4
# 105
# stil
# stil_g_ch2_g6_compr.mp4
# 106
# nijmegen_nijmegen_rennen
# nijmegen_nijmegen_rennen_g_ch2_g6_compr.mp4
# 107
# Donner
# Donner_g_ch3_g6_compr.mp4
# 108
# Donner
# Donner_g_ch1_g7_compr.mp4
# 109
# stil
# stil_g_ch1_g15_compr.mp4
# 110
# kalt
# kalt_g_ch1_g8_compr.mp4
# 111
# lndw_lndw_rennen
# lndw_lndw_rennen_g_ch3_g15_compr.mp4
# 112
# kalt
# kalt_g_ch3_g5_compr.mp4
# 113
# langsam
# langsam_g_ch2_g11_compr.mp4
# 114
# nijmegen_nijmegen_rennen
# nijmegen_nijmegen_rennen_g_ch1_g4_compr.mp4
# 115
# stil
# stil_g_ch1_g4_compr.mp4
# 116
# kalt
# kalt_g_ch2_g18_compr.mp4
# 117
# Donner
# Donner_g_ch3_g11_compr.mp4
# 118
# stil
# stil_g_ch1_g11_compr.mp4
# 119
# kalt
# kalt_g_ch2_g19_compr.mp4
# 120
# Donner
# Donner_g_ch3_g2_compr.mp4
# 121
# stil
# stil_g_ch2_g2_compr.mp4
# 122
# nijmegen_nijmegen_rennen
# nijmegen_nijmegen_rennen_g_ch2_g2_compr.mp4
# 123
# langzaam
# langzaam_g_ch2_g6_compr.mp4
# 124
# kalt
# kalt_g_ch1_g12_compr.mp4
# 125
# leise
# leise_g_ch3_g19_compr.mp4
# 126
# onweer
# onweer_g_ch1_g10_compr.mp4
# 127
# langsam
# langsam_g_ch1_g17_compr.mp4
# 128
# lndw_lndw_rennen
# lndw_lndw_rennen_g_ch2_g10_compr.mp4
# 129
# koud
# koud_g_ch1_g13_compr.mp4
# 130
# leise
# leise_g_ch3_g7_compr.mp4
# 131
# lndw_lndw_rennen
# lndw_lndw_rennen_g_ch3_g8_compr.mp4
# 132
# langsam
# langsam_g_ch3_g14_compr.mp4
# 133
# lndw_lndw_rennen
# lndw_lndw_rennen_g_ch1_g5_compr.mp4
# 134
# leise
# leise_g_ch1_g6_compr.mp4
# 135
# koud
# koud_g_ch1_g8_compr.mp4
# 136
# Donner
# Donner_g_ch2_g14_compr.mp4
# 137
# nijmegen_nijmegen_rennen
# nijmegen_nijmegen_rennen_g_ch1_g13_compr.mp4
# 138
# leise
# leise_g_ch3_g18_compr.mp4
# 139
# langsam
# langsam_g_ch2_g8_compr.mp4
# 140
# langzaam
# langzaam_g_ch1_g0_compr.mp4
# 141
# leise
# leise_g_ch1_g13_compr.mp4
# 142
# leise
# leise_g_ch2_g0_compr.mp4
# 143
# langzaam
# langzaam_g_ch1_g11_compr.mp4
# 144
# Donner
# Donner_g_ch2_g10_compr.mp4
# 145
# langsam
# langsam_g_ch3_g3_compr.mp4
# 146
# lndw_lndw_rennen
# lndw_lndw_rennen_g_ch1_g1_compr.mp4
# 147
# langsam
# langsam_g_ch3_g10_compr.mp4
# 148
# leise
# leise_g_ch1_g2_compr.mp4
# 149
# koud
# koud_g_ch1_g9_compr.mp4
# 150
# lndw_lndw_rennen
# lndw_lndw_rennen_g_ch2_g14_compr.mp4
# 151
# onweer
# onweer_g_ch1_g14_compr.mp4
# 152
# langzaam
# langzaam_g_ch2_g2_compr.mp4
# 153
# kalt
# kalt_g_ch1_g16_compr.mp4
# 154
# langzaam
# langzaam_g_ch1_g15_compr.mp4
# 155
# leise
# leise_g_ch2_g4_compr.mp4
# 156
# lndw_lndw_rennen
# lndw_lndw_rennen_g_ch2_g3_compr.mp4
# 157
# leise
# leise_g_ch1_g9_compr.mp4
# 158
# langzaam
# langzaam_g_ch1_g4_compr.mp4
# 159
# nijmegen_nijmegen_rennen
# nijmegen_nijmegen_rennen_g_ch1_g9_compr.mp4
# 160
# Donner
# Donner_g_ch2_g15_compr.mp4
# 161
# langsam
# langsam_g_ch3_g2_compr.mp4
# 162
# lndw_lndw_rennen
# lndw_lndw_rennen_g_ch1_g4_compr.mp4
# 163
# langsam
# langsam_g_ch3_g15_compr.mp4
# 164
# leise
# leise_g_ch1_g3_compr.mp4
# 165
# koud
# koud_g_ch1_g16_compr.mp4
# 166
# lndw_lndw_rennen
# lndw_lndw_rennen_g_ch2_g11_compr.mp4
# 167
# onweer
# onweer_g_ch1_g11_compr.mp4
# 168
# kalt
# kalt_g_ch1_g9_compr.mp4
# 169
# langzaam
# langzaam_g_ch2_g3_compr.mp4
# 170
# langzaam
# langzaam_g_ch1_g10_compr.mp4
# 171
# leise
# leise_g_ch2_g1_compr.mp4
# 172
# lndw_lndw_rennen
# lndw_lndw_rennen_g_ch2_g2_compr.mp4
# 173
# leise
# leise_g_ch1_g16_compr.mp4
# 174
# langzaam
# langzaam_g_ch1_g1_compr.mp4
# 175
# nijmegen_nijmegen_rennen
# nijmegen_nijmegen_rennen_g_ch1_g16_compr.mp4
# 176
# langsam
# langsam_g_ch1_g7_compr.mp4
# 177
# kalt
# kalt_g_ch1_g13_compr.mp4
# 178
# onweer
# onweer_g_ch1_g15_compr.mp4
# 179
# lndw_lndw_rennen
# lndw_lndw_rennen_g_ch2_g15_compr.mp4
# 180
# koud
# koud_g_ch1_g12_compr.mp4
# 181
# kalt
# kalt_g_ch3_g18_compr.mp4
# 182
# langsam
# langsam_g_ch3_g11_compr.mp4
# 183
# lndw_lndw_rennen
# lndw_lndw_rennen_g_ch1_g0_compr.mp4
# 184
# 185
# langsam
# langsam_g_ch3_g6_compr.mp4
# 186
# Donner
# Donner_g_ch2_g11_compr.mp4
# 187
# nijmegen_nijmegen_rennen
# nijmegen_nijmegen_rennen_g_ch1_g12_compr.mp4
# 188
# langzaam
# langzaam_g_ch1_g5_compr.mp4
# 189
# kalt
# kalt_g_ch3_g19_compr.mp4
# 190
# leise
# leise_g_ch1_g12_compr.mp4
# 191
# leise
# leise_g_ch2_g5_compr.mp4
# 192
# lndw_lndw_rennen
# lndw_lndw_rennen_g_ch2_g6_compr.mp4
# 193
# langzaam
# langzaam_g_ch1_g14_compr.mp4
# 194
# leise
# leise_g_ch2_g19_compr.mp4
# 195
# Donner
# Donner_g_ch1_g17_compr.mp4
# 196
# lndw_lndw_rennen
# lndw_lndw_rennen_g_ch3_g10_compr.mp4
# 197
# langsam
# langsam_g_ch2_g14_compr.mp4
# 198
# kalt
# kalt_g_ch3_g0_compr.mp4
# 199
# nijmegen_nijmegen_rennen
# nijmegen_nijmegen_rennen_g_ch1_g1_compr.mp4
# 200
# stil
# stil_g_ch1_g1_compr.mp4
# 201
# Donner
# Donner_g_ch3_g14_compr.mp4
# 202
# leise
# leise_g_ch2_g18_compr.mp4
# 203
# kalt
# kalt_g_ch2_g7_compr.mp4
# 204
# stil
# stil_g_ch1_g14_compr.mp4
# 205
# Donner
# Donner_g_ch3_g3_compr.mp4
# 206
# stil
# stil_g_ch2_g3_compr.mp4
# 207
# nijmegen_nijmegen_rennen
# nijmegen_nijmegen_rennen_g_ch2_g3_compr.mp4
# 208
# lndw_lndw_rennen
# lndw_lndw_rennen_g_ch1_g17_compr.mp4
# 209
# Donner
# Donner_g_ch3_g10_compr.mp4
# 210
# nijmegen_nijmegen_rennen
# nijmegen_nijmegen_rennen_g_ch1_g5_compr.mp4
# 211
# stil
# stil_g_ch1_g5_compr.mp4
# 212
# langsam
# langsam_g_ch2_g10_compr.mp4
# 213
# kalt
# kalt_g_ch3_g4_compr.mp4
# 214
# lndw_lndw_rennen
# lndw_lndw_rennen_g_ch3_g14_compr.mp4
# 215
# Donner
# Donner_g_ch2_g8_compr.mp4
# 216
# stil
# stil_g_ch1_g10_compr.mp4
# 217
# leise
# leise_g_ch1_g11_compr.mp4
# 218
# langzaam
# langzaam_g_ch1_g13_compr.mp4
# 219
# leise
# leise_g_ch2_g6_compr.mp4
# 220
# lndw_lndw_rennen
# lndw_lndw_rennen_g_ch2_g5_compr.mp4
# 221
# nijmegen_nijmegen_rennen
# nijmegen_nijmegen_rennen_g_ch1_g11_compr.mp4
# 222
# langzaam
# langzaam_g_ch1_g6_compr.mp4
# 223
# 224
# langsam
# langsam_g_ch3_g12_compr.mp4
# 225
# leise
# leise_g_ch1_g0_compr.mp4
# 226
# kalt
# kalt_g_ch3_g17_compr.mp4
# 227
# Donner
# Donner_g_ch2_g12_compr.mp4
# 228
# langsam
# langsam_g_ch3_g5_compr.mp4
# 229
# onweer
# onweer_g_ch1_g16_compr.mp4
# 230
# kalt
# kalt_g_ch1_g14_compr.mp4
# 231
# langsam
# langsam_g_ch1_g8_compr.mp4
# 232
# langzaam
# langzaam_g_ch2_g0_compr.mp4
# 233
# koud
# koud_g_ch1_g11_compr.mp4
# 234
# lndw_lndw_rennen
# lndw_lndw_rennen_g_ch2_g16_compr.mp4
# 235
# langzaam
# langzaam_g_ch1_g2_compr.mp4
# 236
# nijmegen_nijmegen_rennen
# nijmegen_nijmegen_rennen_g_ch1_g15_compr.mp4
# 237
# leise
# leise_g_ch2_g2_compr.mp4
# 238
# lndw_lndw_rennen
# lndw_lndw_rennen_g_ch2_g1_compr.mp4
# 239
# langzaam
# langzaam_g_ch1_g9_compr.mp4
# 240
# leise
# leise_g_ch1_g15_compr.mp4
# 241
# lndw_lndw_rennen
# lndw_lndw_rennen_g_ch2_g12_compr.mp4
# 242
# koud
# koud_g_ch1_g15_compr.mp4
# 243
# kalt
# kalt_g_ch1_g10_compr.mp4
# 244
# langzaam
# langzaam_g_ch2_g4_compr.mp4
# 245
# onweer
# onweer_g_ch1_g12_compr.mp4
# 246
# langsam
# langsam_g_ch3_g1_compr.mp4
# 247
# Donner
# Donner_g_ch2_g16_compr.mp4
# 248
# langsam
# langsam_g_ch3_g16_compr.mp4
# 249
# lndw_lndw_rennen
# lndw_lndw_rennen_g_ch1_g3_compr.mp4
# 250
# leise
# leise_g_ch1_g4_compr.mp4
# 251
# stil
# stil_g_ch1_g9_compr.mp4
# 252
# stil
# stil_g_ch2_g0_compr.mp4
# 253
# lndw_lndw_rennen
# lndw_lndw_rennen_g_ch1_g19_compr.mp4
# 254
# nijmegen_nijmegen_rennen
# nijmegen_nijmegen_rennen_g_ch2_g0_compr.mp4
# 255
# Donner
# Donner_g_ch3_g0_compr.mp4
# 256
# lndw_lndw_rennen
# lndw_lndw_rennen_g_ch3_g13_compr.mp4
# 257
# Donner
# Donner_g_ch2_g7_compr.mp4
# 258
# Donner
# Donner_g_ch3_g9_compr.mp4
# 259
# lndw_lndw_rennen
# lndw_lndw_rennen_g_ch1_g18_compr.mp4
# 260
# langsam
# langsam_g_ch2_g9_compr.mp4
# 261
# kalt
# kalt_g_ch3_g3_compr.mp4
# 262
# nijmegen_nijmegen_rennen
# nijmegen_nijmegen_rennen_g_ch1_g6_compr.mp4
# 263
# stil
# stil_g_ch1_g6_compr.mp4
# 264
# Donner
# Donner_g_ch3_g4_compr.mp4
# 265
# stil
# stil_g_ch2_g4_compr.mp4
# 266
# nijmegen_nijmegen_rennen
# nijmegen_nijmegen_rennen_g_ch2_g4_compr.mp4
# 267
# kalt
# kalt_g_ch2_g8_compr.mp4
# 268
# stil
# stil_g_ch1_g13_compr.mp4
# 269
# leise
# leise_g_ch2_g17_compr.mp4
# 270
# Donner
# Donner_g_ch1_g19_compr.mp4
# 271
# nijmegen_nijmegen_rennen
# nijmegen_nijmegen_rennen_g_ch1_g2_compr.mp4
# 272
# stil
# stil_g_ch1_g2_compr.mp4
# 273
# langsam
# langsam_g_ch2_g13_compr.mp4
# 274
# Donner
# Donner_g_ch3_g13_compr.mp4
# 275
# lndw_lndw_rennen
# lndw_lndw_rennen_g_ch3_g9_compr.mp4
# 276
# Donner
# Donner_g_ch1_g18_compr.mp4
# 277
# Donner
# Donner_g_ch3_g1_compr.mp4
# 278
# stil
# stil_g_ch2_g1_compr.mp4
# 279
# nijmegen_nijmegen_rennen
# nijmegen_nijmegen_rennen_g_ch2_g1_compr.mp4
# 280
# stil
# stil_g_ch1_g12_compr.mp4
# 281
# nijmegen_nijmegen_rennen
# nijmegen_nijmegen_rennen_g_ch1_g3_compr.mp4
# 282
# stil
# stil_g_ch1_g3_compr.mp4
# 283
# kalt
# kalt_g_ch2_g17_compr.mp4
# 284
# kalt
# kalt_g_ch3_g6_compr.mp4
# 285
# langsam
# langsam_g_ch2_g12_compr.mp4
# 286
# Donner
# Donner_g_ch3_g12_compr.mp4
# 287
# lndw_lndw_rennen
# lndw_lndw_rennen_g_ch3_g16_compr.mp4
# 288
# kalt
# kalt_g_ch1_g7_compr.mp4
# 289
# Donner
# Donner_g_ch1_g8_compr.mp4
# 290
# stil
# stil_g_ch1_g16_compr.mp4
# 291
# stil
# stil_g_ch2_g5_compr.mp4
# 292
# nijmegen_nijmegen_rennen
# nijmegen_nijmegen_rennen_g_ch2_g5_compr.mp4
# 293
# onweer
# onweer_g_ch1_g7_compr.mp4
# 294
# Donner
# Donner_g_ch3_g5_compr.mp4
# 295
# lndw_lndw_rennen
# lndw_lndw_rennen_g_ch3_g12_compr.mp4
# 296
# Donner
# Donner_g_ch3_g16_compr.mp4
# 297
# kalt
# kalt_g_ch3_g2_compr.mp4
# 298
# langsam
# langsam_g_ch2_g16_compr.mp4
# 299
# langzaam
# langzaam_g_ch1_g3_compr.mp4
# 300
# nijmegen_nijmegen_rennen
# nijmegen_nijmegen_rennen_g_ch1_g10_compr.mp4
# 301
# leise
# leise_g_ch2_g3_compr.mp4
# 302
# lndw_lndw_rennen
# lndw_lndw_rennen_g_ch2_g4_compr.mp4
# 303
# langzaam
# langzaam_g_ch1_g16_compr.mp4
# 304
# leise
# leise_g_ch1_g10_compr.mp4
# 305
# lndw_lndw_rennen
# lndw_lndw_rennen_g_ch2_g13_compr.mp4
# 306
# koud
# koud_g_ch1_g10_compr.mp4
# 307
# langzaam
# langzaam_g_ch2_g1_compr.mp4
# 308
# kalt
# kalt_g_ch1_g15_compr.mp4
# 309
# onweer
# onweer_g_ch1_g13_compr.mp4
# 310
# langsam
# langsam_g_ch3_g4_compr.mp4
# 311
# Donner
# Donner_g_ch2_g9_compr.mp4
# 312
# langsam
# langsam_g_ch3_g9_compr.mp4
# 313
# lndw_lndw_rennen
# lndw_lndw_rennen_g_ch1_g2_compr.mp4
# 314
# leise
# leise_g_ch1_g1_compr.mp4
# 315
# leise
# leise_g_ch1_g14_compr.mp4
# 316
# langzaam
# langzaam_g_ch1_g12_compr.mp4
# 317
# lndw_lndw_rennen
# lndw_lndw_rennen_g_ch2_g0_compr.mp4
# 318
# leise
# leise_g_ch3_g17_compr.mp4
# 319
# langsam
# langsam_g_ch1_g19_compr.mp4
# 320
# nijmegen_nijmegen_rennen
# nijmegen_nijmegen_rennen_g_ch1_g14_compr.mp4
# 321
# lndw_lndw_rennen
# lndw_lndw_rennen_g_ch1_g6_compr.mp4
# 322
# langsam
# langsam_g_ch3_g13_compr.mp4
# 323
# leise
# leise_g_ch1_g5_compr.mp4
# 324
# Donner
# Donner_g_ch2_g13_compr.mp4
# 325
# koud
# koud_g_ch1_g7_compr.mp4
# 326
# langsam
# langsam_g_ch3_g0_compr.mp4
# 327
# onweer
# onweer_g_ch1_g9_compr.mp4
# 328
# langsam
# langsam_g_ch1_g18_compr.mp4
# 329
# langzaam
# langzaam_g_ch2_g5_compr.mp4
# 330
# kalt
# kalt_g_ch1_g11_compr.mp4
# 331
# koud
# koud_g_ch1_g14_compr.mp4
# 332
# leise
# leise_g_ch3_g8_compr.mp4
# 333
# lndw_lndw_rennen
# lndw_lndw_rennen_g_ch3_g7_compr.mp4
# 334
# lndw_lndw_rennen
# lndw_lndw_rennen_g_ch2_g9_compr.mp4
# 335
# langsam
# langsam_g_ch2_g1_compr.mp4
# 336
# leise
# leise_g_ch3_g11_compr.mp4
# 337
# langzaam
# langzaam_g_ch1_g18_compr.mp4
# 338
# koud
# koud_g_ch2_g3_compr.mp4
# 339
# lndw_lndw_rennen
# lndw_lndw_rennen_g_ch3_g1_compr.mp4
# 340
# leise
# leise_g_ch3_g2_compr.mp4
# 341
# kalt
# kalt_g_ch1_g17_compr.mp4
# 342
# langsam
# langsam_g_ch1_g3_compr.mp4
# 343
# langsam
# langsam_g_ch1_g12_compr.mp4
# 344
# koud
# koud_g_ch1_g1_compr.mp4
# 345
# langzaam
# langzaam_g_ch1_g19_compr.mp4
# 346
# kalt
# kalt_g_ch3_g14_compr.mp4
# 347
# leise
# leise_g_ch3_g15_compr.mp4
# 348
# langsam
# langsam_g_ch2_g5_compr.mp4
# 349
# leise
# leise_g_ch1_g7_compr.mp4
# 350
# lndw_lndw_rennen
# lndw_lndw_rennen_g_ch1_g8_compr.mp4
# 351
# kalt
# kalt_g_ch3_g10_compr.mp4
# 352
# koud
# koud_g_ch1_g5_compr.mp4
# 353
# langsam
# langsam_g_ch1_g16_compr.mp4
# 354
# 355
# lndw_lndw_rennen
# lndw_lndw_rennen_g_ch3_g5_compr.mp4
# 356
# leise
# leise_g_ch3_g6_compr.mp4
# 357
# onweer
# onweer_g_ch1_g1_compr.mp4
# 358
# leise
# leise_g_ch2_g10_compr.mp4
# 359
# lndw_lndw_rennen
# lndw_lndw_rennen_g_ch3_g19_compr.mp4
# 360
# Donner
# Donner_g_ch1_g2_compr.mp4
# 361
# kalt
# kalt_g_ch2_g15_compr.mp4
# 362
# kalt
# kalt_g_ch3_g8_compr.mp4
# 363
# onweer
# onweer_g_ch2_g3_compr.mp4
# 364
# lndw_lndw_rennen
# lndw_lndw_rennen_g_ch1_g13_compr.mp4
# 365
# Donner
# Donner_g_ch2_g4_compr.mp4
# 366
# lndw_lndw_rennen
# lndw_lndw_rennen_g_ch3_g18_compr.mp4
# 367
# Donner
# Donner_g_ch1_g9_compr.mp4
# 368
# kalt
# kalt_g_ch1_g5_compr.mp4
# 369
# Donner
# Donner_g_ch1_g6_compr.mp4
# 370
# leise
# leise_g_ch2_g14_compr.mp4
# 371
# stil
# stil_g_ch1_g18_compr.mp4
# 372
# kalt
# kalt_g_ch2_g3_compr.mp4
# 373
# Donner
# Donner_g_ch3_g19_compr.mp4
# 374
# onweer
# onweer_g_ch1_g5_compr.mp4
# 375
# Donner
# Donner_g_ch3_g7_compr.mp4
# 376
# langsam
# langsam_g_ch2_g19_compr.mp4
# 377
# kalt
# kalt_g_ch1_g1_compr.mp4
# 378
# Donner
# Donner_g_ch1_g13_compr.mp4
# 379
# stil
# stil_g_ch1_g19_compr.mp4
# 380
# Donner
# Donner_g_ch2_g0_compr.mp4
# 381
# Donner
# Donner_g_ch3_g18_compr.mp4
# 382
# lndw_lndw_rennen
# lndw_lndw_rennen_g_ch1_g9_compr.mp4
# 383
# kalt
# kalt_g_ch2_g11_compr.mp4
# 384
# 385
# leise
# leise_g_ch2_g11_compr.mp4
# 386
# kalt
# kalt_g_ch2_g2_compr.mp4
# 387
# onweer
# onweer_g_ch1_g0_compr.mp4
# 388
# Donner
# Donner_g_ch1_g12_compr.mp4
# 389
# kalt
# kalt_g_ch1_g4_compr.mp4
# 390
# Donner
# Donner_g_ch2_g5_compr.mp4
# 391
# lndw_lndw_rennen
# lndw_lndw_rennen_g_ch1_g16_compr.mp4
# 392
# onweer
# onweer_g_ch2_g6_compr.mp4
# 393
# kalt
# kalt_g_ch2_g14_compr.mp4
# 394
# stil
# stil_g_ch1_g8_compr.mp4
# 395
# nijmegen_nijmegen_rennen
# nijmegen_nijmegen_rennen_g_ch1_g8_compr.mp4
# 396
# onweer
# onweer_g_ch1_g4_compr.mp4
# 397
# leise
# leise_g_ch2_g15_compr.mp4
# 398
# Donner
# Donner_g_ch1_g3_compr.mp4
# 399
# kalt
# kalt_g_ch2_g10_compr.mp4
# 400
# onweer
# onweer_g_ch2_g2_compr.mp4
# 401
# lndw_lndw_rennen
# lndw_lndw_rennen_g_ch1_g12_compr.mp4
# 402
# Donner
# Donner_g_ch2_g1_compr.mp4
# 403
# kalt
# kalt_g_ch1_g0_compr.mp4
# 404
# Donner
# Donner_g_ch1_g16_compr.mp4
# 405
# koud
# koud_g_ch2_g6_compr.mp4
# 406
# lndw_lndw_rennen
# lndw_lndw_rennen_g_ch2_g7_compr.mp4
# 407
# leise
# leise_g_ch2_g8_compr.mp4
# 408
# leise
# leise_g_ch3_g10_compr.mp4
# 409
# onweer
# onweer_g_ch1_g19_compr.mp4
# 410
# langzaam
# langzaam_g_ch1_g8_compr.mp4
# 411
# langsam
# langsam_g_ch2_g0_compr.mp4
# 412
# lndw_lndw_rennen
# lndw_lndw_rennen_g_ch2_g19_compr.mp4
# 413
# kalt
# kalt_g_ch3_g15_compr.mp4
# 414
# langsam
# langsam_g_ch3_g7_compr.mp4
# 415
# koud
# koud_g_ch1_g0_compr.mp4
# 416
# langsam
# langsam_g_ch1_g9_compr.mp4
# 417
# onweer
# onweer_g_ch1_g18_compr.mp4
# 418
# langsam
# langsam_g_ch1_g6_compr.mp4
# 419
# lndw_lndw_rennen
# lndw_lndw_rennen_g_ch3_g0_compr.mp4
# 420
# lndw_lndw_rennen
# lndw_lndw_rennen_g_ch2_g18_compr.mp4
# 421
# langsam
# langsam_g_ch2_g4_compr.mp4
# 422
# nijmegen_nijmegen_rennen
# nijmegen_nijmegen_rennen_g_ch1_g17_compr.mp4
# 423
# leise
# leise_g_ch3_g14_compr.mp4
# 424
# Donner
# Donner_g_ch2_g19_compr.mp4
# 425
# langsam
# langsam_g_ch3_g19_compr.mp4
# 426
# leise
# leise_g_ch1_g17_compr.mp4
# 427
# koud
# koud_g_ch2_g2_compr.mp4
# 428
# lndw_lndw_rennen
# lndw_lndw_rennen_g_ch3_g4_compr.mp4
# 429
# leise
# leise_g_ch3_g3_compr.mp4
# 430
# koud
# koud_g_ch1_g17_compr.mp4
# 431
# langsam
# langsam_g_ch1_g2_compr.mp4
# 432
# langsam
# langsam_g_ch1_g13_compr.mp4
# 433
# koud
# koud_g_ch1_g4_compr.mp4
# 434
# Donner
# Donner_g_ch2_g18_compr.mp4
# 435
# kalt
# kalt_g_ch3_g11_compr.mp4
# 436
# langsam
# langsam_g_ch3_g18_compr.mp4
# 437
# 438
# 439
# 440
# 441
# 442
# 443
# 444
# 445
# 446
# 447
# 448
# 449
# 450
# 451
# 452
# 453
# 454
#      participantID generation_number chain_number chainID event   age  \
# 0                0               NaN          NaN     NaN   NaN   NaN
# 1                1                 1            1   ch1g1  lndw  26.0
# 2                2                 2            1   ch1g2  lndw  24.0
# 3                3                 3            1   ch1g3  lndw  32.0
# 4                4                 4            1   ch1g4  lndw  60.0
# ..             ...               ...          ...     ...   ...   ...
# 125            125               NaN          NaN     NaN   NaN   NaN
# 126            126               NaN          NaN     NaN   NaN   NaN
# 127            127               NaN          NaN     NaN   NaN   NaN
# 128            128               NaN          NaN     NaN   NaN   NaN
# 129            129               NaN          NaN     NaN   NaN   NaN
#
#     extrovert TotalLanguages                            Gender  \
# 0         NaN            NaN                               NaN
# 1        40.0            3.0                  Woman / Weiblich
# 2        17.0            7.0  Prefer not to say / Keine Angabe
# 3        60.0            3.0                  Woman / Weiblich
# 4        86.0            3.0                  Woman / Weiblich
# ..        ...            ...                               ...
# 125       NaN            NaN                               NaN
# 126       NaN            NaN                               NaN
# 127       NaN            NaN                               NaN
# 128       NaN            NaN                               NaN
# 129       NaN            NaN                               NaN
#
#     NumOfNativeLanguages diff_in_age diff_in_extrovert diff_in_gender  \
# 0                    NaN         NaN               NaN            NaN
# 1                    1.0         NaN               NaN            NaN
# 2                    1.0           2                23              1
# 3                    1.0           8                43              1
# 4                    1.0          28                26              0
# ..                   ...         ...               ...            ...
# 125                  NaN         NaN               NaN            NaN
# 126                  NaN         NaN               NaN            NaN
# 127                  NaN         NaN               NaN            NaN
# 128                  NaN         NaN               NaN            NaN
# 129                  NaN         NaN               NaN            NaN
#
#     diff_in_TotalNativeLanguages diff_in_TotalLanguages  total_dist_Donner  \
# 0                            NaN                    NaN                NaN
# 1                            NaN                    NaN         371.541098
# 2                              0                      4         351.309346
# 3                              0                      4         856.364741
# 4                              0                      0         241.742928
# ..                           ...                    ...                ...
# 125                          NaN                    NaN                NaN
# 126                          NaN                    NaN                NaN
# 127                          NaN                    NaN                NaN
# 128                          NaN                    NaN                NaN
# 129                          NaN                    NaN                NaN
#
#      total_dist_kalt  total_dist_rennen  total_dist_leise  total_dist_langsam
# 0                NaN                NaN               NaN                 NaN
# 1          63.483812          76.828965        916.667481          510.707335
# 2        1320.565591         323.659309        891.667651          492.246006
# 3        1222.207596          93.707357        347.211312          468.033224
# 4         364.106321         153.041460       1065.744041          459.273360
# ..               ...                ...               ...                 ...
# 125              NaN                NaN               NaN                 NaN
# 126              NaN                NaN               NaN                 NaN
# 127              NaN                NaN               NaN                 NaN
# 128              NaN                NaN               NaN                 NaN
# 129              NaN                NaN               NaN                 NaN
#
# [130 rows x 20 columns]

# %%
big_df.columns
# Out:
# Index(['participantID', 'generation_number', 'chain_number', 'chainID',
#        'event', 'age', 'extrovert', 'TotalLanguages', 'Gender',
#        'NumOfNativeLanguages', 'diff_in_age', 'diff_in_extrovert',
#        'diff_in_gender', 'diff_in_TotalNativeLanguages',
#        'diff_in_TotalLanguages', 'total_dist_Donner',
#        'diff_in_gesture_space_Donner', 'gesture_space_Donner',
#        'diff_in_entropy_Donner', 'entropy_Donner',
#        'diff_in_variability_Donner', 'variability_Donner',
#        'diff_in_arm_bounding_box_Donner', 'arm_bounding_box_Donner',
#        'diff_in_intermittency_Donner', 'total_body_intermittency_Donner',
#        'diff_in_time_Donner', 'time_Donner', 'total_dist_kalt',
#        'diff_in_gesture_space_kalt', 'gesture_space_kalt',
#        'diff_in_entropy_kalt', 'entropy_kalt', 'diff_in_variability_kalt',
#        'variability_kalt', 'diff_in_arm_bounding_box_kalt',
#        'arm_bounding_box_kalt', 'diff_in_intermittency_kalt',
#        'total_body_intermittency_kalt', 'diff_in_time_kalt', 'time_kalt',
#        'total_dist_rennen', 'diff_in_gesture_space_rennen',
#        'gesture_space_rennen', 'diff_in_entropy_rennen', 'entropy_rennen',
#        'diff_in_variability_rennen', 'variability_rennen',
#        'diff_in_arm_bounding_box_rennen', 'arm_bounding_box_rennen',
#        'diff_in_intermittency_rennen', 'total_body_intermittency_rennen',
#        'diff_in_time_rennen', 'time_rennen', 'total_dist_leise',
#        'diff_in_gesture_space_leise', 'gesture_space_leise',
#        'diff_in_entropy_leise', 'entropy_leise', 'diff_in_variability_leise',
#        'variability_leise', 'diff_in_arm_bounding_box_leise',
#        'arm_bounding_box_leise', 'diff_in_intermittency_leise',
#        'total_body_intermittency_leise', 'diff_in_time_leise', 'time_leise',
#        'total_dist_langsam', 'diff_in_gesture_space_langsam',
#        'gesture_space_langsam', 'diff_in_entropy_langsam', 'entropy_langsam',
#        'diff_in_variability_langsam', 'variability_langsam',
#        'diff_in_arm_bounding_box_langsam', 'arm_bounding_box_langsam',
#        'diff_in_intermittency_langsam', 'total_body_intermittency_langsam',
#        'diff_in_time_langsam', 'time_langsam', 'diff_in_gesture_space_mean',
#        'diff_in_entropy_mean', 'diff_in_variability_mean',
#        'diff_in_arm_bounding_box_mean', 'diff_in_intermittency_mean',
#        'diff_in_time_mean', 'total_dist_mean', 'gesture_space_mean',
#        'entropy_mean', 'variability_mean'],
#       dtype='object')

# %%
big_df = pd.read_csv('/Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/StatisticsFolder/gesture_to_prev_gesture_extended.csv')

# %%
normed_features = pd.read_csv('/Users/gillianrosenberg/Documents/GitHub/FLESH_IteratedLearning/StatisticsFolder/normed_features.csv')

# %%
# create a final dataframe with everything that needed to perform statistics including feature data and comparison data
final_dataframe = normed_features[['participantID', 'Age', 'Gender', 'NumOfNativeLanguages', 'TotalLanguages', 'event', 'Extroversion', 'fileID', 'chainID', 'generation_number', 'chain_number', 'gesture', 'gesture_chain', 'left_wrist_space2D', 'right_wrist_space2D', 'left_knee_space2D',
       'right_knee_space2D', 'nose_space2D', 'total_arm_boundingbox2D',
       'total_lower_body_boundingbox2D', 'left_arm_entropy',
       'right_arm_entropy', 'left_wrist_entropy',
       'total_arm_entropy2Daggregated', 'left_wrist_variability2D',
       'right_wrist_variability2D', 'left_knee_variability2D',
       'right_knee_variability2D', 'left_wrist_submovements',
       'right_wrist_submovements', 'left_knee_submovements',
       'right_wrist_SpeedAVG', 'left_wrist_SpeedAVG', 'left_knee_SpeedAVG',
       'right_knee_SpeedAVG', 'right_wrist_AccelAVG', 'left_wrist_AccelAVG',
       'right_knee_AccelAVG', 'left_knee_AccelAVG', 'right_wrist_SpeedSD',
       'left_wrist_SpeedSD', 'right_knee_SpeedSD', 'left_knee_SpeedSD',
       'right_wrist_AccelSD', 'left_wrist_AccelSD', 'right_wrist_SpeedRange',
       'left_wrist_SpeedRange', 'right_knee_SpeedRange',
       'left_knee_SpeedRange', 'right_wrist_AccelRange',
       'left_wrist_AccelRange', 'right_knee_AccelRange',
       'left_knee_AccelRange', 'right_wrist_SpeedIntegral',
       'left_wrist_SpeedIntegral', 'right_knee_SpeedIntegral',
       'left_knee_SpeedIntegral',  'X_embeddings', 'Y_embeddings']].copy()
translation_dictionary = {"koud": "kalt", "langzaam": "langsam", "nijmegen_nijmegen_rennen": "rennen", "onweer": "Donner", "stil": "leise"}

for index, row in final_dataframe.iterrows():
    # get the relevent information for the current gesture
    participantID = row['participantID']
    gesture = row['gesture']
    event = row["event"]
    if event == 'nijmegen':
        participantID_curr = (participantID_curr)+60
        gesture = translation_dictionary[gesture]
    if event == 'lndw':
        if gesture == 'lndw_lndw_rennen':
            gesture = 'rennen'
    
    
    final_dataframe.loc[index, "generation_number"] = (final_dataframe.loc[index, "generation_number"]) + 1
    curr_row = big_df[big_df["participantID"] == participantID]
    # find the total distance between this gesture and the previous gesture
    final_dataframe.loc[index, 'total_distance'] = curr_row['total_dist_' + gesture].iloc[0]

    ## add in all of the original features
    

    """
    # find the diff_in_gesture_space between this gesture and the previous gesture
    final_dataframe.loc[index, 'diff_in_gesture_space'] = curr_row['diff_in_gesture_space_' + gesture].iloc[0]
    # find the diff_in_entropy between this gesture and the previous gesture 
    final_dataframe.loc[index, 'diff_in_entropy'] = curr_row['diff_in_entropy_' + gesture].iloc[0]
    # find the diff_in_variability between this gesture and the previous gesture 
    final_dataframe.loc[index, 'diff_in_variability'] = curr_row['diff_in_variability_' + gesture].iloc[0]
    # find the diff_in_boundingbox between this gesture and the previous gesture 
    final_dataframe.loc[index, 'diff_in_arm_bounding_box'] = curr_row['diff_in_arm_bounding_box_' + gesture].iloc[0]
    # find the diff_in_intermittency between this gesture and the previous gesture 
    final_dataframe.loc[index, 'diff_in_intermittency'] = curr_row['diff_in_intermittency_' + gesture].iloc[0]
    # find the diff_in_time between this gesture and the previous gesture 
    final_dataframe.loc[index, 'diff_in_time'] = curr_row['diff_in_time_' + gesture].iloc[0]
    """
    # find the difference in age an extroversion between this participant and the previous
    final_dataframe.loc[index, 'diff_in_age'] = curr_row['diff_in_age'].iloc[0]
    final_dataframe.loc[index, 'diff_in_extrovet'] = curr_row['diff_in_extrovert'].iloc[0]
    final_dataframe.loc[index, 'diff_in_gender'] = curr_row['diff_in_gender'].iloc[0]
    final_dataframe.loc[index, 'diff_in_TotalLanguages'] = curr_row['diff_in_TotalLanguages'].iloc[0]
    final_dataframe.loc[index, 'diff_in_TotalNativeLanguages'] = curr_row['diff_in_TotalNativeLanguages'].iloc[0]

    # get the categorical age
    Age = curr_row["age"].iloc[0]
    age_category = ""
    if Age < 12:
        age_category = "Gen_Alpha"
    if Age >= 12 and Age <28:
        age_category = "Gen_Z"
    if Age >= 28 and Age <45:
        age_category = "Millenial"
    if Age >= 45 and Age <60:
        age_category = "GenX"
    if Age >= 60 and Age <78:
        age_category = "Baby_Boomer"
    if Age >=78:
        age_category = "Silent_Gen"

    final_dataframe.loc[index, 'Age_category'] = age_category

    #get the categorical extroversion
    extrovert = curr_row["extrovert"].iloc[0]
    extrovert_category = ""
    if extrovert < 50:
        extrovert_category = "Introvert"
    if Age >= 50:
        extrovert_category = "Extrovert"

    final_dataframe.loc[index, 'Extrovert_category'] = extrovert_category

# save to a dataframe
globals()["final_dataframe"] = final_dataframe

globals()["final_dataframe"].to_csv(os.path.join(curfolder, f'{"final_stats_dataframe_extended_february"}.csv'), index=False)
final_dataframe
# Out:
#      participantID   Age            Gender  NumOfNativeLanguages  \
# 0               23  35.0  Woman / Weiblich                   1.0
# 1                0   NaN               NaN                   NaN
# 2               16  27.0    Man / Männlich                   1.0
# 3               22  32.0         Man / Man                   NaN
# 4               30  45.0  Woman / Weiblich                   1.0
# ..             ...   ...               ...                   ...
# 440              0   NaN               NaN                   NaN
# 441              0   NaN               NaN                   NaN
# 442              0   NaN               NaN                   NaN
# 443              0   NaN               NaN                   NaN
# 444              0   NaN               NaN                   NaN
#
#      TotalLanguages     event  Extroversion                      fileID  \
# 0               4.0      lndw          43.0   Donner_g_ch2_g3_compr.mp4
# 1               NaN      lndw           NaN     kalt_g_ch1_g0_compr.mp4
# 2               2.0      lndw          30.0  Donner_g_ch1_g16_compr.mp4
# 3               5.0  nijmegen          91.0   onweer_g_ch2_g2_compr.mp4
# 4               2.0      lndw          51.0    kalt_g_ch2_g10_compr.mp4
# ..              ...       ...           ...                         ...
# 440             NaN      lndw           NaN  langsam_g_ch3_g0_compr.mp4
# 441             NaN      lndw           NaN   Donner_g_ch2_g0_compr.mp4
# 442             NaN      lndw           NaN   Donner_g_ch3_g0_compr.mp4
# 443             NaN      lndw           NaN     kalt_g_ch2_g0_compr.mp4
# 444             NaN      lndw           NaN     kalt_g_ch3_g0_compr.mp4
#
#     chainID  generation_number  ...  X_embeddings Y_embeddings total_distance  \
# 0     ch2g3                4.0  ...      9.953186    16.553760            NaN
# 1     ch1g0                1.0  ...     -3.047547     8.861458            NaN
# 2    ch1g16               17.0  ...     10.690100    15.937997            NaN
# 3     ch2g2                3.0  ...     -3.587382    10.205219            NaN
# 4    ch2g10               11.0  ...      6.838797    14.397810            NaN
# ..      ...                ...  ...           ...          ...            ...
# 440   ch3g0                1.0  ...      9.217481    14.313458            NaN
# 441   ch2g0                1.0  ...      9.867407    16.319271            NaN
# 442   ch3g0                1.0  ...      9.867407    16.319271            NaN
# 443   ch2g0                1.0  ...     -3.047547     8.861458            NaN
# 444   ch3g0                1.0  ...     -3.047547     8.861458            NaN
#
#      diff_in_age  diff_in_extrovet  diff_in_gender  diff_in_TotalLanguages  \
# 0           24.0              26.0             0.0                     1.0
# 1            NaN               NaN             NaN                     NaN
# 2           17.0              40.0             1.0                     3.0
# 3           37.0              19.0             1.0                     0.0
# 4           24.0               6.0             0.0                     2.0
# ..           ...               ...             ...                     ...
# 440          NaN               NaN             NaN                     NaN
# 441          NaN               NaN             NaN                     NaN
# 442          NaN               NaN             NaN                     NaN
# 443          NaN               NaN             NaN                     NaN
# 444          NaN               NaN             NaN                     NaN
#
#      diff_in_TotalNativeLanguages  Age_category  Extrovert_category
# 0                             0.0     Millenial           Introvert
# 1                             NaN
# 2                             0.0         Gen_Z           Introvert
# 3                             0.0          GenX           Extrovert
# 4                             0.0          GenX
# ..                            ...           ...                 ...
# 440                           NaN
# 441                           NaN
# 442                           NaN
# 443                           NaN
# 444                           NaN
#
# [445 rows x 67 columns]

# %%
final_dataframe
# Out:
# Index(['participantID', 'Age', 'BirthPlace', 'Gender', 'NativeLanguages',
#        'NumOfNativeLanguages', 'Other Languages', 'TotalLanguages',
#        'Extroversion', 'Hand', 'fileID', 'chainID', 'generation_number',
#        'chain_number', 'gesture', 'gesture_chain', 'event',
#        'left_wrist_space2D', 'right_wrist_space2D', 'left_knee_space2D',
#        'right_knee_space2D', 'nose_space2D', 'total_arm_boundingbox2D',
#        'total_lower_body_boundingbox2D', 'left_arm_entropy',
#        'right_arm_entropy', 'left_wrist_entropy',
#        'total_arm_entropy2Daggregated', 'left_wrist_variability2D',
#        'right_wrist_variability2D', 'left_knee_variability2D',
#        'right_knee_variability2D', 'left_wrist_submovements',
#        'right_wrist_submovements', 'left_knee_submovements',
#        'right_wrist_SpeedAVG', 'left_wrist_SpeedAVG', 'left_knee_SpeedAVG',
#        'right_knee_SpeedAVG', 'right_wrist_AccelAVG', 'left_wrist_AccelAVG',
#        'right_knee_AccelAVG', 'left_knee_AccelAVG', 'right_wrist_SpeedSD',
#        'left_wrist_SpeedSD', 'right_knee_SpeedSD', 'left_knee_SpeedSD',
#        'right_wrist_AccelSD', 'left_wrist_AccelSD', 'right_wrist_SpeedRange',
#        'left_wrist_SpeedRange', 'right_knee_SpeedRange',
#        'left_knee_SpeedRange', 'right_wrist_AccelRange',
#        'left_wrist_AccelRange', 'right_knee_AccelRange',
#        'left_knee_AccelRange', 'right_wrist_SpeedIntegral',
#        'left_wrist_SpeedIntegral', 'right_knee_SpeedIntegral',
#        'left_knee_SpeedIntegral', 'X_embeddings', 'Y_embeddings'],
#       dtype='object')
