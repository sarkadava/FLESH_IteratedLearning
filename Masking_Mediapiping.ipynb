# %% [markdown]
# # Using Media-Pipe (and Optionally Masking)
# <br>
# <div align="center">Wim Pouw (wim.pouw@donders.ru.nl)</div>
#
# <img src="Images/envision_banner.png" alt="isolated" width="300"/>
#
# ## Info documents
#
# This python notebook runs you through the procedure of taking videos as inputs with a single person in the video, and outputting the 1 outputs of the kinematic timeseries, and optionally masking video with facial, hand, and arm kinematics ovelayen.
#
# The masked-piper tool is a simple but effective modification of the the Holistic Tracking by Google's Mediapipe so that we can use it as a CPU-based light weigth tool to mask your video data while maintaining background information, and also preserving information about body kinematics.
#
# * location Repository:  https://github.com/WimPouw/envisionBOX_modulesWP/tree/main/Mediapipe_Optional_Masking
#
# * location Jupyter notebook: https://github.com/WimPouw/envisionBOX_modulesWP/blob/main/MultimodalMerging/Masking_Mediapiping.ipynb
#
# Current Github: https://github.com/WimPouw/TowardsMultimodalOpenScience
#
# ## Additional information backbone of the tool (Mediapipe Holistic Tracking)
# https://google.github.io/mediapipe/solutions/holistic.html
#
# ## Citation of mediapipe
# citation: Lugaresi, C., Tang, J., Nash, H., McClanahan, C., Uboweja, E., Hays, M., ... & Grundmann, M. (2019). Mediapipe: A framework for building perception pipelines. arXiv preprint arXiv:1906.08172.
#
# ## Citation of masked piper
# * citation: Owoyele, B., Trujillo, J., De Melo, G., & Pouw, W. (2022). Masked-Piper: Masking personal identities in visual recordings while preserving multimodal information. SoftwareX, 20, 101236.
# * Original Repo: https://github.com/WimPouw/TowardsMultimodalOpenScience
#
# ## Modification that is the basis of this tool
# Our modification of the Mediapipe tool is using the body sillhoette to distinguish the background from the body contained in the video, then track the body, and create new video that only keeps the background, masks the body, and overlays the kinematics back onto the mask. We further modify the original code so that timeseries are produced that provide all the kinematic information per frame over time.
#
# ## Use
# Make sure to install all the packages in requirements.txt. Then move your videos that you want to mask into the input folder. Then run this code, which will loop through all the videos contained in the input folder; and saves all the results in the output folders.
#
# Please use, improve and adapt as you see fit.
#
# Team: Babajide Owoyele, James Trujillo, Gerard de Melo, Wim Pouw (wim.pouw@donders.ru.nl)

# %%
#load in required packages
import mediapipe as mp #mediapipe
import cv2 #opencv
import math #basic operations
import numpy as np #basic operations
import pandas as pd #data wrangling
import csv #csv saving
import os #some basic functions for inspecting folder structure etc.

#list all videos in input_videofolder
from os import listdir
from os.path import isfile, join

mypath = "./Input_Videos/" #this is your folder with (all) your video(s)
vfiles = [f for f in listdir(mypath) if isfile(join(mypath, f))] #loop through the filenames and collect them in a list
#time series output folder
inputfol = "./Input_Videos/"
outputf_mask = "./Output_Videos/"
outtputf_ts = "./Output_TimeSeries/"

#check videos to be processed
print("The following folder is set as the output folder where all the pose time series are stored")
print(os.path.abspath(outtputf_ts))
print("\n The following folder is set as the output folder for saving the masked videos ")
print(os.path.abspath(outputf_mask))
print("\n The following video(s) will be processed for masking: ")
print(vfiles)
# Out:
# The following folder is set as the output folder where all the pose time series are stored
# d:\FLESH_IteratedLearning\Output_TimeSeries
#
#  The following folder is set as the output folder for saving the masked videos
# d:\FLESH_IteratedLearning\Output_Videos
#
#  The following video(s) will be processed for masking:
# ['Donner_g_ch1_g10_compr.mp4', 'Donner_g_ch1_g11_compr.mp4', 'Donner_g_ch1_g12_compr.mp4', 'Donner_g_ch1_g13_compr.mp4', 'Donner_g_ch1_g14_compr.mp4', 'Donner_g_ch1_g15_compr.mp4', 'Donner_g_ch1_g16_compr.mp4', 'Donner_g_ch1_g17_compr.mp4', 'Donner_g_ch1_g18_compr.mp4', 'Donner_g_ch1_g19_compr.mp4', 'Donner_g_ch1_g1_compr.mp4', 'Donner_g_ch1_g20_compr.mp4', 'Donner_g_ch1_g2_compr.mp4', 'Donner_g_ch1_g3_compr.mp4', 'Donner_g_ch1_g4_compr.mp4', 'Donner_g_ch1_g5_compr.mp4', 'Donner_g_ch1_g6_compr.mp4', 'Donner_g_ch1_g7_compr.mp4', 'Donner_g_ch1_g8_compr.mp4', 'Donner_g_ch1_g9_compr.mp4', 'Donner_g_ch2_g10_compr.mp4', 'Donner_g_ch2_g11_compr.mp4', 'Donner_g_ch2_g12_compr.mp4', 'Donner_g_ch2_g13_compr.mp4', 'Donner_g_ch2_g14_compr.mp4', 'Donner_g_ch2_g15_compr.mp4', 'Donner_g_ch2_g16_compr.mp4', 'Donner_g_ch2_g17_compr.mp4', 'Donner_g_ch2_g18_compr.mp4', 'Donner_g_ch2_g19_compr.mp4', 'Donner_g_ch2_g1_compr.mp4', 'Donner_g_ch2_g20_compr.mp4', 'Donner_g_ch2_g2_compr.mp4', 'Donner_g_ch2_g3_compr.mp4', 'Donner_g_ch2_g4_compr.mp4', 'Donner_g_ch2_g5_compr.mp4', 'Donner_g_ch2_g6_compr.mp4', 'Donner_g_ch2_g7_compr.mp4', 'Donner_g_ch2_g8_compr.mp4', 'Donner_g_ch2_g9_compr.mp4', 'Donner_g_ch3_g10_compr.mp4', 'Donner_g_ch3_g11_compr.mp4', 'Donner_g_ch3_g12_compr.mp4', 'Donner_g_ch3_g13_compr.mp4', 'Donner_g_ch3_g14_compr.mp4', 'Donner_g_ch3_g15_compr.mp4', 'Donner_g_ch3_g16_compr.mp4', 'Donner_g_ch3_g17_compr.mp4', 'Donner_g_ch3_g18_compr.mp4', 'Donner_g_ch3_g19_compr.mp4', 'Donner_g_ch3_g1_compr.mp4', 'Donner_g_ch3_g20_compr.mp4', 'Donner_g_ch3_g2_compr.mp4', 'Donner_g_ch3_g3_compr.mp4', 'Donner_g_ch3_g4_compr.mp4', 'Donner_g_ch3_g5_compr.mp4', 'Donner_g_ch3_g6_compr.mp4', 'Donner_g_ch3_g7_compr.mp4', 'Donner_g_ch3_g8_compr.mp4', 'Donner_g_ch3_g9_compr.mp4', 'files_for_G.zip', 'kalt_g_ch1_g10_compr.mp4', 'kalt_g_ch1_g11_compr.mp4', 'kalt_g_ch1_g12_compr.mp4', 'kalt_g_ch1_g13_compr.mp4', 'kalt_g_ch1_g14_compr.mp4', 'kalt_g_ch1_g15_compr.mp4', 'kalt_g_ch1_g16_compr.mp4', 'kalt_g_ch1_g17_compr.mp4', 'kalt_g_ch1_g18_compr.mp4', 'kalt_g_ch1_g19_compr.mp4', 'kalt_g_ch1_g1_compr.mp4', 'kalt_g_ch1_g20_compr.mp4', 'kalt_g_ch1_g2_compr.mp4', 'kalt_g_ch1_g3_compr.mp4', 'kalt_g_ch1_g4_compr.mp4', 'kalt_g_ch1_g5_compr.mp4', 'kalt_g_ch1_g6_compr.mp4', 'kalt_g_ch1_g7_compr.mp4', 'kalt_g_ch1_g8_compr.mp4', 'kalt_g_ch1_g9_compr.mp4', 'kalt_g_ch2_g10_compr.mp4', 'kalt_g_ch2_g11_compr.mp4', 'kalt_g_ch2_g12_compr.mp4', 'kalt_g_ch2_g13_compr.mp4', 'kalt_g_ch2_g14_compr.mp4', 'kalt_g_ch2_g15_compr.mp4', 'kalt_g_ch2_g16_compr.mp4', 'kalt_g_ch2_g17_compr.mp4', 'kalt_g_ch2_g18_compr.mp4', 'kalt_g_ch2_g19_compr.mp4', 'kalt_g_ch2_g1_compr.mp4', 'kalt_g_ch2_g20_compr.mp4', 'kalt_g_ch2_g2_compr.mp4', 'kalt_g_ch2_g3_compr.mp4', 'kalt_g_ch2_g4_compr.mp4', 'kalt_g_ch2_g5_compr.mp4', 'kalt_g_ch2_g6_compr.mp4', 'kalt_g_ch2_g7_compr.mp4', 'kalt_g_ch2_g8_compr.mp4', 'kalt_g_ch2_g9_compr.mp4', 'kalt_g_ch3_g10_compr.mp4', 'kalt_g_ch3_g11_compr.mp4', 'kalt_g_ch3_g12_compr.mp4', 'kalt_g_ch3_g13_compr.mp4', 'kalt_g_ch3_g14_compr.mp4', 'kalt_g_ch3_g15_compr.mp4', 'kalt_g_ch3_g16_compr.mp4', 'kalt_g_ch3_g17_compr.mp4', 'kalt_g_ch3_g18_compr.mp4', 'kalt_g_ch3_g19_compr.mp4', 'kalt_g_ch3_g1_compr.mp4', 'kalt_g_ch3_g20_compr.mp4', 'kalt_g_ch3_g2_compr.mp4', 'kalt_g_ch3_g3_compr.mp4', 'kalt_g_ch3_g4_compr.mp4', 'kalt_g_ch3_g5_compr.mp4', 'kalt_g_ch3_g6_compr.mp4', 'kalt_g_ch3_g7_compr.mp4', 'kalt_g_ch3_g8_compr.mp4', 'kalt_g_ch3_g9_compr.mp4', 'langsam_g_ch1_g10_compr.mp4', 'langsam_g_ch1_g11_compr.mp4', 'langsam_g_ch1_g12_compr.mp4', 'langsam_g_ch1_g13_compr.mp4', 'langsam_g_ch1_g14_compr.mp4', 'langsam_g_ch1_g15_compr.mp4', 'langsam_g_ch1_g16_compr.mp4', 'langsam_g_ch1_g17_compr.mp4', 'langsam_g_ch1_g18_compr.mp4', 'langsam_g_ch1_g19_compr.mp4', 'langsam_g_ch1_g1_compr.mp4', 'langsam_g_ch1_g20_compr.mp4', 'langsam_g_ch1_g2_compr.mp4', 'langsam_g_ch1_g3_compr.mp4', 'langsam_g_ch1_g4_compr.mp4', 'langsam_g_ch1_g5_compr.mp4', 'langsam_g_ch1_g6_compr.mp4', 'langsam_g_ch1_g7_compr.mp4', 'la ...

# %%
#initialize modules and functions

#load in mediapipe modules
mp_holistic = mp.solutions.holistic
# Import drawing_utils and drawing_styles.
mp_drawing = mp.solutions.drawing_utils
mp_drawing_styles = mp.solutions.drawing_styles

##################FUNCTIONS AND OTHER VARIABLES
#landmarks 33x that are used by Mediapipe (Blazepose)
markersbody = ['NOSE', 'LEFT_EYE_INNER', 'LEFT_EYE', 'LEFT_EYE_OUTER', 'RIGHT_EYE_OUTER', 'RIGHT_EYE', 'RIGHT_EYE_OUTER',
          'LEFT_EAR', 'RIGHT_EAR', 'MOUTH_LEFT', 'MOUTH_RIGHT', 'LEFT_SHOULDER', 'RIGHT_SHOULDER', 'LEFT_ELBOW', 
          'RIGHT_ELBOW', 'LEFT_WRIST', 'RIGHT_WRIST', 'LEFT_PINKY', 'RIGHT_PINKY', 'LEFT_INDEX', 'RIGHT_INDEX',
          'LEFT_THUMB', 'RIGHT_THUMB', 'LEFT_HIP', 'RIGHT_HIP', 'LEFT_KNEE', 'RIGHT_KNEE', 'LEFT_ANKLE', 'RIGHT_ANKLE',
          'LEFT_HEEL', 'RIGHT_HEEL', 'LEFT_FOOT_INDEX', 'RIGHT_FOOT_INDEX']

markershands = ['LEFT_WRIST', 'LEFT_THUMB_CMC', 'LEFT_THUMB_MCP', 'LEFT_THUMB_IP', 'LEFT_THUMB_TIP', 'LEFT_INDEX_FINGER_MCP',
              'LEFT_INDEX_FINGER_PIP', 'LEFT_INDEX_FINGER_DIP', 'LEFT_INDEX_FINGER_TIP', 'LEFT_MIDDLE_FINGER_MCP', 
               'LEFT_MIDDLE_FINGER_PIP', 'LEFT_MIDDLE_FINGER_DIP', 'LEFT_MIDDLE_FINGER_TIP', 'LEFT_RING_FINGER_MCP', 
               'LEFT_RING_FINGER_PIP', 'LEFT_RING_FINGER_DIP', 'LEFT_RING_FINGER_TIP', 'LEFT_PINKY_FINGER_MCP', 
               'LEFT_PINKY_FINGER_PIP', 'LEFT_PINKY_FINGER_DIP', 'LEFT_PINKY_FINGER_TIP',
              'RIGHT_WRIST', 'RIGHT_THUMB_CMC', 'RIGHT_THUMB_MCP', 'RIGHT_THUMB_IP', 'RIGHT_THUMB_TIP', 'RIGHT_INDEX_FINGER_MCP',
              'RIGHT_INDEX_FINGER_PIP', 'RIGHT_INDEX_FINGER_DIP', 'RIGHT_INDEX_FINGER_TIP', 'RIGHT_MIDDLE_FINGER_MCP', 
               'RIGHT_MIDDLE_FINGER_PIP', 'RIGHT_MIDDLE_FINGER_DIP', 'RIGHT_MIDDLE_FINGER_TIP', 'RIGHT_RING_FINGER_MCP', 
               'RIGHT_RING_FINGER_PIP', 'RIGHT_RING_FINGER_DIP', 'RIGHT_RING_FINGER_TIP', 'RIGHT_PINKY_FINGER_MCP', 
               'RIGHT_PINKY_FINGER_PIP', 'RIGHT_PINKY_FINGER_DIP', 'RIGHT_PINKY_FINGER_TIP']
facemarks = [str(x) for x in range(478)] #there are 478 points for the face mesh (see google holistic face mesh info for landmarks)

print("Note that we have the following number of pose keypoints for markers body")
print(len(markersbody))

print("\n Note that we have the following number of pose keypoints for markers hands")
print(len(markershands))

print("\n Note that we have the following number of pose keypoints for markers face")
print(len(facemarks ))

#set up the column names and objects for the time series data (add time as the first variable)
markerxyzbody = ['time']
markerxyzhands = ['time']
markerxyzface = ['time']

for mark in markersbody:
    for pos in ['X', 'Y', 'Z', 'visibility']: #for markers of the body you also have a visibility reliability score
        nm = pos + "_" + mark
        markerxyzbody.append(nm)
for mark in markershands:
    for pos in ['X', 'Y', 'Z']:
        nm = pos + "_" + mark
        markerxyzhands.append(nm)
for mark in facemarks:
    for pos in ['X', 'Y', 'Z']:
        nm = pos + "_" + mark
        markerxyzface.append(nm)

#check if there are numbers in a string
def num_there(s):
    return any(i.isdigit() for i in s)

#take some google classification object and convert it into a string
def makegoginto_str(gogobj):
    gogobj = str(gogobj).strip("[]")
    gogobj = gogobj.split("\n")
    return(gogobj[:-1]) #ignore last element as this has nothing

#make the stringifyd position traces into clean numerical values
def listpostions(newsamplemarks):
    newsamplemarks = makegoginto_str(newsamplemarks)
    tracking_p = []
    for value in newsamplemarks:
        if num_there(value):
            stripped = value.split(':', 1)[1]
            stripped = stripped.strip() #remove spaces in the string if present
            tracking_p.append(stripped) #add to this list  
    return(tracking_p)
# Out:
# Note that we have the following number of pose keypoints for markers body
# 33
#
#  Note that we have the following number of pose keypoints for markers hands
# 42
#
#  Note that we have the following number of pose keypoints for markers face
# 478

# %% [markdown]
# ## Main procedure Masked-Piper
# The following chunk of code loops through all the videos you have loaded into the input folder, then assess each frame for body poses, extract kinematic info, masks the body in a new frame that keeps the background, projects the kinematic info on the mask, and stores the kinematic info for that frame into the time series .csv for the hand + body + face.

# %%
#### This is code for realworld landmarks

# do you want to apply masking?
masking = True

# We will now loop over all the videos that are present in the video file
for vidf in vfiles:
    print("We will now process video:")
    print(vidf)
    print("This is video number " + str(vfiles.index(vidf)) + " of " + str(len(vfiles)) + " videos in total")
    
    # Capture the video and check video settings
    videoname = vidf.split("/")[-1]
    #videoname2 = videoname.replace("mp4", "avi")
    videoloc = mypath + videoname
    capture = cv2.VideoCapture(videoloc)  # load the video capture
    frameWidth = capture.get(cv2.CAP_PROP_FRAME_WIDTH) #check frame width 1280 
    frameHeight = capture.get(cv2.CAP_PROP_FRAME_HEIGHT) #check frame height 720
    samplerate = capture.get(cv2.CAP_PROP_FPS)   #fps = frames per second 30
    #print(frameWidth, frameHeight, samplerate)

    # Create an empty video file to project the pose tracking on
    fourcc = cv2.VideoWriter_fourcc(*'avc1')  # for different video formats you could use e.g., *'XVID'
    #print(fourcc)
    out = cv2.VideoWriter(outputf_mask + videoname, fourcc, fps=samplerate, 
                          frameSize=(int(frameWidth), int(frameHeight)))

    # Initialize Mediapipe Holistic
    time = 0
    tsbody = [markerxyzbody]  # These are the time series objects starting with column names initialized above
    tshands = [markerxyzhands]
    tsface = [markerxyzface]
    tsbody_world = [markerxyzbody]  # For world landmarks (3D coordinates)
    tsface_world = [markerxyzface]  # For normalized 3D face landmarks
    tshands_world = [markerxyzhands]  # For normalized 3D hand landmarks
    
    with mp_holistic.Holistic(
            static_image_mode=False, enable_segmentation=True, refine_face_landmarks=True) as holistic:
        while (True):
            ret, image = capture.read()  # read frame
            if ret == True:  # if there is a frame
                image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)  # ensure the image is in RGB format
                results = holistic.process(image)  # apply Mediapipe holistic processing
                
                h, w, c = image.shape
                if results.face_landmarks or results.pose_landmarks or results.left_hand_landmarks or results.right_hand_landmarks:
                    if masking == False:
                        original_image = cv2.cvtColor(image, cv2.COLOR_RGB2BGR)
                    elif masking == True:
                        # Masking logic here (if needed)
                        original_image = np.concatenate([image, np.full((h, w, 1), 255, dtype=np.uint8)], axis=-1)
                        mask_img = np.zeros_like(image, dtype=np.uint8) #set up basic mask image
                        mask_img[:, :] = (255,255,255) #set up basic mask image
                        segm_2class = 0.2 + 0.8 * results.segmentation_mask #set up a segmentation of the results of mediapipe
                        segm_2class = np.repeat(segm_2class[..., np.newaxis], 3, axis=2) #set up a segmentation of the results of mediapipe
                        annotated_image = mask_img * segm_2class * (1 - segm_2class) #take the basic mask image and make a sillhouette mask
                        # append Alpha channel to sillhouetted mask so that we can overlay it to the original image
                        mask = np.concatenate([annotated_image, np.full((h, w, 1), 255, dtype=np.uint8)], axis=-1)
                        # Zero background where we want to overlay
                        original_image[mask==0]=0 #for the original image we are going to set everything at zero for places where the mask has to go
                        original_image = cv2.cvtColor(original_image, cv2.COLOR_RGB2BGR)
                    
                    # Draw left hand, right hand, face, and body pose landmarks
                    mp_drawing.draw_landmarks(original_image, results.left_hand_landmarks, mp_holistic.HAND_CONNECTIONS)
                    mp_drawing.draw_landmarks(original_image, results.right_hand_landmarks, mp_holistic.HAND_CONNECTIONS)
                    mp_drawing.draw_landmarks(
                        original_image, results.face_landmarks, mp_holistic.FACEMESH_TESSELATION)
                    mp_drawing.draw_landmarks(
                        original_image, results.pose_landmarks, mp_holistic.POSE_CONNECTIONS)
                    
                    # Save pose landmarks (2D image-based)
                    samplebody = listpostions(results.pose_landmarks)
                    samplehands = listpostions([results.left_hand_landmarks, results.right_hand_landmarks])
                    sampleface = listpostions(results.face_landmarks)
                    samplebody.insert(0, time)
                    samplehands.insert(0, time)
                    sampleface.insert(0, time)
                    tsbody.append(samplebody)
                    tshands.append(samplehands)
                    tsface.append(sampleface)
                    
                    # Save pose world landmarks (3D coordinates in meters)
                    if results.pose_world_landmarks:
                        samplebody_world = listpostions(results.pose_world_landmarks)
                        samplebody_world.insert(0, time)
                        tsbody_world.append(samplebody_world)

                    # Save face and hand landmarks (as normalized 3D landmarks)
                    if results.face_landmarks:
                        sampleface_world = listpostions(results.face_landmarks)
                        sampleface_world.insert(0, time)
                        tsface_world.append(sampleface_world)

                    if results.left_hand_landmarks or results.right_hand_landmarks:
                        samplehands_world = listpostions([results.left_hand_landmarks, results.right_hand_landmarks])
                        samplehands_world.insert(0, time)
                        tshands_world.append(samplehands_world)

                else:
                    # If no landmarks detected, append NaNs
                    samplebody = [np.nan for x in range(len(markerxyzbody)-1)]
                    samplehands = [np.nan for x in range(len(markerxyzhands)-1)]
                    sampleface = [np.nan for x in range(len(markerxyzface)-1)]
                    samplebody.insert(0, time)
                    samplehands.insert(0, time)
                    sampleface.insert(0, time)
                    tsbody.append(samplebody)
                    tshands.append(samplehands)
                    tsface.append(sampleface)

                    # Append NaNs for world coordinates as well
                    samplebody_world = [np.nan for x in range(len(markerxyzbody)-1)]
                    samplebody_world.insert(0, time)
                    tsbody_world.append(samplebody_world)

                    sampleface_world = [np.nan for x in range(len(markerxyzface)-1)]
                    sampleface_world.insert(0, time)
                    tsface_world.append(sampleface_world)

                    samplehands_world = [np.nan for x in range(len(markerxyzhands)-1)]
                    samplehands_world.insert(0, time)
                    tshands_world.append(samplehands_world)

                # Show the video as we process
                cv2.imshow("resizedimage", original_image)
                out.write(original_image)  # save the frame to the new masked video
                time += (1000 / samplerate)  # update the time variable for the next frame
            
            if cv2.waitKey(1) == 27:  # allow the use of ESCAPE to break the loop
                break
            if ret == False:  # if there are no more frames, break the loop
                break

    # Once done, de-initialize all processes
    out.release()
    capture.release()
    cv2.destroyAllWindows()

    # Save CSV data for body, face, and hands
    filebody = open(outtputf_ts + videoname + '_body.csv', 'w+', newline='')
    with filebody:
        write = csv.writer(filebody)
        write.writerows(tsbody)
    
    filehands = open(outtputf_ts + videoname + '_hands.csv', 'w+', newline='')
    with filehands:
        write = csv.writer(filehands)
        write.writerows(tshands)
    
    fileface = open(outtputf_ts + videoname + '_face.csv', 'w+', newline='')
    with fileface:
        write = csv.writer(fileface)
        write.writerows(tsface)

    # Save world coordinates (in meters) to CSV for body, face, and hands
    filebody_world = open(outtputf_ts + videoname + '_body_world.csv', 'w+', newline='')
    with filebody_world:
        write = csv.writer(filebody_world)
        write.writerows(tsbody_world)

    fileface_world = open(outtputf_ts + videoname + '_face_world.csv', 'w+', newline='')
    with fileface_world:
        write = csv.writer(fileface_world)
        write.writerows(tsface_world)

    filehands_world = open(outtputf_ts + videoname + '_hands_world.csv', 'w+', newline='')
    with filehands_world:
        write = csv.writer(filehands_world)
        write.writerows(tshands_world)

print("Done with processing all folders; go look in your output folders!")
# Out:
# We will now process video:
# Donner_g_ch1_g10_compr.mp4
# This is video number 0 of 301 videos in total
# We will now process video:
# Donner_g_ch1_g11_compr.mp4
# This is video number 1 of 301 videos in total
# We will now process video:
# Donner_g_ch1_g12_compr.mp4
# This is video number 2 of 301 videos in total
# We will now process video:
# Donner_g_ch1_g13_compr.mp4
# This is video number 3 of 301 videos in total
# We will now process video:
# Donner_g_ch1_g14_compr.mp4
# This is video number 4 of 301 videos in total
# We will now process video:
# Donner_g_ch1_g15_compr.mp4
# This is video number 5 of 301 videos in total
# We will now process video:
# Donner_g_ch1_g16_compr.mp4
# This is video number 6 of 301 videos in total
# We will now process video:
# Donner_g_ch1_g17_compr.mp4
# This is video number 7 of 301 videos in total
# We will now process video:
# Donner_g_ch1_g18_compr.mp4
# This is video number 8 of 301 videos in total
# We will now process video:
# Donner_g_ch1_g19_compr.mp4
# This is video number 9 of 301 videos in total
# We will now process video:
# Donner_g_ch1_g1_compr.mp4
# This is video number 10 of 301 videos in total
# We will now process video:
# Donner_g_ch1_g20_compr.mp4
# This is video number 11 of 301 videos in total
# We will now process video:
# Donner_g_ch1_g2_compr.mp4
# This is video number 12 of 301 videos in total
# We will now process video:
# Donner_g_ch1_g3_compr.mp4
# This is video number 13 of 301 videos in total
# We will now process video:
# Donner_g_ch1_g4_compr.mp4
# This is video number 14 of 301 videos in total
# We will now process video:
# Donner_g_ch1_g5_compr.mp4
# This is video number 15 of 301 videos in total
# We will now process video:
# Donner_g_ch1_g6_compr.mp4
# This is video number 16 of 301 videos in total
# We will now process video:
# Donner_g_ch1_g7_compr.mp4
# This is video number 17 of 301 videos in total
# We will now process video:
# Donner_g_ch1_g8_compr.mp4
# This is video number 18 of 301 videos in total
# We will now process video:
# Donner_g_ch1_g9_compr.mp4
# This is video number 19 of 301 videos in total
# We will now process video:
# Donner_g_ch2_g10_compr.mp4
# This is video number 20 of 301 videos in total
# We will now process video:
# Donner_g_ch2_g11_compr.mp4
# This is video number 21 of 301 videos in total
# We will now process video:
# Donner_g_ch2_g12_compr.mp4
# This is video number 22 of 301 videos in total
# We will now process video:
# Donner_g_ch2_g13_compr.mp4
# This is video number 23 of 301 videos in total
# We will now process video:
# Donner_g_ch2_g14_compr.mp4
# This is video number 24 of 301 videos in total
# We will now process video:
# Donner_g_ch2_g15_compr.mp4
# This is video number 25 of 301 videos in total
# We will now process video:
# Donner_g_ch2_g16_compr.mp4
# This is video number 26 of 301 videos in total
# We will now process video:
# Donner_g_ch2_g17_compr.mp4
# This is video number 27 of 301 videos in total
# We will now process video:
# Donner_g_ch2_g18_compr.mp4
# This is video number 28 of 301 videos in total
# We will now process video:
# Donner_g_ch2_g19_compr.mp4
# This is video number 29 of 301 videos in total
# We will now process video:
# Donner_g_ch2_g1_compr.mp4
# This is video number 30 of 301 videos in total
# We will now process video:
# Donner_g_ch2_g20_compr.mp4
# This is video number 31 of 301 videos in total
# We will now process video:
# Donner_g_ch2_g2_compr.mp4
# This is video number 32 of 301 videos in total
# We will now process video:
# Donner_g_ch2_g3_compr.mp4
# This is video number 33 of 301 videos in total
# We will now process video:
# Donner_g_ch2_g4_compr.mp4
# This is video number 34 of 301 videos in total
# We will now process video:
# Donner_g_ch2_g5_compr.mp4
# This is video number 35 of 301 videos in total
# We will now process video:
# Donner_g_ch2_g6_compr.mp4
# This is video number 36 of 301 videos in total
# We will now process video:
# Donner_g_ch2_g7_compr.mp4
# This is video number 37 of 301 videos in total
# We will now process video:
# Donner_g_ch2_g8_compr.mp4
# This is video number 38 of 301 videos in total
# We will now process video:
# Donner_g_ch2_g9_compr.mp4
# This is video number 39 of 301 videos in total
# We will now process video:
# Donner_g_ch3_g10_compr.mp4
# This is video number 40 of 301 videos in total
# We will now process video:
# Donner_g_ch3_g11_compr.mp4
# This is video number 41 of 301 videos in total
# We will now process video:
# Donner_g_ch3_g12_compr.mp4
# This is video number 42 of 301 videos in total
# We will now process video:
# Donner_g_ch3_g13_compr.mp4
# This is video number 43 of 301 videos in total
# We will now process video:
# Donner_g_ch3_g14_compr.mp4
# This is video number 44 of 301 videos in total
# We will now process video:
# Donner_g_ch3_g15_compr.mp4
# This is video number 45 of 301 videos in total
# We will now process video:
# Donner_g_ch3_g16_compr.mp4
# This is video number 46 of 301 videos in total
# We will now process video:
# Donner_g_ch3_g17_compr.mp4
# This is video number 47 of 301 videos in total
# We will now process video:
# Donner_g_ch3_g18_compr.mp4
# This is video number 48 of 301 videos in total
# We will now process video:
# Donner_g_ch3_g19_compr.mp4
# This is video number 49 of 301 videos in total
# We will now process video:
# Donner_g_ch3_g1_compr.mp4
# This is video number 50 of 301 videos in total
# We will now process video:
# Donner_g_ch3_g20_compr.mp4
# This is video number 51 of 301 videos in total
# We will now process video:
# Donner_g_ch3_g2_compr.mp4
# This is video number 52 of 301 videos in total
# We will now process video:
# Donner_g_ch3_g3_compr.mp4
# This is video number 53 of 301 videos in total
# We will now process video:
# Donner_g_ch3_g4_compr.mp4
# This is video number 54 of 301 videos in total
# We will now process video:
# Donner_g_ch3_g5_compr.mp4
# This is video number 55 of 301 videos in total
# We will now process video:
# Donner_g_ch3_g6_compr.mp4
# This is video number 56 of 301 videos in total
# We will now process video:
# Donner_g_ch3_g7_compr.mp4
# This is video number 57 of 301 videos in total
# We will now process video:
# Donner_g_ch3_g8_compr.mp4
# This is video number 58 of 301 videos in total
# We will now process video:
# Donner_g_ch3_g9_compr.mp4
# This is video number 59 of 301 videos in total
# We will now process video:
# files_for_G.zip
# This is video number 60 of 301 videos in total
# We will now process video:
# kalt_g_ch1_g10_compr.mp4
# This is video number 61 of 301 videos in total
# We will now process video:
# kalt_g_ch1_g11_compr.mp4
# This is video number 62 of 301 videos in total
# We will now process video:
# kalt_g_ch1_g12_compr.mp4
# This is video number 63 of 301 videos in total
# We will now process video:
# kalt_g_ch1_g13_compr.mp4
# This is video number 64 of 301 videos in total
# We will now process video:
# kalt_g_ch1_g14_compr.mp4
# This is video number 65 of 301 videos in total
# We will now process video:
# kalt_g_ch1_g15_compr.mp4
# This is video number 66 of 301 videos in total
# We will now process video:
# kalt_g_ch1_g16_compr.mp4
# This is video number 67 of 301 videos in total
# We will now process video:
# kalt_g_ch1_g17_compr.mp4
# This is video number 68 of 301 videos in total
# We will now process video:
# kalt_g_ch1_g18_compr.mp4
# This is video number 69 of 301 videos in total
# We will now process video:
# kalt_g_ch1_g19_compr.mp4
# This is video number 70 of 301 videos in total
# We will now process video:
# kalt_g_ch1_g1_compr.mp4
# This is video number 71 of 301 videos in total
# We will now process video:
# kalt_g_ch1_g20_compr.mp4
# This is video number 72 of 301 videos in total
# We will now process video:
# kalt_g_ch1_g2_compr.mp4
# This is video number 73 of 301 videos in total
# We will now process video:
# kalt_g_ch1_g3_compr.mp4
# This is video number 74 of 301 videos in total
# We will now process video:
# kalt_g_ch1_g4_compr.mp4
# This is video number 75 of 301 videos in total
# We will now process video:
# kalt_g_ch1_g5_compr.mp4
# This is video number 76 of 301 videos in total
# We will now process video:
# kalt_g_ch1_g6_compr.mp4
# This is video number 77 of 301 videos in total
# We will now process video:
# kalt_g_ch1_g7_compr.mp4
# This is video number 78 of 301 videos in total
# We will now process video:
# kalt_g_ch1_g8_compr.mp4
# This is video number 79 of 301 videos in total
# We will now process video:
# kalt_g_ch1_g9_compr.mp4
# This is video number 80 of 301 videos in total
# We will now process video:
# kalt_g_ch2_g10_compr.mp4
# This is video number 81 of 301 videos in total
# We will now process video:
# kalt_g_ch2_g11_compr.mp4
# This is video number 82 of 301 videos in total
# We will now process video:
# kalt_g_ch2_g12_compr.mp4
# This is video number 83 of 301 videos in total
# We will now process video:
# kalt_g_ch2_g13_compr.mp4
# This is video number 84 of 301 videos in total
# We will now process video:
# kalt_g_ch2_g14_compr.mp4
# This is video number 85 of 301 videos in total
# We will now process video:
# kalt_g_ch2_g15_compr.mp4
# This is video number 86 of 301 videos in total
# We will now process video:
# kalt_g_ch2_g16_compr.mp4
# This is video number 87 of 301 videos in total
# We will now process video:
# kalt_g_ch2_g17_compr.mp4
# This is video number 88 of 301 videos in total
# We will now process video:
# kalt_g_ch2_g18_compr.mp4
# This is video number 89 of 301 videos in total
# We will now process video:
# kalt_g_ch2_g19_compr.mp4
# This is video number 90 of 301 videos in total
# We will now process video:
# kalt_g_ch2_g1_compr.mp4
# This is video number 91 of 301 videos in total
# We will now process video:
# kalt_g_ch2_g20_compr.mp4
# This is video number 92 of 301 videos in total
# We will now process video:
# kalt_g_ch2_g2_compr.mp4
# This is video number 93 of 301 videos in total
# We will now process video:
# kalt_g_ch2_g3_compr.mp4
# This is video number 94 of 301 videos in total
# We will now process video:
# kalt_g_ch2_g4_compr.mp4
# This is video number 95 of 301 videos in total
# We will now process video:
# kalt_g_ch2_g5_compr.mp4
# This is video number 96 of 301 videos in total
# We will now process video:
# kalt_g_ch2_g6_compr.mp4
# This is video number 97 of 301 videos in total
# We will now process video:
# kalt_g_ch2_g7_compr.mp4
# This is video number 98 of 301 videos in total
# We will now process video:
# kalt_g_ch2_g8_compr.mp4
# This is video number 99 of 301 videos in total
# We will now process video:
# kalt_g_ch2_g9_compr.mp4
# This is video number 100 of 301 videos in total
# We will now process video:
# kalt_g_ch3_g10_compr.mp4
# This is video number 101 of 301 videos in total
# We will now process video:
# kalt_g_ch3_g11_compr.mp4
# This is video number 102 of 301 videos in total
# We will now process video:
# kalt_g_ch3_g12_compr.mp4
# This is video number 103 of 301 videos in total
# We will now process video:
# kalt_g_ch3_g13_compr.mp4
# This is video number 104 of 301 videos in total
# We will now process video:
# kalt_g_ch3_g14_compr.mp4
# This is video number 105 of 301 videos in total
# We will now process video:
# kalt_g_ch3_g15_compr.mp4
# This is video number 106 of 301 videos in total
# We will now process video:
# kalt_g_ch3_g16_compr.mp4
# This is video number 107 of 301 videos in total
# We will now process video:
# kalt_g_ch3_g17_compr.mp4
# This is video number 108 of 301 videos in total
# We will now process video:
# kalt_g_ch3_g18_compr.mp4
# This is video number 109 of 301 videos in total
# We will now process video:
# kalt_g_ch3_g19_compr.mp4
# This is video number 110 of 301 videos in total
# We will now process video:
# kalt_g_ch3_g1_compr.mp4
# This is video number 111 of 301 videos in total
# We will now process video:
# kalt_g_ch3_g20_compr.mp4
# This is video number 112 of 301 videos in total
# We will now process video:
# kalt_g_ch3_g2_compr.mp4
# This is video number 113 of 301 videos in total
# We will now process video:
# kalt_g_ch3_g3_compr.mp4
# This is video number 114 of 301 videos in total
# We will now process video:
# kalt_g_ch3_g4_compr.mp4
# This is video number 115 of 301 videos in total
# We will now process video:
# kalt_g_ch3_g5_compr.mp4
# This is video number 116 of 301 videos in total
# We will now process video:
# kalt_g_ch3_g6_compr.mp4
# This is video number 117 of 301 videos in total
# We will now process video:
# kalt_g_ch3_g7_compr.mp4
# This is video number 118 of 301 videos in total
# We will now process video:
# kalt_g_ch3_g8_compr.mp4
# This is video number 119 of 301 videos in total
# We will now process video:
# kalt_g_ch3_g9_compr.mp4
# This is video number 120 of 301 videos in total
# We will now process video:
# langsam_g_ch1_g10_compr.mp4
# This is video number 121 of 301 videos in total
# We will now process video:
# langsam_g_ch1_g11_compr.mp4
# This is video number 122 of 301 videos in total
# We will now process video:
# langsam_g_ch1_g12_compr.mp4
# This is video number 123 of 301 videos in total
# We will now process video:
# langsam_g_ch1_g13_compr.mp4
# This is video number 124 of 301 videos in total
# We will now process video:
# langsam_g_ch1_g14_compr.mp4
# This is video number 125 of 301 videos in total
# We will now process video:
# langsam_g_ch1_g15_compr.mp4
# This is video number 126 of 301 videos in total
# We will now process video:
# langsam_g_ch1_g16_compr.mp4
# This is video number 127 of 301 videos in total
# We will now process video:
# langsam_g_ch1_g17_compr.mp4
# This is video number 128 of 301 videos in total
# We will now process video:
# langsam_g_ch1_g18_compr.mp4
# This is video number 129 of 301 videos in total
# We will now process video:
# langsam_g_ch1_g19_compr.mp4
# This is video number 130 of 301 videos in total
# We will now process video:
# langsam_g_ch1_g1_compr.mp4
# This is video number 131 of 301 videos in total
# We will now process video:
# langsam_g_ch1_g20_compr.mp4
# This is video number 132 of 301 videos in total
# We will now process video:
# langsam_g_ch1_g2_compr.mp4
# This is video number 133 of 301 videos in total
# We will now process video:
# langsam_g_ch1_g3_compr.mp4
# This is video number 134 of 301 videos in total
# We will now process video:
# langsam_g_ch1_g4_compr.mp4
# This is video number 135 of 301 videos in total
# We will now process video:
# langsam_g_ch1_g5_compr.mp4
# This is video number 136 of 301 videos in total
# We will now process video:
# langsam_g_ch1_g6_compr.mp4
# This is video number 137 of 301 videos in total
# We will now process video:
# langsam_g_ch1_g7_compr.mp4
# This is video number 138 of 301 videos in total
# We will now process video:
# langsam_g_ch1_g8_compr.mp4
# This is video number 139 of 301 videos in total
# We will now process video:
# langsam_g_ch1_g9_compr.mp4
# This is video number 140 of 301 videos in total
# We will now process video:
# langsam_g_ch2_g10_compr.mp4
# This is video number 141 of 301 videos in total
# We will now process video:
# langsam_g_ch2_g11_compr.mp4
# This is video number 142 of 301 videos in total
# We will now process video:
# langsam_g_ch2_g12_compr.mp4
# This is video number 143 of 301 videos in total
# We will now process video:
# langsam_g_ch2_g13_compr.mp4
# This is video number 144 of 301 videos in total
# We will now process video:
# langsam_g_ch2_g14_compr.mp4
# This is video number 145 of 301 videos in total
# We will now process video:
# langsam_g_ch2_g15_compr.mp4
# This is video number 146 of 301 videos in total
# We will now process video:
# langsam_g_ch2_g16_compr.mp4
# This is video number 147 of 301 videos in total
# We will now process video:
# langsam_g_ch2_g17_compr.mp4
# This is video number 148 of 301 videos in total
# We will now process video:
# langsam_g_ch2_g18_compr.mp4
# This is video number 149 of 301 videos in total
# We will now process video:
# langsam_g_ch2_g19_compr.mp4
# This is video number 150 of 301 videos in total
# We will now process video:
# langsam_g_ch2_g1_compr.mp4
# This is video number 151 of 301 videos in total
# We will now process video:
# langsam_g_ch2_g20_compr.mp4
# This is video number 152 of 301 videos in total
# We will now process video:
# langsam_g_ch2_g2_compr.mp4
# This is video number 153 of 301 videos in total
# We will now process video:
# langsam_g_ch2_g3_compr.mp4
# This is video number 154 of 301 videos in total
# We will now process video:
# langsam_g_ch2_g4_compr.mp4
# This is video number 155 of 301 videos in total
# We will now process video:
# langsam_g_ch2_g5_compr.mp4
# This is video number 156 of 301 videos in total
# We will now process video:
# langsam_g_ch2_g6_compr.mp4
# This is video number 157 of 301 videos in total
# We will now process video:
# langsam_g_ch2_g7_compr.mp4
# This is video number 158 of 301 videos in total
# We will now process video:
# langsam_g_ch2_g8_compr.mp4
# This is video number 159 of 301 videos in total
# We will now process video:
# langsam_g_ch2_g9_compr.mp4
# This is video number 160 of 301 videos in total
# We will now process video:
# langsam_g_ch3_g10_compr.mp4
# This is video number 161 of 301 videos in total
# We will now process video:
# langsam_g_ch3_g11_compr.mp4
# This is video number 162 of 301 videos in total
# We will now process video:
# langsam_g_ch3_g12_compr.mp4
# This is video number 163 of 301 videos in total
# We will now process video:
# langsam_g_ch3_g13_compr.mp4
# This is video number 164 of 301 videos in total
# We will now process video:
# langsam_g_ch3_g14_compr.mp4
# This is video number 165 of 301 videos in total
# We will now process video:
# langsam_g_ch3_g15_compr.mp4
# This is video number 166 of 301 videos in total
# We will now process video:
# langsam_g_ch3_g16_compr.mp4
# This is video number 167 of 301 videos in total
# We will now process video:
# langsam_g_ch3_g17_compr.mp4
# This is video number 168 of 301 videos in total
# We will now process video:
# langsam_g_ch3_g18_compr.mp4
# This is video number 169 of 301 videos in total
# We will now process video:
# langsam_g_ch3_g19_compr.mp4
# This is video number 170 of 301 videos in total
# We will now process video:
# langsam_g_ch3_g1_compr.mp4
# This is video number 171 of 301 videos in total
# We will now process video:
# langsam_g_ch3_g20_compr.mp4
# This is video number 172 of 301 videos in total
# We will now process video:
# langsam_g_ch3_g2_compr.mp4
# This is video number 173 of 301 videos in total
# We will now process video:
# langsam_g_ch3_g3_compr.mp4
# This is video number 174 of 301 videos in total
# We will now process video:
# langsam_g_ch3_g4_compr.mp4
# This is video number 175 of 301 videos in total
# We will now process video:
# langsam_g_ch3_g5_compr.mp4
# This is video number 176 of 301 videos in total
# We will now process video:
# langsam_g_ch3_g6_compr.mp4
# This is video number 177 of 301 videos in total
# We will now process video:
# langsam_g_ch3_g7_compr.mp4
# This is video number 178 of 301 videos in total
# We will now process video:
# langsam_g_ch3_g8_compr.mp4
# This is video number 179 of 301 videos in total
# We will now process video:
# langsam_g_ch3_g9_compr.mp4
# This is video number 180 of 301 videos in total
# We will now process video:
# leise_g_ch1_g10_compr.mp4
# This is video number 181 of 301 videos in total
# We will now process video:
# leise_g_ch1_g11_compr.mp4
# This is video number 182 of 301 videos in total
# We will now process video:
# leise_g_ch1_g12_compr.mp4
# This is video number 183 of 301 videos in total
# We will now process video:
# leise_g_ch1_g13_compr.mp4
# This is video number 184 of 301 videos in total
# We will now process video:
# leise_g_ch1_g14_compr.mp4
# This is video number 185 of 301 videos in total
# We will now process video:
# leise_g_ch1_g15_compr.mp4
# This is video number 186 of 301 videos in total
# We will now process video:
# leise_g_ch1_g16_compr.mp4
# This is video number 187 of 301 videos in total
# We will now process video:
# leise_g_ch1_g17_compr.mp4
# This is video number 188 of 301 videos in total
# We will now process video:
# leise_g_ch1_g18_compr.mp4
# This is video number 189 of 301 videos in total
# We will now process video:
# leise_g_ch1_g19_compr.mp4
# This is video number 190 of 301 videos in total
# We will now process video:
# leise_g_ch1_g1_compr.mp4
# This is video number 191 of 301 videos in total
# We will now process video:
# leise_g_ch1_g20_compr.mp4
# This is video number 192 of 301 videos in total
# We will now process video:
# leise_g_ch1_g2_compr.mp4
# This is video number 193 of 301 videos in total
# We will now process video:
# leise_g_ch1_g3_compr.mp4
# This is video number 194 of 301 videos in total
# We will now process video:
# leise_g_ch1_g4_compr.mp4
# This is video number 195 of 301 videos in total
# We will now process video:
# leise_g_ch1_g5_compr.mp4
# This is video number 196 of 301 videos in total
# We will now process video:
# leise_g_ch1_g6_compr.mp4
# This is video number 197 of 301 videos in total
# We will now process video:
# leise_g_ch1_g7_compr.mp4
# This is video number 198 of 301 videos in total
# We will now process video:
# leise_g_ch1_g8_compr.mp4
# This is video number 199 of 301 videos in total
# We will now process video:
# leise_g_ch1_g9_compr.mp4
# This is video number 200 of 301 videos in total
# We will now process video:
# leise_g_ch2_g10_compr.mp4
# This is video number 201 of 301 videos in total
# We will now process video:
# leise_g_ch2_g11_compr.mp4
# This is video number 202 of 301 videos in total
# We will now process video:
# leise_g_ch2_g12_compr.mp4
# This is video number 203 of 301 videos in total
# We will now process video:
# leise_g_ch2_g13_compr.mp4
# This is video number 204 of 301 videos in total
# We will now process video:
# leise_g_ch2_g14_compr.mp4
# This is video number 205 of 301 videos in total
# We will now process video:
# leise_g_ch2_g15_compr.mp4
# This is video number 206 of 301 videos in total
# We will now process video:
# leise_g_ch2_g16_compr.mp4
# This is video number 207 of 301 videos in total
# We will now process video:
# leise_g_ch2_g17_compr.mp4
# This is video number 208 of 301 videos in total
# We will now process video:
# leise_g_ch2_g18_compr.mp4
# This is video number 209 of 301 videos in total
# We will now process video:
# leise_g_ch2_g19_compr.mp4
# This is video number 210 of 301 videos in total
# We will now process video:
# leise_g_ch2_g1_compr.mp4
# This is video number 211 of 301 videos in total
# We will now process video:
# leise_g_ch2_g20_compr.mp4
# This is video number 212 of 301 videos in total
# We will now process video:
# leise_g_ch2_g2_compr.mp4
# This is video number 213 of 301 videos in total
# We will now process video:
# leise_g_ch2_g3_compr.mp4
# This is video number 214 of 301 videos in total
# We will now process video:
# leise_g_ch2_g4_compr.mp4
# This is video number 215 of 301 videos in total
# We will now process video:
# leise_g_ch2_g5_compr.mp4
# This is video number 216 of 301 videos in total
# We will now process video:
# leise_g_ch2_g6_compr.mp4
# This is video number 217 of 301 videos in total
# We will now process video:
# leise_g_ch2_g7_compr.mp4
# This is video number 218 of 301 videos in total
# We will now process video:
# leise_g_ch2_g8_compr.mp4
# This is video number 219 of 301 videos in total
# We will now process video:
# leise_g_ch2_g9_compr.mp4
# This is video number 220 of 301 videos in total
# We will now process video:
# leise_g_ch3_g10_compr.mp4
# This is video number 221 of 301 videos in total
# We will now process video:
# leise_g_ch3_g11_compr.mp4
# This is video number 222 of 301 videos in total
# We will now process video:
# leise_g_ch3_g12_compr.mp4
# This is video number 223 of 301 videos in total
# We will now process video:
# leise_g_ch3_g13_compr.mp4
# This is video number 224 of 301 videos in total
# We will now process video:
# leise_g_ch3_g14_compr.mp4
# This is video number 225 of 301 videos in total
# We will now process video:
# leise_g_ch3_g15_compr.mp4
# This is video number 226 of 301 videos in total
# We will now process video:
# leise_g_ch3_g16_compr.mp4
# This is video number 227 of 301 videos in total
# We will now process video:
# leise_g_ch3_g17_compr.mp4
# This is video number 228 of 301 videos in total
# We will now process video:
# leise_g_ch3_g18_compr.mp4
# This is video number 229 of 301 videos in total
# We will now process video:
# leise_g_ch3_g19_compr.mp4
# This is video number 230 of 301 videos in total
# We will now process video:
# leise_g_ch3_g1_compr.mp4
# This is video number 231 of 301 videos in total
# We will now process video:
# leise_g_ch3_g20_compr.mp4
# This is video number 232 of 301 videos in total
# We will now process video:
# leise_g_ch3_g2_compr.mp4
# This is video number 233 of 301 videos in total
# We will now process video:
# leise_g_ch3_g3_compr.mp4
# This is video number 234 of 301 videos in total
# We will now process video:
# leise_g_ch3_g4_compr.mp4
# This is video number 235 of 301 videos in total
# We will now process video:
# leise_g_ch3_g5_compr.mp4
# This is video number 236 of 301 videos in total
# We will now process video:
# leise_g_ch3_g6_compr.mp4
# This is video number 237 of 301 videos in total
# We will now process video:
# leise_g_ch3_g7_compr.mp4
# This is video number 238 of 301 videos in total
# We will now process video:
# leise_g_ch3_g8_compr.mp4
# This is video number 239 of 301 videos in total
# We will now process video:
# leise_g_ch3_g9_compr.mp4
# This is video number 240 of 301 videos in total
# We will now process video:
# rennen_g_ch1_g10_compr.mp4
# This is video number 241 of 301 videos in total
# We will now process video:
# rennen_g_ch1_g11_compr.mp4
# This is video number 242 of 301 videos in total
# We will now process video:
# rennen_g_ch1_g12_compr.mp4
# This is video number 243 of 301 videos in total
# We will now process video:
# rennen_g_ch1_g13_compr.mp4
# This is video number 244 of 301 videos in total
# We will now process video:
# rennen_g_ch1_g14_compr.mp4
# This is video number 245 of 301 videos in total
# We will now process video:
# rennen_g_ch1_g15_compr.mp4
# This is video number 246 of 301 videos in total
# We will now process video:
# rennen_g_ch1_g16_compr.mp4
# This is video number 247 of 301 videos in total
# We will now process video:
# rennen_g_ch1_g17_compr.mp4
# This is video number 248 of 301 videos in total
# We will now process video:
# rennen_g_ch1_g18_compr.mp4
# This is video number 249 of 301 videos in total
# We will now process video:
# rennen_g_ch1_g19_compr.mp4
# This is video number 250 of 301 videos in total
# We will now process video:
# rennen_g_ch1_g1_compr.mp4
# This is video number 251 of 301 videos in total
# We will now process video:
# rennen_g_ch1_g20_compr.mp4
# This is video number 252 of 301 videos in total
# We will now process video:
# rennen_g_ch1_g2_compr.mp4
# This is video number 253 of 301 videos in total
# We will now process video:
# rennen_g_ch1_g3_compr.mp4
# This is video number 254 of 301 videos in total
# We will now process video:
# rennen_g_ch1_g4_compr.mp4
# This is video number 255 of 301 videos in total
# We will now process video:
# rennen_g_ch1_g5_compr.mp4
# This is video number 256 of 301 videos in total
# We will now process video:
# rennen_g_ch1_g6_compr.mp4
# This is video number 257 of 301 videos in total
# We will now process video:
# rennen_g_ch1_g7_compr.mp4
# This is video number 258 of 301 videos in total
# We will now process video:
# rennen_g_ch1_g8_compr.mp4
# This is video number 259 of 301 videos in total
# We will now process video:
# rennen_g_ch1_g9_compr.mp4
# This is video number 260 of 301 videos in total
# We will now process video:
# rennen_g_ch2_g10_compr.mp4
# This is video number 261 of 301 videos in total
# We will now process video:
# rennen_g_ch2_g11_compr.mp4
# This is video number 262 of 301 videos in total
# We will now process video:
# rennen_g_ch2_g12_compr.mp4
# This is video number 263 of 301 videos in total
# We will now process video:
# rennen_g_ch2_g13_compr.mp4
# This is video number 264 of 301 videos in total
# We will now process video:
# rennen_g_ch2_g14_compr.mp4
# This is video number 265 of 301 videos in total
# We will now process video:
# rennen_g_ch2_g15_compr.mp4
# This is video number 266 of 301 videos in total
# We will now process video:
# rennen_g_ch2_g16_compr.mp4
# This is video number 267 of 301 videos in total
# We will now process video:
# rennen_g_ch2_g17_compr.mp4
# This is video number 268 of 301 videos in total
# We will now process video:
# rennen_g_ch2_g18_compr.mp4
# This is video number 269 of 301 videos in total
# We will now process video:
# rennen_g_ch2_g19_compr.mp4
# This is video number 270 of 301 videos in total
# We will now process video:
# rennen_g_ch2_g1_compr.mp4
# This is video number 271 of 301 videos in total
# We will now process video:
# rennen_g_ch2_g20_compr.mp4
# This is video number 272 of 301 videos in total
# We will now process video:
# rennen_g_ch2_g2_compr.mp4
# This is video number 273 of 301 videos in total
# We will now process video:
# rennen_g_ch2_g3_compr.mp4
# This is video number 274 of 301 videos in total
# We will now process video:
# rennen_g_ch2_g4_compr.mp4
# This is video number 275 of 301 videos in total
# We will now process video:
# rennen_g_ch2_g5_compr.mp4
# This is video number 276 of 301 videos in total
# We will now process video:
# rennen_g_ch2_g6_compr.mp4
# This is video number 277 of 301 videos in total
# We will now process video:
# rennen_g_ch2_g7_compr.mp4
# This is video number 278 of 301 videos in total
# We will now process video:
# rennen_g_ch2_g8_compr.mp4
# This is video number 279 of 301 videos in total
# We will now process video:
# rennen_g_ch2_g9_compr.mp4
# This is video number 280 of 301 videos in total
# We will now process video:
# rennen_g_ch3_g10_compr.mp4
# This is video number 281 of 301 videos in total
# We will now process video:
# rennen_g_ch3_g11_compr.mp4
# This is video number 282 of 301 videos in total
# We will now process video:
# rennen_g_ch3_g12_compr.mp4
# This is video number 283 of 301 videos in total
# We will now process video:
# rennen_g_ch3_g13_compr.mp4
# This is video number 284 of 301 videos in total
# We will now process video:
# rennen_g_ch3_g14_compr.mp4
# This is video number 285 of 301 videos in total
# We will now process video:
# rennen_g_ch3_g15_compr.mp4
# This is video number 286 of 301 videos in total
# We will now process video:
# rennen_g_ch3_g16_compr.mp4
# This is video number 287 of 301 videos in total
# We will now process video:
# rennen_g_ch3_g17_compr.mp4
# This is video number 288 of 301 videos in total
# We will now process video:
# rennen_g_ch3_g18_compr.mp4
# This is video number 289 of 301 videos in total
# We will now process video:
# rennen_g_ch3_g19_compr.mp4
# This is video number 290 of 301 videos in total
# We will now process video:
# rennen_g_ch3_g1_compr.mp4
# This is video number 291 of 301 videos in total
# We will now process video:
# rennen_g_ch3_g20_compr.mp4
# This is video number 292 of 301 videos in total
# We will now process video:
# rennen_g_ch3_g2_compr.mp4
# This is video number 293 of 301 videos in total
# We will now process video:
# rennen_g_ch3_g3_compr.mp4
# This is video number 294 of 301 videos in total
# We will now process video:
# rennen_g_ch3_g4_compr.mp4
# This is video number 295 of 301 videos in total
# We will now process video:
# rennen_g_ch3_g5_compr.mp4
# This is video number 296 of 301 videos in total
# We will now process video:
# rennen_g_ch3_g6_compr.mp4
# This is video number 297 of 301 videos in total
# We will now process video:
# rennen_g_ch3_g7_compr.mp4
# This is video number 298 of 301 videos in total
# We will now process video:
# rennen_g_ch3_g8_compr.mp4
# This is video number 299 of 301 videos in total
# We will now process video:
# rennen_g_ch3_g9_compr.mp4
# This is video number 300 of 301 videos in total
# Done with processing all folders; go look in your output folders!

# %%
#### This is code without realworld landmarks

# do you want to apply masking?
masking = True             # We want masked videos 

#We will now loop over all the videos that are present in the video file
for vidf in vfiles:
    print("We will now process video:")
    print(vidf)
    print("This is video number" + str(vfiles.index(vidf))+ "of" + str(len(vfiles)) + "videos in total")
    #capture the video, and check video settings
    videoname = vidf
    videoloc = inputfol + videoname
    capture = cv2.VideoCapture(videoloc) #load in the videocapture
    frameWidth = capture.get(cv2.CAP_PROP_FRAME_WIDTH) #check frame width
    frameHeight = capture.get(cv2.CAP_PROP_FRAME_HEIGHT) #check frame height
    samplerate = capture.get(cv2.CAP_PROP_FPS)   #fps = frames per second

    #make an 'empty' video file where we project the pose tracking on
    fourcc = cv2.VideoWriter_fourcc(*'MP4V') #for different video formats you could use e.g., *'XVID'
    out = cv2.VideoWriter(outputf_mask+videoname, fourcc, 
                          fps = samplerate, frameSize = (int(frameWidth), int(frameHeight)))

    # Run MediaPipe frame by frame using Holistic with `enable_segmentation=True` to get pose segmentation.
    time = 0
    tsbody = [markerxyzbody]   #these will be your time series objects, which start with collumn names initialized above
    tshands = [markerxyzhands] #these will be your time series objects, which start with collumn names initialized above
    tsface = [markerxyzface]   #these will be your time series objects, which start with collumn names initialized above
    with mp_holistic.Holistic(
            static_image_mode=False, enable_segmentation=True, refine_face_landmarks=True) as holistic:
        while (True):
            ret, image = capture.read() #read frame
            if ret == True: #if there is a frame
                image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB) #make sure the image is in RGB format
                results = holistic.process(image) #apply Mediapipe holistic processing
                # Draw pose segmentation
                h, w, c = image.shape
                if  np.all(results.face_landmarks) != None: #check if there is a pose found
                    if masking == False:
                        original_image = cv2.cvtColor(image, cv2.COLOR_RGB2BGR)
                    if masking == True:
                        original_image = np.concatenate([image, np.full((h, w, 1), 255, dtype=np.uint8)], axis=-1)
                        mask_img = np.zeros_like(image, dtype=np.uint8) #set up basic mask image
                        mask_img[:, :] = (255,255,255) #set up basic mask image
                        segm_2class = 0.2 + 0.8 * results.segmentation_mask #set up a segmentation of the results of mediapipe
                        segm_2class = np.repeat(segm_2class[..., np.newaxis], 3, axis=2) #set up a segmentation of the results of mediapipe
                        annotated_image = mask_img * segm_2class * (1 - segm_2class) #take the basic mask image and make a sillhouette mask
                        # append Alpha channel to sillhouetted mask so that we can overlay it to the original image
                        mask = np.concatenate([annotated_image, np.full((h, w, 1), 255, dtype=np.uint8)], axis=-1)
                        # Zero background where we want to overlay
                        original_image[mask==0]=0 #for the original image we are going to set everything at zero for places where the mask has to go
                        original_image = cv2.cvtColor(original_image, cv2.COLOR_RGB2BGR)
                    #now lets draw on the original_image the left and right hand landmarks, the facemesh and the body poses
                        #left hand
                    mp_drawing.draw_landmarks(original_image, results.left_hand_landmarks, mp_holistic.HAND_CONNECTIONS)
                        #right hand
                    mp_drawing.draw_landmarks(original_image, results.right_hand_landmarks, mp_holistic.HAND_CONNECTIONS)
                        #face
                    mp_drawing.draw_landmarks(
                            original_image,
                            results.face_landmarks,
                            mp_holistic.FACEMESH_TESSELATION,
                            landmark_drawing_spec=None,
                            connection_drawing_spec=mp_drawing_styles
                            .get_default_face_mesh_tesselation_style())
                        #body
                    mp_drawing.draw_landmarks(
                            original_image,
                            results.pose_landmarks,
                            mp_holistic.POSE_CONNECTIONS,
                            landmark_drawing_spec=mp_drawing_styles.
                            get_default_pose_landmarks_style())
                    #######################now save everything to a time series
                        #make a variable list with x, y, z, info where data is appended to
                    samplebody = listpostions(results.pose_landmarks)
                    samplehands = listpostions([results.left_hand_landmarks, results.right_hand_landmarks])
                    sampleface = listpostions(results.face_landmarks)
                    samplebody.insert(0, time)
                    samplehands.insert(0, time)
                    sampleface.insert(0, time)
                    tsbody.append(samplebody)   #append to the timeseries object
                    tshands.append(samplehands) #append to the timeseries object
                    tsface.append(sampleface)   #append to the timeseries object
                #show the video as we process
                if np.all(results.face_landmarks) == None:
                    original_image = cv2.cvtColor(image, cv2.COLOR_RGB2BGR)
                    # add empy row of DATA NA
                    samplebody = [np.nan for x in range(len(markerxyzbody)-1)]
                    samplehands = [np.nan for x in range(len(markerxyzhands)-1)]
                    sampleface = [np.nan for x in range(len(markerxyzface)-1)]
                    samplebody.insert(0, time)
                    samplehands.insert(0, time)
                    sampleface.insert(0, time)
                    tsbody.append(samplebody)   #append to the timeseries object
                    tshands.append(samplehands) #append to the timeseries object
                    tsface.append(sampleface)   #append to the timeseries object
                #show the video as we process (you can comment this out, if you want to run this process in the background)
                cv2.imshow("resizedimage", original_image)
                out.write(original_image) #save the frame to the new masked video
                time = time+(1000/samplerate)#update the time variable  for the next frame
            if cv2.waitKey(1) == 27: #allow the use of ESCAPE to break the loop
                   break
            if ret == False: #if there are no more frames, break the loop
                break

    #once done de-initialize all processes
    out.release()
    capture.release()
    cv2.destroyAllWindows()
     ####################################################### data to be written row-wise in csv fil
    # opening the csv file in 'w+' mode
    filebody = open(outtputf_ts + vidf[:-4]+'_body.csv', 'w+', newline ='')
    #write it
    with filebody:    
        write = csv.writer(filebody)
        write.writerows(tsbody)
     # opening the csv file in 'w+' mode
    filehands = open(outtputf_ts + vidf[:-4]+'_hands.csv', 'w+', newline ='')
    #write it
    with filehands:
        write = csv.writer(filehands)
        write.writerows(tshands)
    # opening the csv file in 'w+' mode
    fileface = open(outtputf_ts + vidf[:-4]+'_face.csv', 'w+', newline ='')
    #write it
    with fileface:    
        write = csv.writer(fileface)
        write.writerows(tsface)

print("Done with processing all folders; go look in your output folders!")
# Out:
# We will now process video:
# Donner_g_ch1_g10_compr_clean.mp4
# This is video number0of300videos in total
# c:\Users\kadava\AppData\Local\anaconda3\envs\IteratedLearning\Lib\site-packages\google\protobuf\symbol_database.py:55: UserWarning: SymbolDatabase.GetPrototype() is deprecated. Please use message_factory.GetMessageClass() instead. SymbolDatabase.GetPrototype() will be removed soon.
#   warnings.warn('SymbolDatabase.GetPrototype() is deprecated. Please '
# We will now process video:
# Donner_g_ch1_g11_compr_clean.mp4
# This is video number1of300videos in total
# We will now process video:
# Donner_g_ch1_g12_compr_clean.mp4
# This is video number2of300videos in total
# We will now process video:
# Donner_g_ch1_g13_compr_clean.mp4
# This is video number3of300videos in total
# We will now process video:
# Donner_g_ch1_g14_compr_clean.mp4
# This is video number4of300videos in total
# We will now process video:
# Donner_g_ch1_g15_compr_clean.mp4
# This is video number5of300videos in total
# We will now process video:
# Donner_g_ch1_g16_compr_clean.mp4
# This is video number6of300videos in total
# We will now process video:
# Donner_g_ch1_g17_compr_clean.mp4
# This is video number7of300videos in total
# We will now process video:
# Donner_g_ch1_g18_compr_clean.mp4
# This is video number8of300videos in total
# We will now process video:
# Donner_g_ch1_g19_compr_clean.mp4
# This is video number9of300videos in total
# We will now process video:
# Donner_g_ch1_g1_compr_clean.mp4
# This is video number10of300videos in total
# We will now process video:
# Donner_g_ch1_g20_compr_clean.mp4
# This is video number11of300videos in total
# We will now process video:
# Donner_g_ch1_g2_compr_clean.mp4
# This is video number12of300videos in total
# We will now process video:
# Donner_g_ch1_g3_compr_clean.mp4
# This is video number13of300videos in total
# We will now process video:
# Donner_g_ch1_g4_compr_clean.mp4
# This is video number14of300videos in total
# We will now process video:
# Donner_g_ch1_g5_compr_clean.mp4
# This is video number15of300videos in total
# We will now process video:
# Donner_g_ch1_g6_compr_clean.mp4
# This is video number16of300videos in total
# We will now process video:
# Donner_g_ch1_g7_compr_clean.mp4
# This is video number17of300videos in total
# We will now process video:
# Donner_g_ch1_g8_compr_clean.mp4
# This is video number18of300videos in total
# We will now process video:
# Donner_g_ch1_g9_compr_clean.mp4
# This is video number19of300videos in total
# We will now process video:
# Donner_g_ch2_g10_compr_clean.mp4
# This is video number20of300videos in total
# We will now process video:
# Donner_g_ch2_g11_compr_clean.mp4
# This is video number21of300videos in total
# We will now process video:
# Donner_g_ch2_g12_compr_clean.mp4
# This is video number22of300videos in total
# We will now process video:
# Donner_g_ch2_g13_compr_clean.mp4
# This is video number23of300videos in total
# We will now process video:
# Donner_g_ch2_g14_compr_clean.mp4
# This is video number24of300videos in total
# We will now process video:
# Donner_g_ch2_g15_compr_clean.mp4
# This is video number25of300videos in total
# We will now process video:
# Donner_g_ch2_g16_compr_clean.mp4
# This is video number26of300videos in total
# We will now process video:
# Donner_g_ch2_g17_compr_clean.mp4
# This is video number27of300videos in total
# We will now process video:
# Donner_g_ch2_g18_compr_clean.mp4
# This is video number28of300videos in total
# We will now process video:
# Donner_g_ch2_g19_compr_clean.mp4
# This is video number29of300videos in total
# We will now process video:
# Donner_g_ch2_g1_compr_clean.mp4
# This is video number30of300videos in total
# We will now process video:
# Donner_g_ch2_g20_compr_clean.mp4
# This is video number31of300videos in total
# We will now process video:
# Donner_g_ch2_g2_compr_clean.mp4
# This is video number32of300videos in total
# We will now process video:
# Donner_g_ch2_g3_compr_clean.mp4
# This is video number33of300videos in total
# We will now process video:
# Donner_g_ch2_g4_compr_clean.mp4
# This is video number34of300videos in total
# We will now process video:
# Donner_g_ch2_g5_compr_clean.mp4
# This is video number35of300videos in total
# We will now process video:
# Donner_g_ch2_g6_compr_clean.mp4
# This is video number36of300videos in total
# We will now process video:
# Donner_g_ch2_g7_compr_clean.mp4
# This is video number37of300videos in total
# We will now process video:
# Donner_g_ch2_g8_compr_clean.mp4
# This is video number38of300videos in total
# We will now process video:
# Donner_g_ch2_g9_compr_clean.mp4
# This is video number39of300videos in total
# We will now process video:
# Donner_g_ch3_g10_compr_clean.mp4
# This is video number40of300videos in total
# We will now process video:
# Donner_g_ch3_g11_compr_clean.mp4
# This is video number41of300videos in total
# We will now process video:
# Donner_g_ch3_g12_compr_clean.mp4
# This is video number42of300videos in total
# We will now process video:
# Donner_g_ch3_g13_compr_clean.mp4
# This is video number43of300videos in total
# We will now process video:
# Donner_g_ch3_g14_compr_clean.mp4
# This is video number44of300videos in total
# We will now process video:
# Donner_g_ch3_g15_compr_clean.mp4
# This is video number45of300videos in total
# We will now process video:
# Donner_g_ch3_g16_compr_clean.mp4
# This is video number46of300videos in total
# We will now process video:
# Donner_g_ch3_g17_compr_clean.mp4
# This is video number47of300videos in total
# We will now process video:
# Donner_g_ch3_g18_compr_clean.mp4
# This is video number48of300videos in total
# We will now process video:
# Donner_g_ch3_g19_compr_clean.mp4
# This is video number49of300videos in total
# We will now process video:
# Donner_g_ch3_g1_compr_clean.mp4
# This is video number50of300videos in total
# We will now process video:
# Donner_g_ch3_g20_compr_clean.mp4
# This is video number51of300videos in total
# We will now process video:
# Donner_g_ch3_g2_compr_clean.mp4
# This is video number52of300videos in total
# We will now process video:
# Donner_g_ch3_g3_compr_clean.mp4
# This is video number53of300videos in total
# We will now process video:
# Donner_g_ch3_g4_compr_clean.mp4
# This is video number54of300videos in total
# We will now process video:
# Donner_g_ch3_g5_compr_clean.mp4
# This is video number55of300videos in total
# We will now process video:
# Donner_g_ch3_g6_compr_clean.mp4
# This is video number56of300videos in total
# We will now process video:
# Donner_g_ch3_g7_compr_clean.mp4
# This is video number57of300videos in total
# We will now process video:
# Donner_g_ch3_g8_compr_clean.mp4
# This is video number58of300videos in total
# We will now process video:
# Donner_g_ch3_g9_compr_clean.mp4
# This is video number59of300videos in total
# We will now process video:
# kalt_g_ch1_g10_compr_clean.mp4
# This is video number60of300videos in total
# We will now process video:
# kalt_g_ch1_g11_compr_clean.mp4
# This is video number61of300videos in total
# We will now process video:
# kalt_g_ch1_g12_compr_clean.mp4
# This is video number62of300videos in total
# We will now process video:
# kalt_g_ch1_g13_compr_clean.mp4
# This is video number63of300videos in total
# We will now process video:
# kalt_g_ch1_g14_compr_clean.mp4
# This is video number64of300videos in total
# We will now process video:
# kalt_g_ch1_g15_compr_clean.mp4
# This is video number65of300videos in total
# We will now process video:
# kalt_g_ch1_g16_compr_clean.mp4
# This is video number66of300videos in total
# We will now process video:
# kalt_g_ch1_g17_compr_clean.mp4
# This is video number67of300videos in total
# We will now process video:
# kalt_g_ch1_g18_compr_clean.mp4
# This is video number68of300videos in total
# We will now process video:
# kalt_g_ch1_g19_compr_clean.mp4
# This is video number69of300videos in total
# We will now process video:
# kalt_g_ch1_g1_compr_clean.mp4
# This is video number70of300videos in total
# We will now process video:
# kalt_g_ch1_g20_compr_clean.mp4
# This is video number71of300videos in total
# We will now process video:
# kalt_g_ch1_g2_compr_clean.mp4
# This is video number72of300videos in total
# We will now process video:
# kalt_g_ch1_g3_compr_clean.mp4
# This is video number73of300videos in total
# We will now process video:
# kalt_g_ch1_g4_compr_clean.mp4
# This is video number74of300videos in total
# We will now process video:
# kalt_g_ch1_g5_compr_clean.mp4
# This is video number75of300videos in total
# We will now process video:
# kalt_g_ch1_g6_compr_clean.mp4
# This is video number76of300videos in total
# We will now process video:
# kalt_g_ch1_g7_compr_clean.mp4
# This is video number77of300videos in total
# We will now process video:
# kalt_g_ch1_g8_compr_clean.mp4
# This is video number78of300videos in total
# We will now process video:
# kalt_g_ch1_g9_compr_clean.mp4
# This is video number79of300videos in total
# We will now process video:
# kalt_g_ch2_g10_compr_clean.mp4
# This is video number80of300videos in total
# We will now process video:
# kalt_g_ch2_g11_compr_clean.mp4
# This is video number81of300videos in total
# We will now process video:
# kalt_g_ch2_g12_compr_clean.mp4
# This is video number82of300videos in total
# We will now process video:
# kalt_g_ch2_g13_compr_clean.mp4
# This is video number83of300videos in total
# We will now process video:
# kalt_g_ch2_g14_compr_clean.mp4
# This is video number84of300videos in total
# We will now process video:
# kalt_g_ch2_g15_compr_clean.mp4
# This is video number85of300videos in total
# We will now process video:
# kalt_g_ch2_g16_compr_clean.mp4
# This is video number86of300videos in total
# We will now process video:
# kalt_g_ch2_g17_compr_clean.mp4
# This is video number87of300videos in total
# We will now process video:
# kalt_g_ch2_g18_compr_clean.mp4
# This is video number88of300videos in total
# We will now process video:
# kalt_g_ch2_g19_compr_clean.mp4
# This is video number89of300videos in total
# We will now process video:
# kalt_g_ch2_g1_compr_clean.mp4
# This is video number90of300videos in total
# We will now process video:
# kalt_g_ch2_g20_compr_clean.mp4
# This is video number91of300videos in total
# We will now process video:
# kalt_g_ch2_g2_compr_clean.mp4
# This is video number92of300videos in total
# We will now process video:
# kalt_g_ch2_g3_compr_clean.mp4
# This is video number93of300videos in total
# We will now process video:
# kalt_g_ch2_g4_compr_clean.mp4
# This is video number94of300videos in total
# We will now process video:
# kalt_g_ch2_g5_compr_clean.mp4
# This is video number95of300videos in total
# We will now process video:
# kalt_g_ch2_g6_compr_clean.mp4
# This is video number96of300videos in total
# We will now process video:
# kalt_g_ch2_g7_compr_clean.mp4
# This is video number97of300videos in total
# We will now process video:
# kalt_g_ch2_g8_compr_clean.mp4
# This is video number98of300videos in total
# We will now process video:
# kalt_g_ch2_g9_compr_clean.mp4
# This is video number99of300videos in total
# We will now process video:
# kalt_g_ch3_g10_compr_clean.mp4
# This is video number100of300videos in total
# We will now process video:
# kalt_g_ch3_g11_compr_clean.mp4
# This is video number101of300videos in total
# We will now process video:
# kalt_g_ch3_g12_compr_clean.mp4
# This is video number102of300videos in total
# We will now process video:
# kalt_g_ch3_g13_compr_clean.mp4
# This is video number103of300videos in total
# We will now process video:
# kalt_g_ch3_g14_compr_clean.mp4
# This is video number104of300videos in total
# We will now process video:
# kalt_g_ch3_g15_compr_clean.mp4
# This is video number105of300videos in total
# We will now process video:
# kalt_g_ch3_g16_compr_clean.mp4
# This is video number106of300videos in total
# We will now process video:
# kalt_g_ch3_g17_compr_clean.mp4
# This is video number107of300videos in total
# We will now process video:
# kalt_g_ch3_g18_compr_clean.mp4
# This is video number108of300videos in total
# We will now process video:
# kalt_g_ch3_g19_compr_clean.mp4
# This is video number109of300videos in total
# We will now process video:
# kalt_g_ch3_g1_compr_clean.mp4
# This is video number110of300videos in total
# We will now process video:
# kalt_g_ch3_g20_compr_clean.mp4
# This is video number111of300videos in total
# We will now process video:
# kalt_g_ch3_g2_compr_clean.mp4
# This is video number112of300videos in total
# We will now process video:
# kalt_g_ch3_g3_compr_clean.mp4
# This is video number113of300videos in total
# We will now process video:
# kalt_g_ch3_g4_compr_clean.mp4
# This is video number114of300videos in total
# We will now process video:
# kalt_g_ch3_g5_compr_clean.mp4
# This is video number115of300videos in total
# We will now process video:
# kalt_g_ch3_g6_compr_clean.mp4
# This is video number116of300videos in total
# We will now process video:
# kalt_g_ch3_g7_compr_clean.mp4
# This is video number117of300videos in total
# We will now process video:
# kalt_g_ch3_g8_compr_clean.mp4
# This is video number118of300videos in total
# We will now process video:
# kalt_g_ch3_g9_compr_clean.mp4
# This is video number119of300videos in total
# We will now process video:
# langsam_g_ch1_g10_compr_clean.mp4
# This is video number120of300videos in total
# We will now process video:
# langsam_g_ch1_g11_compr_clean.mp4
# This is video number121of300videos in total
# We will now process video:
# langsam_g_ch1_g12_compr_clean.mp4
# This is video number122of300videos in total
# We will now process video:
# langsam_g_ch1_g13_compr_clean.mp4
# This is video number123of300videos in total
# We will now process video:
# langsam_g_ch1_g14_compr_clean.mp4
# This is video number124of300videos in total
# We will now process video:
# langsam_g_ch1_g15_compr_clean.mp4
# This is video number125of300videos in total
# We will now process video:
# langsam_g_ch1_g16_compr_clean.mp4
# This is video number126of300videos in total
# We will now process video:
# langsam_g_ch1_g17_compr_clean.mp4
# This is video number127of300videos in total
# We will now process video:
# langsam_g_ch1_g18_compr_clean.mp4
# This is video number128of300videos in total
# We will now process video:
# langsam_g_ch1_g19_compr_clean.mp4
# This is video number129of300videos in total
# We will now process video:
# langsam_g_ch1_g1_compr_clean.mp4
# This is video number130of300videos in total
# We will now process video:
# langsam_g_ch1_g20_compr_clean.mp4
# This is video number131of300videos in total
# We will now process video:
# langsam_g_ch1_g2_compr_clean.mp4
# This is video number132of300videos in total
# We will now process video:
# langsam_g_ch1_g3_compr_clean.mp4
# This is video number133of300videos in total
# We will now process video:
# langsam_g_ch1_g4_compr_clean.mp4
# This is video number134of300videos in total
# We will now process video:
# langsam_g_ch1_g5_compr_clean.mp4
# This is video number135of300videos in total
# We will now process video:
# langsam_g_ch1_g6_compr_clean.mp4
# This is video number136of300videos in total
# We will now process video:
# langsam_g_ch1_g7_compr_clean.mp4
# This is video number137of300videos in total
# We will now process video:
# langsam_g_ch1_g8_compr_clean.mp4
# This is video number138of300videos in total
# We will now process video:
# langsam_g_ch1_g9_compr_clean.mp4
# This is video number139of300videos in total
# We will now process video:
# langsam_g_ch2_g10_compr_clean.mp4
# This is video number140of300videos in total
# We will now process video:
# langsam_g_ch2_g11_compr_clean.mp4
# This is video number141of300videos in total
# We will now process video:
# langsam_g_ch2_g12_compr_clean.mp4
# This is video number142of300videos in total
# We will now process video:
# langsam_g_ch2_g13_compr_clean.mp4
# This is video number143of300videos in total
# We will now process video:
# langsam_g_ch2_g14_compr_clean.mp4
# This is video number144of300videos in total
# We will now process video:
# langsam_g_ch2_g15_compr_clean.mp4
# This is video number145of300videos in total
# We will now process video:
# langsam_g_ch2_g16_compr_clean.mp4
# This is video number146of300videos in total
# We will now process video:
# langsam_g_ch2_g17_compr_clean.mp4
# This is video number147of300videos in total
# We will now process video:
# langsam_g_ch2_g18_compr_clean.mp4
# This is video number148of300videos in total
# We will now process video:
# langsam_g_ch2_g19_compr_clean.mp4
# This is video number149of300videos in total
# We will now process video:
# langsam_g_ch2_g1_compr_clean.mp4
# This is video number150of300videos in total
# We will now process video:
# langsam_g_ch2_g20_compr_clean.mp4
# This is video number151of300videos in total
# We will now process video:
# langsam_g_ch2_g2_compr_clean.mp4
# This is video number152of300videos in total
# We will now process video:
# langsam_g_ch2_g3_compr_clean.mp4
# This is video number153of300videos in total
# We will now process video:
# langsam_g_ch2_g4_compr_clean.mp4
# This is video number154of300videos in total
# We will now process video:
# langsam_g_ch2_g5_compr_clean.mp4
# This is video number155of300videos in total
# We will now process video:
# langsam_g_ch2_g6_compr_clean.mp4
# This is video number156of300videos in total
# We will now process video:
# langsam_g_ch2_g7_compr_clean.mp4
# This is video number157of300videos in total
# We will now process video:
# langsam_g_ch2_g8_compr_clean.mp4
# This is video number158of300videos in total
# We will now process video:
# langsam_g_ch2_g9_compr_clean.mp4
# This is video number159of300videos in total
# We will now process video:
# langsam_g_ch3_g10_compr_clean.mp4
# This is video number160of300videos in total
# We will now process video:
# langsam_g_ch3_g11_compr_clean.mp4
# This is video number161of300videos in total
# We will now process video:
# langsam_g_ch3_g12_compr_clean.mp4
# This is video number162of300videos in total
# We will now process video:
# langsam_g_ch3_g13_compr_clean.mp4
# This is video number163of300videos in total
# We will now process video:
# langsam_g_ch3_g14_compr_clean.mp4
# This is video number164of300videos in total
# We will now process video:
# langsam_g_ch3_g15_compr_clean.mp4
# This is video number165of300videos in total
# We will now process video:
# langsam_g_ch3_g16_compr_clean.mp4
# This is video number166of300videos in total
# We will now process video:
# langsam_g_ch3_g17_compr_clean.mp4
# This is video number167of300videos in total
# We will now process video:
# langsam_g_ch3_g18_compr_clean.mp4
# This is video number168of300videos in total
# We will now process video:
# langsam_g_ch3_g19_compr_clean.mp4
# This is video number169of300videos in total
# We will now process video:
# langsam_g_ch3_g1_compr_clean.mp4
# This is video number170of300videos in total
# We will now process video:
# langsam_g_ch3_g20_compr_clean.mp4
# This is video number171of300videos in total
# We will now process video:
# langsam_g_ch3_g2_compr_clean.mp4
# This is video number172of300videos in total
# We will now process video:
# langsam_g_ch3_g3_compr_clean.mp4
# This is video number173of300videos in total
# We will now process video:
# langsam_g_ch3_g4_compr_clean.mp4
# This is video number174of300videos in total
# We will now process video:
# langsam_g_ch3_g5_compr_clean.mp4
# This is video number175of300videos in total
# We will now process video:
# langsam_g_ch3_g6_compr_clean.mp4
# This is video number176of300videos in total
# We will now process video:
# langsam_g_ch3_g7_compr_clean.mp4
# This is video number177of300videos in total
# We will now process video:
# langsam_g_ch3_g8_compr_clean.mp4
# This is video number178of300videos in total
# We will now process video:
# langsam_g_ch3_g9_compr_clean.mp4
# This is video number179of300videos in total
# We will now process video:
# leise_g_ch1_g10_compr_clean.mp4
# This is video number180of300videos in total
# We will now process video:
# leise_g_ch1_g11_compr_clean.mp4
# This is video number181of300videos in total
# We will now process video:
# leise_g_ch1_g12_compr_clean.mp4
# This is video number182of300videos in total
# We will now process video:
# leise_g_ch1_g13_compr_clean.mp4
# This is video number183of300videos in total
# We will now process video:
# leise_g_ch1_g14_compr_clean.mp4
# This is video number184of300videos in total
# We will now process video:
# leise_g_ch1_g15_compr_clean.mp4
# This is video number185of300videos in total
# We will now process video:
# leise_g_ch1_g16_compr_clean.mp4
# This is video number186of300videos in total
# We will now process video:
# leise_g_ch1_g17_compr_clean.mp4
# This is video number187of300videos in total
# We will now process video:
# leise_g_ch1_g18_compr_clean.mp4
# This is video number188of300videos in total
# We will now process video:
# leise_g_ch1_g19_compr_clean.mp4
# This is video number189of300videos in total
# We will now process video:
# leise_g_ch1_g1_compr_clean.mp4
# This is video number190of300videos in total
# We will now process video:
# leise_g_ch1_g20_compr_clean.mp4
# This is video number191of300videos in total
# We will now process video:
# leise_g_ch1_g2_compr_clean.mp4
# This is video number192of300videos in total
# We will now process video:
# leise_g_ch1_g3_compr_clean.mp4
# This is video number193of300videos in total
# We will now process video:
# leise_g_ch1_g4_compr_clean.mp4
# This is video number194of300videos in total
# We will now process video:
# leise_g_ch1_g5_compr_clean.mp4
# This is video number195of300videos in total
# We will now process video:
# leise_g_ch1_g6_compr_clean.mp4
# This is video number196of300videos in total
# We will now process video:
# leise_g_ch1_g7_compr_clean.mp4
# This is video number197of300videos in total
# We will now process video:
# leise_g_ch1_g8_compr_clean.mp4
# This is video number198of300videos in total
# We will now process video:
# leise_g_ch1_g9_compr_clean.mp4
# This is video number199of300videos in total
# We will now process video:
# leise_g_ch2_g10_compr_clean.mp4
# This is video number200of300videos in total
# We will now process video:
# leise_g_ch2_g11_compr_clean.mp4
# This is video number201of300videos in total
# We will now process video:
# leise_g_ch2_g12_compr_clean.mp4
# This is video number202of300videos in total
# We will now process video:
# leise_g_ch2_g13_compr_clean.mp4
# This is video number203of300videos in total
# We will now process video:
# leise_g_ch2_g14_compr_clean.mp4
# This is video number204of300videos in total
# We will now process video:
# leise_g_ch2_g15_compr_clean.mp4
# This is video number205of300videos in total
# We will now process video:
# leise_g_ch2_g16_compr_clean.mp4
# This is video number206of300videos in total
# We will now process video:
# leise_g_ch2_g17_compr_clean.mp4
# This is video number207of300videos in total
# We will now process video:
# leise_g_ch2_g18_compr_clean.mp4
# This is video number208of300videos in total
# We will now process video:
# leise_g_ch2_g19_compr_clean.mp4
# This is video number209of300videos in total
# We will now process video:
# leise_g_ch2_g1_compr_clean.mp4
# This is video number210of300videos in total
# We will now process video:
# leise_g_ch2_g20_compr_clean.mp4
# This is video number211of300videos in total
# We will now process video:
# leise_g_ch2_g2_compr_clean.mp4
# This is video number212of300videos in total
# We will now process video:
# leise_g_ch2_g3_compr_clean.mp4
# This is video number213of300videos in total
# We will now process video:
# leise_g_ch2_g4_compr_clean.mp4
# This is video number214of300videos in total
# We will now process video:
# leise_g_ch2_g5_compr_clean.mp4
# This is video number215of300videos in total
# We will now process video:
# leise_g_ch2_g6_compr_clean.mp4
# This is video number216of300videos in total
# We will now process video:
# leise_g_ch2_g7_compr_clean.mp4
# This is video number217of300videos in total
# We will now process video:
# leise_g_ch2_g8_compr_clean.mp4
# This is video number218of300videos in total
# We will now process video:
# leise_g_ch2_g9_compr_clean.mp4
# This is video number219of300videos in total
# We will now process video:
# leise_g_ch3_g10_compr_clean.mp4
# This is video number220of300videos in total
# We will now process video:
# leise_g_ch3_g11_compr_clean.mp4
# This is video number221of300videos in total
# We will now process video:
# leise_g_ch3_g12_compr_clean.mp4
# This is video number222of300videos in total
# We will now process video:
# leise_g_ch3_g13_compr_clean.mp4
# This is video number223of300videos in total
# We will now process video:
# leise_g_ch3_g14_compr_clean.mp4
# This is video number224of300videos in total
# We will now process video:
# leise_g_ch3_g15_compr_clean.mp4
# This is video number225of300videos in total
# We will now process video:
# leise_g_ch3_g16_compr_clean.mp4
# This is video number226of300videos in total
# We will now process video:
# leise_g_ch3_g17_compr_clean.mp4
# This is video number227of300videos in total
# We will now process video:
# leise_g_ch3_g18_compr_clean.mp4
# This is video number228of300videos in total
# We will now process video:
# leise_g_ch3_g19_compr_clean.mp4
# This is video number229of300videos in total
# We will now process video:
# leise_g_ch3_g1_compr_clean.mp4
# This is video number230of300videos in total
# We will now process video:
# leise_g_ch3_g20_compr_clean.mp4
# This is video number231of300videos in total
# We will now process video:
# leise_g_ch3_g2_compr_clean.mp4
# This is video number232of300videos in total
# We will now process video:
# leise_g_ch3_g3_compr_clean.mp4
# This is video number233of300videos in total
# We will now process video:
# leise_g_ch3_g4_compr_clean.mp4
# This is video number234of300videos in total
# We will now process video:
# leise_g_ch3_g5_compr_clean.mp4
# This is video number235of300videos in total
# We will now process video:
# leise_g_ch3_g6_compr_clean.mp4
# This is video number236of300videos in total
# We will now process video:
# leise_g_ch3_g7_compr_clean.mp4
# This is video number237of300videos in total
# We will now process video:
# leise_g_ch3_g8_compr_clean.mp4
# This is video number238of300videos in total
# We will now process video:
# leise_g_ch3_g9_compr_clean.mp4
# This is video number239of300videos in total
# We will now process video:
# rennen_g_ch1_g10_compr_clean.mp4
# This is video number240of300videos in total
# We will now process video:
# rennen_g_ch1_g11_compr_clean.mp4
# This is video number241of300videos in total
# We will now process video:
# rennen_g_ch1_g12_compr_clean.mp4
# This is video number242of300videos in total
# We will now process video:
# rennen_g_ch1_g13_compr_clean.mp4
# This is video number243of300videos in total
# We will now process video:
# rennen_g_ch1_g14_compr_clean.mp4
# This is video number244of300videos in total
# We will now process video:
# rennen_g_ch1_g15_compr_clean.mp4
# This is video number245of300videos in total
# We will now process video:
# rennen_g_ch1_g16_compr_clean.mp4
# This is video number246of300videos in total
# We will now process video:
# rennen_g_ch1_g17_compr_clean.mp4
# This is video number247of300videos in total
# We will now process video:
# rennen_g_ch1_g18_compr_clean.mp4
# This is video number248of300videos in total
# We will now process video:
# rennen_g_ch1_g19_compr_clean.mp4
# This is video number249of300videos in total
# We will now process video:
# rennen_g_ch1_g1_compr_clean.mp4
# This is video number250of300videos in total
# We will now process video:
# rennen_g_ch1_g20_compr_clean.mp4
# This is video number251of300videos in total
# We will now process video:
# rennen_g_ch1_g2_compr_clean.mp4
# This is video number252of300videos in total
# We will now process video:
# rennen_g_ch1_g3_compr_clean.mp4
# This is video number253of300videos in total
# We will now process video:
# rennen_g_ch1_g4_compr_clean.mp4
# This is video number254of300videos in total
# We will now process video:
# rennen_g_ch1_g5_compr_clean.mp4
# This is video number255of300videos in total
# We will now process video:
# rennen_g_ch1_g6_compr_clean.mp4
# This is video number256of300videos in total
# We will now process video:
# rennen_g_ch1_g7_compr_clean.mp4
# This is video number257of300videos in total
# We will now process video:
# rennen_g_ch1_g8_compr_clean.mp4
# This is video number258of300videos in total
# We will now process video:
# rennen_g_ch1_g9_compr_clean.mp4
# This is video number259of300videos in total
# We will now process video:
# rennen_g_ch2_g10_compr_clean.mp4
# This is video number260of300videos in total
# We will now process video:
# rennen_g_ch2_g11_compr_clean.mp4
# This is video number261of300videos in total
# We will now process video:
# rennen_g_ch2_g12_compr_clean.mp4
# This is video number262of300videos in total
# We will now process video:
# rennen_g_ch2_g13_compr_clean.mp4
# This is video number263of300videos in total
# We will now process video:
# rennen_g_ch2_g14_compr_clean.mp4
# This is video number264of300videos in total
# We will now process video:
# rennen_g_ch2_g15_compr_clean.mp4
# This is video number265of300videos in total
# We will now process video:
# rennen_g_ch2_g16_compr_clean.mp4
# This is video number266of300videos in total
# We will now process video:
# rennen_g_ch2_g17_compr_clean.mp4
# This is video number267of300videos in total
# We will now process video:
# rennen_g_ch2_g18_compr_clean.mp4
# This is video number268of300videos in total
# We will now process video:
# rennen_g_ch2_g19_compr_clean.mp4
# This is video number269of300videos in total
# We will now process video:
# rennen_g_ch2_g1_compr_clean.mp4
# This is video number270of300videos in total
# We will now process video:
# rennen_g_ch2_g20_compr_clean.mp4
# This is video number271of300videos in total
# We will now process video:
# rennen_g_ch2_g2_compr_clean.mp4
# This is video number272of300videos in total
# We will now process video:
# rennen_g_ch2_g3_compr_clean.mp4
# This is video number273of300videos in total
# We will now process video:
# rennen_g_ch2_g4_compr_clean.mp4
# This is video number274of300videos in total
# We will now process video:
# rennen_g_ch2_g5_compr_clean.mp4
# This is video number275of300videos in total
# We will now process video:
# rennen_g_ch2_g6_compr_clean.mp4
# This is video number276of300videos in total
# We will now process video:
# rennen_g_ch2_g7_compr_clean.mp4
# This is video number277of300videos in total
# We will now process video:
# rennen_g_ch2_g8_compr_clean.mp4
# This is video number278of300videos in total
# We will now process video:
# rennen_g_ch2_g9_compr_clean.mp4
# This is video number279of300videos in total
# We will now process video:
# rennen_g_ch3_g10_compr_clean.mp4
# This is video number280of300videos in total
# We will now process video:
# rennen_g_ch3_g11_compr_clean.mp4
# This is video number281of300videos in total
# We will now process video:
# rennen_g_ch3_g12_compr_clean.mp4
# This is video number282of300videos in total
# We will now process video:
# rennen_g_ch3_g13_compr_clean.mp4
# This is video number283of300videos in total
# We will now process video:
# rennen_g_ch3_g14_compr_clean.mp4
# This is video number284of300videos in total
# We will now process video:
# rennen_g_ch3_g15_compr_clean.mp4
# This is video number285of300videos in total
# We will now process video:
# rennen_g_ch3_g16_compr_clean.mp4
# This is video number286of300videos in total
# We will now process video:
# rennen_g_ch3_g17_compr_clean.mp4
# This is video number287of300videos in total
# We will now process video:
# rennen_g_ch3_g18_compr_clean.mp4
# This is video number288of300videos in total
# We will now process video:
# rennen_g_ch3_g19_compr_clean.mp4
# This is video number289of300videos in total
# We will now process video:
# rennen_g_ch3_g1_compr_clean.mp4
# This is video number290of300videos in total
# We will now process video:
# rennen_g_ch3_g20_compr_clean.mp4
# This is video number291of300videos in total
# We will now process video:
# rennen_g_ch3_g2_compr_clean.mp4
# This is video number292of300videos in total
# We will now process video:
# rennen_g_ch3_g3_compr_clean.mp4
# This is video number293of300videos in total
# We will now process video:
# rennen_g_ch3_g4_compr_clean.mp4
# This is video number294of300videos in total
# We will now process video:
# rennen_g_ch3_g5_compr_clean.mp4
# This is video number295of300videos in total
# We will now process video:
# rennen_g_ch3_g6_compr_clean.mp4
# This is video number296of300videos in total
# We will now process video:
# rennen_g_ch3_g7_compr_clean.mp4
# This is video number297of300videos in total
# We will now process video:
# rennen_g_ch3_g8_compr_clean.mp4
# This is video number298of300videos in total
# We will now process video:
# rennen_g_ch3_g9_compr_clean.mp4
# This is video number299of300videos in total
# Done with processing all folders; go look in your output folders!
